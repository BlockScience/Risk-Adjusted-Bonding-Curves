# %% [markdown]
# # Validation test of the entire composite system

# %%
import sys
sys.path.append('../')

import matplotlib.pyplot as plt
import run2
# Out:
# <class 'list'>
# [1000]
#
# Initial Conditions (config.py) :  {'reserve': 300, 'price': 1, 'realized_price': 0, 'spot_price': 1, 'private_price': 0, 'private_alpha': 0, 'kappa': 0, 'supply': 600.0, 'alpha': [0.5], 'supply_0': 200, 'supply_1': 200, 'supply_free': 600.0, 'attestations': 40, 'attestations_0': 20, 'attestations_1': 20, 'invariant_V': 1200.0, 'invariant_I': 650.0, 'agent_attestations_1': 0, 'agent_attestations_0': 0, 'agent_reserve': 50, 'agent_supply': 50, 'agent_supply_1': 10, 'agent_supply_0': 10, 'agent_supply_free': 30}
# Params (config.py) :  {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 1000, 'C': 700, 'period': 2000}

# %%
exp = run2.run()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1dc3f75a6cbb> in <module>
# ----> 1 exp = run2.run()
#
# NameError: name 'run2' is not defined

# %%
plt.plot(exp.private_alpha)

# %%
plt.plot(exp.private_price)

# %%
plt.plot(exp.reserve)

# %%
plt.plot(exp.supply)

# %%
plt.plot(exp.price)

# %%
plt.plot(exp.alpha)

# %%
plt.plot(exp.supply_1)

# %%
plt.plot(exp.supply_0)

# %%
plt.plot(exp.agent_supply_1)

# %%
plt.plot(exp.agent_supply_0)

# %%
plt.plot(exp.attestations_1)

# %%
plt.plot(exp.attestations_0)

# %% [markdown]
# ## Agents implement an agent behaviour heurstic to make attestations

# %%
import sys
sys.path.append('../')

import matplotlib.pyplot as plt
import run2
# Out:
# <class 'list'>
# [1000]
#
# Initial Conditions (config.py) :  {'reserve': 300, 'price': 1, 'realized_price': 0, 'spot_price': 1, 'private_price': 0, 'private_alpha': 0, 'kappa': 0, 'supply': 600.0, 'alpha': [0.5], 'supply_0': 200, 'supply_1': 200, 'supply_free': 600.0, 'attestations': 40, 'attestations_0': 20, 'attestations_1': 20, 'invariant_V': 1200.0, 'invariant_I': 650.0, 'agent_attestations_1': 0, 'agent_attestations_0': 0, 'agent_reserve': 50, 'agent_supply': 50, 'agent_supply_1': 10, 'agent_supply_0': 10, 'agent_supply_free': 30}
# Params (config.py) :  {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 1000, 'C': 700, 'f': 0.03, 'm': 0.15, 'period': 2000}

# %%
exp2 = run2.run()
# Out:
# Configurations Length: 1
# Execution Method: local_simulations
# Execution Mode: single_threaded
# Negative attestation. | alpha =  0.5 private_alpha =  0
# amt_neg =  25.56619290192345
# amt_Q0 =  0.42165832152918803
# --------------------------------------
# Negative attestation. | alpha =  0.5 private_alpha =  0.06
# amt_neg =  26.439761640216197
# amt_Q0 =  0.43591220768341987
# RESERVE =  300.01963492178675  | deltaR =  0.0  | deltaS =  0
# SUPPLY =  600.0196346005221  | deltaR =  0.019634921786748638  | deltaS =  -0.019634600522067558
# AGENT RESERVE = 49.980365078213254 deltar =  0.0 policy_input['amt_to_bond'] =  0.019634921786748638
# AGENT SUPPLY = 30.019634600522068 deltas =  0.019634600522067558 policy_input['amt_to_burn'] =  0
# SPOT PRICE P (from bondburn update) =  1.0
# PRICE pbar (from bondburn update) = 1.0000163621704816
# C = 700 alpha =  0.5 R =  300 deltaR =  0.019634921786748638
# I (from bondburn) = 650.0196349217867
# --------------------------------------
# ...

# %%
plt.plot(exp2.private_alpha)

# %%
plt.plot(exp2.alpha)

# %%
plt.plot(exp2.kappa)

# %%
plt.plot(exp2.price)

# %%
plt.plot(exp2.reserve)

# %%
plt.plot(exp2.supply)

# %%
plt.plot(exp2.supply_0)

# %%
plt.plot(exp2.supply_1)

# %%
plt.plot(exp2.agent_supply)

# %%
plt.plot(exp2.agent_supply_free)

# %%
plt.plot(exp2.agent_supply_0)

# %%
plt.plot(exp2.agent_supply_1)

# %% [markdown]
# ## Randomly drop supply tokens at regular intervals

# %% [markdown]
# ### Positive attestations

# %%
import sys
sys.path.append('../')

import matplotlib.pyplot as plt
import run2
# Out:
# <class 'list'>
# [1000]
#
# Initial Conditions (config.py) :  {'reserve': 300, 'price': 1, 'realized_price': 0, 'spot_price': 1, 'private_price': 0, 'private_alpha': 0, 'kappa': 0, 'supply': 600.0, 'alpha': [0.5], 'supply_0': 200, 'supply_1': 200, 'supply_free': 600.0, 'attestations': 40, 'attestations_0': 20, 'attestations_1': 20, 'invariant_V': 1200.0, 'invariant_I': 650.0, 'agent_attestations_1': 0, 'agent_attestations_0': 0, 'agent_reserve': 50, 'agent_supply': 50, 'agent_supply_1': 10, 'agent_supply_0': 10, 'agent_supply_free': 30}
# Params (config.py) :  {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 1000, 'C': 700, 'f': 0.03, 'm': 0.15, 'period': 2000}

# %%
exp3 = run2.run()
# Out:
# Configurations Length: 1
# Execution Method: local_simulations
# Execution Mode: single_threaded
# Negative attestation. | alpha =  0.5 private_alpha =  0
# amt_neg =  25.90103691297807
# amt_Q0 =  0.42712309509064017
# --------------------------------------
# Positive attestation. | alpha =  0.5 private_alpha =  0.56
# amt_pos =  4.734214011672068
# amt_Q1 =  0.0787485335727034
# RESERVE =  300.01963492178675  | deltaR =  0.0  | deltaS =  0
# SUPPLY =  600.0196346005221  | deltaR =  0.019634921786748638  | deltaS =  -0.019634600522067558
# AGENT RESERVE = 49.980365078213254 deltar =  0.0 policy_input['amt_to_bond'] =  0.019634921786748638
# AGENT SUPPLY = 30.019634600522068 deltas =  0.019634600522067558 policy_input['amt_to_burn'] =  0
# SPOT PRICE P (from bondburn update) =  1.0
# PRICE pbar (from bondburn update) = 1.0000163621704816
# C = 700 alpha =  0.5 R =  300 deltaR =  0.019634921786748638
# I (from bondburn) = 650.0196349217867
# --------------------------------------
# ...

# %%
plt.plot(exp3.private_alpha)

# %%
plt.plot(exp3.alpha)

# %%
plt.plot(exp3.agent_supply_free)

# %%
plt.plot(exp3.agent_supply_0)

# %%
plt.plot(exp3.agent_supply_1)

# %%
plt.plot(exp3.supply)

# %%
plt.plot(exp3.reserve)

# %%
plt.plot(exp3.agent_reserve)

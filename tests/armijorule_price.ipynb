# %% [markdown]
# # Agent Behaviour Model for Price using Armijo Rule

# %%
import sys
sys.path.append('../')

import pandas as pd

import matplotlib.pyplot as plt
# import run2

from src.sim import run

import seaborn as sns

# For analysis
import numpy as np
import pandas as pd

sns.set_style("whitegrid")

experiments = run.run()
# Out:
# Initial Conditions (config.py) :  {'reserve': 1000, 'pbar': 1, 'realized_price': 0, 'spot_price': 1, 'kappa': 0, 'supply': 2000.0, 'alpha': [0.5], 'alpha_bar': [0.5], 'supply_0': 30, 'supply_1': 30, 'supply_free': 2000.0, 'attestations': 40, 'attestations_0': 20, 'attestations_1': 20, 'invariant_V': 4000.0, 'invariant_I': 2000.0, 'agents':    id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0   0                     0                     0            100
# 1   1                     0                     0            100
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0               3               3                 44                  0.3
# 1               3               3                 44                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  1.5  , 'chosen_agent': 0}
# -----------------PSUB---------------------
# Params (config.py) :  {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 1000, 'C': 2000, 'f': 0.03, 'm': 0.15, 'beta': 0.9, 'dust': 1e-08, 'period': 2000, 'rules_price': 'martin', 'E': 0.2}
# Configurations Length: 1
# Execution Method: single_proc_exec
# Execution Mode: single_threaded
#    id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0   0                     0                     0            100
# 1   1                     0                     0            100
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0               3               3                 44                  0.3
# 1               3               3                 44                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  1.5
# --------------TIMESTEP 0 --------------
# CHOSEN AGENT =     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1   1                     0                     0            100
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1               3               3                 44                  0.7
#
#    agent_private_price
# 1                  1.5   Time  0
# r 100
# PROTO RP (BOND) =  1.0244044238467123
# Agent bonds. Amt to bond =  99.99999899999999
# Positive attestation. | alpha =  0.5 private_alpha =  0.7
# amt_pos =  12.555788908925049
# amt_Q1 =  0.062680722719608
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 99.99999899999999
# PRICE (BOND/BURN):  1.0244044238467123
# PRICE pbar (from bondburn update) = 1.0244044238467123
# r 1.0000000116860974e-06
# PROTO RP (BOND) =  1.0488085533318836
# Agent bonds. Amt to bond =  1.0000000016860972e-06
# Positive attestation. | alpha =  0.5 private_alpha =  0.7
# amt_pos =  33.08992233824794
# amt_Q1 =  0.15713274771440577
# PRICE (ATTEST):  1.6681240930057635
# Positive attestation 1
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000                   0.0     100.000000
# 1  1.0              0.157133                   0.0       0.000001
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000             3.0          44.000000                  0.3
# 1       36.089922             3.0         108.527773                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  1.5
# --------------TIMESTEP 1 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0              0.157133                   0.0       0.000001
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1       36.089922             3.0         108.527773                  0.7
#
#    agent_private_price
# 1                  1.5   Time  1
# r 1.0000000116860974e-06
# PROTO RP (BURN) =  1.5759199076151411
# Agent burns. Amt to burn =  108.52777196331463
# Negative attestation. | alpha =  0.7199138583756411 private_alpha =  0.7
# amt_neg =  5.074531272504878
# amt_Q0 =  0.024177265138707327
# ::::delta R:::: 171.0310763661039
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  1.5759199076151411
# PRICE pbar (from bondburn update) = 1.5759199076151411
# r 171.0310773661039
# PROTO RP (BURN) =  1.6506935077743177
# Agent burns. Amt to burn =  9.76749538675017e-07
# Negative attestation. | alpha =  0.7199138583756411 private_alpha =  0.7
# amt_neg =  6.551811195453013e-08
# amt_Q0 =  3.2938540783788994e-10
# PRICE (ATTEST):  0.9504433657601438
# Negative attestation 1
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000          0.000000e+00     100.000000
# 1  1.0              0.157133          3.293854e-10     171.031077
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000             3.0          44.000000                  0.3
# 1       36.089922             3.0           0.000001                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  1.5
# --------------TIMESTEP 2 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0                   0.0          100.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0             3.0               44.0                  0.3
#
#    agent_private_price
# 0                  0.5   Time  2
# r 100.0
# PROTO RP (BURN) =  0.9395653034843697
# Agent burns. Amt to burn =  43.99999956
# Negative attestation. | alpha =  0.6458992059607979 private_alpha =  0.3
# amt_neg =  19.32894947445266
# amt_Q0 =  0.09693990621046703
# ::::delta R:::: 41.340872939903534
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  0.9395653034843697
# PRICE pbar (from bondburn update) = 0.9395653034843697
# r 141.34087293990353
# PROTO RP (BURN) =  0.9286901781463395
# Agent burns. Amt to burn =  4.3999976910495324e-07
# Negative attestation. | alpha =  0.6458992059607979 private_alpha =  0.3
# amt_neg =  1.4854223874167287e-07
# amt_Q0 =  7.636780097312375e-10
# PRICE (ATTEST):  1.0474057654522164
# Negative attestation 1
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000          7.636780e-10     141.340873
# 1  1.0              0.157133          3.293854e-10     171.031077
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000             3.0       2.914575e-07                  0.3
# 1       36.089922             3.0       1.019759e-06                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  1.5
# --------------TIMESTEP 3 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          7.636780e-10     141.340873
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0             3.0       2.914575e-07                  0.3
#
#    agent_private_price
# 0                  0.5   Time  3
# r 141.34087293990353
# PROTO RP (BURN) =  1.0474057134064565
# Agent burns. Amt to burn =  2.9145753184870275e-07
# Negative attestation. | alpha =  0.6266019646472706 private_alpha =  0.3
# amt_neg =  9.470082239513012e-08
# amt_Q0 =  4.86868323461528e-10
# ::::delta R:::: 3.052742840736755e-07
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  1.0474057134064565
# PRICE pbar (from bondburn update) = 1.0474057134064565
# r 141.34087324517782
# Agent supply too low. No bond/burn | s_free =  -2.2445910008150871e-13
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  1.1006339358957336
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000          7.636780e-10     141.340873
# 1  1.0              0.157133          3.293854e-10     171.031077
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000             3.0      -2.244591e-13                  0.3
# 1       36.089922             3.0       1.019759e-06                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  1.5
# --------------TIMESTEP 4 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          7.636780e-10     141.340873
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0             3.0      -2.244591e-13                  0.3
#
#    agent_private_price
# 0                  0.5   Time  4
# r 141.34087324517782
# Agent supply too low. No bond/burn | s_free =  -2.2445910008150871e-13
# Agent supply too low. Cannot attest
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  1.1006339358957333
# PRICE pbar (from bondburn update) = 0.0
# r 141.34087324517782
# PROTO RP (BURN) =  -0.8280263395185197
# Agent burns. Amt to burn =  4.1189572950441137e-13
# Negative attestation. | alpha =  0.6266019646472706 private_alpha =  0.3
# amt_neg =  1.416323298009893e-13
# amt_Q0 =  0.0
# PRICE (ATTEST):  1.1006339361173185
# Negative attestation 1
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000          7.636780e-10     141.340873
# 1  1.0              0.157133          3.293854e-10     171.031077
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000             3.0       3.160296e-13                  0.3
# 1       36.089922             3.0       1.019759e-06                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  1.5
# --------------TIMESTEP 5 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0              0.157133          3.293854e-10     171.031077
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1       36.089922             3.0           0.000001                  0.7
#
#    agent_private_price
# 1                  1.5   Time  5
# r 171.0310773661039
# PROTO RP (BOND) =  1.1601288292400644
# Agent bonds. Amt to bond =  171.0310756557931
# Positive attestation. | alpha =  0.6266019645025914 private_alpha =  0.7
# amt_pos =  1.0363780390880095e-07
# amt_Q1 =  5.37004393634971e-10
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 171.0310756557931
# PRICE (BOND/BURN):  1.1601288292400644
# PRICE pbar (from bondburn update) = 1.1601288292400644
# r 1.7103107836646814e-06
# PROTO RP (BOND) =  1.2202235035086146
# Agent bonds. Amt to bond =  1.7103107665615734e-06
# Positive attestation. | alpha =  0.6266019645025914 private_alpha =  0.7
# amt_pos =  10.884636790989132
# amt_Q1 =  0.05235770872618588
# PRICE (ATTEST):  1.3892342933912312
# Positive attestation 1
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0               0.00000          7.636780e-10     141.340873
# 1  1.0               0.20949          3.293854e-10       0.000002
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000             3.0       3.160296e-13                  0.3
# 1       46.974559             3.0       1.365396e+02                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  1.5
# --------------TIMESTEP 6 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0               0.20949          3.293854e-10       0.000002
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1       46.974559             3.0         136.539574                  0.7
#
#    agent_private_price
# 1                  1.5   Time  6
# r 1.7103107836646814e-06
# PROTO RP (BOND) =  1.3892333681865074
# Agent bonds. Amt to bond =  1.7103107665615734e-06
# Negative attestation. | alpha =  0.73496810727695 private_alpha =  0.7
# amt_neg =  10.738060043140976
# amt_Q0 =  0.05125088095505485
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 1.7103107665615734e-06
# PRICE (BOND/BURN):  1.3892333681865074
# PRICE pbar (from bondburn update) = 1.3892333681865074
# r 1.710310800590812e-14
# PROTO RP (BOND) =  1.3892342948182528
# Agent bonds. Amt to bond =  1.710310783487704e-14
# Negative attestation. | alpha =  0.73496810727695 private_alpha =  0.7
# amt_neg =  5.126537347084767
# amt_Q0 =  0.02448442844139065
# PRICE (ATTEST):  1.1398287017323032
# Negative attestation 1
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0               0.00000          7.636780e-10   1.413409e+02
# 1  1.0               0.20949          2.448443e-02   1.710311e-14
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000        3.000000       3.160296e-13                  0.3
# 1       46.974559        8.126537       1.314130e+02                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  1.5
# --------------TIMESTEP 7 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          7.636780e-10     141.340873
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0             3.0       3.160296e-13                  0.3
#
#    agent_private_price
# 0                  0.5   Time  7
# r 141.34087324517782
# PROTO RP (BURN) =  1.438939139074958
# Agent burns. Amt to burn =  3.160295932869022e-13
# Negative attestation. | alpha =  0.7031237306732452 private_alpha =  0.3
# amt_neg =  1.38657447885333e-13
# amt_Q0 =  0.0
# ::::delta R:::: 4.547473508864641e-13
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  1.438939139074958
# PRICE pbar (from bondburn update) = 1.438939139074958
# r 141.34087324517827
# PROTO RP (BURN) =  0.0
# Agent burns. Amt to burn =  4.092726145493579e-13
# Negative attestation. | alpha =  0.7031237306732452 private_alpha =  0.3
# amt_neg =  2.149954387129459e-13
# amt_Q0 =  0.0
# PRICE (ATTEST):  1.1779641282250553
# Negative attestation 1
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0               0.00000          7.636780e-10   1.413409e+02
# 1  1.0               0.20949          2.448443e-02   1.710311e-14
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000        3.000000       2.397519e-13                  0.3
# 1       46.974559        8.126537       1.314130e+02                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  1.5
# --------------TIMESTEP 8 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          7.636780e-10     141.340873
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0             3.0       2.397519e-13                  0.3
#
#    agent_private_price
# 0                  0.5   Time  8
# r 141.34087324517827
# PROTO RP (BURN) =  2.8451119241369467
# Agent burns. Amt to burn =  2.3975191293629507e-13
# Negative attestation. | alpha =  0.7031237306732437 private_alpha =  0.3
# amt_neg =  9.773268127718815e-14
# amt_Q0 =  0.0
# ::::delta R:::: 6.821210263296962e-13
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  2.8451119241369467
# PRICE pbar (from bondburn update) = 2.8451119241369467
# r 141.34087324517895
# PROTO RP (BURN) =  0.0
# Agent burns. Amt to burn =  2.1577672492361728e-21
# Negative attestation. | alpha =  0.7031237306732437 private_alpha =  0.3
# amt_neg =  1.0338076740271205e-21
# amt_Q0 =  0.0
# PRICE (ATTEST):  1.1779641282250537
# Negative attestation 1
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0               0.00000          7.636780e-10   1.413409e+02
# 1  1.0               0.20949          2.448443e-02   1.710311e-14
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000        3.000000       1.363712e-21                  0.3
# 1       46.974559        8.126537       1.314130e+02                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  1.5
# --------------TIMESTEP 9 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          7.636780e-10     141.340873
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0             3.0       1.363712e-21                  0.3
#
#    agent_private_price
# 0                  0.5   Time  9
# r 141.34087324517895
# PROTO RP (BURN) =  0.0
# Agent burns. Amt to burn =  1.2273403519160337e-21
# Negative attestation. | alpha =  0.7031237306732434 private_alpha =  0.3
# amt_neg =  6.421842306239492e-22
# amt_Q0 =  0.0
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  0.0
# PRICE pbar (from bondburn update) = 0.0
# r 141.34087324517895
# PROTO RP (BOND) =  0.4732289878181325
# Agent bonds. Amt to bond =  54.75834968075076
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  1.1779641282250541
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0               0.00000          7.636780e-10   1.413409e+02
# 1  1.0               0.20949          2.448443e-02   1.710311e-14
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000        3.000000      -9.094947e-13                  0.3
# 1       46.974559        8.126537       1.314130e+02                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  1.5
# --------------TIMESTEP 10 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0               0.20949              0.024484   1.710311e-14
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1       46.974559        8.126537         131.413038                  0.7
#
#    agent_private_price
# 1                  1.5   Time  10
# r 1.710310800590812e-14
# PROTO RP (BOND) =  -0.037610131871108225
# Agent bonds. Amt to bond =  1.710310783487704e-14
# Negative attestation. | alpha =  0.7031237306732434 private_alpha =  0.7
# amt_neg =  0.7757730829887813
# amt_Q0 =  0.0037115678771639667
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 1.710310783487704e-14
# PRICE (BOND/BURN):  -0.037610131871108225
# PRICE pbar (from bondburn update) = -0.037610131871108225
# r 1.710310806155621e-22
# PROTO RP (BOND) =  1.1779641282250541
# Agent bonds. Amt to bond =  1.7103107890525128e-22
# Negative attestation. | alpha =  0.7031237306732434 private_alpha =  0.7
# amt_neg =  0.5806283170422813
# amt_Q0 =  0.0027779922888955793
# PRICE (ATTEST):  1.1703723757323727
# Negative attestation 1
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0               0.00000          7.636780e-10   1.413409e+02
# 1  1.0               0.20949          2.726242e-02   1.710311e-22
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000        3.000000      -9.094947e-13                  0.3
# 1       46.974559        8.707166       1.308324e+02                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  1.5
# --------------TIMESTEP 11 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          7.636780e-10     141.340873
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0             3.0      -9.094947e-13                  0.3
#
#    agent_private_price
# 0                  0.5   Time  11
# r 141.34087324517895
# Agent supply too low. No bond/burn | s_free =  -9.09494701636557e-13
# Agent supply too low. Cannot attest
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  1.1703723757323725
# PRICE pbar (from bondburn update) = 0.0
# r 141.34087324517895
# Agent supply too low. No bond/burn | s_free =  -4.547473507500929e-13
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  1.1746823764875458
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0               0.00000          7.636780e-10   1.413409e+02
# 1  1.0               0.20949          2.726242e-02   1.710311e-22
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000        3.000000      -4.547474e-13                  0.3
# 1       46.974559        8.707166       1.308324e+02                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  1.5
# --------------TIMESTEP 12 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0               0.20949              0.027262   1.710311e-22
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1       46.974559        8.707166         130.832409                  0.7
#
#    agent_private_price
# 1                  1.5   Time  12
# r 1.710310806155621e-22
# PROTO RP (BOND) =  1.1746823764875463
# Agent bonds. Amt to bond =  1.7103107890525128e-22
# Positive attestation. | alpha =  0.6996901747251154 private_alpha =  0.7
# amt_pos =  0.728763065406938
# amt_Q1 =  0.003518888562571002
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 1.7103107890525128e-22
# PRICE (BOND/BURN):  1.1746823764875463
# PRICE pbar (from bondburn update) = 1.7103107890525127e-17
# r 1.710310825877204e-30
# PROTO RP (BOND) =  1.1746823764875463
# Agent bonds. Amt to bond =  1.7103108087740955e-30
# Positive attestation. | alpha =  0.6996901747251154 private_alpha =  0.7
# amt_pos =  2.2154855178498885
# amt_Q1 =  0.010695743387372536
# PRICE (ATTEST):  1.1885223853008393
# Positive attestation 1
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000          7.636780e-10   1.413409e+02
# 1  1.0              0.220186          2.726242e-02   1.710311e-30
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000        3.000000      -4.547474e-13                  0.3
# 1       49.190045        8.707166       1.286169e+02                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  1.5
# --------------TIMESTEP 13 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          7.636780e-10     141.340873
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0             3.0      -4.547474e-13                  0.3
#
#    agent_private_price
# 0                  0.5   Time  13
# r 141.34087324517895
# Agent supply too low. No bond/burn | s_free =  -4.547473507500929e-13
# Agent supply too low. Cannot attest
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  1.1885223853008393
# PRICE pbar (from bondburn update) = 0.0
# r 141.34087324517895
# PROTO RP (BURN) =  -1.666666682833528
# Agent burns. Amt to burn =  4.092726118278256e-13
# Negative attestation. | alpha =  0.7058540685759037 private_alpha =  0.3
# amt_neg =  2.0013644330198513e-13
# amt_Q0 =  0.0
# PRICE (ATTEST):  1.180573752559536
# Negative attestation 1
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000          7.636780e-10   1.413409e+02
# 1  1.0              0.220186          2.726242e-02   1.710311e-30
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000        3.000000       2.546109e-13                  0.3
# 1       49.190045        8.707166       1.286169e+02                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  1.5
# --------------TIMESTEP 14 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          7.636780e-10     141.340873
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0             3.0       2.546109e-13                  0.3
#
#    agent_private_price
# 0                  0.5   Time  14
# r 141.34087324517895
# PROTO RP (BURN) =  1.786048207850202
# Agent burns. Amt to burn =  2.546109051747411e-13
# Negative attestation. | alpha =  0.7058540685759025 private_alpha =  0.3
# amt_neg =  1.0263942227181224e-13
# amt_Q0 =  0.0
# ::::delta R:::: 4.547473508864641e-13
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  1.786048207850202
# PRICE pbar (from bondburn update) = 1.786048207850202
# r 141.3408732451794
# Agent supply too low. No bond/burn | s_free =  -9.094946992268192e-13
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  1.180573752559535
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000          7.636780e-10   1.413409e+02
# 1  1.0              0.220186          2.726242e-02   1.710311e-30
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000        3.000000      -9.094947e-13                  0.3
# 1       49.190045        8.707166       1.286169e+02                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  1.5
# --------------TIMESTEP 15 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          7.636780e-10     141.340873
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0             3.0      -9.094947e-13                  0.3
#
#    agent_private_price
# 0                  0.5   Time  15
# r 141.3408732451794
# Agent supply too low. No bond/burn | s_free =  -9.094946992268192e-13
# Agent supply too low. Cannot attest
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  1.1805737525595352
# PRICE pbar (from bondburn update) = -0.0
# r 141.3408732451794
# Agent supply too low. No bond/burn | s_free =  -1.3642420501132832e-12
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  1.1805737525595354
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000          7.636780e-10   1.413409e+02
# 1  1.0              0.220186          2.726242e-02   1.710311e-30
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000        3.000000      -1.364242e-12                  0.3
# 1       49.190045        8.707166       1.286169e+02                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  1.5
# --------------TIMESTEP 16 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          7.636780e-10     141.340873
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0             3.0      -1.364242e-12                  0.3
#
#    agent_private_price
# 0                  0.5   Time  16
# r 141.3408732451794
# Agent supply too low. No bond/burn | s_free =  -1.3642420501132832e-12
# Agent supply too low. Cannot attest
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  1.1805737525595354
# PRICE pbar (from bondburn update) = 0.0
# r 141.3408732451794
# Agent supply too low. No bond/burn | s_free =  -9.094946992268191e-13
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  1.1805737525595352
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000          7.636780e-10   1.413409e+02
# 1  1.0              0.220186          2.726242e-02   1.710311e-30
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000        3.000000      -9.094947e-13                  0.3
# 1       49.190045        8.707166       1.286169e+02                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  1.5
# --------------TIMESTEP 17 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          7.636780e-10     141.340873
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0             3.0      -9.094947e-13                  0.3
#
#    agent_private_price
# 0                  0.5   Time  17
# r 141.3408732451794
# Agent supply too low. No bond/burn | s_free =  -9.094946992268191e-13
# Agent supply too low. Cannot attest
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  1.1805737525595354
# PRICE pbar (from bondburn update) = 0.0
# r 141.3408732451794
# Agent supply too low. No bond/burn | s_free =  -4.5474734834035494e-13
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  1.1805737525595348
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000          7.636780e-10   1.413409e+02
# 1  1.0              0.220186          2.726242e-02   1.710311e-30
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000        3.000000      -4.547473e-13                  0.3
# 1       49.190045        8.707166       1.286169e+02                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  1.5
# --------------TIMESTEP 18 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          7.636780e-10     141.340873
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0             3.0      -4.547473e-13                  0.3
#
#    agent_private_price
# 0                  0.5   Time  18
# r 141.3408732451794
# Agent supply too low. No bond/burn | s_free =  -4.5474734834035494e-13
# Agent supply too low. Cannot attest
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  1.1805737525595348
# PRICE pbar (from bondburn update) = 0.0
# r 141.3408732451794
# PROTO RP (BURN) =  -198449792.75428241
# Agent burns. Amt to burn =  2.2914982403107145e-21
# Negative attestation. | alpha =  0.7058540685759025 private_alpha =  0.3
# amt_neg =  1.0994092974980949e-21
# amt_Q0 =  0.0
# PRICE (ATTEST):  1.1805737525595346
# Negative attestation 1
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000          7.636780e-10   1.413409e+02
# 1  1.0              0.220186          2.726242e-02   1.710311e-30
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000        3.000000       1.446700e-21                  0.3
# 1       49.190045        8.707166       1.286169e+02                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  1.5
# --------------TIMESTEP 19 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0              0.220186              0.027262   1.710311e-30
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1       49.190045        8.707166         128.616924                  0.7
#
#    agent_private_price
# 1                  1.5   Time  19
# r 1.710310825877204e-30
# PROTO RP (BOND) =  3.761013242716186e-18
# Agent bonds. Amt to bond =  1.7103108087740955e-30
# Negative attestation. | alpha =  0.7058540685759023 private_alpha =  0.7
# amt_neg =  2.9737352814066798
# amt_Q0 =  0.014225622605651404
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 1.7103108087740955e-30
# PRICE (BOND/BURN):  3.761013242716186e-18
# PRICE pbar (from bondburn update) = 3.761013242716186e-18
# r 1.7103108398598757e-38
# PROTO RP (BOND) =  1.1805737525595346
# Agent bonds. Amt to bond =  1.710310822756767e-38
# Negative attestation. | alpha =  0.7058540685759023 private_alpha =  0.7
# amt_neg =  3.1012294674082828
# amt_Q0 =  0.014835297893454502
# PRICE (ATTEST):  1.1426181701579177
# Negative attestation 1
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000          7.636780e-10   1.413409e+02
# 1  1.0              0.220186          4.209772e-02   1.710311e-38
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000        3.000000       1.446700e-21                  0.3
# 1       49.190045       11.808395       1.355157e+02                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  1.5
# --------------TIMESTEP 20 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          7.636780e-10     141.340873
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0             3.0       1.446700e-21                  0.3
#
#    agent_private_price
# 0                  0.5   Time  20
# r 141.3408732451794
# PROTO RP (BURN) =  0.0
# Agent burns. Amt to burn =  1.3020298824571125e-21
# Negative attestation. | alpha =  0.6882707565079643 private_alpha =  0.3
# amt_neg =  5.906284813510268e-22
# amt_Q0 =  0.0
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  0.0
# PRICE pbar (from bondburn update) = 0.0
# r 141.3408732451794
# PROTO RP (BOND) =  0.4586438359065689
# Agent bonds. Amt to bond =  54.75834968075093
# Negative attestation. | alpha =  0.6882707565079643 private_alpha =  0.3
# amt_neg =  7.107743694450644e-23
# amt_Q0 =  0.0
# PRICE (ATTEST):  1.1637678330399857
# Negative attestation 1
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000          7.636780e-10   1.413409e+02
# 1  1.0              0.220186          4.209772e-02   1.710311e-38
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000        3.000000       7.359256e-23                  0.3
# 1       49.190045       11.808395       1.355157e+02                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  1.5
# --------------TIMESTEP 21 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          7.636780e-10     141.340873
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0             3.0       7.359256e-23                  0.3
#
#    agent_private_price
# 0                  0.5   Time  21
# r 141.3408732451794
# PROTO RP (BURN) =  0.0
# Agent burns. Amt to burn =  6.623330735362146e-23
# Negative attestation. | alpha =  0.6882707565079643 private_alpha =  0.3
# amt_neg =  3.011416381966323e-23
# amt_Q0 =  0.0
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  0.0
# PRICE pbar (from bondburn update) = 0.0
# r 141.3408732451794
# PROTO RP (BOND) =  0.4673710037756693
# Agent bonds. Amt to bond =  54.75834968075093
# Negative attestation. | alpha =  0.6882707565079643 private_alpha =  0.3
# amt_neg =  2.9465243133440287e-13
# amt_Q0 =  0.0
# PRICE (ATTEST):  1.1637678330399852
# Negative attestation 1
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000          7.636780e-10   1.413409e+02
# 1  1.0              0.220186          4.209772e-02   1.710311e-38
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000        3.000000       6.148423e-13                  0.3
# 1       49.190045       11.808395       1.355157e+02                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  1.5
# --------------TIMESTEP 22 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0              0.220186              0.042098   1.710311e-38
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1       49.190045       11.808395         135.515694                  0.7
#
#    agent_private_price
# 1                  1.5   Time  22
# r 1.7103108398598757e-38
# PROTO RP (BOND) =  1.8805066367322028e-26
# Agent bonds. Amt to bond =  1.710310822756767e-38
# Positive attestation. | alpha =  0.6882707565079628 private_alpha =  0.7
# amt_pos =  3.208772654278944
# amt_Q1 =  0.015497416518794811
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 1.710310822756767e-38
# PRICE (BOND/BURN):  1.8805066367322028e-26
# PRICE pbar (from bondburn update) = 1.8805066367322028e-26
# r 1.7103108557947652e-46
# PROTO RP (BOND) =  1.163767833039985
# Agent bonds. Amt to bond =  1.7103108386916566e-46
# Positive attestation. | alpha =  0.6882707565079628 private_alpha =  0.7
# amt_pos =  3.7094970144426704
# amt_Q1 =  0.017914695668187597
# PRICE (ATTEST):  1.1864222056505473
# Positive attestation 1
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000          7.636780e-10   1.413409e+02
# 1  1.0              0.238101          4.209772e-02   1.710311e-46
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000        3.000000       6.148423e-13                  0.3
# 1       52.899542       11.808395       1.318062e+02                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  1.5
# --------------TIMESTEP 23 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0              0.238101              0.042098   1.710311e-46
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1       52.899542       11.808395         131.806197                  0.7
#
#    agent_private_price
# 1                  1.5   Time  23
# r 1.7103108557947652e-46
# PROTO RP (BOND) =  1.1864222056505473
# Agent bonds. Amt to bond =  1.7103108386916566e-46
# Positive attestation. | alpha =  0.6983781441693085 private_alpha =  0.7
# amt_pos =  1.1206069914395629
# amt_Q1 =  0.005418343769775016
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 1.7103108386916566e-46
# PRICE (BOND/BURN):  1.1864222056505473
# PRICE pbar (from bondburn update) = 1.7103108386916565e-41
# r 1.7103108633023602e-54
# PROTO RP (BOND) =  1.1864222056505473
# Agent bonds. Amt to bond =  1.7103108461992515e-54
# Positive attestation. | alpha =  0.6983781441693085 private_alpha =  0.7
# amt_pos =  2.8491570752012247
# amt_Q1 =  0.013773363067210095
# PRICE (ATTEST):  1.1899034546690037
# Positive attestation 1
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000          7.636780e-10   1.413409e+02
# 1  1.0              0.251874          4.209772e-02   1.710311e-54
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000        3.000000       6.148423e-13                  0.3
# 1       55.748699       11.808395       1.289570e+02                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  1.5
# --------------TIMESTEP 24 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          7.636780e-10     141.340873
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0             3.0       6.148423e-13                  0.3
#
#    agent_private_price
# 0                  0.5   Time  24
# r 141.3408732451794
# PROTO RP (BURN) =  1.1094244262942934
# Agent burns. Amt to burn =  6.148422642974621e-13
# Negative attestation. | alpha =  0.7057071069909137 private_alpha =  0.3
# amt_neg =  2.3053701794670114e-13
# amt_Q0 =  0.0
# ::::delta R:::: 6.821210263296962e-13
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  1.1094244262942934
# PRICE pbar (from bondburn update) = 1.1094244262942934
# r 141.3408732451801
# PROTO RP (BURN) =  0.0
# Agent burns. Amt to burn =  4.0927261723867193e-13
# Negative attestation. | alpha =  0.7057071069909137 private_alpha =  0.3
# amt_neg =  2.2526592508960395e-13
# amt_Q0 =  0.0
# PRICE (ATTEST):  1.1804332884330786
# Negative attestation 1
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000          7.636780e-10   1.413409e+02
# 1  1.0              0.251874          4.209772e-02   1.710311e-54
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000        3.000000       2.294814e-13                  0.3
# 1       55.748699       11.808395       1.289570e+02                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  1.5
# --------------TIMESTEP 25 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          7.636780e-10     141.340873
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0             3.0       2.294814e-13                  0.3
#
#    agent_private_price
# 0                  0.5   Time  25
# r 141.3408732451801
# PROTO RP (BURN) =  1.9816302852004468
# Agent burns. Amt to burn =  2.294814296504685e-13
# Negative attestation. | alpha =  0.7057071069909122 private_alpha =  0.3
# amt_neg =  7.868345347666484e-14
# amt_Q0 =  0.0
# ::::delta R:::: 4.547473508864641e-13
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  1.9816302852004468
# PRICE pbar (from bondburn update) = 1.9816302852004468
# r 141.34087324518055
# PROTO RP (BURN) =  0.0
# Agent burns. Amt to burn =  8.185452254755159e-13
# Negative attestation. | alpha =  0.7057071069909122 private_alpha =  0.3
# amt_neg =  3.808801973441933e-13
# amt_Q0 =  0.0
# PRICE (ATTEST):  1.1804332884330768
# Negative attestation 1
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000          7.636780e-10   1.413409e+02
# 1  1.0              0.251874          4.209772e-02   1.710311e-54
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000        3.000000       5.286145e-13                  0.3
# 1       55.748699       11.808395       1.289570e+02                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  1.5
# --------------TIMESTEP 26 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0              0.251874              0.042098   1.710311e-54
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1       55.748699       11.808395          128.95704                  0.7
#
#    agent_private_price
# 1                  1.5   Time  26
# r 1.7103108633023602e-54
# PROTO RP (BOND) =  -1.880506662507487e-42
# Agent bonds. Amt to bond =  1.7103108461992515e-54
# Negative attestation. | alpha =  0.70570710699091 private_alpha =  0.7
# amt_neg =  2.8207987738244653
# amt_Q0 =  0.01350425398976146
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 1.7103108461992515e-54
# PRICE (BOND/BURN):  -1.880506662507487e-42
# PRICE pbar (from bondburn update) = -1.880506662507487e-42
# r 1.7103108701595696e-62
# PROTO RP (BOND) =  1.1804332884330768
# Agent bonds. Amt to bond =  1.7103108530564608e-62
# Negative attestation. | alpha =  0.70570710699091 private_alpha =  0.7
# amt_neg =  3.2247041732215056
# amt_Q0 =  0.015437161101692486
# PRICE (ATTEST):  1.1440261991785903
# Negative attestation 1
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000          7.636780e-10   1.413409e+02
# 1  1.0              0.251874          5.753488e-02   1.710311e-62
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000        3.000000       5.286145e-13                  0.3
# 1       55.748699       15.033099       1.257323e+02                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  1.5
# --------------TIMESTEP 27 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0              0.251874              0.057535   1.710311e-62
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1       55.748699       15.033099         125.732336                  0.7
#
#    agent_private_price
# 1                  1.5   Time  27
# r 1.7103108701595696e-62
# PROTO RP (BOND) =  1.8805066700470684e-50
# Agent bonds. Amt to bond =  1.7103108530564608e-62
# Positive attestation. | alpha =  0.6888619082771428 private_alpha =  0.7
# amt_pos =  2.308582748391924
# amt_Q1 =  0.011168440558458169
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 1.7103108530564608e-62
# PRICE (BOND/BURN):  1.8805066700470684e-50
# PRICE pbar (from bondburn update) = 1.8805066700470684e-50
# r 1.7103108796501247e-70
# PROTO RP (BOND) =  1.1440261991785905
# Agent bonds. Amt to bond =  1.710310862547016e-70
# Positive attestation. | alpha =  0.6888619082771428 private_alpha =  0.7
# amt_pos =  2.2523570890835596
# amt_Q1 =  0.010896505713815213
# PRICE (ATTEST):  1.177066961723563
# Positive attestation 1
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000          7.636780e-10   1.413409e+02
# 1  1.0              0.262771          5.753488e-02   1.710311e-70
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000        3.000000       5.286145e-13                  0.3
# 1       58.001056       15.033099       1.234800e+02                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  1.5
# --------------TIMESTEP 28 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0              0.262771              0.057535   1.710311e-70
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1       58.001056       15.033099         123.479979                  0.7
#
#    agent_private_price
# 1                  1.5   Time  28
# r 1.7103108796501247e-70
# PROTO RP (BOND) =  1.1770669617235625
# Agent bonds. Amt to bond =  1.710310862547016e-70
# Positive attestation. | alpha =  0.6945884664375584 private_alpha =  0.7
# amt_pos =  1.5939899151072587
# amt_Q1 =  0.0077161972577048455
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 1.710310862547016e-70
# PRICE (BOND/BURN):  1.1770669617235627
# PRICE pbar (from bondburn update) = 1.7103108625470158e-65
# r 1.7103108838034213e-78
# PROTO RP (BOND) =  1.1770669617235625
# Agent bonds. Amt to bond =  1.7103108667003124e-78
# Positive attestation. | alpha =  0.6945884664375584 private_alpha =  0.7
# amt_pos =  2.821765909693518
# amt_Q1 =  0.01365762171582285
# PRICE (ATTEST):  1.1852190343890778
# Positive attestation 1
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000          7.636780e-10   1.413409e+02
# 1  1.0              0.276428          5.753488e-02   1.710311e-78
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000        3.000000       5.286145e-13                  0.3
# 1       60.822822       15.033099       1.206582e+02                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  1.5
# --------------TIMESTEP 29 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          7.636780e-10     141.340873
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0             3.0       5.286145e-13                  0.3
#
#    agent_private_price
# 0                  0.5   Time  29
# r 141.34087324518055
# PROTO RP (BURN) =  1.2903940858127771
# Agent burns. Amt to burn =  5.286145014374042e-13
# Negative attestation. | alpha =  0.7014719669519035 private_alpha =  0.3
# amt_neg =  2.5228512121621727e-13
# amt_Q0 =  0.0
# ::::delta R:::: 6.821210263296962e-13
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  1.2903940858127771
# PRICE pbar (from bondburn update) = 1.2903940858127771
# r 141.34087324518123
# PROTO RP (BURN) =  0.0
# Agent burns. Amt to burn =  4.7575305077008815e-21
# Negative attestation. | alpha =  0.7014719669519035 private_alpha =  0.3
# amt_neg =  2.0008465905879004e-21
# amt_Q0 =  0.0
# PRICE (ATTEST):  1.176385392202003
# Negative attestation 1
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000          7.636780e-10   1.413409e+02
# 1  1.0              0.276428          5.753488e-02   1.710311e-78
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000        3.000000       3.285298e-21                  0.3
# 1       60.822822       15.033099       1.206582e+02                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  1.5
# --------------TIMESTEP 30 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# ...
# Agent supply too low. No bond/burn | s_free =  -4.5472674860069365e-13
# Agent supply too low. Cannot attest
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  1.1764473863631613
# PRICE pbar (from bondburn update) = 0.0
# r 161.5926251423855
# PROTO RP (BURN) =  -1.111060785718291
# Agent burns. Amt to burn =  4.092911537620995e-13
# Negative attestation. | alpha =  0.6982455844021478 private_alpha =  0.3
# amt_neg =  2.0079082742657511e-13
# amt_Q0 =  0.0
# PRICE (ATTEST):  1.1734468542175125
# Negative attestation 1
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000              0.060150   1.615926e+02
# 1  1.0              0.536216              0.111647  1.710311e-302
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000       15.482731       2.539771e-13                  0.3
# 1      113.929478       26.286675       5.629798e+01                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  1.5
# --------------TIMESTEP 90 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0               0.06015     161.592625
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0       15.482731       2.539771e-13                  0.3
#
#    agent_private_price
# 0                  0.5   Time  90
# r 161.5926251423855
# PROTO RP (BURN) =  1.7905051649782657
# Agent burns. Amt to burn =  2.5397712320588817e-13
# Negative attestation. | alpha =  0.6982455844021472 private_alpha =  0.3
# amt_neg =  1.2719926494561073e-13
# amt_Q0 =  0.0
# ::::delta R:::: 4.547473508864641e-13
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  1.7905051649782657
# PRICE pbar (from bondburn update) = 1.7905051649782657
# r 161.59262514238594
# PROTO RP (BURN) =  0.0
# Agent burns. Amt to burn =  8.185452256959772e-13
# Negative attestation. | alpha =  0.6982455844021472 private_alpha =  0.3
# amt_neg =  4.108354007389353e-13
# amt_Q0 =  0.0
# PRICE (ATTEST):  1.173446854217511
# Negative attestation 1
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000              0.060150   1.615926e+02
# 1  1.0              0.536216              0.111647  1.710311e-302
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000       15.482731       4.986593e-13                  0.3
# 1      113.929478       26.286675       5.629798e+01                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  1.5
# --------------TIMESTEP 91 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0               0.06015     161.592625
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0       15.482731       4.986593e-13                  0.3
#
#    agent_private_price
# 0                  0.5   Time  91
# r 161.59262514238594
# PROTO RP (BURN) =  1.3679099703190514
# Agent burns. Amt to burn =  4.986592985871711e-13
# Negative attestation. | alpha =  0.6982455844021457 private_alpha =  0.3
# amt_neg =  2.40643484898103e-13
# amt_Q0 =  0.0
# ::::delta R:::: 6.821210263296962e-13
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  1.3679099703190514
# PRICE pbar (from bondburn update) = 1.3679099703190514
# r 161.59262514238662
# PROTO RP (BURN) =  0.0
# Agent burns. Amt to burn =  4.487933739221519e-21
# Negative attestation. | alpha =  0.6982455844021457 private_alpha =  0.3
# amt_neg =  2.0559236958507177e-21
# amt_Q0 =  0.0
# PRICE (ATTEST):  1.1734468542175096
# Negative attestation 1
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000              0.060150   1.615926e+02
# 1  1.0              0.536216              0.111647  1.710311e-302
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000       15.482731       2.930669e-21                  0.3
# 1      113.929478       26.286675       5.629798e+01                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  1.5
# --------------TIMESTEP 92 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0               0.06015     161.592625
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0       15.482731       2.930669e-21                  0.3
#
#    agent_private_price
# 0                  0.5   Time  92
# r 161.59262514238662
# PROTO RP (BURN) =  0.0
# Agent burns. Amt to burn =  2.6376024314591862e-21
# Negative attestation. | alpha =  0.6982455844021453 private_alpha =  0.3
# amt_neg =  1.1089455062496651e-21
# amt_Q0 =  0.0
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  0.0
# PRICE pbar (from bondburn update) = 0.0
# r 161.59262514238662
# PROTO RP (BOND) =  0.4742074745661107
# Agent bonds. Amt to bond =  62.60429322541418
# Negative attestation. | alpha =  0.6982455844021453 private_alpha =  0.3
# amt_neg =  2.198540442529268e-13
# amt_Q0 =  0.0
# PRICE (ATTEST):  1.1734468542175092
# Negative attestation 1
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000              0.060150   1.615926e+02
# 1  1.0              0.536216              0.111647  1.710311e-302
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000       15.482731       2.348933e-13                  0.3
# 1      113.929478       26.286675       5.629798e+01                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  1.5
# --------------TIMESTEP 93 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0              0.536216              0.111647  1.710311e-302
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1      113.929478       26.286675          56.297981                  0.7
#
#    agent_private_price
# 1                  1.5   Time  93
# r 1.7103111567678555e-302
# PROTO RP (BOND) =  -3.761013970352416e-290
# Agent bonds. Amt to bond =  1.7103111396647438e-302
# Positive attestation. | alpha =  0.6982455844021447 private_alpha =  0.7
# amt_pos =  0.3372853488750368
# amt_Q1 =  0.0016689864453003414
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 1.7103111396647438e-302
# PRICE (BOND/BURN):  -3.761013970352416e-290
# PRICE pbar (from bondburn update) = -3.761013970352416e-290
# r 1.710311174618e-310
# PROTO RP (BOND) =  1.173446854217509
# Agent bonds. Amt to bond =  1.7103111575149e-310
# Positive attestation. | alpha =  0.6982455844021447 private_alpha =  0.7
# amt_pos =  0.24976180097134404
# amt_Q1 =  0.0012359073911869009
# PRICE (ATTEST):  1.1742903572346561
# Positive attestation 1
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000              0.060150   1.615926e+02
# 1  1.0              0.537452              0.111647  1.710311e-310
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0         3.00000       15.482731       2.348933e-13                  0.3
# 1       114.17924       26.286675       5.604822e+01                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  1.5
# --------------TIMESTEP 94 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0              0.537452              0.111647  1.710311e-310
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1       114.17924       26.286675          56.048219                  0.7
#
#    agent_private_price
# 1                  1.5   Time  94
# r 1.710311174618e-310
# PROTO RP (BOND) =  -1.8805070048026601e-298
# Agent bonds. Amt to bond =  1.7103111575149e-310
# Positive attestation. | alpha =  0.6986185329443532 private_alpha =  0.7
# amt_pos =  0.1396978897473129
# amt_Q1 =  0.0006913240292243533
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 1.7103111575149e-310
# PRICE (BOND/BURN):  -1.8805070048026601e-298
# PRICE pbar (from bondburn update) = -1.8805070048026601e-298
# r 1.71031e-318
# PROTO RP (BOND) =  1.1742903572346566
# Agent bonds. Amt to bond =  1.71031e-318
# Positive attestation. | alpha =  0.6986185329443532 private_alpha =  0.7
# amt_pos =  0.702561179337641
# amt_Q1 =  0.003476534217762281
# PRICE (ATTEST):  1.1761716745679727
# Positive attestation 1
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000              0.060150   1.615926e+02
# 1  1.0              0.540928              0.111647  1.710312e-318
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000       15.482731       2.348933e-13                  0.3
# 1      114.881801       26.286675       5.534566e+01                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  1.5
# --------------TIMESTEP 95 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0               0.06015     161.592625
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0       15.482731       2.348933e-13                  0.3
#
#    agent_private_price
# 0                  0.5   Time  95
# r 161.59262514238662
# PROTO RP (BURN) =  2.9039611305912807
# Agent burns. Amt to burn =  2.3489330457767124e-13
# Negative attestation. | alpha =  0.6996626825023452 private_alpha =  0.3
# amt_neg =  1.1255096596382244e-13
# amt_Q0 =  0.0
# ::::delta R:::: 6.821210263296962e-13
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  2.9039611305912807
# PRICE pbar (from bondburn update) = 2.9039611305912807
# r 161.5926251423873
# Agent supply too low. No bond/burn | s_free =  -9.094946994239951e-13
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  1.1748127339681265
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000              0.060150   1.615926e+02
# 1  1.0              0.540928              0.111647  1.710312e-318
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000       15.482731      -9.094947e-13                  0.3
# 1      114.881801       26.286675       5.534566e+01                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  1.5
# --------------TIMESTEP 96 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0              0.540928              0.111647  1.710312e-318
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1      114.881801       26.286675          55.345658                  0.7
#
#    agent_private_price
# 1                  1.5   Time  96
# r 1.71031e-318
# PROTO RP (BOND) =  -3.761015833365705e-306
# Agent bonds. Amt to bond =  1.71031e-318
# Positive attestation. | alpha =  0.6996626825023452 private_alpha =  0.7
# amt_pos =  0.5433604586008516
# amt_Q1 =  0.002689256510658944
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 1.71031e-318
# PRICE (BOND/BURN):  -3.761015833365705e-306
# PRICE pbar (from bondburn update) = -3.761015833365705e-306
# r 0.0
# Agent reserve too low. No bond/burn | r =  0.0
# Positive attestation. | alpha =  0.6996626825023452 private_alpha =  0.7
# amt_pos =  0.8319817895088139
# amt_Q1 =  0.0041175882902998165
# PRICE (ATTEST):  1.1775960694442413
# Positive attestation 1
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000              0.060150     161.592625
# 1  1.0              0.545046              0.111647       0.000000
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000       15.482731      -9.094947e-13                  0.3
# 1      115.713783       26.286675       5.451368e+01                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  1.5
# --------------TIMESTEP 97 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0               0.06015     161.592625
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0       15.482731      -9.094947e-13                  0.3
#
#    agent_private_price
# 0                  0.5   Time  97
# r 161.5926251423873
# Agent supply too low. No bond/burn | s_free =  -9.094946994239951e-13
# Agent supply too low. Cannot attest
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  1.1775960694442413
# PRICE pbar (from bondburn update) = -0.0
# r 161.5926251423873
# Agent supply too low. No bond/burn | s_free =  -1.8189894011969232e-12
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  1.1759955563304922
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000              0.060150     161.592625
# 1  1.0              0.545046              0.111647       0.000000
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000       15.482731      -1.818989e-12                  0.3
# 1      115.713783       26.286675       5.451368e+01                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  1.5
# --------------TIMESTEP 98 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0              0.545046              0.111647            0.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1      115.713783       26.286675          54.513676                  0.7
#
#    agent_private_price
# 1                  1.5   Time  98
# r 0.0
# Agent reserve too low. No bond/burn | r =  0.0
# Negative attestation. | alpha =  0.7008898588491818 private_alpha =  0.7
# amt_neg =  0.5278625669512866
# amt_Q0 =  0.0025656085914197257
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  1.1759955563304918
# PRICE pbar (from bondburn update) = 0.0
# r 0.0
# Agent reserve too low. No bond/burn | r =  0.0
# Negative attestation. | alpha =  0.7008898588491818 private_alpha =  0.7
# amt_neg =  1.486555490576042
# amt_Q0 =  0.0072243789096497904
# PRICE (ATTEST):  1.165430772850294
# Negative attestation 1
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000              0.060150     161.592625
# 1  1.0              0.545046              0.118871       0.000000
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000       15.482731      -1.818989e-12                  0.3
# 1      115.713783       27.773231       5.302712e+01                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  1.5
# --------------TIMESTEP 99 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0               0.06015     161.592625
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0       15.482731      -1.818989e-12                  0.3
#
#    agent_private_price
# 0                  0.5   Time  99
# r 161.5926251423873
# Agent supply too low. No bond/burn | s_free =  -1.8189894011969232e-12
# Agent supply too low. Cannot attest
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  1.1654307728502942
# PRICE pbar (from bondburn update) = -0.0
# r 161.5926251423873
# PROTO RP (BURN) =  1.161701055160267
# Agent burns. Amt to burn =  9.99999989999727
# Negative attestation. | alpha =  0.6961832090269959 private_alpha =  0.3
# amt_neg =  4.143586420884557
# amt_Q0 =  0.020137818223999834
# PRICE (ATTEST):  1.1432916524167411
# Negative attestation 1
# config_ids =  [{'M': {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 1000, 'C': 2000, 'f': 0.03, 'm': 0.15, 'beta': 0.9, 'dust': 1e-08, 'period': 2000, 'rules_price': 'martin', 'E': 0.2}, 'simulation_id': 0, 'run_id': 0}]

# %%
plt.plot(experiments.dataset[0].kappa)
plt.title('Kappa')
plt.ylabel('$\kappa$')
plt.xlabel('t')
# Out:
# Text(0.5, 0, 't')

# %%
plt.plot(experiments.dataset[0].alpha)
plt.title('Alpha')
plt.ylabel('alpha')
plt.xlabel('t')
# Out:
# Text(0.5, 0, 't')

# %%
plt.plot(experiments.dataset[0].reserve)
plt.title('Reserve')
plt.ylabel('R')
plt.xlabel('t')
# Out:
# Text(0.5, 0, 't')

# %%
plt.plot(experiments.dataset[0].supply)
plt.title('Supply')
plt.ylabel('S')
plt.xlabel('t')
# Out:
# Text(0.5, 0, 't')

# %%
plt.plot(experiments.dataset[0].spot_price)
plt.title('Price')
plt.ylabel('P')
plt.xlabel('t')
# Out:
# Text(0.5, 0, 't')

# %%
plt.plot(experiments.dataset[0].invariant_V)
plt.title('Invariant V')
plt.ylabel('V')
plt.xlabel('t')
# Out:
# Text(0.5, 0, 't')

# %%
plt.plot(experiments.dataset[0].invariant_I)
plt.title('Invariant I')
plt.ylabel('I')
plt.xlabel('t')
# Out:
# Text(0.5, 0, 't')

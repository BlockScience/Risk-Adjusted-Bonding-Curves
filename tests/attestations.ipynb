# %% [markdown]
# ## Positive attestations only

# %%
import sys
sys.path.append('../')

import matplotlib.pyplot as plt
import run2
# Out:
# <class 'list'>
# [1000]
#
# Initial Conditions (config.py) :  {'reserve': 300, 'price': 1, 'realized_price': 0, 'spot_price': 1, 'private_price': 0, 'private_alpha': 0, 'kappa': 0, 'supply': 600.0, 'alpha': [0.5], 'supply_0': 0, 'supply_1': 0, 'supply_free': 600.0, 'attestations': 40, 'attestations_0': 20, 'attestations_1': 20, 'invariant_V': 1200.0, 'invariant_I': 650.0, 'agent_attestations_1': 0, 'agent_attestations_0': 0, 'agent_reserve': 50, 'agent_supply': 50, 'agent_supply_1': 0, 'agent_supply_0': 0}
# Params (config.py) :  {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 1000, 'C': 700, 'period': 2000}

# %%
exp = run2.run()
# Out:
# Configurations Length: 1
# Execution Method: local_simulations
# Execution Mode: single_threaded
# Negative attestation. | alpha =  0.5 private_alpha =  0
# amt_neg =  4.5
# amt_Q0 =  0.07485989988473385
# --------------------------------------
# Positive attestation. | alpha =  0.5 private_alpha =  1.00078539687147
# amt_pos =  4.5
# amt_Q1 =  0.07485989988473385
# I (attest) =  69.28802148421639
# pre_1 =  0.0037290372265643395  | pre_2 =  0.0075  | pre_3 =  0.0
# mu_1 =  2.7967779199232547e-05
# pre_4 =  2.25  | pre_5 =  0.027967779199232545  | pre_6 =  5.25
# alpha_bar =  0.4308667401625063
# Positive attestation
# Q0 =  20 | Q1 =  20 | q0 =  0 | q1 =  0
# deltaq0 =  0 deltaq1 =  0.07485989988473385
# s =  50 | delta_s =  4.5
# new_alpha =  0.444693392130005
# kappa  =  0.23096007161405463
# SPOT PRICE P (from attest update =  0.11548003580702731
# Positive attestation. | alpha =  0.444693392130005 private_alpha =  1.00078539687147
# amt_pos =  12.740000000000002
# ...

# %%
print(exp)
# Out:
#       index  reserve  price  realized_price  spot_price  private_price  \
# 0         0      300      1               0    1.000000       0.000000
# 1         1      300      1               0    1.000000       0.000000
# 2         2      300      1               0    1.000000       1.000785
# 3         3      300      1               0    1.000000       1.000785
# 4         4      300      1               0    0.177806       1.000785
# 5         5      300      1               0    0.177806       1.000785
# 6         6      300      1               0    0.177806       1.000785
# 7         7      300      1               0    0.177806       1.000785
# 8         8      300      1               0    0.177806       1.001571
# 9         9      300      1               0    0.177806       1.001571
# 10       10      300      1               0    0.006928       1.001571
# 11       11      300      1               0    0.006928       1.001571
# ...

# %%
alpha_result = exp.loc[:, "alpha"]

print(alpha_result)
# Out:
# 0       0.500000
# 1       0.500000
# 2       0.500000
# 3       0.500000
# 4      -0.276167
# 5      -0.276167
# 6      -0.276167
# 7      -0.276167
# 8      -0.276167
# 9      -0.276167
# 10     -0.422633
# 11     -0.422633
# 12     -0.422633
# 13     -0.422633
# 14     -0.422633
# 15     -0.422633
# 16     -0.502033
# 17     -0.502033
# 18     -0.502033
# 19     -0.502033
# 20     -0.502033
# 21     -0.502033
# 22     -0.581489
# 23     -0.581489
# 24     -0.581489
# 25     -0.581489
# 26     -0.581489
# 27     -0.581489
# 28     -0.679442
# 29     -0.679442
# 30     -0.679442
# 31     -0.679442
# 32     -0.679442
# 33     -0.679442
# 34     -0.818738
# 35     -0.818738
# 36     -0.818738
# 37     -0.818738
# 38     -0.818738
# 39     -0.818738
# 40     -1.059901
# 41     -1.059901
# 42     -1.059901
# 43     -1.059901
# 44     -1.059901
# 45     -1.059901
# 46     -1.750470
# 47     -1.750470
# 48     -1.750470
# 49     -1.750470
# 50     -1.750470
# 51     -1.750470
# ...

# %%
plt.plot(exp.alpha)

# %%
plt.plot(exp.agent_supply)

# %%
plt.plot(exp.agent_supply_1)

# %%
plt.plot(exp.agent_supply_0)

# %%
plt.plot(exp.attestations)

# %%
plt.plot(exp.attestations_1)

# %%
plt.plot(exp.attestations_0)

# %% [markdown]
# ## Positive and Negative Attestations

# %%
import sys
sys.path.append('../')

import matplotlib.pyplot as plt
import run2
# Out:
# <class 'list'>
# [1000]
#
# Initial Conditions (config.py) :  {'reserve': 300, 'price': 1, 'realized_price': 0, 'spot_price': 1, 'private_price': 0, 'private_alpha': 0, 'kappa': 0, 'supply': 600.0, 'alpha': [0.5], 'supply_0': 200, 'supply_1': 200, 'supply_free': 600.0, 'attestations': 40, 'attestations_0': 20, 'attestations_1': 20, 'invariant_V': 1200.0, 'invariant_I': 650.0, 'agent_attestations_1': 0, 'agent_attestations_0': 0, 'agent_reserve': 50, 'agent_supply': 50, 'agent_supply_1': 10, 'agent_supply_0': 10, 'agent_supply_free': 30}
# Params (config.py) :  {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 1000, 'C': 700, 'period': 2000}

# %%
exp2 = run2.run()
# Out:
# Configurations Length: 1
# Execution Method: local_simulations
# Execution Mode: single_threaded
# Negative attestation. | alpha =  0.5 private_alpha =  0
# amt_neg =  4.0
# amt_Q0 =  0.06655592438987945
# --------------------------------------
# Positive attestation. | alpha =  0.5 private_alpha =  0.73
# amt_pos =  17.0
# amt_Q1 =  0.28135432690167494
# I (attest) =  651.6825653254548
# attest action  =  attest_pos
# B =  0.0
# EQUALIZED
# kappa  =  2.1722752177515163
# Spot Price P (attest) =  1.0861376088757582
# Positive attestation. | alpha =  0.5 private_alpha =  0.73
# amt_pos =  3.0
# amt_Q1 =  0.04993765576342124
# --------------------------------------
# Positive attestation. | alpha =  0.5 private_alpha =  0.82
# amt_pos =  2.0
# amt_Q1 =  0.03330560175562436
# I (attest) =  650.2386533973793
# attest action  =  attest_pos
# B =  0.0
# EQUALIZED
# kappa  =  2.1674621779912644
# Spot Price P (attest) =  1.0837310889956322
# ...

# %%
plt.plot(exp2.private_alpha)

# %%
plt.plot(exp2.alpha)

# %%
plt.plot(exp2.price)

# %%
plt.plot(exp2.spot_price)

# %%
plt.plot(exp2.kappa)

# %% [markdown]
# ## Private alpha is greater than 0.5
#
# **Expectation: All attestations are positive until agent runs out of $s_{free}$ tokens, given that $\alpha_{initial} = 0.5$ When $s_{free} = 0$ attestations cease.**

# %%
import sys
sys.path.append('../')

import matplotlib.pyplot as plt
import run2
# Out:
# <class 'list'>
# [1000]
#
# Initial Conditions (config.py) :  {'reserve': 300, 'price': 1, 'realized_price': 0, 'spot_price': 1, 'private_price': 0, 'private_alpha': 0, 'kappa': 0, 'supply': 600.0, 'alpha': [0.5], 'supply_0': 200, 'supply_1': 200, 'supply_free': 600.0, 'attestations': 40, 'attestations_0': 20, 'attestations_1': 20, 'invariant_V': 1200.0, 'invariant_I': 650.0, 'agent_attestations_1': 0, 'agent_attestations_0': 0, 'agent_reserve': 50, 'agent_supply': 50, 'agent_supply_1': 10, 'agent_supply_0': 10, 'agent_supply_free': 30}
# Params (config.py) :  {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 1000, 'C': 700, 'period': 2000}

# %%
exp3 = run2.run()
# Out:
# Configurations Length: 1
# Execution Method: local_simulations
# Execution Mode: single_threaded
# Negative attestation. | alpha =  0.5 private_alpha =  0
# amt_neg =  17.0
# amt_Q0 =  0.28135432690167494
# --------------------------------------
# Positive attestation. | alpha =  0.5 private_alpha =  0.92
# amt_pos =  17.5
# amt_Q1 =  0.28957039137760265
# I (attest) =  651.7377075092113
# mu_1 =  0.0051735578846454746
# alpha_bar =  0.5740298862342551
# Positive attestation
# Q0 =  20 | Q1 =  20 | q0 =  0 | q1 =  0
# deltaq0 =  0 deltaq1 =  0.28957039137760265
# s =  50 | delta_s =  17.5
# new_alpha =  0.5024824392988733
# kappa  =  2.1724590250307045
# Spot Price P (attest) =  1.0862295125153523
# Positive attestation. | alpha =  0.5024824392988733 private_alpha =  0.92
# amt_pos =  19.5
# amt_Q1 =  0.3224014329015734
# --------------------------------------
# Positive attestation. | alpha =  0.5024824392988733 private_alpha =  0.81
# amt_pos =  9.5
# amt_Q1 =  0.15771151032113906
# ...

# %%
plt.plot(exp3.private_alpha)

# %%
plt.plot(exp3.alpha)

# %% [markdown]
# ## Private alpha is less than 0.5
#
# **Expectation: All attestations are negative until agent runs out of $s_{free}$ tokens, given that $\alpha_{initial} = 0.5$ When $s_{free} = 0$ attestations cease.**

# %%
import sys
sys.path.append('../')

import matplotlib.pyplot as plt
import run2
# Out:
# <class 'list'>
# [1000]
#
# Initial Conditions (config.py) :  {'reserve': 300, 'price': 1, 'realized_price': 0, 'spot_price': 1, 'private_price': 0, 'private_alpha': 0, 'kappa': 0, 'supply': 600.0, 'alpha': [0.5], 'supply_0': 200, 'supply_1': 200, 'supply_free': 600.0, 'attestations': 40, 'attestations_0': 20, 'attestations_1': 20, 'invariant_V': 1200.0, 'invariant_I': 650.0, 'agent_attestations_1': 0, 'agent_attestations_0': 0, 'agent_reserve': 50, 'agent_supply': 50, 'agent_supply_1': 10, 'agent_supply_0': 10, 'agent_supply_free': 30}
# Params (config.py) :  {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 1000, 'C': 700, 'period': 2000}

# %%
exp4 = run2.run()
# Out:
# Configurations Length: 1
# Execution Method: local_simulations
# Execution Mode: single_threaded
# Negative attestation. | alpha =  0.5 private_alpha =  0
# amt_neg =  1.5
# amt_Q0 =  0.0249843945007866
# --------------------------------------
# Negative attestation. | alpha =  0.5 private_alpha =  0.01
# amt_neg =  6.0
# amt_Q0 =  0.099751242241779
# I (attest) =  645.8578658899651
# pre_1 =  0.004962809790010788  | pre_2 =  0.3433333333333333  | pre_3 =  0.0
# B =  0.0017038980279037038
# Negative attestation.
# Q0 =  20 | Q1 =  20 | q0 =  0 | q1 =  0
# deltaq0 =  0.099751242241779 deltaq1 =  0
# s =  50 | delta_s =  6.0
# new_alpha =  0.494082665557093
# kappa  =  2.1528595529665506
# Spot Price P (attest) =  1.0764297764832753
# Negative attestation. | alpha =  0.494082665557093 private_alpha =  0.01
# amt_neg =  1.0
# amt_Q0 =  0.016742819431425443
# --------------------------------------
# Negative attestation. | alpha =  0.494082665557093 private_alpha =  0.48
# ...

# %%
plt.plot(exp4.private_alpha)

# %%
plt.plot(exp4.alpha)

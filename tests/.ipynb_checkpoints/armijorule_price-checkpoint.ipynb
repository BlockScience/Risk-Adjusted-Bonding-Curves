# %%
import sys
sys.path.append('../')

import pandas as pd

import matplotlib.pyplot as plt
# import run2

from src.sim import run

import seaborn as sns

# For analysis
import numpy as np
import pandas as pd

sns.set_style("whitegrid")

experiments = run.run()
# Out:
# Initial Conditions (config.py) :  {'reserve': 1000, 'pbar': 1, 'realized_price': 0, 'spot_price': 1, 'kappa': 0, 'supply': 2000.0, 'alpha': [0.5], 'alpha_bar': [0.5], 'supply_0': 30, 'supply_1': 30, 'supply_free': 2000.0, 'attestations': 40, 'attestations_0': 20, 'attestations_1': 20, 'invariant_V': 4000.0, 'invariant_I': 2000.0, 'agents':    id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0   0                     0                     0            100
# 1   1                     0                     0            100
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0               3               3                 44                  0.3
# 1               3               3                 44                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  1.5  , 'chosen_agent': 0}
# -----------------PSUB---------------------
# Params (config.py) :  {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 1000, 'C': 2000, 'f': 0.03, 'm': 0.15, 'beta': 0.9, 'dust': 1e-08, 'period': 2000, 'rules_price': 'martin', 'E': 0.2}
# Configurations Length: 1
# Execution Method: single_proc_exec
# Execution Mode: single_threaded
#    id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0   0                     0                     0            100
# 1   1                     0                     0            100
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0               3               3                 44                  0.3
# 1               3               3                 44                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  1.5
# --------------TIMESTEP 0 --------------
# CHOSEN AGENT =     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0   0                     0                     0            100
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0               3               3                 44                  0.3
#
#    agent_private_price
# 0                  0.5   Time  0
# r 100
# No trade. P =  1 private_price =  0.5
# Negative attestation. | alpha =  0.5 private_alpha =  0.3
# amt_neg =  9.464971349348785
# amt_Q0 =  0.04726899779293525
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  1.0
# PRICE pbar (from bondburn update) = 0.0
# r 100.0
# No trade. P =  1.0 private_price =  0.5
# Negative attestation. | alpha =  0.5 private_alpha =  0.3
# amt_neg =  10.9709098475434
# amt_Q0 =  0.05477952931691288
# PRICE (ATTEST):  0.8661134218355514
# Negative attestation 1
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0               0.05478          100.0
# 1  1.0                   0.0               0.00000          100.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        13.97091           33.02909                  0.3
# 1             3.0         3.00000           44.00000                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  1.5
# --------------TIMESTEP 1 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0                   0.0                   0.0          100.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1             3.0             3.0               44.0                  0.7
#
#    agent_private_price
# 1                  1.5   Time  1
# r 100.0
# No trade. P =  0.8661134218355514 private_price =  1.5
# Positive attestation. | alpha =  0.4227084035479422 private_alpha =  0.7
# amt_pos =  14.77550676688969
# amt_Q1 =  0.07374158828836741
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  0.8661134218355514
# PRICE pbar (from bondburn update) = 0.0
# r 100.0
# No trade. P =  0.8661134218355514 private_price =  1.5
# Positive attestation. | alpha =  0.4227084035479422 private_alpha =  0.7
# amt_pos =  15.493299327615578
# amt_Q1 =  0.07731704848840337
# PRICE (ATTEST):  1.1634006295971187
# Positive attestation 1
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000               0.05478          100.0
# 1  1.0              0.077317               0.00000          100.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000        13.97091          33.029090                  0.3
# 1       18.493299         3.00000          28.506701                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  1.5
# --------------TIMESTEP 2 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0               0.05478          100.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        13.97091           33.02909                  0.3
#
#    agent_private_price
# 0                  0.5   Time  2
# r 100.0
# PROTO RP (BURN) =  1.1506776860241745
# Agent burns. Amt to burn =  33.0290898221657
# Negative attestation. | alpha =  0.5261518003993464 private_alpha =  0.3
# amt_neg =  7.91791944237331
# amt_Q0 =  0.039658819042606874
# ::::delta R:::: 38.00583664805424
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  1.1506776860241745
# PRICE pbar (from bondburn update) = 1.1506776860241745
# r 138.00583664805424
# PROTO RP (BURN) =  1.1379796555809893
# Agent burns. Amt to burn =  3.3029044413380516e-07
# Negative attestation. | alpha =  0.5261518003993464 private_alpha =  0.3
# amt_neg =  1.0534892903657546e-07
# amt_Q0 =  5.370563172743508e-10
# PRICE (ATTEST):  0.9670039014888524
# Negative attestation 1
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000               0.05478     138.005837
# 1  1.0              0.077317               0.00000     100.000000
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000        13.97091       2.249415e-07                  0.3
# 1       18.493299         3.00000       2.850670e+01                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  1.5
# --------------TIMESTEP 3 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0               0.05478     138.005837
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        13.97091       2.249415e-07                  0.3
#
#    agent_private_price
# 0                  0.5   Time  3
# r 138.00583664805424
# No trade. P =  0.9670039014888524 private_price =  0.5
# Negative attestation. | alpha =  0.5071631205866283 private_alpha =  0.3
# amt_neg =  5.3772781055039924e-08
# amt_Q0 =  2.741256495305057e-10
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  0.967003901488852
# PRICE pbar (from bondburn update) = 0.0
# r 138.00583664805424
# No trade. P =  0.967003901488852 private_price =  0.5
# Negative attestation. | alpha =  0.5071631205866283 private_alpha =  0.3
# amt_neg =  5.557425871233436e-08
# amt_Q0 =  2.8330785017268477e-10
# PRICE (ATTEST):  1.0047532441410032
# Negative attestation 1
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000               0.05478     138.005837
# 1  1.0              0.077317               0.00000     100.000000
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000        13.97091       1.693679e-07                  0.3
# 1       18.493299         3.00000       2.850670e+01                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  1.5
# --------------TIMESTEP 4 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0               0.05478     138.005837
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        13.97091       1.693679e-07                  0.3
#
#    agent_private_price
# 0                  0.5   Time  4
# r 138.00583664805424
# No trade. P =  1.0047532441410032 private_price =  0.5
# Negative attestation. | alpha =  0.5071631202475898 private_alpha =  0.3
# amt_neg =  4.2431203769236213e-08
# amt_Q0 =  2.1630717565477702e-10
# ::::delta R:::: 1.1368683772161603e-13
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  1.0047532441410034
# PRICE pbar (from bondburn update) = 0.0
# r 138.00583664805436
# No trade. P =  1.0047532441410034 private_price =  0.5
# Negative attestation. | alpha =  0.5071631202475898 private_alpha =  0.3
# amt_neg =  4.386825892588115e-08
# amt_Q0 =  2.23632452112875e-10
# PRICE (ATTEST):  1.0047532439454483
# Negative attestation 1
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000               0.05478     138.005837
# 1  1.0              0.077317               0.00000     100.000000
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000        13.97091       1.254997e-07                  0.3
# 1       18.493299         3.00000       2.850670e+01                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  1.5
# --------------TIMESTEP 5 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0               0.05478     138.005837
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        13.97091       1.254997e-07                  0.3
#
#    agent_private_price
# 0                  0.5   Time  5
# r 138.00583664805436
# No trade. P =  1.0047532439454483 private_price =  0.5
# Negative attestation. | alpha =  0.5071631199799654 private_alpha =  0.3
# amt_neg =  3.360902276503909e-08
# amt_Q0 =  1.7133576717624307e-10
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  1.0047532439454485
# PRICE pbar (from bondburn update) = -0.0
# r 138.00583664805436
# No trade. P =  1.0047532439454485 private_price =  0.5
# Negative attestation. | alpha =  0.5071631199799654 private_alpha =  0.3
# amt_neg =  3.492883678088762e-08
# amt_Q0 =  1.7805988112873624e-10
# PRICE (ATTEST):  1.004753243787251
# Negative attestation 1
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000               0.05478     138.005837
# 1  1.0              0.077317               0.00000     100.000000
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000        13.97091       9.057016e-08                  0.3
# 1       18.493299         3.00000       2.850670e+01                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  1.5
# --------------TIMESTEP 6 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0               0.05478     138.005837
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        13.97091       9.057016e-08                  0.3
#
#    agent_private_price
# 0                  0.5   Time  6
# r 138.00583664805436
# No trade. P =  1.004753243787251 private_price =  0.5
# Negative attestation. | alpha =  0.5071631197668773 private_alpha =  0.3
# amt_neg =  2.1546113840765634e-08
# amt_Q0 =  1.0983906937329073e-10
# ::::delta R:::: -1.1368683772161603e-13
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  1.0047532437872508
# PRICE pbar (from bondburn update) = 0.0
# r 138.00583664805424
# No trade. P =  1.0047532437872508 private_price =  0.5
# Negative attestation. | alpha =  0.5071631197668773 private_alpha =  0.3
# amt_neg =  1.7098407427888477e-08
# amt_Q0 =  8.71641102697151e-11
# PRICE (ATTEST):  1.0047532437978082
# Negative attestation 1
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000               0.05478     138.005837
# 1  1.0              0.077317               0.00000     100.000000
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000        13.97091       7.347244e-08                  0.3
# 1       18.493299         3.00000       2.850670e+01                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  1.5
# --------------TIMESTEP 7 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0              0.077317                   0.0          100.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1       18.493299             3.0          28.506701                  0.7
#
#    agent_private_price
# 1                  1.5   Time  7
# r 100.0
# No trade. P =  1.0047532437978082 private_price =  1.5
# Positive attestation. | alpha =  0.5071631196625661 private_alpha =  0.7
# amt_pos =  5.499160797790272
# amt_Q1 =  0.028046000415445776
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  1.004753243797808
# PRICE pbar (from bondburn update) = 0.0
# r 100.0
# No trade. P =  1.004753243797808 private_price =  1.5
# Positive attestation. | alpha =  0.5071631196625661 private_alpha =  0.7
# amt_pos =  6.192976554530526
# amt_Q1 =  0.031581717236545126
# PRICE (ATTEST):  1.0759497234181439
# Positive attestation 1
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000               0.05478     138.005837
# 1  1.0              0.108899               0.00000     100.000000
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000        13.97091       7.347244e-08                  0.3
# 1       24.686276         3.00000       2.231372e+01                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  1.5
# --------------TIMESTEP 8 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0               0.05478     138.005837
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        13.97091       7.347244e-08                  0.3
#
#    agent_private_price
# 0                  0.5   Time  8
# r 138.00583664805424
# No trade. P =  1.0759497234181439 private_price =  0.5
# Negative attestation. | alpha =  0.538991092776775 private_alpha =  0.3
# amt_neg =  2.3791996375204816e-08
# amt_Q0 =  1.2128787531554864e-10
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  1.0759497234181434
# PRICE pbar (from bondburn update) = 0.0
# r 138.00583664805424
# No trade. P =  1.0759497234181434 private_price =  0.5
# Negative attestation. | alpha =  0.538991092776775 private_alpha =  0.3
# amt_neg =  2.3308388835660296e-08
# amt_Q0 =  1.1882088251440262e-10
# PRICE (ATTEST):  1.0371156674205881
# Negative attestation 1
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000               0.05478     138.005837
# 1  1.0              0.108899               0.00000     100.000000
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000        13.97091       5.016405e-08                  0.3
# 1       24.686276         3.00000       2.231372e+01                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  1.5
# --------------TIMESTEP 9 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0              0.108899                   0.0          100.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1       24.686276             3.0          22.313724                  0.7
#
#    agent_private_price
# 1                  1.5   Time  9
# r 100.0
# No trade. P =  1.0371156674205881 private_price =  1.5
# Positive attestation. | alpha =  0.5389910926354148 private_alpha =  0.7
# amt_pos =  3.894374640260925
# amt_Q1 =  0.019896802069800303
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  1.0371156674205884
# PRICE pbar (from bondburn update) = -0.0
# r 100.0
# No trade. P =  1.0371156674205884 private_price =  1.5
# Positive attestation. | alpha =  0.5389910926354148 private_alpha =  0.7
# amt_pos =  5.569878170971416
# amt_Q1 =  0.0284510912579316
# PRICE (ATTEST):  1.0947125691311728
# Positive attestation 1
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0               0.00000               0.05478     138.005837
# 1  1.0               0.13735               0.00000     100.000000
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000        13.97091       5.016405e-08                  0.3
# 1       30.256154         3.00000       1.674385e+01                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  1.5
# --------------TIMESTEP 10 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0               0.05478     138.005837
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        13.97091       5.016405e-08                  0.3
#
#    agent_private_price
# 0                  0.5   Time  10
# r 138.00583664805424
# No trade. P =  1.0947125691311728 private_price =  0.5
# Negative attestation. | alpha =  0.56429813883192 private_alpha =  0.3
# amt_neg =  1.7609050831057153e-08
# amt_Q0 =  8.976914779530166e-11
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  1.0947125691311725
# PRICE pbar (from bondburn update) = -0.0
# r 138.00583664805424
# No trade. P =  1.0947125691311725 private_price =  0.5
# Negative attestation. | alpha =  0.56429813883192 private_alpha =  0.3
# amt_neg =  1.725328351139324e-08
# amt_Q0 =  8.795230111141441e-11
# PRICE (ATTEST):  1.062847665793271
# Negative attestation 1
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0               0.00000               0.05478     138.005837
# 1  1.0               0.13735               0.00000     100.000000
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000        13.97091       3.291054e-08                  0.3
# 1       30.256154         3.00000       1.674385e+01                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  1.5
# --------------TIMESTEP 11 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0               0.05478     138.005837
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        13.97091       3.291054e-08                  0.3
#
#    agent_private_price
# 0                  0.5   Time  11
# r 138.00583664805424
# No trade. P =  1.062847665793271 private_price =  0.5
# Negative attestation. | alpha =  0.5642981387283833 private_alpha =  0.3
# amt_neg =  8.913962261643843e-09
# amt_Q0 =  4.5443432375369364e-11
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  1.0628476657932708
# PRICE pbar (from bondburn update) = 0.0
# r 138.00583664805424
# No trade. P =  1.0628476657932708 private_price =  0.5
# Negative attestation. | alpha =  0.5642981387283833 private_alpha =  0.3
# amt_neg =  1.1658121334367305e-08
# amt_Q0 =  5.943048000800388e-11
# PRICE (ATTEST):  1.0628476657621888
# Negative attestation 1
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0               0.00000               0.05478     138.005837
# 1  1.0               0.13735               0.00000     100.000000
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000        13.97091       2.125264e-08                  0.3
# 1       30.256154         3.00000       1.674385e+01                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  1.5
# --------------TIMESTEP 12 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0               0.05478     138.005837
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        13.97091       2.125264e-08                  0.3
#
#    agent_private_price
# 0                  0.5   Time  12
# r 138.00583664805424
# No trade. P =  1.0628476657621888 private_price =  0.5
# Negative attestation. | alpha =  0.564298138658423 private_alpha =  0.3
# amt_neg =  5.90735811301688e-09
# amt_Q0 =  3.0116015007891596e-11
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  1.0628476657621886
# PRICE pbar (from bondburn update) = 0.0
# r 138.00583664805424
# No trade. P =  1.0628476657621886 private_price =  0.5
# Negative attestation. | alpha =  0.564298138658423 private_alpha =  0.3
# amt_neg =  5.01253030283891e-09
# amt_Q0 =  2.5551633020151116e-11
# PRICE (ATTEST):  1.0628476657791759
# Negative attestation 1
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0               0.00000               0.05478     138.005837
# 1  1.0               0.13735               0.00000     100.000000
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000        13.97091       1.624080e-08                  0.3
# 1       30.256154         3.00000       1.674385e+01                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  1.5
# --------------TIMESTEP 13 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0               0.13735                   0.0          100.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1       30.256154             3.0          16.743846                  0.7
#
#    agent_private_price
# 1                  1.5   Time  13
# r 100.0
# No trade. P =  1.0628476657791759 private_price =  1.5
# Positive attestation. | alpha =  0.564298138628343 private_alpha =  0.7
# amt_pos =  3.120943646798425
# amt_Q1 =  0.015969383146203796
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  1.0628476657791759
# PRICE pbar (from bondburn update) = 0.0
# r 100.0
# No trade. P =  1.0628476657791759 private_price =  1.5
# Positive attestation. | alpha =  0.564298138628343 private_alpha =  0.7
# amt_pos =  3.0932292378746067
# amt_Q1 =  0.015827628513330156
# PRICE (ATTEST):  1.0921142169159561
# Positive attestation 1
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000               0.05478     138.005837
# 1  1.0              0.153177               0.00000     100.000000
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000        13.97091       1.624080e-08                  0.3
# 1       33.349383         3.00000       1.365062e+01                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  1.5
# --------------TIMESTEP 14 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0               0.05478     138.005837
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        13.97091       1.624080e-08                  0.3
#
#    agent_private_price
# 0                  0.5   Time  14
# r 138.00583664805424
# No trade. P =  1.0921142169159561 private_price =  0.5
# Negative attestation. | alpha =  0.5771879311538954 private_alpha =  0.3
# amt_neg =  6.079536144889279e-09
# amt_Q0 =  3.099326696069682e-11
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  1.0921142169159568
# PRICE pbar (from bondburn update) = -0.0
# r 138.00583664805424
# No trade. P =  1.0921142169159568 private_price =  0.5
# Negative attestation. | alpha =  0.5771879311538954 private_alpha =  0.3
# amt_neg =  6.197595458911317e-09
# amt_Q0 =  3.159442946639999e-11
# PRICE (ATTEST):  1.0759539017818858
# Negative attestation 1
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000               0.05478     138.005837
# 1  1.0              0.153177               0.00000     100.000000
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000        13.97091       1.004252e-08                  0.3
# 1       33.349383         3.00000       1.365062e+01                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  1.5
# --------------TIMESTEP 15 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0              0.153177                   0.0          100.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1       33.349383             3.0          13.650617                  0.7
#
#    agent_private_price
# 1                  1.5   Time  15
# r 100.0
# No trade. P =  1.0759539017818858 private_price =  1.5
# Positive attestation. | alpha =  0.5771879311169796 private_alpha =  0.7
# amt_pos =  1.811569369871972
# amt_Q1 =  0.009278346873132639
# ::::delta R:::: 1.1368683772161603e-13
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  1.0759539017818858
# PRICE pbar (from bondburn update) = 0.0
# r 100.00000000000011
# No trade. P =  1.0759539017818858 private_price =  1.5
# Positive attestation. | alpha =  0.5771879311169796 private_alpha =  0.7
# amt_pos =  2.7484937863897505
# amt_Q1 =  0.014075334458712166
# PRICE (ATTEST):  1.1007371918550377
# Positive attestation 1
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000               0.05478     138.005837
# 1  1.0              0.167253               0.00000     100.000000
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000        13.97091       1.004252e-08                  0.3
# 1       36.097877         3.00000       1.090212e+01                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  1.5
# --------------TIMESTEP 16 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0               0.05478     138.005837
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        13.97091       1.004252e-08                  0.3
#
#    agent_private_price
# 0                  0.5   Time  16
# r 138.00583664805424
# PROTO RP (BURN) =  1.100719696086636
# Agent burns. Amt to burn =  1.0042519130572665e-08
# Negative attestation. | alpha =  0.5880176643776145 private_alpha =  0.3
# amt_neg =  2.540805882984344e-09
# amt_Q0 =  1.2949485678426485e-11
# ::::delta R:::: 1.105399860534817e-08
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  1.100719696086636
# PRICE pbar (from bondburn update) = 1.100719696086636
# r 138.00583665910824

# %%
plt.plot(experiments.dataset[0].kappa)
plt.title('Kappa')
plt.ylabel('$\kappa$')
plt.xlabel('t')
# Out:
# Text(0.5, 0, 't')

# %%
plt.plot(experiments.dataset[0].alpha)
plt.title('Alpha')
plt.ylabel('alpha')
plt.xlabel('t')
# Out:
# Text(0.5, 0, 't')

# %%
plt.plot(experiments.dataset[0].reserve)
plt.title('Reserve')
plt.ylabel('R')
plt.xlabel('t')
# Out:
# Text(0.5, 0, 't')

# %%
plt.plot(experiments.dataset[0].supply)
plt.title('Supply')
plt.ylabel('S')
plt.xlabel('t')
# Out:
# Text(0.5, 0, 't')

# %%
plt.plot(experiments.dataset[0].spot_price)
plt.title('Price')
plt.ylabel('P')
plt.xlabel('t')
# Out:
# Text(0.5, 0, 't')

# %%
plt.plot(experiments.dataset[0].invariant_V)
plt.title('Invariant V')
plt.ylabel('V')
plt.xlabel('t')
# Out:
# Text(0.5, 0, 't')

# %%
plt.plot(experiments.dataset[0].invariant_I)
plt.title('Invariant I')
plt.ylabel('I')
plt.xlabel('t')
# Out:
# Text(0.5, 0, 't')

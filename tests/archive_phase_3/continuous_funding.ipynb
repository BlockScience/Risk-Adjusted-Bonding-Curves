# %%
pip show cadCAD
# Out:
# Name: cadCAD
# Version: 0.4.22
# Summary: cadCAD: a differential games based simulation software package for research, validation, and         Computer Aided Design of economic systems
# Home-page: https://github.com/cadCAD-org/cadCAD
# Author: Joshua E. Jodesty
# Author-email: joshua@block.science
# License: LICENSE.txt
# Location: /usr/local/lib/python3.7/site-packages
# Requires: pathos, pandas, funcy, fn
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
# import sys
# sys.path.append('../')
import pandas as pd

import matplotlib.pyplot as plt
# import run2

from src.sim import run

import seaborn as sns

# For analysis
import numpy as np
import pandas as pd

sns.set_style("whitegrid")
# Out:
#                   ___________    ____
#   ________ __ ___/ / ____/   |  / __ \
#  / ___/ __` / __  / /   / /| | / / / /
# / /__/ /_/ / /_/ / /___/ ___ |/ /_/ /
# \___/\__,_/\__,_/\____/_/  |_/_____/
# by cadCAD
#
# Execution Mode: multi_proc
# Configuration Count: 1
# Dimensions of the first simulation: (Timesteps, Params, Runs, Vars) = (100, 16, 4, 22)
# Execution Method: parallelize_simulations
# Execution Mode: parallelized
#    id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0   0                     0                     0           1000
# 1   1                     0                     0           1000
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0               3               3               4994                  0.5
# 1               3               3               4994                  0.5
#
#    agent_private_price
# 0                  0.5
# 1                  1.5
# --------------TIMESTEP 0 --------------
# CHOSEN AGENT =     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0   0                     0                     0           1000
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0               3               3               4994                  0.5
#
#    agent_private_price
# 0                  0.5   Time  0
# agent['agent_private_price'] =  0.499
# agent['agent_private_alpha'] =  0.499
# r 1000
# PROTO RP (BURN) =  0.8751500012484998
# Agent burns. Amt to burn =  4993.99995006
# Negative attestation. | alpha =  0.5 private_alpha =  0.499
# amt_neg =  136.738981576686
# amt_Q0 =  0.06825302888952667
# ::::delta R:::: 4370.499062530017
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  0.8751500012484998
# PRICE pbar (from bondburn update) = 0.8751500012484998
# r 5370.499062530017
# PROTO RP (BURN) =  0.7502999868636259
# Agent burns. Amt to burn =  4.993999978151249e-05
# Negative attestation. | alpha =  0.5 private_alpha =  0.499
# amt_neg =  6.178416140195772e-07
# amt_Q0 =  4.1172842912828855e-10
# r 5370.499062530017
# PROTO RP (BURN) =  0.7502999868636259
# Agent burns. Amt to burn =  4.993999978151249e-05
# Negative attestation. | alpha =  0.5 private_alpha =  0.499
# amt_neg =  8.029864761087851e-07
# amt_Q0 =  5.351097343009314e-10
# PRICE (ATTEST):  0.5221113014791349
# Negative attestation 1
# S =  15006.000049940001
# KAPPA  =  1.3917401032694852
# R =  5629.500937469983
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          5.351097e-10    5370.499063
# 1  1.0                   0.0          0.000000e+00    1000.000000
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        3.000001           0.000049                0.499
# 1             3.0        3.000000        4994.000000                0.500
#
#    agent_private_price
# 0                0.499
# 1                1.500
# --------------TIMESTEP 1 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          5.351097e-10    5370.499063
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        3.000001           0.000049                0.499
#
#    agent_private_price
# 0                0.499   Time  1
# agent['agent_private_price'] =  0.498
# agent['agent_private_alpha'] =  0.498
# r 5370.499062530017
# PROTO RP (BURN) =  0.5221113054669293
# Agent burns. Amt to burn =  4.9137013313433574e-05
# Positive attestation. | alpha =  0.28147504146011654 private_alpha =  0.498
# amt_pos =  1.3864329163243616e-05
# amt_Q1 =  9.239187193088583e-09
# ::::delta R:::: 2.565499016782269e-05
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  0.5221113054669293
# PRICE pbar (from bondburn update) = 0.5221113054669293
# r 5370.499088185007
# PROTO RP (BURN) =  0.0
# Agent burns. Amt to burn =  5.353504463597928e-12
# Positive attestation. | alpha =  0.28147504146011654 private_alpha =  0.498
# amt_pos =  1.555780754556539e-12
# amt_Q1 =  0.0
# r 5370.499088185007
# PROTO RP (BURN) =  0.0
# Agent burns. Amt to burn =  5.353504463597928e-12
# Positive attestation. | alpha =  0.28147504146011654 private_alpha =  0.498
# amt_pos =  1.6937600417886024e-12
# amt_Q1 =  0.0
# PRICE (ATTEST):  0.7502999943195954
# Positive attestation 1
# S =  15006.000000802993
# KAPPA  =  1.9999999807678062
# R =  5629.500911814993
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          5.351097e-10    5370.499088
# 1  1.0                   0.0          0.000000e+00    1000.000000
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        3.000001       4.254578e-12                0.498
# 1             3.0        3.000000       4.994000e+03                0.500
#
#    agent_private_price
# 0                0.498
# 1                1.500
# --------------TIMESTEP 2 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0                   0.0                   0.0         1000.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1             3.0             3.0             4994.0                  0.5
#
#    agent_private_price
# 1                  1.5   Time  2
# agent['agent_private_price'] =  0.497
# agent['agent_private_alpha'] =  0.497
# r 1000.0
# PROTO RP (BURN) =  0.6254499986290477
# Agent burns. Amt to burn =  4993.99995006
# Positive attestation. | alpha =  0.2814750401773785 private_alpha =  0.497
# amt_pos =  1322.5935765622012
# amt_Q1 =  0.8627673144232029
# ::::delta R:::: 3123.497261918491
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  0.6254499986290477
# PRICE pbar (from bondburn update) = 0.6254499986290477
# r 4123.497261918491
# PROTO RP (BURN) =  0.5005999636835464
# Agent burns. Amt to burn =  4.9940003419491266e-05
# Positive attestation. | alpha =  0.2814750401773785 private_alpha =  0.497
# amt_pos =  9.788861188959744e-06
# amt_Q1 =  9.777125775656259e-09
# r 4123.497261918491
# PROTO RP (BURN) =  0.5005999636835464
# Agent burns. Amt to burn =  4.9940003419491266e-05
# Positive attestation. | alpha =  0.2814750401773785 private_alpha =  0.497
# amt_pos =  9.864739806557174e-06
# amt_Q1 =  9.85291404020927e-09
# PRICE (ATTEST):  0.32196149973765353
# Positive attestation 1
# S =  10012.000050742998
# KAPPA  =  1.28630241693535
# R =  2506.003649896502
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0          0.000000e+00          5.351097e-10    5370.499088
# 1  1.0          9.852914e-09          0.000000e+00    4123.497262
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0         3.00000        3.000001       4.254578e-12                0.498
# 1         3.00001        3.000000       4.007526e-05                0.497
#
#    agent_private_price
# 0                0.498
# 1                0.497
# --------------TIMESTEP 3 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0          9.852914e-09                   0.0    4123.497262
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1         3.00001             3.0            0.00004                0.497
#
#    agent_private_price
# 1                0.497   Time  3
# agent['agent_private_price'] =  0.49599999999999994
# agent['agent_private_alpha'] =  0.49599999999999994
# r 4123.497261918491
# PROTO RP (BOND) =  0.36434644385448894
# Agent bonds. Amt to bond =  4123.497220683518
# Positive attestation. | alpha =  0.12530021560044877 private_alpha =  0.49599999999999994
# amt_pos =  1.4161587858841193e-05
# amt_Q1 =  1.4144614375629052e-08
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 4123.497220683518
# PRICE (BOND/BURN):  0.36434644385448894
# PRICE pbar (from bondburn update) = 0.36434644385448894
# r 4.123497274122201e-05
# PROTO RP (BOND) =  -7.688830879368801e-09
# Agent bonds. Amt to bond =  4.123497232887228e-05
# Positive attestation. | alpha =  0.12530021560044877 private_alpha =  0.49599999999999994
# amt_pos =  4505.091056306686
# amt_Q1 =  2.0110328974102956
# r 4.123497274122201e-05
# PROTO RP (BOND) =  -7.688830879368801e-09
# Agent bonds. Amt to bond =  4.123497232887228e-05
# Positive attestation. | alpha =  0.12530021560044877 private_alpha =  0.49599999999999994
# amt_pos =  4524.726565581955
# amt_Q1 =  2.019396015224178
# PRICE (ATTEST):  -0.18758847914778015
# Positive attestation 1
# S =  21329.51745824195
# KAPPA  =  -0.8759607599075272
# R =  4567.752260238261
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000          5.351097e-10    5370.499088
# 1  1.0              2.019396          0.000000e+00       0.000041
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000        3.000001       4.254578e-12                0.498
# 1     4527.726575        3.000000       6.792791e+03                0.496
#
#    agent_private_price
# 0                0.498
# 1                0.496
# --------------TIMESTEP 4 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0              2.019396                   0.0       0.000041
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1     4527.726575             3.0        6792.790882                0.496
#
#    agent_private_price
# 1                0.496   Time  4
# agent['agent_private_price'] =  0.495
# agent['agent_private_alpha'] =  0.495
# r 4.123497274122201e-05
# PROTO RP (BOND) =  -0.18758849772335429
# Agent bonds. Amt to bond =  4.123497232887228e-05
# Negative attestation. | alpha =  0.9782315617812606 private_alpha =  0.495
# amt_neg =  3679.808352562747
# amt_Q0 =  1.6566098489260594
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 4.123497232887228e-05
# PRICE (BOND/BURN):  -0.18758849772335429
# PRICE pbar (from bondburn update) = -0.18758849772335429
# r 4.1234972657537214e-13
# PROTO RP (BOND) =  3.751769574300008e-09
# Agent bonds. Amt to bond =  4.1234972245187487e-13
# Negative attestation. | alpha =  0.9782315617812606 private_alpha =  0.495
# amt_neg =  3055.2712060523872
# amt_Q0 =  1.384494015442185
# r 4.1234972657537214e-13
# PROTO RP (BOND) =  3.751769574300008e-09
# Agent bonds. Amt to bond =  4.1234972245187487e-13
# Negative attestation. | alpha =  0.9782315617812606 private_alpha =  0.495
# amt_neg =  3657.480102084152
# amt_Q0 =  1.6469402286138535
# PRICE (ATTEST):  0.27521574149102657
# Negative attestation 1
# S =  21329.517238425848
# KAPPA  =  1.2851438829163573
# R =  4567.752280855748
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000          5.351097e-10   5.370499e+03
# 1  1.0              2.019396          1.646940e+00   4.123497e-13
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000        3.000001       4.254578e-12                0.498
# 1     4527.726575     3660.480102       3.135311e+03                0.495
#
#    agent_private_price
# 0                0.498
# 1                0.495
# --------------TIMESTEP 5 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          5.351097e-10    5370.499088
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        3.000001       4.254578e-12                0.498
#
#    agent_private_price
# 0                0.498   Time  5
# agent['agent_private_price'] =  0.494
# agent['agent_private_alpha'] =  0.494
# r 5370.499088185007
# PROTO RP (BOND) =  0.30297492214404226
# Agent bonds. Amt to bond =  5370.499034480016
# Positive attestation. | alpha =  0.2677210558781801 private_alpha =  0.494
# amt_pos =  9.012714648515918e-13
# amt_Q1 =  0.0
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 5370.499034480016
# PRICE (BOND/BURN):  0.30297492214404226
# PRICE pbar (from bondburn update) = 0.30297492214404226
# r 5.3704990932601504e-05
# PROTO RP (BOND) =  -6.326192715855686e-09
# Agent bonds. Amt to bond =  5.3704990395551594e-05
# Positive attestation. | alpha =  0.2677210558781801 private_alpha =  0.494
# amt_pos =  4926.28524271082
# amt_Q1 =  1.3474872011899655
# r 5.3704990932601504e-05
# PROTO RP (BOND) =  -6.326192715855686e-09
# Agent bonds. Amt to bond =  5.3704990395551594e-05
# Positive attestation. | alpha =  0.2677210558781801 private_alpha =  0.494
# amt_pos =  3612.8706393699917
# amt_Q1 =  0.9959429800026999
# PRICE (ATTEST):  0.6858192297120562
# Positive attestation 1
# S =  39055.403580684695
# KAPPA  =  3.692946389015225
# R =  7253.001798095756
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.995943          5.351097e-10   5.370499e-05
# 1  1.0              2.019396          1.646940e+00   4.123497e-13
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0     3615.870639        3.000001       14113.015703                0.494
# 1     4527.726575     3660.480102        3135.310560                0.495
#
#    agent_private_price
# 0                0.494
# 1                0.495
# --------------TIMESTEP 6 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0              2.019396               1.64694   4.123497e-13
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1     4527.726575     3660.480102         3135.31056                0.495
#
#    agent_private_price
# 1                0.495   Time  6
# agent['agent_private_price'] =  0.493
# agent['agent_private_alpha'] =  0.493
# r 4.1234972657537214e-13
# PROTO RP (BURN) =  0.6149984721043222
# Agent burns. Amt to burn =  3135.3105287389008
# Negative attestation. | alpha =  0.5575811651242366 private_alpha =  0.493
# amt_neg =  254.0048147450659
# amt_Q0 =  0.07027857168154238
# ::::delta R:::: 1928.2111847470187
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  0.6149984721043222
# PRICE pbar (from bondburn update) = 0.6149984721043222
# r 1928.2111847470192
# PROTO RP (BURN) =  0.5474419395189729
# Agent burns. Amt to burn =  3.135310558288343e-05
# Negative attestation. | alpha =  0.5575811651242366 private_alpha =  0.493
# amt_neg =  2.049647887645176e-06
# amt_Q0 =  6.175982725327934e-10
# r 1928.2111847470192
# PROTO RP (BURN) =  0.5474419395189729
# Agent burns. Amt to burn =  3.135310558288343e-05
# Negative attestation. | alpha =  0.5575811651242366 private_alpha =  0.493
# amt_neg =  2.280386370362164e-06
# amt_Q0 =  6.871255432323565e-10
# PRICE (ATTEST):  0.2873990803428811
# Negative attestation 1
# S =  35920.09305194579
# KAPPA  =  1.938743221767286
# R =  5324.790613348738
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.995943          5.351097e-10       0.000054
# 1  1.0              2.019396          1.646940e+00    1928.211185
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0     3615.870639        3.000001       14113.015703                0.494
# 1     4527.726575     3660.480104           0.000029                0.493
#
#    agent_private_price
# 0                0.494
# 1                0.493
# --------------TIMESTEP 7 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.995943          5.351097e-10       0.000054
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0     3615.870639        3.000001       14113.015703                0.494
#
#    agent_private_price
# 0                0.494   Time  7
# agent['agent_private_price'] =  0.492
# agent['agent_private_alpha'] =  0.492
# r 5.3704990932601504e-05
# PROTO RP (BOND) =  0.2873990932301972
# Agent bonds. Amt to bond =  5.3704990395551594e-05
# Positive attestation. | alpha =  0.4455777554334586 private_alpha =  0.492
# amt_pos =  1160.030662666605
# amt_Q1 =  0.36868439467112435
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 5.3704990395551594e-05
# PRICE (BOND/BURN):  0.2873990932301972
# PRICE pbar (from bondburn update) = 0.2873990932301972
# r 5.370499102938867e-13
# PROTO RP (BOND) =  -5.7479818749629605e-09
# Agent bonds. Amt to bond =  5.370499049233875e-13
# Positive attestation. | alpha =  0.4455777554334586 private_alpha =  0.492
# amt_pos =  1115.1352522725715
# amt_Q1 =  0.35452379693183117
# r 5.370499102938867e-13
# PROTO RP (BOND) =  -5.7479818749629605e-09
# Agent bonds. Amt to bond =  5.370499049233875e-13
# Positive attestation. | alpha =  0.4455777554334586 private_alpha =  0.492
# amt_pos =  1126.024917110271
# amt_Q1 =  0.3579593268188503
# PRICE (ATTEST):  0.4506448591336682
# Positive attestation 1
# S =  35920.09323881134
# KAPPA  =  3.0399702920640315
# R =  5324.790640201233
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              1.353902          5.351097e-10   5.370499e-13
# 1  1.0              2.019396          1.646940e+00   1.928211e+03
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0     4741.895556        3.000001       12986.990973                0.492
# 1     4527.726575     3660.480104           0.000029                0.493
#
#    agent_private_price
# 0                0.492
# 1                0.493
# --------------TIMESTEP 8 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              1.353902          5.351097e-10   5.370499e-13
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0     4741.895556        3.000001       12986.990973                0.492
#
#    agent_private_price
# 0                0.492   Time  8
# agent['agent_private_price'] =  0.49099999999999994
# agent['agent_private_alpha'] =  0.49099999999999994
# r 5.370499102938867e-13
# PROTO RP (BOND) =  0.07381157689490749
# Agent bonds. Amt to bond =  5.370499049233875e-13
# Positive attestation. | alpha =  0.4776645766216961 private_alpha =  0.49099999999999994
# amt_pos =  539.7520361420776
# amt_Q1 =  0.17495424329613815
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 5.370499049233875e-13
# PRICE (BOND/BURN):  0.07381157689490749
# PRICE pbar (from bondburn update) = 0.07381157689490749
# r 5.3704991065947464e-21
# PROTO RP (BOND) =  0.4506448591336684
# Agent bonds. Amt to bond =  5.370499052889755e-21
# Positive attestation. | alpha =  0.4776645766216961 private_alpha =  0.49099999999999994
# amt_pos =  228.86280702301102
# amt_Q1 =  0.0743425832950733
# r 5.3704991065947464e-21
# PROTO RP (BOND) =  0.4506448591336684
# Agent bonds. Amt to bond =  5.370499052889755e-21
# Positive attestation. | alpha =  0.4776645766216961 private_alpha =  0.49099999999999994
# amt_pos =  429.59802509997445
# amt_Q1 =  0.13935485106447654
# PRICE (ATTEST):  0.4325314371963692
# Positive attestation 1
# S =  35920.09323881135
# KAPPA  =  2.9177803603229564
# R =  5324.790640201233
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              1.493257          5.351097e-10   5.370499e-21
# 1  1.0              2.019396          1.646940e+00   1.928211e+03
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0     5171.493582        3.000001       12557.392948                0.491
# 1     4527.726575     3660.480104           0.000029                0.493
#
#    agent_private_price
# 0                0.491
# 1                0.493
# --------------TIMESTEP 9 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              1.493257          5.351097e-10   5.370499e-21
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0     5171.493582        3.000001       12557.392948                0.491
#
#    agent_private_price
# 0                0.491   Time  9
# agent['agent_private_price'] =  0.49
# agent['agent_private_alpha'] =  0.49
# r 5.3704991065947464e-21
# PROTO RP (BOND) =  2.460385898171784e-10
# Agent bonds. Amt to bond =  5.370499052889755e-21
# Positive attestation. | alpha =  0.48894862303467934 private_alpha =  0.49
# amt_pos =  374.2745413020585
# amt_Q1 =  0.12217928250074479
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 5.370499052889755e-21
# PRICE (BOND/BURN):  2.460385898171784e-10
# PRICE pbar (from bondburn update) = 2.460385898171784e-10
# r 5.370499133810833e-29
# PROTO RP (BOND) =  0.43253143719636905
# Agent bonds. Amt to bond =  5.370499080105842e-29
# Positive attestation. | alpha =  0.48894862303467934 private_alpha =  0.49
# amt_pos =  344.3650742897356
# amt_Q1 =  0.11243877754237949
# r 5.370499133810833e-29
# PROTO RP (BOND) =  0.43253143719636905
# Agent bonds. Amt to bond =  5.370499080105842e-29
# Positive attestation. | alpha =  0.48894862303467934 private_alpha =  0.49
# amt_pos =  119.1401381552923
# amt_Q1 =  0.03896122608045723
# PRICE (ATTEST):  0.42534468424784444
# Positive attestation 1
# S =  35920.09323881137
# KAPPA  =  2.8692997995951175
# R =  5324.790640201233
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              1.532218          5.351097e-10   5.370499e-29
# 1  1.0              2.019396          1.646940e+00   1.928211e+03
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0     5290.633720        3.000001       12438.252809                0.490
# 1     4527.726575     3660.480104           0.000029                0.493
#
#    agent_private_price
# 0                0.490
# 1                0.493
# --------------TIMESTEP 10 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0              2.019396               1.64694    1928.211185
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1     4527.726575     3660.480104           0.000029                0.493
#
#    agent_private_price
# 1                0.493   Time  10
# agent['agent_private_price'] =  0.489
# agent['agent_private_alpha'] =  0.489
# r 1928.2111847470192
# PROTO RP (BOND) =  0.4720385442991205
# Agent bonds. Amt to bond =  1928.2111654649073
# Negative attestation. | alpha =  0.4919921811868317 private_alpha =  0.489
# amt_neg =  5.720064058774323e-07
# amt_Q0 =  1.7235457122876387e-10
# ::::delta R:::: 9.094947017729282e-13
# ::::AMTBOND:::: 1928.2111654649073
# PRICE (BOND/BURN):  0.4720385442991205
# PRICE pbar (from bondburn update) = 0.4720385442991205
# r 1.9282112816654262e-05
# PROTO RP (BOND) =  -9.939300171805908e-09
# Agent bonds. Amt to bond =  1.9282112623833134e-05
# Negative attestation. | alpha =  0.4919921811868317 private_alpha =  0.489
# amt_neg =  28.891108497027194
# amt_Q0 =  0.007815172631999457
# r 1.9282112816654262e-05
# PROTO RP (BOND) =  -9.939300171805908e-09
# Agent bonds. Amt to bond =  1.9282112623833134e-05
# Negative attestation. | alpha =  0.4919921811868317 private_alpha =  0.489
# amt_neg =  43.52381469631469
# amt_Q0 =  0.011772308563180497
# PRICE (ATTEST):  0.43743500036504845
# Negative attestation 1
# S =  40004.95280960744
# KAPPA  =  2.7826133436673355
# R =  6288.896222933686
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              1.532218          5.351097e-10   5.370499e-29
# 1  1.0              2.019396          1.658713e+00   1.928211e-05
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0     5290.633720        3.000001       12438.252809                0.490
# 1     4527.726575     3704.003919        4041.335785                0.489
#
#    agent_private_price
# 0                0.490
# 1                0.489
# --------------TIMESTEP 11 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0              2.019396              1.658713       0.000019
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1     4527.726575     3704.003919        4041.335785                0.489
#
#    agent_private_price
# 1                0.489   Time  11
# agent['agent_private_price'] =  0.488
# agent['agent_private_alpha'] =  0.488
# r 1.9282112816654262e-05
# PROTO RP (BOND) =  0.43743486291689326
# Agent bonds. Amt to bond =  1.9282112623833134e-05
# Negative attestation. | alpha =  0.5475057181954512 private_alpha =  0.488
# amt_neg =  328.1366591637961
# amt_Q0 =  0.0886453162555061
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 1.9282112623833134e-05
# PRICE (BOND/BURN):  0.43743486291689326
# PRICE pbar (from bondburn update) = 0.43743486291689326
# r 1.9282112798807427e-13
# PROTO RP (BOND) =  -8.748700138408469e-09
# Agent bonds. Amt to bond =  1.9282112605986297e-13
# Negative attestation. | alpha =  0.5475057181954512 private_alpha =  0.488
# amt_neg =  455.0634633640488
# amt_Q0 =  0.12283751934110723
# r 1.9282112798807427e-13
# PROTO RP (BOND) =  -8.748700138408469e-09
# Agent bonds. Amt to bond =  1.9282112605986297e-13
# Negative attestation. | alpha =  0.5475057181954512 private_alpha =  0.488
# amt_neg =  388.94542943909664
# amt_Q0 =  0.10503300222398872
# PRICE (ATTEST):  0.39958127476471106
# Negative attestation 1
# S =  40004.952853687406
# KAPPA  =  2.541818065844291
# R =  6288.8962325747425
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              1.532218          5.351097e-10   5.370499e-29
# 1  1.0              2.019396          1.763746e+00   1.928211e-13
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0     5290.633720        3.000001       12438.252809                0.490
# 1     4527.726575     4092.949348        3652.390400                0.488
#
#    agent_private_price
# 0                0.490
# 1                0.488
# --------------TIMESTEP 12 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0              2.019396              1.763746   1.928211e-13
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1     4527.726575     4092.949348          3652.3904                0.488
#
#    agent_private_price
# 1                0.488   Time  12
# agent['agent_private_price'] =  0.487
# agent['agent_private_alpha'] =  0.487
# r 1.9282112798807427e-13
# PROTO RP (BOND) =  -0.0066252834432400385
# Agent bonds. Amt to bond =  1.9282112605986297e-13
# Negative attestation. | alpha =  0.5228426524102142 private_alpha =  0.487
# amt_neg =  284.4006636587789
# amt_Q0 =  0.07722371162821623
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 1.9282112605986297e-13
# PRICE (BOND/BURN):  -0.0066252834432400385
# PRICE pbar (from bondburn update) = -0.0066252834432400385
# r 1.928211296992977e-21
# PROTO RP (BOND) =  0.3995812747647114
# Agent bonds. Amt to bond =  1.928211277710864e-21
# Negative attestation. | alpha =  0.5228426524102142 private_alpha =  0.487
# amt_neg =  214.4109577461754
# amt_Q0 =  0.058244659606653024
# r 1.928211296992977e-21
# PROTO RP (BOND) =  0.3995812747647114
# Agent bonds. Amt to bond =  1.928211277710864e-21
# Negative attestation. | alpha =  0.5228426524102142 private_alpha =  0.487
# amt_neg =  249.68066154594075
# amt_Q0 =  0.06781077897841485
# PRICE (ATTEST):  0.3999041622693751
# Negative attestation 1
# S =  40004.95285368738
# KAPPA  =  2.5438720191810007
# R =  6288.8962325747425
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              1.532218          5.351097e-10   5.370499e-29
# 1  1.0              2.019396          1.831556e+00   1.928211e-21
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0     5290.633720        3.000001       12438.252809                0.490
# 1     4527.726575     4342.630010        3402.709738                0.487
#
#    agent_private_price
# 0                0.490
# 1                0.487
# --------------TIMESTEP 13 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              1.532218          5.351097e-10   5.370499e-29
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0      5290.63372        3.000001       12438.252809                 0.49
#
#    agent_private_price
# 0                 0.49   Time  13
# agent['agent_private_price'] =  0.48599999999999993
# agent['agent_private_alpha'] =  0.48599999999999993
# r 5.370499133810833e-29
# PROTO RP (BOND) =  2.4603859106402852e-18
# Agent bonds. Amt to bond =  5.370499080105842e-29
# Negative attestation. | alpha =  0.5081484752353731 private_alpha =  0.48599999999999993
# amt_neg =  514.7644297908821
# amt_Q0 =  0.14001001049210468
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 5.370499080105842e-29
# PRICE (BOND/BURN):  2.4603859106402852e-18
# PRICE pbar (from bondburn update) = 2.4603859106402852e-18
# r 5.370499121611922e-37
# PROTO RP (BOND) =  0.39990416226937514
# Agent bonds. Amt to bond =  5.370499067906931e-37
# Negative attestation. | alpha =  0.5081484752353731 private_alpha =  0.48599999999999993
# amt_neg =  524.0086021527271
# amt_Q0 =  0.14251616523390043
# r 5.370499121611922e-37
# PROTO RP (BOND) =  0.39990416226937514
# Agent bonds. Amt to bond =  5.370499067906931e-37
# Negative attestation. | alpha =  0.5081484752353731 private_alpha =  0.48599999999999993
# amt_neg =  313.1944648100724
# amt_Q0 =  0.08529184118679711
# PRICE (ATTEST):  0.38979513011555283
# Negative attestation 1
# S =  40004.9528536874
# KAPPA  =  2.479566401827144
# R =  6288.8962325747425
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              1.532218              0.085292   5.370499e-37
# 1  1.0              2.019396              1.831556   1.928211e-21
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0     5290.633720      316.194466       12125.058345                0.486
# 1     4527.726575     4342.630010        3402.709738                0.487
#
#    agent_private_price
# 0                0.486
# 1                0.487
# --------------TIMESTEP 14 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              1.532218              0.085292   5.370499e-37
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0      5290.63372      316.194466       12125.058345                0.486
#
#    agent_private_price
# 0                0.486   Time  14
# agent['agent_private_price'] =  0.485
# agent['agent_private_alpha'] =  0.485
# r 5.370499121611922e-37
# PROTO RP (BOND) =  -3.6905788575774e-26
# Agent bonds. Amt to bond =  5.370499067906931e-37
# Negative attestation. | alpha =  0.4908444430912807 private_alpha =  0.485
# amt_neg =  326.4763292020455
# amt_Q0 =  0.0892488605614745
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 5.370499067906931e-37
# PRICE (BOND/BURN):  -3.6905788575774e-26
# PRICE pbar (from bondburn update) = -3.6905788575774e-26
# r 5.370499139821147e-45
# PROTO RP (BOND) =  0.3897951301155528
# Agent bonds. Amt to bond =  5.370499086116156e-45
# Negative attestation. | alpha =  0.4908444430912807 private_alpha =  0.485
# amt_neg =  160.91266736292232
# amt_Q0 =  0.044034038095253566
# r 5.370499139821147e-45
# PROTO RP (BOND) =  0.3897951301155528
# Agent bonds. Amt to bond =  5.370499086116156e-45
# Negative attestation. | alpha =  0.4908444430912807 private_alpha =  0.485
# amt_neg =  102.11801563799638
# amt_Q0 =  0.02795502103802231
# PRICE (ATTEST):  0.39580999814026213
# Negative attestation 1
# S =  40004.952853687384
# KAPPA  =  2.517828205305992
# R =  6288.8962325747425
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              1.532218              0.113247   5.370499e-45
# 1  1.0              2.019396              1.831556   1.928211e-21
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0     5290.633720      418.312481       12022.940329                0.485
# 1     4527.726575     4342.630010        3402.709738                0.487
#
#    agent_private_price
# 0                0.485
# 1                0.487
# --------------TIMESTEP 15 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              1.532218              0.113247   5.370499e-45
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0      5290.63372      418.312481       12022.940329                0.485
#
#    agent_private_price
# 0                0.485   Time  15
# agent['agent_private_price'] =  0.484
# agent['agent_private_alpha'] =  0.484
# r 5.370499139821147e-45
# PROTO RP (BOND) =  -3.6905788700906843e-34
# Agent bonds. Amt to bond =  5.370499086116156e-45
# Negative attestation. | alpha =  0.48545438551687825 private_alpha =  0.484
# amt_neg =  24.11227300282854
# amt_Q0 =  0.006612423453883269
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 5.370499086116156e-45
# PRICE (BOND/BURN):  -3.6905788700906843e-34
# PRICE pbar (from bondburn update) = -3.6905788700906843e-34
# r 5.370499149504916e-53
# PROTO RP (BOND) =  0.39580999814026213
# Agent bonds. Amt to bond =  5.370499095799924e-53
# Negative attestation. | alpha =  0.48545438551687825 private_alpha =  0.484
# amt_neg =  95.15464497602751
# amt_Q0 =  0.02608314193580236
# r 5.370499149504916e-53
# PROTO RP (BOND) =  0.39580999814026213
# Agent bonds. Amt to bond =  5.370499095799924e-53
# Negative attestation. | alpha =  0.48545438551687825 private_alpha =  0.484
# amt_neg =  253.32363640185477
# amt_Q0 =  0.0693709673358194
# PRICE (ATTEST):  0.38417184483500716
# Negative attestation 1
# S =  40004.95285368737
# KAPPA  =  2.4437955361280332
# R =  6288.8962325747425
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              1.532218              0.182618   5.370499e-53
# 1  1.0              2.019396              1.831556   1.928211e-21
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0     5290.633720      671.636118       11769.616693                0.484
# 1     4527.726575     4342.630010        3402.709738                0.487
#
#    agent_private_price
# 0                0.484
# 1                0.487
# --------------TIMESTEP 16 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0              2.019396              1.831556   1.928211e-21
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1     4527.726575      4342.63001        3402.709738                0.487
#
#    agent_private_price
# 1                0.487   Time  16
# agent['agent_private_price'] =  0.483
# agent['agent_private_alpha'] =  0.483
# r 1.928211296992977e-21
# PROTO RP (BOND) =  1.3250567004074455e-10
# Agent bonds. Amt to bond =  1.928211277710864e-21
# Positive attestation. | alpha =  0.472580816650911 private_alpha =  0.483
# amt_pos =  91.92834824024419
# amt_Q1 =  0.027044384472016243
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 1.928211277710864e-21
# PRICE (BOND/BURN):  1.3250567004074455e-10
# PRICE pbar (from bondburn update) = 1.3250567004074455e-10
# r 1.9282113062074925e-29
# PROTO RP (BOND) =  0.38417184483500727
# Agent bonds. Amt to bond =  1.9282112869253793e-29
# Positive attestation. | alpha =  0.472580816650911 private_alpha =  0.483
# amt_pos =  77.5443464284892
# amt_Q1 =  0.022814804982225215
# r 1.9282113062074925e-29
# PROTO RP (BOND) =  0.38417184483500727
# Agent bonds. Amt to bond =  1.9282112869253793e-29
# Positive attestation. | alpha =  0.472580816650911 private_alpha =  0.483
# amt_pos =  128.20920433526518
# amt_Q1 =  0.037709310002306984
# PRICE (ATTEST):  0.39754378509382404
# Positive attestation 1
# S =  40004.952853687384
# KAPPA  =  2.5288571780812648
# R =  6288.8962325747425
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              1.532218              0.182618   5.370499e-53
# 1  1.0              2.057105              1.831556   1.928211e-29
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0      5290.63372      671.636118       11769.616693                0.484
# 1      4655.93578     4342.630010        3274.500534                0.483
#
#    agent_private_price
# 0                0.484
# 1                0.483
# --------------TIMESTEP 17 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0              2.057105              1.831556   1.928211e-29
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1      4655.93578      4342.63001        3274.500534                0.483
#
#    agent_private_price
# 1                0.483   Time  17
# agent['agent_private_price'] =  0.482
# agent['agent_private_alpha'] =  0.482
# r 1.9282113062074925e-29
# PROTO RP (BOND) =  -2.6501134134792245e-18
# Agent bonds. Amt to bond =  1.9282112869253793e-29
# Positive attestation. | alpha =  0.4758077251488778 private_alpha =  0.482
# amt_pos =  103.5840962970765
# amt_Q1 =  0.03051995985707765
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 1.9282112869253793e-29
# PRICE (BOND/BURN):  -2.6501134134792245e-18
# PRICE pbar (from bondburn update) = -2.6501134134792245e-18
# r 1.928211321737951e-37
# PROTO RP (BOND) =  0.3975437850938239
# Agent bonds. Amt to bond =  1.9282113024558376e-37
# Positive attestation. | alpha =  0.4758077251488778 private_alpha =  0.482
# amt_pos =  109.02634776441994
# amt_Q1 =  0.03212237144422238
# r 1.928211321737951e-37
# PROTO RP (BOND) =  0.3975437850938239
# Agent bonds. Amt to bond =  1.9282113024558376e-37
# Positive attestation. | alpha =  0.4758077251488778 private_alpha =  0.482
# amt_pos =  125.1384569058878
# amt_Q1 =  0.03686576908054502
# PRICE (ATTEST):  0.3990261395776691
# Positive attestation 1
# S =  40004.95285368738
# KAPPA  =  2.5382867375851257
# R =  6288.8962325747425
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              1.532218              0.182618   5.370499e-53
# 1  1.0              2.093971              1.831556   1.928211e-37
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0     5290.633720      671.636118       11769.616693                0.484
# 1     4781.074237     4342.630010        3149.362077                0.482
#
#    agent_private_price
# 0                0.484
# 1                0.482
# --------------TIMESTEP 18 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              1.532218              0.182618   5.370499e-53
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0      5290.63372      671.636118       11769.616693                0.484
#
#    agent_private_price
# 0                0.484   Time  18
# agent['agent_private_price'] =  0.4809999999999999
# agent['agent_private_alpha'] =  0.4809999999999999
# r 5.370499149504916e-53
# PROTO RP (BOND) =  0.3990261395776689
# Agent bonds. Amt to bond =  5.370499095799924e-53
# Positive attestation. | alpha =  0.4789194926907814 private_alpha =  0.4809999999999999
# amt_pos =  387.1682600693977
# amt_Q1 =  0.11405194284086452
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 5.370499095799924e-53
# PRICE (BOND/BURN):  0.3990261395776689
# PRICE pbar (from bondburn update) = 5.370499095799923e-48
# r 5.370499218250215e-61
# PROTO RP (BOND) =  0.3990261395776689
# Agent bonds. Amt to bond =  5.3704991645452225e-61
# Positive attestation. | alpha =  0.4789194926907814 private_alpha =  0.4809999999999999
# amt_pos =  275.4866892844692
# amt_Q1 =  0.08120911830925545
# r 5.370499218250215e-61
# PROTO RP (BOND) =  0.3990261395776689
# Agent bonds. Amt to bond =  5.3704991645452225e-61
# Positive attestation. | alpha =  0.4789194926907814 private_alpha =  0.4809999999999999
# amt_pos =  194.15980489171997
# amt_Q1 =  0.05726420780111637
# PRICE (ATTEST):  0.40272379323682317
# Positive attestation 1
# S =  40004.95285368738
# KAPPA  =  2.561808267410585
# R =  6288.8962325747425
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              1.589483              0.182618   5.370499e-61
# 1  1.0              2.093971              1.831556   1.928211e-37
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0     5484.793525      671.636118       11575.456888                0.481
# 1     4781.074237     4342.630010        3149.362077                0.482
#
#    agent_private_price
# 0                0.481
# 1                0.482
# --------------TIMESTEP 19 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0              2.093971              1.831556   1.928211e-37
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1     4781.074237      4342.63001        3149.362077                0.482
#
#    agent_private_price
# 1                0.482   Time  19
# agent['agent_private_price'] =  0.48
# agent['agent_private_alpha'] =  0.48
# r 1.928211321737951e-37
# PROTO RP (BOND) =  -6.62528358706031e-27
# Agent bonds. Amt to bond =  1.9282113024558376e-37
# Negative attestation. | alpha =  0.4836751232781003 private_alpha =  0.48
# amt_neg =  39.53013101320143
# amt_Q0 =  0.01087375760671958
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 1.9282113024558376e-37
# PRICE (BOND/BURN):  -6.62528358706031e-27
# PRICE pbar (from bondburn update) = -6.62528358706031e-27
# r 1.9282113501814063e-45
# PROTO RP (BOND) =  0.40272379323682345
# Agent bonds. Amt to bond =  1.9282113308992926e-45
# Negative attestation. | alpha =  0.4836751232781003 private_alpha =  0.48
# amt_neg =  77.18845927162138
# amt_Q0 =  0.021227638005137096
# r 1.9282113501814063e-45
# PROTO RP (BOND) =  0.40272379323682345
# Agent bonds. Amt to bond =  1.9282113308992926e-45
# Negative attestation. | alpha =  0.4836751232781003 private_alpha =  0.48
# amt_neg =  66.49153248008847
# amt_Q0 =  0.01828709141165454
# PRICE (ATTEST):  0.39489949122567525
# Negative attestation 1
# S =  40004.95285368735
# KAPPA  =  2.512036284936508
# R =  6288.8962325747425
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              1.589483              0.182618   5.370499e-61
# 1  1.0              2.093971              1.849843   1.928211e-45
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0     5484.793525      671.636118       11575.456888                0.481
# 1     4781.074237     4409.121543        3092.870545                0.480
#
#    agent_private_price
# 0                0.481
# 1                0.480
# --------------TIMESTEP 20 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              1.589483              0.182618   5.370499e-61
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0     5484.793525      671.636118       11575.456888                0.481
#
#    agent_private_price
# 0                0.481   Time  20
# agent['agent_private_price'] =  0.479
# agent['agent_private_alpha'] =  0.479
# r 5.370499218250215e-61
# PROTO RP (BOND) =  7.381157847973457e-50
# Agent bonds. Amt to bond =  5.3704991645452225e-61
# Negative attestation. | alpha =  0.4804016202101968 private_alpha =  0.479
# amt_neg =  186.22379331224042
# amt_Q0 =  0.0512212169824369
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 5.3704991645452225e-61
# PRICE (BOND/BURN):  7.381157847973457e-50
# PRICE pbar (from bondburn update) = 7.381157847973457e-50
# r 5.370499246502873e-69
# PROTO RP (BOND) =  0.3948994912256751
# Agent bonds. Amt to bond =  5.37049919279788e-69
# Negative attestation. | alpha =  0.4804016202101968 private_alpha =  0.479
# amt_neg =  106.4217981652016
# amt_Q0 =  0.029286084249695338
# r 5.370499246502873e-69
# PROTO RP (BOND) =  0.3948994912256751
# Agent bonds. Amt to bond =  5.37049919279788e-69
# Negative attestation. | alpha =  0.4804016202101968 private_alpha =  0.479
# amt_neg =  30.7313739091566
# amt_Q0 =  0.00846092512632237
# PRICE (ATTEST):  0.39548987044062806
# Negative attestation 1
# S =  40004.952853687355
# KAPPA  =  2.515791807652506
# R =  6288.8962325747425
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              1.589483              0.191079   5.370499e-69
# 1  1.0              2.093971              1.849843   1.928211e-45
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0     5484.793525      702.367492       11544.725514                0.479
# 1     4781.074237     4409.121543        3092.870545                0.480
#
#    agent_private_price
# 0                0.479
# 1                0.480
# --------------TIMESTEP 21 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0              2.093971              1.849843   1.928211e-45
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1     4781.074237     4409.121543        3092.870545                 0.48
#
#    agent_private_price
# 1                 0.48   Time  21
# agent['agent_private_price'] =  0.478
# agent['agent_private_alpha'] =  0.478
# r 1.9282113501814063e-45
# PROTO RP (BOND) =  -6.625283684791277e-35
# Agent bonds. Amt to bond =  1.9282113308992926e-45
# Negative attestation. | alpha =  0.4789035825852002 private_alpha =  0.478
# amt_neg =  30.771137060844893
# amt_Q0 =  0.008475123940938
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 1.9282113308992926e-45
# PRICE (BOND/BURN):  -6.625283684791277e-35
# PRICE pbar (from bondburn update) = -6.625283684791277e-35
# r 1.928211365130025e-53
# PROTO RP (BOND) =  0.39548987044062833
# Agent bonds. Amt to bond =  1.9282113458479112e-53
# Negative attestation. | alpha =  0.4789035825852002 private_alpha =  0.478
# amt_neg =  15.765397049544825
# amt_Q0 =  0.004342583062778673
# r 1.928211365130025e-53
# PROTO RP (BOND) =  0.39548987044062833
# Agent bonds. Amt to bond =  1.9282113458479112e-53
# Negative attestation. | alpha =  0.4789035825852002 private_alpha =  0.478
# amt_neg =  68.49801185745581
# amt_Q0 =  0.018861584953318
# PRICE (ATTEST):  0.39249890577765484
# Negative attestation 1
# S =  40004.952853687326
# KAPPA  =  2.4967656708068175
# R =  6288.8962325747425
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              1.589483              0.191079   5.370499e-69
# 1  1.0              2.093971              1.868705   1.928211e-53
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0     5484.793525      702.367492       11544.725514                0.479
# 1     4781.074237     4477.619554        3024.372533                0.478
#
#    agent_private_price
# 0                0.479
# 1                0.478
# --------------TIMESTEP 22 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0              2.093971              1.868705   1.928211e-53
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1     4781.074237     4477.619554        3024.372533                0.478
#
#    agent_private_price
# 1                0.478   Time  22
# agent['agent_private_price'] =  0.477
# agent['agent_private_alpha'] =  0.477
# r 1.928211365130025e-53
# PROTO RP (BOND) =  -6.625283736154339e-43
# Agent bonds. Amt to bond =  1.9282113458479112e-53
# Positive attestation. | alpha =  0.47559795271673005 private_alpha =  0.477
# amt_pos =  56.21848646880486
# amt_Q1 =  0.016635196239242245
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 1.9282113458479112e-53
# PRICE (BOND/BURN):  -6.625283736154339e-43
# PRICE pbar (from bondburn update) = -6.625283736154339e-43
# r 1.9282113672851033e-61
# PROTO RP (BOND) =  0.392498905777655
# Agent bonds. Amt to bond =  1.9282113480029896e-61
# Positive attestation. | alpha =  0.47559795271673005 private_alpha =  0.477
# amt_pos =  89.35408827077895
# amt_Q1 =  0.0264346399432415
# r 1.9282113672851033e-61
# PROTO RP (BOND) =  0.392498905777655
# Agent bonds. Amt to bond =  1.9282113480029896e-61
# Positive attestation. | alpha =  0.47559795271673005 private_alpha =  0.477
# amt_pos =  17.792500210685677
# amt_Q1 =  0.0052661105861875265
# PRICE (ATTEST):  0.3955144676539947
# Positive attestation 1
# S =  40004.9528536873
# KAPPA  =  2.5159482755484053
# R =  6288.8962325747425
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              1.589483              0.191079   5.370499e-69
# 1  1.0              2.099237              1.868705   1.928211e-61
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0     5484.793525      702.367492       11544.725514                0.479
# 1     4798.866737     4477.619554        3006.580032                0.477
#
#    agent_private_price
# 0                0.479
# 1                0.477
# --------------TIMESTEP 23 --------------
# ...
# agent['agent_private_alpha'] =  0.40800000000000003
# r 5410.836525231999
# Agent supply too low. No bond/burn | s_free =  -2.1827872740617367e-11
# Agent supply too low. Cannot attest
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  0.9794170786335097
# PRICE pbar (from bondburn update) = 0.0
# r 5410.836525231999
# Agent supply too low. No bond/burn | s_free =  -3.637978705158802e-12
# Agent supply too low. Cannot attest
# r 5410.836525231999
# Agent supply too low. No bond/burn | s_free =  -3.637978705158802e-12
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  0.9794170786334939
# S =  19999.99999999978
# KAPPA  =  1.9588341572669665
# R =  10000
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0              0.000593    5383.053283
# 1  1.0                   0.0              0.000695    5410.836525
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        4.185793       1.618921e-11                0.409
# 1             3.0        4.390200      -3.637979e-12                0.408
#
#    agent_private_price
# 0                0.409
# 1                0.408
# --------------TIMESTEP 92 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0                   0.0              0.000695    5410.836525
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1             3.0          4.3902      -3.637979e-12                0.408
#
#    agent_private_price
# 1                0.408   Time  92
# agent['agent_private_price'] =  0.407
# agent['agent_private_alpha'] =  0.407
# r 5410.836525231999
# Agent supply too low. No bond/burn | s_free =  -3.637978705158802e-12
# Agent supply too low. Cannot attest
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  0.9794170786334935
# PRICE pbar (from bondburn update) = 0.0
# r 5410.836525231999
# PROTO RP (BURN) =  -0.27777777860978436
# Agent burns. Amt to burn =  1.3096723666302548e-11
# Negative attestation. | alpha =  0.4794170786334833 private_alpha =  0.407
# amt_neg =  1.7274106002360326e-12
# amt_Q0 =  0.0
# r 5410.836525231999
# PROTO RP (BURN) =  -0.27777777860978436
# Agent burns. Amt to burn =  1.3096723666302548e-11
# Negative attestation. | alpha =  0.4794170786334833 private_alpha =  0.407
# amt_neg =  1.388080526974292e-12
# amt_Q0 =  0.0
# PRICE (ATTEST):  0.979417078633493
# Negative attestation 1
# S =  19999.9999999998
# KAPPA  =  1.9588341572669665
# R =  10000
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0              0.000593    5383.053283
# 1  1.0                   0.0              0.000695    5410.836525
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        4.185793       1.618921e-11                0.409
# 1             3.0        4.390200       1.316383e-11                0.407
#
#    agent_private_price
# 0                0.409
# 1                0.407
# --------------TIMESTEP 93 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0              0.000593    5383.053283
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        4.185793       1.618921e-11                0.409
#
#    agent_private_price
# 0                0.409   Time  93
# agent['agent_private_price'] =  0.406
# agent['agent_private_alpha'] =  0.406
# r 5383.05328348204
# PROTO RP (BURN) =  0.898865126492864
# Agent burns. Amt to burn =  1.618920881394588e-11
# Negative attestation. | alpha =  0.47941707863347266 private_alpha =  0.406
# amt_neg =  1.8962458695366677e-12
# amt_Q0 =  0.0
# ::::delta R:::: 1.4551915228366852e-11
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  0.898865126492864
# PRICE pbar (from bondburn update) = 0.898865126492864
# r 5383.053283482054
# PROTO RP (BURN) =  0.0
# Agent burns. Amt to burn =  1.637090461390654e-11
# Negative attestation. | alpha =  0.47941707863347266 private_alpha =  0.406
# amt_neg =  2.206318259273425e-12
# amt_Q0 =  0.0
# r 5383.053283482054
# PROTO RP (BURN) =  0.0
# Agent burns. Amt to burn =  1.637090461390654e-11
# Negative attestation. | alpha =  0.47941707863347266 private_alpha =  0.406
# amt_neg =  1.5975716354814214e-12
# amt_Q0 =  0.0
# PRICE (ATTEST):  0.9794170786334816
# Negative attestation 1
# S =  19999.999999999818
# KAPPA  =  1.9588341572669454
# R =  10000
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0              0.000593    5383.053283
# 1  1.0                   0.0              0.000695    5410.836525
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        4.185793       1.659232e-11                0.406
# 1             3.0        4.390200       1.316383e-11                0.407
#
#    agent_private_price
# 0                0.406
# 1                0.407
# --------------TIMESTEP 94 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0                   0.0              0.000695    5410.836525
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1             3.0          4.3902       1.316383e-11                0.407
#
#    agent_private_price
# 1                0.407   Time  94
# agent['agent_private_price'] =  0.40499999999999997
# agent['agent_private_alpha'] =  0.40499999999999997
# r 5410.836525231999
# PROTO RP (BURN) =  1.1054465200527945
# Agent burns. Amt to burn =  1.3163834671687123e-11
# Negative attestation. | alpha =  0.47941707863346045 private_alpha =  0.40499999999999997
# amt_neg =  1.8397518468195887e-12
# amt_Q0 =  0.0
# ::::delta R:::: 1.4551915228366852e-11
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  1.1054465200527945
# PRICE pbar (from bondburn update) = 1.1054465200527945
# r 5410.836525232014
# Agent supply too low. No bond/burn | s_free =  -3.6379786754533647e-12
# Agent supply too low. Cannot attest
# r 5410.836525232014
# Agent supply too low. No bond/burn | s_free =  -3.6379786754533647e-12
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  0.9794170786334695
# S =  19999.999999999814
# KAPPA  =  1.9588341572669208
# R =  10000
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0              0.000593    5383.053283
# 1  1.0                   0.0              0.000695    5410.836525
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        4.185793       1.659232e-11                0.406
# 1             3.0        4.390200      -3.637979e-12                0.405
#
#    agent_private_price
# 0                0.406
# 1                0.405
# --------------TIMESTEP 95 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0              0.000593    5383.053283
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        4.185793       1.659232e-11                0.406
#
#    agent_private_price
# 0                0.406   Time  95
# agent['agent_private_price'] =  0.404
# agent['agent_private_alpha'] =  0.404
# r 5383.053283482054
# PROTO RP (BURN) =  1.0962837872474616
# Agent burns. Amt to burn =  1.6592322395946008e-11
# Negative attestation. | alpha =  0.47941707863346045 private_alpha =  0.404
# amt_neg =  1.5004678788061746e-12
# amt_Q0 =  0.0
# ::::delta R:::: 1.8189894035458565e-11
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  1.0962837872474616
# PRICE pbar (from bondburn update) = 1.0962837872474616
# r 5383.053283482072
# PROTO RP (BURN) =  0.0
# Agent burns. Amt to burn =  3.2741810429716332e-12
# Negative attestation. | alpha =  0.47941707863346045 private_alpha =  0.404
# amt_neg =  4.0547805828518555e-13
# amt_Q0 =  0.0
# r 5383.053283482072
# PROTO RP (BURN) =  0.0
# Agent burns. Amt to burn =  3.2741810429716332e-12
# Negative attestation. | alpha =  0.47941707863346045 private_alpha =  0.404
# amt_neg =  3.536466866734147e-13
# amt_Q0 =  0.0
# PRICE (ATTEST):  0.9794170786334693
# Negative attestation 1
# S =  19999.999999999818
# KAPPA  =  1.9588341572669208
# R =  10000
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0              0.000593    5383.053283
# 1  1.0                   0.0              0.000695    5410.836525
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        4.185793       3.284332e-12                0.404
# 1             3.0        4.390200      -3.637979e-12                0.405
#
#    agent_private_price
# 0                0.404
# 1                0.405
# --------------TIMESTEP 96 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0                   0.0              0.000695    5410.836525
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1             3.0          4.3902      -3.637979e-12                0.405
#
#    agent_private_price
# 1                0.405   Time  96
# agent['agent_private_price'] =  0.403
# agent['agent_private_alpha'] =  0.403
# r 5410.836525232014
# Agent supply too low. No bond/burn | s_free =  -3.6379786754533647e-12
# Agent supply too low. Cannot attest
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  0.979417078633469
# PRICE pbar (from bondburn update) = 0.0
# r 5410.836525232014
# PROTO RP (BURN) =  -30706847.729451288
# Agent burns. Amt to burn =  1.1847451223729768e-19
# Negative attestation. | alpha =  0.4794170786334577 private_alpha =  0.403
# amt_neg =  1.1049224129907493e-20
# amt_Q0 =  0.0
# r 5410.836525232014
# PROTO RP (BURN) =  -30706847.729451288
# Agent burns. Amt to burn =  1.1847451223729768e-19
# Negative attestation. | alpha =  0.4794170786334577 private_alpha =  0.403
# amt_neg =  1.2857095719220239e-20
# amt_Q0 =  0.0
# PRICE (ATTEST):  0.9794170786334665
# Negative attestation 1
# S =  19999.99999999982
# KAPPA  =  1.9588341572669157
# R =  10000
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0              0.000593    5383.053283
# 1  1.0                   0.0              0.000695    5410.836525
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        4.185793       3.284332e-12                0.404
# 1             3.0        4.390200       1.187813e-19                0.403
#
#    agent_private_price
# 0                0.404
# 1                0.403
# --------------TIMESTEP 97 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0                   0.0              0.000695    5410.836525
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1             3.0          4.3902       1.187813e-19                0.403
#
#    agent_private_price
# 1                0.403   Time  97
# agent['agent_private_price'] =  0.40199999999999997
# agent['agent_private_alpha'] =  0.40199999999999997
# r 5410.836525232014
# PROTO RP (BURN) =  0.0
# Agent burns. Amt to burn =  1.0690312620571332e-19
# Negative attestation. | alpha =  0.4794170786334577 private_alpha =  0.40199999999999997
# amt_neg =  1.6669385428788745e-20
# amt_Q0 =  0.0
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  0.0
# PRICE pbar (from bondburn update) = 0.0
# r 5410.836525232014
# PROTO RP (BOND) =  0.38182131595940333
# Agent bonds. Amt to bond =  1886.6420203875825
# Negative attestation. | alpha =  0.4794170786334577 private_alpha =  0.40199999999999997
# amt_neg =  4.668624359345713e-13
# amt_Q0 =  0.0
# r 5410.836525232014
# PROTO RP (BOND) =  0.38182131595940333
# Agent bonds. Amt to bond =  1886.6420203875825
# Negative attestation. | alpha =  0.4794170786334577 private_alpha =  0.40199999999999997
# amt_neg =  3.849962399054396e-13
# amt_Q0 =  0.0
# PRICE (ATTEST):  0.9794170786334663
# Negative attestation 1
# S =  19999.999999999825
# KAPPA  =  1.9588341572669157
# R =  10000
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0              0.000593    5383.053283
# 1  1.0                   0.0              0.000695    5410.836525
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        4.185793       3.284332e-12                0.404
# 1             3.0        4.390200       3.252983e-12                0.402
#
#    agent_private_price
# 0                0.404
# 1                0.402
# --------------TIMESTEP 98 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0              0.000593    5383.053283
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        4.185793       3.284332e-12                0.404
#
#    agent_private_price
# 0                0.404   Time  98
# agent['agent_private_price'] =  0.401
# agent['agent_private_alpha'] =  0.401
# r 5383.053283482072
# PROTO RP (BURN) =  1.1076768506648003
# Agent burns. Amt to burn =  3.2843322534982006e-12
# Negative attestation. | alpha =  0.47941707863345473 private_alpha =  0.401
# amt_neg =  2.9332821232226876e-13
# amt_Q0 =  0.0
# ::::delta R:::: 3.637978807091713e-12
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  1.1076768506648003
# PRICE pbar (from bondburn update) = 1.1076768506648003
# r 5383.053283482076
# PROTO RP (BURN) =  0.0
# Agent burns. Amt to burn =  3.2741809231997224e-12
# Negative attestation. | alpha =  0.47941707863345473 private_alpha =  0.401
# amt_neg =  3.628291732561602e-13
# amt_Q0 =  0.0
# r 5383.053283482076
# PROTO RP (BURN) =  0.0
# Agent burns. Amt to burn =  3.2741809231997224e-12
# Negative attestation. | alpha =  0.47941707863345473 private_alpha =  0.401
# amt_neg =  4.0649981518171155e-13
# amt_Q0 =  0.0
# PRICE (ATTEST):  0.9794170786334632
# Negative attestation 1
# S =  19999.99999999983
# KAPPA  =  1.9588341572669095
# R =  10000
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0              0.000593    5383.053283
# 1  1.0                   0.0              0.000695    5410.836525
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        4.185793       3.231479e-12                0.401
# 1             3.0        4.390200       3.252983e-12                0.402
#
#    agent_private_price
# 0                0.401
# 1                0.402
# --------------TIMESTEP 99 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0              0.000593    5383.053283
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        4.185793       3.231479e-12                0.401
#
#    agent_private_price
# 0                0.401   Time  99
# agent['agent_private_price'] =  0.39999999999999997
# agent['agent_private_alpha'] =  0.39999999999999997
# r 5383.053283482076
# PROTO RP (BURN) =  1.125793735810867
# Agent burns. Amt to burn =  3.2314789924385333e-12
# Negative attestation. | alpha =  0.4794170786334516 private_alpha =  0.39999999999999997
# amt_neg =  3.42587381016483e-13
# amt_Q0 =  0.0
# ::::delta R:::: 3.637978807091713e-12
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  1.125793735810867
# PRICE pbar (from bondburn update) = 1.125793735810867
# r 5383.05328348208
# PROTO RP (BURN) =  0.9791823023854461
# Agent burns. Amt to burn =  9.999999900021827
# Negative attestation. | alpha =  0.4794170786334516 private_alpha =  0.39999999999999997
# amt_neg =  1.1054917943666733
# amt_Q0 =  0.0005527738558769036
# r 5387.05328348208
# PROTO RP (BURN) =  0.9791823023854461
# Agent burns. Amt to burn =  9.999999900021827
# Negative attestation. | alpha =  0.4794170786334516 private_alpha =  0.39999999999999997
# amt_neg =  0.8999830251666134
# amt_Q0 =  0.0004500154297892719
# PRICE (ATTEST):  0.9662808172306919
# Negative attestation 1
# S =  19999.99999999985
# KAPPA  =  1.9325616344613692
# R =  10000
# Total execution time: 9.18s

# %%
experiments = run.run()
# Out:
# config_ids =  [{'M': {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 10000, 'C': 20000, 'f': 0.03, 'm': 0.15, 'beta': 0.9, 'dust': 1e-08, 'period': 2000, 'rules_price': 'martin', 'E': 0.2, 'ENABLE_CONTINUOUS': True, 'THETA': 0.5, 'ENABLE_BURN': True, 'fee_numerator': 997, 'fee_denominator': 1000}, 'simulation_id': 0, 'run_id': 0, 'subset_id': 0}, {'M': {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 10000, 'C': 20000, 'f': 0.03, 'm': 0.15, 'beta': 0.9, 'dust': 1e-08, 'period': 2000, 'rules_price': 'martin', 'E': 0.2, 'ENABLE_CONTINUOUS': True, 'THETA': 0.5, 'ENABLE_BURN': False, 'fee_numerator': 997, 'fee_denominator': 1000}, 'simulation_id': 0, 'run_id': 1, 'subset_id': 1}, {'M': {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 10000, 'C': 20000, 'f': 0.03, 'm': 0.15, 'beta': 0.9, 'dust': 1e-08, 'period': 2000, 'rules_price': 'martin', 'E': 0.2, 'ENABLE_CONTINUOUS': False, 'THETA': 0.5, 'ENABLE_BURN': True, 'fee_numerator': 997, 'fee_denominator': 1000}, 'simulation_id': 0, 'run_id': 2, 'subset_id': 2}, {'M': {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 10000, 'C': 20000, 'f': 0.03, 'm': 0.15, 'beta': 0.9, 'dust': 1e-08, 'period': 2000, 'rules_price': 'martin', 'E': 0.2, 'ENABLE_CONTINUOUS': False, 'THETA': 0.5, 'ENABLE_BURN': False, 'fee_numerator': 997, 'fee_denominator': 1000}, 'simulation_id': 0, 'run_id': 3, 'subset_id': 3}]
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
experiments = experiments.sort_values(by =['ENABLE_CONTINUOUS']).reset_index(drop=True)

cols = 1
rows = 1
cc_idx = 0


while cc_idx<len(experiments):
    cc = experiments.iloc[cc_idx]['ENABLE_CONTINUOUS']
    cc_label = experiments.iloc[cc_idx]['ENABLE_CONTINUOUS']
#     secondary_label = experiments.iloc[cc_idx]['string']
    sub_experiments = experiments[experiments['ENABLE_CONTINUOUS']==cc]
    cc_idx += len(sub_experiments)
    fig, axs = plt.subplots(ncols=cols, nrows=rows, figsize=(15*cols,7*rows))
    sub_experiments.reset_index(drop=False)
    for i, experiment in sub_experiments.iterrows():
        df = experiment['dataset'].copy()
        # filter out starting point
        df = df[df.timestep > 0] 
        # FIRST RUN ONLY
        df = df[df.run == 1]  
           
        plot_label = experiment['ENABLE_CONTINUOUS']
        ax = axs
        title = 'ENABLE_CONTINUOUS TEST: Reserve Funds vs. Funds to Project' + '\n' + 'Scenario: ' + str(cc_label)  + ' ENABLE_CONTINUOUS'
        # + 'Scenario: ' + str(cc_label)  + ' rules_price'
        ax.set_title(title)
        ax.set_ylabel('Funds')
        colors = ['b','orange', 'g', 'magenta', 'r', 'k' ]
        
        df.plot(x='timestep', y='funds_from_bond', label='funds_from_bond', ax=ax, legend=True)
        df.plot(x='timestep', y='reserve', label='reserve', ax=ax, legend=True, color = colors[5])

        ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

        ax.set_xlabel('Timesteps')
        ax.grid(color='0.9', linestyle='-', linewidth=1)

        plt.tight_layout()
        
fig.tight_layout(rect=[0, 0, 1, .97])
fig.patch.set_alpha(1)
display(fig)
plt.close()

# %% [markdown]
# ## Burn not allowed, secondary trading allowed

# %% [markdown]
# ENABLE_BURN = False <br/>
# ENABLE_CONTINUOUS = True <br/>

# %%
# import sys
# sys.path.append('../')
import pandas as pd

import matplotlib.pyplot as plt
# import run2

from src.sim import run

import seaborn as sns

# For analysis
import numpy as np
import pandas as pd

sns.set_style("whitegrid")
# Out:
# Initial Conditions (config.py) :  {'reserve': 10000, 'pbar': 1, 'realized_price': 0, 'spot_price': 1, 'kappa': 0, 'supply': 20000.0, 'alpha': [0.5], 'alpha_bar': [0.5], 'supply_0': 30, 'supply_1': 30, 'supply_free': 20000.0, 'attestations': 40, 'attestations_0': 20, 'attestations_1': 20, 'invariant_V': 40000.0, 'invariant_I': 20000.0, 'agents':    id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0   0                     0                     0           1000
# 1   1                     0                     0           1000
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0               3               3               4994                  0.5
# 1               3               3               4994                  0.5
#
#    agent_private_price
# 0                  0.5
# 1                  1.5  , 'chosen_agent': 0, 'public_alpha': 0, 'funds_from_bond': 0, 'UNI_supply': 20000.0, 'UNI_reserve': 10000}
# -----------------PSUB---------------------
# Params (config.py) :  {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 10000, 'C': 20000, 'f': 0.03, 'm': 0.15, 'beta': 0.9, 'dust': 1e-08, 'period': 2000, 'rules_price': 'martin', 'E': 0.2, 'ENABLE_CONTINUOUS': True, 'THETA': 0.5, 'ENABLE_BURN': False, 'fee_numerator': 997, 'fee_denominator': 1000}
#
#                   ___________    ____
#   ________ __ ___/ / ____/   |  / __ \
#  / ___/ __` / __  / /   / /| | / / / /
# / /__/ /_/ / /_/ / /___/ ___ |/ /_/ /
# \___/\__,_/\__,_/\____/_/  |_/_____/
# by cadCAD
#
# Execution Mode: multi_proc
# Configuration Count: 1
# Dimensions of the first simulation: (Timesteps, Params, Runs, Vars) = (100, 16, 1, 22)
# Execution Method: single_proc_exec
# Execution Mode: single_threaded
#    id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0   0                     0                     0           1000
# 1   1                     0                     0           1000
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0               3               3               4994                  0.5
# 1               3               3               4994                  0.5
#
#    agent_private_price
# 0                  0.5
# 1                  1.5
# --------------TIMESTEP 0 --------------
# CHOSEN AGENT =     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1   1                     0                     0           1000
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1               3               3               4994                  0.5
#
#    agent_private_price
# 1                  1.5   Time  0
# agent['agent_private_price'] =  0.499
# agent['agent_private_alpha'] =  0.499
# r 1000
# PROTO RP (BURN) =  0.8751500012484998
# Agent burns. Amt to burn =  4993.99995006
# Negative attestation. | alpha =  0.5 private_alpha =  0.499
# amt_neg =  106.40110705319516
# amt_Q0 =  0.053129983647539625
# ::::delta R:::: 4370.499062530017
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  0.8751500012484998
# PRICE pbar (from bondburn update) = 0.8751500012484998
# r 5370.499062530017
# PROTO RP (BURN) =  1.0000000282117485
# Agent burns. Amt to burn =  4.993999978151249e-05
# Negative attestation. | alpha =  0.5 private_alpha =  0.499
# amt_neg =  8.765659974860071e-07
# amt_Q0 =  4.382805229852238e-10
# r 5370.499062530017
# PROTO RP (BURN) =  1.0000000282117485
# Agent burns. Amt to burn =  4.993999978151249e-05
# Negative attestation. | alpha =  0.5 private_alpha =  0.499
# amt_neg =  9.988870430610685e-08
# amt_Q0 =  4.994227253973804e-11
# PRICE (ATTEST):  0.9999999983351884
# Negative attestation 1
# S =  20000.0
# KAPPA  =  1.9999999966703768
# R =  10000.0
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          0.000000e+00    1000.000000
# 1  1.0                   0.0          4.994227e-11    5370.499063
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0             3.0         4994.00000                0.500
# 1             3.0             3.0            0.00005                0.499
#
#    agent_private_price
# 0                0.500
# 1                0.499
# --------------TIMESTEP 1 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0                   0.0          4.994227e-11    5370.499063
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1             3.0             3.0            0.00005                0.499
#
#    agent_private_price
# 1                0.499   Time  1
# agent['agent_private_price'] =  0.498
# agent['agent_private_alpha'] =  0.498
# r 5370.499062530017
# PROTO RP (BURN) =  0.9999999697054609
# Agent burns. Amt to burn =  4.984011107820527e-05
# Negative attestation. | alpha =  0.4999999991675942 private_alpha =  0.498
# amt_neg =  1.2917360600497054e-06
# amt_Q0 =  6.4586558323915e-10
# ::::delta R:::: 4.984010956832208e-05
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  0.9999999697054609
# PRICE pbar (from bondburn update) = 0.9999999697054609
# r 5370.499112370127
# PROTO RP (BURN) =  0.0
# Agent burns. Amt to burn =  4.4856100196825353e-13
# Negative attestation. | alpha =  0.4999999991675942 private_alpha =  0.498
# amt_neg =  1.4891896543641287e-14
# amt_Q0 =  0.0
# r 5370.499112370127
# PROTO RP (BURN) =  0.0
# Agent burns. Amt to burn =  4.4856100196825353e-13
# Negative attestation. | alpha =  0.4999999991675942 private_alpha =  0.498
# amt_neg =  1.0600191539091491e-14
# amt_Q0 =  0.0
# PRICE (ATTEST):  0.9999999991675943
# Negative attestation 1
# S =  20000.0
# KAPPA  =  1.9999999983351886
# R =  10000.0
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          0.000000e+00    1000.000000
# 1  1.0                   0.0          4.994227e-11    5370.499112
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0             3.0       4.994000e+03                0.500
# 1             3.0             3.0       4.878009e-13                0.498
#
#    agent_private_price
# 0                0.500
# 1                0.498
# --------------TIMESTEP 2 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0                   0.0         1000.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0             3.0             4994.0                  0.5
#
#    agent_private_price
# 0                  0.5   Time  2
# agent['agent_private_price'] =  0.497
# agent['agent_private_alpha'] =  0.497
# r 1000.0
# PROTO RP (BURN) =  0.875150000709368
# Agent burns. Amt to burn =  4993.99995006
# Negative attestation. | alpha =  0.49999999916759397 private_alpha =  0.497
# amt_neg =  84.83451511332662
# amt_Q0 =  0.04237237210881795
# ::::delta R:::: 4370.4990598375925
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  0.875150000709368
# PRICE pbar (from bondburn update) = 0.875150000709368
# r 5370.4990598375925
# PROTO RP (BURN) =  1.0000000282117485
# Agent burns. Amt to burn =  4.993999978151249e-05
# Negative attestation. | alpha =  0.49999999916759397 private_alpha =  0.497
# amt_neg =  1.7179172199741186e-06
# amt_Q0 =  8.589573496941361e-10
# r 5370.4990598375925
# PROTO RP (BURN) =  1.0000000282117485
# Agent burns. Amt to burn =  4.993999978151249e-05
# Negative attestation. | alpha =  0.49999999916759397 private_alpha =  0.497
# amt_neg =  5.164695503720751e-07
# amt_Q0 =  2.5823343463635775e-10
# PRICE (ATTEST):  0.9999999905597683
# Negative attestation 1
# S =  20000.0
# KAPPA  =  1.9999999811195366
# R =  10000.0
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          2.582334e-10    5370.499060
# 1  1.0                   0.0          4.994227e-11    5370.499112
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        3.000001       4.942353e-05                0.497
# 1             3.0        3.000000       4.878009e-13                0.498
#
#    agent_private_price
# 0                0.497
# 1                0.498
# --------------TIMESTEP 3 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0                   0.0          4.994227e-11    5370.499112
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1             3.0             3.0       4.878009e-13                0.498
#
#    agent_private_price
# 1                0.498   Time  3
# agent['agent_private_price'] =  0.49599999999999994
# agent['agent_private_alpha'] =  0.49599999999999994
# r 5370.499112370127
# PROTO RP (BURN) =  0.0
# Agent burns. Amt to burn =  4.3902082967847286e-13
# Negative attestation. | alpha =  0.4999999948636812 private_alpha =  0.49599999999999994
# amt_neg =  9.433680969409106e-15
# amt_Q0 =  0.0
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  0.0
# PRICE pbar (from bondburn update) = 0.0
# r 5370.499112370127
# PROTO RP (BOND) =  0.482075524442939
# Agent bonds. Amt to bond =  2311.823746091207
# Agent supply too low. Cannot attest
# r 5370.499112370127
# PROTO RP (BOND) =  0.482075524442939
# Agent bonds. Amt to bond =  2311.823746091207
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  0.9999999948636821
# S =  19999.99999999998
# KAPPA  =  1.9999999897273624
# R =  10000.0
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          2.582334e-10    5370.499060
# 1  1.0                   0.0          4.994227e-11    5370.499112
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        3.000001       4.942353e-05                0.497
# 1             3.0        3.000000      -1.814111e-11                0.496
#
#    agent_private_price
# 0                0.497
# 1                0.496
# --------------TIMESTEP 4 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          2.582334e-10     5370.49906
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        3.000001           0.000049                0.497
#
#    agent_private_price
# 0                0.497   Time  4
# agent['agent_private_price'] =  0.495
# agent['agent_private_alpha'] =  0.495
# r 5370.4990598375925
# PROTO RP (BURN) =  1.0000000334815116
# Agent burns. Amt to burn =  4.942353023630512e-05
# Negative attestation. | alpha =  0.4999999948636812 private_alpha =  0.495
# amt_neg =  1.0613594044622016e-06
# amt_Q0 =  5.306777239948049e-10
# ::::delta R:::: 4.942353189107962e-05
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  1.0000000334815116
# PRICE pbar (from bondburn update) = 1.0000000334815116
# r 5370.499109261124
# PROTO RP (BURN) =  0.0
# Agent burns. Amt to burn =  1.6815716241498713e-11
# Negative attestation. | alpha =  0.4999999948636812 private_alpha =  0.495
# amt_neg =  2.860951089352775e-13
# amt_Q0 =  0.0
# r 5370.499109261124
# PROTO RP (BURN) =  0.0
# Agent burns. Amt to burn =  1.6815716241498713e-11
# Negative attestation. | alpha =  0.4999999948636812 private_alpha =  0.495
# amt_neg =  6.764488652364553e-13
# amt_Q0 =  0.0
# PRICE (ATTEST):  0.9999999948636812
# Negative attestation 1
# S =  20000.0
# KAPPA  =  1.9999999897273624
# R =  10000.0
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          2.582334e-10    5370.499109
# 1  1.0                   0.0          4.994227e-11    5370.499112
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        3.000001       1.800768e-11                0.495
# 1             3.0        3.000000      -1.814111e-11                0.496
#
#    agent_private_price
# 0                0.495
# 1                0.496
# --------------TIMESTEP 5 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          2.582334e-10    5370.499109
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        3.000001       1.800768e-11                0.495
#
#    agent_private_price
# 0                0.495   Time  5
# agent['agent_private_price'] =  0.494
# agent['agent_private_alpha'] =  0.494
# r 5370.499109261124
# PROTO RP (BURN) =  1.0101186679065155
# Agent burns. Amt to burn =  1.8007680298748824e-11
# Negative attestation. | alpha =  0.4999999948636755 private_alpha =  0.494
# amt_neg =  4.5023641585542797e-13
# amt_Q0 =  0.0
# ::::delta R:::: 1.8189894035458565e-11
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  1.0101186679065155
# PRICE pbar (from bondburn update) = 1.0101186679065155
# r 5370.499109261143
# PROTO RP (BURN) =  0.0
# Agent burns. Amt to burn =  1.6370904630272787e-11
# Negative attestation. | alpha =  0.4999999948636755 private_alpha =  0.494
# amt_neg =  3.928748168595897e-13
# amt_Q0 =  0.0
# r 5370.499109261143
# PROTO RP (BURN) =  0.0
# Agent burns. Amt to burn =  1.6370904630272787e-11
# Negative attestation. | alpha =  0.4999999948636755 private_alpha =  0.494
# amt_neg =  5.94283304606341e-13
# amt_Q0 =  0.0
# PRICE (ATTEST):  0.9999999948636745
# Negative attestation 1
# S =  20000.00000000002
# KAPPA  =  1.9999999897273508
# R =  10000.0
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          2.582334e-10    5370.499109
# 1  1.0                   0.0          4.994227e-11    5370.499112
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        3.000001       1.759561e-11                0.494
# 1             3.0        3.000000      -1.814111e-11                0.496
#
#    agent_private_price
# 0                0.494
# 1                0.496
# --------------TIMESTEP 6 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0                   0.0          4.994227e-11    5370.499112
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1             3.0             3.0      -1.814111e-11                0.496
#
#    agent_private_price
# 1                0.496   Time  6
# agent['agent_private_price'] =  0.493
# agent['agent_private_alpha'] =  0.493
# r 5370.499112370127
# Agent supply too low. No bond/burn | s_free =  -1.8141113938394058e-11
# Agent supply too low. Cannot attest
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  0.9999999948636741
# PRICE pbar (from bondburn update) = 0.0
# r 5370.499112370127
# PROTO RP (BURN) =  -414.3286871306289
# Agent burns. Amt to burn =  4.390208691903509e-14
# Negative attestation. | alpha =  0.4999999948636706 private_alpha =  0.493
# amt_neg =  1.4977448320821294e-15
# amt_Q0 =  0.0
# r 5370.499112370127
# PROTO RP (BURN) =  -414.3286871306289
# Agent burns. Amt to burn =  4.390208691903509e-14
# Negative attestation. | alpha =  0.4999999948636706 private_alpha =  0.493
# amt_neg =  1.0211585067107767e-15
# amt_Q0 =  0.0
# PRICE (ATTEST):  0.9999999948636689
# Negative attestation 1
# S =  20000.000000000036
# KAPPA  =  1.9999999897273413
# R =  10000.0
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          2.582334e-10    5370.499109
# 1  1.0                   0.0          4.994227e-11    5370.499112
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        3.000001       1.759561e-11                0.494
# 1             3.0        3.000000       4.775894e-14                0.493
#
#    agent_private_price
# 0                0.494
# 1                0.493
# --------------TIMESTEP 7 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0                   0.0          4.994227e-11    5370.499112
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1             3.0             3.0       4.775894e-14                0.493
#
#    agent_private_price
# 1                0.493   Time  7
# agent['agent_private_price'] =  0.492
# agent['agent_private_alpha'] =  0.492
# r 5370.499112370127
# PROTO RP (BURN) =  0.0
# Agent burns. Amt to burn =  4.298304427218582e-14
# Negative attestation. | alpha =  0.4999999948636706 private_alpha =  0.492
# amt_neg =  4.537844194960609e-16
# amt_Q0 =  0.0
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  0.0
# PRICE pbar (from bondburn update) = 0.0
# r 5370.499112370127
# PROTO RP (BOND) =  0.48207552674869675
# Agent bonds. Amt to bond =  2311.823746091207
# Agent supply too low. Cannot attest
# r 5370.499112370127
# PROTO RP (BOND) =  0.48207552674869675
# Agent bonds. Amt to bond =  2311.823746091207
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  0.9999999948636692
# S =  20000.00000000003
# KAPPA  =  1.9999999897273413
# R =  10000.0
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          2.582334e-10    5370.499109
# 1  1.0                   0.0          4.994227e-11    5370.499112
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        3.000001       1.759561e-11                0.494
# 1             3.0        3.000000      -7.271182e-12                0.492
#
#    agent_private_price
# 0                0.494
# 1                0.492
# --------------TIMESTEP 8 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          2.582334e-10    5370.499109
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        3.000001       1.759561e-11                0.494
#
#    agent_private_price
# 0                0.494   Time  8
# agent['agent_private_price'] =  0.49099999999999994
# agent['agent_private_alpha'] =  0.49099999999999994
# r 5370.499109261143
# PROTO RP (BURN) =  1.0337745196479284
# Agent burns. Amt to burn =  1.759561073497292e-11
# Negative attestation. | alpha =  0.4999999948636706 private_alpha =  0.49099999999999994
# amt_neg =  7.023589069995996e-13
# amt_Q0 =  0.0
# ::::delta R:::: 1.8189894035458565e-11
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  1.0337745196479284
# PRICE pbar (from bondburn update) = 1.0337745196479284
# r 5370.499109261161
# Agent supply too low. No bond/burn | s_free =  -7.275957438227317e-12
# Agent supply too low. Cannot attest
# r 5370.499109261161
# Agent supply too low. No bond/burn | s_free =  -7.275957438227317e-12
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  0.9999999948636695
# S =  20000.000000000022
# KAPPA  =  1.9999999897273413
# R =  10000.0
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          2.582334e-10    5370.499109
# 1  1.0                   0.0          4.994227e-11    5370.499112
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        3.000001      -7.275957e-12                0.491
# 1             3.0        3.000000      -7.271182e-12                0.492
#
#    agent_private_price
# 0                0.491
# 1                0.492
# --------------TIMESTEP 9 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          2.582334e-10    5370.499109
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        3.000001      -7.275957e-12                0.491
#
#    agent_private_price
# 0                0.491   Time  9
# agent['agent_private_price'] =  0.49
# agent['agent_private_alpha'] =  0.49
# r 5370.499109261161
# Agent supply too low. No bond/burn | s_free =  -7.275957438227317e-12
# Agent supply too low. Cannot attest
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  0.9999999948636697
# PRICE pbar (from bondburn update) = -0.0
# r 5370.499109261161
# Agent supply too low. No bond/burn | s_free =  -1.091393624531903e-11
# Agent supply too low. Cannot attest
# r 5370.499109261161
# Agent supply too low. No bond/burn | s_free =  -1.091393624531903e-11
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  0.9999999948636697
# S =  20000.00000000002
# KAPPA  =  1.9999999897273413
# R =  10000.0
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          2.582334e-10    5370.499109
# 1  1.0                   0.0          4.994227e-11    5370.499112
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        3.000001      -1.091394e-11                0.490
# 1             3.0        3.000000      -7.271182e-12                0.492
#
#    agent_private_price
# 0                0.490
# 1                0.492
# --------------TIMESTEP 10 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          2.582334e-10    5370.499109
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        3.000001      -1.091394e-11                 0.49
#
#    agent_private_price
# 0                 0.49   Time  10
# agent['agent_private_price'] =  0.489
# agent['agent_private_alpha'] =  0.489
# r 5370.499109261161
# Agent supply too low. No bond/burn | s_free =  -1.091393624531903e-11
# Agent supply too low. Cannot attest
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  0.99999999486367
# PRICE pbar (from bondburn update) = -0.0
# r 5370.499109261161
# Agent supply too low. No bond/burn | s_free =  -1.4551915052410743e-11
# Agent supply too low. Cannot attest
# r 5370.499109261161
# Agent supply too low. No bond/burn | s_free =  -1.4551915052410743e-11
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  0.9999999948636699
# S =  20000.000000000015
# KAPPA  =  1.9999999897273413
# R =  10000.0
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          2.582334e-10    5370.499109
# 1  1.0                   0.0          4.994227e-11    5370.499112
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        3.000001      -1.455192e-11                0.489
# 1             3.0        3.000000      -7.271182e-12                0.492
#
#    agent_private_price
# 0                0.489
# 1                0.492
# --------------TIMESTEP 11 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0                   0.0          4.994227e-11    5370.499112
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1             3.0             3.0      -7.271182e-12                0.492
#
#    agent_private_price
# 1                0.492   Time  11
# agent['agent_private_price'] =  0.488
# agent['agent_private_alpha'] =  0.488
# r 5370.499112370127
# Agent supply too low. No bond/burn | s_free =  -7.271181719897816e-12
# Agent supply too low. Cannot attest
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  0.9999999948636702
# PRICE pbar (from bondburn update) = -0.0
# r 5370.499112370127
# Agent supply too low. No bond/burn | s_free =  -1.0909160526989528e-11
# Agent supply too low. Cannot attest
# r 5370.499112370127
# Agent supply too low. No bond/burn | s_free =  -1.0909160526989528e-11
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  0.9999999948636701
# S =  20000.00000000001
# KAPPA  =  1.9999999897273413
# R =  10000.0
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          2.582334e-10    5370.499109
# 1  1.0                   0.0          4.994227e-11    5370.499112
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        3.000001      -1.455192e-11                0.489
# 1             3.0        3.000000      -1.090916e-11                0.488
#
#    agent_private_price
# 0                0.489
# 1                0.488
# --------------TIMESTEP 12 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          2.582334e-10    5370.499109
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        3.000001      -1.455192e-11                0.489
#
#    agent_private_price
# 0                0.489   Time  12
# agent['agent_private_price'] =  0.487
# agent['agent_private_alpha'] =  0.487
# r 5370.499109261161
# Agent supply too low. No bond/burn | s_free =  -1.4551915052410743e-11
# Agent supply too low. Cannot attest
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  0.9999999948636705
# PRICE pbar (from bondburn update) = -0.0
# r 5370.499109261161
# Agent supply too low. No bond/burn | s_free =  -2.182787266659417e-11
# Agent supply too low. Cannot attest
# r 5370.499109261161
# Agent supply too low. No bond/burn | s_free =  -2.182787266659417e-11
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  0.9999999948636704
# S =  20000.000000000004
# KAPPA  =  1.9999999897273413
# R =  10000.0
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          2.582334e-10    5370.499109
# 1  1.0                   0.0          4.994227e-11    5370.499112
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        3.000001      -2.182787e-11                0.487
# 1             3.0        3.000000      -1.090916e-11                0.488
#
#    agent_private_price
# 0                0.487
# 1                0.488
# --------------TIMESTEP 13 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          2.582334e-10    5370.499109
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        3.000001      -2.182787e-11                0.487
#
#    agent_private_price
# 0                0.487   Time  13
# agent['agent_private_price'] =  0.48599999999999993
# agent['agent_private_alpha'] =  0.48599999999999993
# r 5370.499109261161
# Agent supply too low. No bond/burn | s_free =  -2.182787266659417e-11
# Agent supply too low. Cannot attest
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  0.9999999948636709
# PRICE pbar (from bondburn update) = -0.0
# r 5370.499109261161
# Agent supply too low. No bond/burn | s_free =  -2.9103830280777595e-11
# Agent supply too low. Cannot attest
# r 5370.499109261161
# Agent supply too low. No bond/burn | s_free =  -2.9103830280777595e-11
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  0.9999999948636709
# S =  19999.999999999996
# KAPPA  =  1.9999999897273413
# R =  10000.0
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          2.582334e-10    5370.499109
# 1  1.0                   0.0          4.994227e-11    5370.499112
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        3.000001      -2.910383e-11                0.486
# 1             3.0        3.000000      -1.090916e-11                0.488
#
#    agent_private_price
# 0                0.486
# 1                0.488
# --------------TIMESTEP 14 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0                   0.0          4.994227e-11    5370.499112
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1             3.0             3.0      -1.090916e-11                0.488
#
#    agent_private_price
# 1                0.488   Time  14
# agent['agent_private_price'] =  0.485
# agent['agent_private_alpha'] =  0.485
# r 5370.499112370127
# Agent supply too low. No bond/burn | s_free =  -1.0909160526989528e-11
# Agent supply too low. Cannot attest
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  0.9999999948636711
# PRICE pbar (from bondburn update) = -0.0
# r 5370.499112370127
# Agent supply too low. No bond/burn | s_free =  -1.4547139334081241e-11
# Agent supply too low. Cannot attest
# r 5370.499112370127
# Agent supply too low. No bond/burn | s_free =  -1.4547139334081241e-11
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  0.9999999948636711
# S =  19999.999999999993
# KAPPA  =  1.9999999897273413
# R =  10000.0
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          2.582334e-10    5370.499109
# 1  1.0                   0.0          4.994227e-11    5370.499112
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        3.000001      -2.910383e-11                0.486
# 1             3.0        3.000000      -1.454714e-11                0.485
#
#    agent_private_price
# 0                0.486
# 1                0.485
# --------------TIMESTEP 15 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0                   0.0          4.994227e-11    5370.499112
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1             3.0             3.0      -1.454714e-11                0.485
#
#    agent_private_price
# 1                0.485   Time  15
# agent['agent_private_price'] =  0.484
# agent['agent_private_alpha'] =  0.484
# r 5370.499112370127
# Agent supply too low. No bond/burn | s_free =  -1.4547139334081241e-11
# Agent supply too low. Cannot attest
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  0.9999999948636713
# PRICE pbar (from bondburn update) = -0.0
# r 5370.499112370127
# Agent supply too low. No bond/burn | s_free =  -1.8185118141172954e-11
# Agent supply too low. Cannot attest
# r 5370.499112370127
# Agent supply too low. No bond/burn | s_free =  -1.8185118141172954e-11
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  0.9999999948636711
# S =  19999.99999999999
# KAPPA  =  1.9999999897273413
# R =  10000.0
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          2.582334e-10    5370.499109
# 1  1.0                   0.0          4.994227e-11    5370.499112
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        3.000001      -2.910383e-11                0.486
# 1             3.0        3.000000      -1.818512e-11                0.484
#
#    agent_private_price
# 0                0.486
# 1                0.484
# --------------TIMESTEP 16 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0                   0.0          4.994227e-11    5370.499112
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1             3.0             3.0      -1.818512e-11                0.484
#
#    agent_private_price
# 1                0.484   Time  16
# agent['agent_private_price'] =  0.483
# agent['agent_private_alpha'] =  0.483
# r 5370.499112370127
# Agent supply too low. No bond/burn | s_free =  -1.8185118141172954e-11
# Agent supply too low. Cannot attest
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  0.9999999948636715
# PRICE pbar (from bondburn update) = -0.0
# r 5370.499112370127
# Agent supply too low. No bond/burn | s_free =  -2.1823096948264667e-11
# Agent supply too low. Cannot attest
# r 5370.499112370127
# Agent supply too low. No bond/burn | s_free =  -2.1823096948264667e-11
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  0.9999999948636713
# S =  19999.999999999985
# KAPPA  =  1.9999999897273413
# R =  10000.0
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          2.582334e-10    5370.499109
# 1  1.0                   0.0          4.994227e-11    5370.499112
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        3.000001      -2.910383e-11                0.486
# 1             3.0        3.000000      -2.182310e-11                0.483
#
#    agent_private_price
# 0                0.486
# 1                0.483
# --------------TIMESTEP 17 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          2.582334e-10    5370.499109
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        3.000001      -2.910383e-11                0.486
#
#    agent_private_price
# 0                0.486   Time  17
# agent['agent_private_price'] =  0.482
# agent['agent_private_alpha'] =  0.482
# r 5370.499109261161
# Agent supply too low. No bond/burn | s_free =  -2.9103830280777595e-11
# Agent supply too low. Cannot attest
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  0.9999999948636717
# PRICE pbar (from bondburn update) = -0.0
# r 5370.499109261161
# Agent supply too low. No bond/burn | s_free =  -3.637978789496102e-11
# Agent supply too low. Cannot attest
# r 5370.499109261161
# Agent supply too low. No bond/burn | s_free =  -3.637978789496102e-11
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  0.9999999948636717
# S =  19999.999999999978
# KAPPA  =  1.9999999897273413
# R =  10000.0
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          2.582334e-10    5370.499109
# 1  1.0                   0.0          4.994227e-11    5370.499112
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        3.000001      -3.637979e-11                0.482
# 1             3.0        3.000000      -2.182310e-11                0.483
#
#    agent_private_price
# 0                0.482
# 1                0.483
# --------------TIMESTEP 18 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0                   0.0          4.994227e-11    5370.499112
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1             3.0             3.0      -2.182310e-11                0.483
#
#    agent_private_price
# 1                0.483   Time  18
# agent['agent_private_price'] =  0.4809999999999999
# agent['agent_private_alpha'] =  0.4809999999999999
# r 5370.499112370127
# Agent supply too low. No bond/burn | s_free =  -2.1823096948264667e-11
# Agent supply too low. Cannot attest
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  0.999999994863672
# PRICE pbar (from bondburn update) = -0.0
# r 5370.499112370127
# Agent supply too low. No bond/burn | s_free =  -2.9099054562448093e-11
# Agent supply too low. Cannot attest
# r 5370.499112370127
# Agent supply too low. No bond/burn | s_free =  -2.9099054562448093e-11
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  0.9999999948636722
# S =  19999.99999999997
# KAPPA  =  1.9999999897273413
# R =  10000.0
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          2.582334e-10    5370.499109
# 1  1.0                   0.0          4.994227e-11    5370.499112
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        3.000001      -3.637979e-11                0.482
# 1             3.0        3.000000      -2.909905e-11                0.481
#
#    agent_private_price
# 0                0.482
# 1                0.481
# --------------TIMESTEP 19 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0                   0.0          4.994227e-11    5370.499112
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1             3.0             3.0      -2.909905e-11                0.481
#
#    agent_private_price
# 1                0.481   Time  19
# agent['agent_private_price'] =  0.48
# agent['agent_private_alpha'] =  0.48
# r 5370.499112370127
# Agent supply too low. No bond/burn | s_free =  -2.9099054562448093e-11
# Agent supply too low. Cannot attest
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  0.9999999948636724
# PRICE pbar (from bondburn update) = -0.0
# r 5370.499112370127
# PROTO RP (BURN) =  0.9997499948705499
# Agent burns. Amt to burn =  9.999999899963624
# Negative attestation. | alpha =  0.4999999948636706 private_alpha =  0.48
# amt_neg =  0.3522971230689999
# amt_Q0 =  0.00017614778583579488
# r 5374.499112370127
# PROTO RP (BURN) =  0.9997499948705499
# Agent burns. Amt to burn =  9.999999899963624
# Negative attestation. | alpha =  0.4999999948636706 private_alpha =  0.48
# amt_neg =  0.23623214702183734
# amt_Q0 =  0.00011811572473168145
# PRICE (ATTEST):  0.9960935534156311
# Negative attestation 1
# S =  19999.999999999964
# KAPPA  =  1.9921871068312587
# R =  10000.0
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          2.582334e-10    5370.499109
# 1  1.0                   0.0          1.181158e-04    5374.499112
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        3.000001      -3.637979e-11                0.482
# 1             3.0        3.236232       9.763768e+00                0.480
#
#    agent_private_price
# 0                0.482
# 1                0.480
# --------------TIMESTEP 20 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0                   0.0              0.000118    5374.499112
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1             3.0        3.236232           9.763768                 0.48
#
#    agent_private_price
# 1                 0.48   Time  20
# agent['agent_private_price'] =  0.479
# agent['agent_private_alpha'] =  0.479
# r 5374.499112370127
# PROTO RP (BURN) =  0.9958523120876689
# Agent burns. Amt to burn =  9.763767755304109
# Negative attestation. | alpha =  0.49803911406354595 private_alpha =  0.479
# amt_neg =  0.578459820456782
# amt_Q0 =  0.00028922952703029533
# ::::delta R:::: 9.723270693806626
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  0.9958523120876689
# PRICE pbar (from bondburn update) = 0.9958523120876689
# r 5384.222383063933
# PROTO RP (BURN) =  0.9960341703478821
# Agent burns. Amt to burn =  9.764131627734728e-08
# Negative attestation. | alpha =  0.49803911406354595 private_alpha =  0.479
# amt_neg =  4.411127044842808e-09
# amt_Q0 =  2.2026954894621303e-12
# r 5384.222383063933
# PROTO RP (BURN) =  0.9960341703478821
# Agent burns. Amt to burn =  9.764131627734728e-08
# Negative attestation. | alpha =  0.49803911406354595 private_alpha =  0.479
# amt_neg =  4.0535338141094874e-09
# amt_Q0 =  2.025058756440991e-12
# PRICE (ATTEST):  0.9980391139966489
# Negative attestation 1
# S =  19999.999999999967
# KAPPA  =  1.9960782279932947
# R =  10000.0
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          2.582334e-10    5370.499109
# 1  1.0                   0.0          1.181158e-04    5384.222383
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        3.000001      -3.637979e-11                0.482
# 1             3.0        3.236232       9.358778e-08                0.479
#
#    agent_private_price
# 0                0.482
# 1                0.479
# --------------TIMESTEP 21 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0                   0.0              0.000118    5384.222383
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1             3.0        3.236232       9.358778e-08                0.479
#
#    agent_private_price
# 1                0.479   Time  21
# agent['agent_private_price'] =  0.478
# agent['agent_private_alpha'] =  0.478
# r 5384.222383063933
# PROTO RP (BURN) =  0.9980480718016153
# Agent burns. Amt to burn =  9.358778250377314e-08
# Negative attestation. | alpha =  0.4980391140300309 private_alpha =  0.478
# amt_neg =  5.23515484211194e-09
# amt_Q0 =  2.6157008937365447e-12
# ::::delta R:::: 9.340510587207973e-08
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  0.9980480718016153
# PRICE pbar (from bondburn update) = 0.9980480718016153
# r 5384.222383157338
# Agent supply too low. No bond/burn | s_free =  -1.0913000543439094e-11
# Agent supply too low. Cannot attest
# r 5384.222383157338
# Agent supply too low. No bond/burn | s_free =  -1.0913000543439094e-11
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  0.9980391140300332
# S =  19999.999999999956
# KAPPA  =  1.996078228060062
# R =  10000.0
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          2.582334e-10    5370.499109
# 1  1.0                   0.0          1.181158e-04    5384.222383
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        3.000001      -3.637979e-11                0.482
# 1             3.0        3.236232      -1.091300e-11                0.478
#
#    agent_private_price
# 0                0.482
# 1                0.478
# --------------TIMESTEP 22 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0                   0.0              0.000118    5384.222383
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1             3.0        3.236232      -1.091300e-11                0.478
#
#    agent_private_price
# 1                0.478   Time  22
# agent['agent_private_price'] =  0.477
# agent['agent_private_alpha'] =  0.477
# r 5384.222383157338
# Agent supply too low. No bond/burn | s_free =  -1.0913000543439094e-11
# Agent supply too low. Cannot attest
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  0.9980391140300336
# PRICE pbar (from bondburn update) = -0.0
# r 5384.222383157338
# Agent supply too low. No bond/burn | s_free =  -2.910289457889766e-11
# Agent supply too low. Cannot attest
# r 5384.222383157338
# Agent supply too low. No bond/burn | s_free =  -2.910289457889766e-11
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  0.9980391140300341
# S =  19999.999999999938
# KAPPA  =  1.996078228060062
# R =  10000.0
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          2.582334e-10    5370.499109
# 1  1.0                   0.0          1.181158e-04    5384.222383
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        3.000001      -3.637979e-11                0.482
# 1             3.0        3.236232      -2.910289e-11                0.477
#
#    agent_private_price
# 0                0.482
# 1                0.477
# --------------TIMESTEP 23 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0                   0.0              0.000118    5384.222383
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1             3.0        3.236232      -2.910289e-11                0.477
#
#    agent_private_price
# 1                0.477   Time  23
# agent['agent_private_price'] =  0.4759999999999999
# agent['agent_private_alpha'] =  0.4759999999999999
# r 5384.222383157338
# Agent supply too low. No bond/burn | s_free =  -2.910289457889766e-11
# Agent supply too low. Cannot attest
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  0.9980391140300343
# PRICE pbar (from bondburn update) = -0.0
# r 5384.222383157338
# Agent supply too low. No bond/burn | s_free =  -4.7292788614356223e-11
# Agent supply too low. Cannot attest
# r 5384.222383157338
# Agent supply too low. No bond/burn | s_free =  -4.7292788614356223e-11
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  0.998039114030035
# S =  19999.99999999992
# KAPPA  =  1.996078228060062
# R =  10000.0
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          2.582334e-10    5370.499109
# 1  1.0                   0.0          1.181158e-04    5384.222383
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        3.000001      -3.637979e-11                0.482
# 1             3.0        3.236232      -4.729279e-11                0.476
#
#    agent_private_price
# 0                0.482
# 1                0.476
# --------------TIMESTEP 24 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0                   0.0              0.000118    5384.222383
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1             3.0        3.236232      -4.729279e-11                0.476
#
#    agent_private_price
# 1                0.476   Time  24
# agent['agent_private_price'] =  0.475
# agent['agent_private_alpha'] =  0.475
# r 5384.222383157338
# Agent supply too low. No bond/burn | s_free =  -4.7292788614356223e-11
# Agent supply too low. Cannot attest
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  0.9980391140300352
# PRICE pbar (from bondburn update) = -0.0
# r 5384.222383157338
# Agent supply too low. No bond/burn | s_free =  -6.548268264981479e-11
# Agent supply too low. Cannot attest
# r 5384.222383157338
# Agent supply too low. No bond/burn | s_free =  -6.548268264981479e-11
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  0.9980391140300359
# S =  19999.9999999999
# KAPPA  =  1.996078228060062
# R =  10000.0
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          2.582334e-10    5370.499109
# 1  1.0                   0.0          1.181158e-04    5384.222383
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        3.000001      -3.637979e-11                0.482
# 1             3.0        3.236232      -6.548268e-11                0.475
#
#    agent_private_price
# 0                0.482
# 1                0.475
# --------------TIMESTEP 25 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          2.582334e-10    5370.499109
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        3.000001      -3.637979e-11                0.482
#
#    agent_private_price
# 0                0.482   Time  25
# agent['agent_private_price'] =  0.474
# agent['agent_private_alpha'] =  0.474
# r 5370.499109261161
# Agent supply too low. No bond/burn | s_free =  -3.637978789496102e-11
# Agent supply too low. Cannot attest
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  0.9980391140300363
# PRICE pbar (from bondburn update) = -0.0
# r 5370.499109261161
# Agent supply too low. No bond/burn | s_free =  -5.4569681930419586e-11
# Agent supply too low. Cannot attest
# r 5370.499109261161
# Agent supply too low. No bond/burn | s_free =  -5.4569681930419586e-11
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  0.9980391140300368
# S =  19999.999999999884
# KAPPA  =  1.996078228060062
# R =  10000.0
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          2.582334e-10    5370.499109
# 1  1.0                   0.0          1.181158e-04    5384.222383
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        3.000001      -5.456968e-11                0.474
# 1             3.0        3.236232      -6.548268e-11                0.475
#
#    agent_private_price
# 0                0.474
# 1                0.475
# --------------TIMESTEP 26 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0                   0.0              0.000118    5384.222383
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1             3.0        3.236232      -6.548268e-11                0.475
#
#    agent_private_price
# 1                0.475   Time  26
# agent['agent_private_price'] =  0.473
# agent['agent_private_alpha'] =  0.473
# r 5384.222383157338
# Agent supply too low. No bond/burn | s_free =  -6.548268264981479e-11
# Agent supply too low. Cannot attest
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  0.9980391140300372
# PRICE pbar (from bondburn update) = -0.0
# r 5384.222383157338
# Agent supply too low. No bond/burn | s_free =  -8.367257668527335e-11
# Agent supply too low. Cannot attest
# r 5384.222383157338
# ...
#    agent_private_price
# 0                0.410
# 1                0.413
# --------------TIMESTEP 90 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0                   0.0              0.001094     5409.82972
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1             3.0        5.187472      -1.818989e-11                0.413
#
#    agent_private_price
# 1                0.413   Time  90
# agent['agent_private_price'] =  0.40900000000000003
# agent['agent_private_alpha'] =  0.40900000000000003
# r 5409.829719947452
# Agent supply too low. No bond/burn | s_free =  -1.8189893967769076e-11
# Agent supply too low. Cannot attest
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  0.9781176438782775
# PRICE pbar (from bondburn update) = -0.0
# r 5409.829719947452
# Agent supply too low. No bond/burn | s_free =  -2.182787277486079e-11
# Agent supply too low. Cannot attest
# r 5409.829719947452
# Agent supply too low. No bond/burn | s_free =  -2.182787277486079e-11
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  0.9781176438782775
# S =  19999.999999999607
# KAPPA  =  1.9562352877565168
# R =  10000.0
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0              0.000279    5383.834392
# 1  1.0                   0.0              0.001094    5409.829720
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        3.558591      -1.382432e-10                0.410
# 1             3.0        5.187472      -2.182787e-11                0.409
#
#    agent_private_price
# 0                0.410
# 1                0.409
# --------------TIMESTEP 91 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0                   0.0              0.001094     5409.82972
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1             3.0        5.187472      -2.182787e-11                0.409
#
#    agent_private_price
# 1                0.409   Time  91
# agent['agent_private_price'] =  0.40800000000000003
# agent['agent_private_alpha'] =  0.40800000000000003
# r 5409.829719947452
# Agent supply too low. No bond/burn | s_free =  -2.182787277486079e-11
# Agent supply too low. Cannot attest
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  0.9781176438782777
# PRICE pbar (from bondburn update) = 0.0
# r 5409.829719947452
# Agent supply too low. No bond/burn | s_free =  -2.182787277486079e-11
# Agent supply too low. Cannot attest
# r 5409.829719947452
# Agent supply too low. No bond/burn | s_free =  -2.182787277486079e-11
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  0.9781176438782775
# S =  19999.999999999607
# KAPPA  =  1.9562352877565168
# R =  10000.0
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0              0.000279    5383.834392
# 1  1.0                   0.0              0.001094    5409.829720
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        3.558591      -1.382432e-10                0.410
# 1             3.0        5.187472      -2.182787e-11                0.408
#
#    agent_private_price
# 0                0.410
# 1                0.408
# --------------TIMESTEP 92 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0              0.000279    5383.834392
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        3.558591      -1.382432e-10                 0.41
#
#    agent_private_price
# 0                 0.41   Time  92
# agent['agent_private_price'] =  0.407
# agent['agent_private_alpha'] =  0.407
# r 5383.834392269521
# Agent supply too low. No bond/burn | s_free =  -1.3824319463688482e-10
# Agent supply too low. Cannot attest
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  0.9781176438782777
# PRICE pbar (from bondburn update) = 0.0
# r 5383.834392269521
# Agent supply too low. No bond/burn | s_free =  -1.3824319463688482e-10
# Agent supply too low. Cannot attest
# r 5383.834392269521
# Agent supply too low. No bond/burn | s_free =  -1.3824319463688482e-10
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  0.9781176438782775
# S =  19999.999999999607
# KAPPA  =  1.9562352877565168
# R =  10000.0
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0              0.000279    5383.834392
# 1  1.0                   0.0              0.001094    5409.829720
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        3.558591      -1.382432e-10                0.407
# 1             3.0        5.187472      -2.182787e-11                0.408
#
#    agent_private_price
# 0                0.407
# 1                0.408
# --------------TIMESTEP 93 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0              0.000279    5383.834392
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        3.558591      -1.382432e-10                0.407
#
#    agent_private_price
# 0                0.407   Time  93
# agent['agent_private_price'] =  0.406
# agent['agent_private_alpha'] =  0.406
# r 5383.834392269521
# Agent supply too low. No bond/burn | s_free =  -1.3824319463688482e-10
# Agent supply too low. Cannot attest
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  0.9781176438782777
# PRICE pbar (from bondburn update) = 0.0
# r 5383.834392269521
# Agent supply too low. No bond/burn | s_free =  -1.3824319463688482e-10
# Agent supply too low. Cannot attest
# r 5383.834392269521
# Agent supply too low. No bond/burn | s_free =  -1.3824319463688482e-10
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  0.9781176438782775
# S =  19999.999999999607
# KAPPA  =  1.9562352877565168
# R =  10000.0
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0              0.000279    5383.834392
# 1  1.0                   0.0              0.001094    5409.829720
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        3.558591      -1.382432e-10                0.406
# 1             3.0        5.187472      -2.182787e-11                0.408
#
#    agent_private_price
# 0                0.406
# 1                0.408
# --------------TIMESTEP 94 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0                   0.0              0.001094     5409.82972
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1             3.0        5.187472      -2.182787e-11                0.408
#
#    agent_private_price
# 1                0.408   Time  94
# agent['agent_private_price'] =  0.40499999999999997
# agent['agent_private_alpha'] =  0.40499999999999997
# r 5409.829719947452
# Agent supply too low. No bond/burn | s_free =  -2.182787277486079e-11
# Agent supply too low. Cannot attest
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  0.9781176438782777
# PRICE pbar (from bondburn update) = 0.0
# r 5409.829719947452
# Agent supply too low. No bond/burn | s_free =  -2.182787277486079e-11
# Agent supply too low. Cannot attest
# r 5409.829719947452
# Agent supply too low. No bond/burn | s_free =  -2.182787277486079e-11
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  0.9781176438782775
# S =  19999.999999999607
# KAPPA  =  1.9562352877565168
# R =  10000.0
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0              0.000279    5383.834392
# 1  1.0                   0.0              0.001094    5409.829720
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        3.558591      -1.382432e-10                0.406
# 1             3.0        5.187472      -2.182787e-11                0.405
#
#    agent_private_price
# 0                0.406
# 1                0.405
# --------------TIMESTEP 95 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0                   0.0              0.001094     5409.82972
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1             3.0        5.187472      -2.182787e-11                0.405
#
#    agent_private_price
# 1                0.405   Time  95
# agent['agent_private_price'] =  0.404
# agent['agent_private_alpha'] =  0.404
# r 5409.829719947452
# Agent supply too low. No bond/burn | s_free =  -2.182787277486079e-11
# Agent supply too low. Cannot attest
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  0.9781176438782777
# PRICE pbar (from bondburn update) = 0.0
# r 5409.829719947452
# Agent supply too low. No bond/burn | s_free =  -2.182787277486079e-11
# Agent supply too low. Cannot attest
# r 5409.829719947452
# Agent supply too low. No bond/burn | s_free =  -2.182787277486079e-11
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  0.9781176438782775
# S =  19999.999999999607
# KAPPA  =  1.9562352877565168
# R =  10000.0
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0              0.000279    5383.834392
# 1  1.0                   0.0              0.001094    5409.829720
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        3.558591      -1.382432e-10                0.406
# 1             3.0        5.187472      -2.182787e-11                0.404
#
#    agent_private_price
# 0                0.406
# 1                0.404
# --------------TIMESTEP 96 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0                   0.0              0.001094     5409.82972
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1             3.0        5.187472      -2.182787e-11                0.404
#
#    agent_private_price
# 1                0.404   Time  96
# agent['agent_private_price'] =  0.403
# agent['agent_private_alpha'] =  0.403
# r 5409.829719947452
# Agent supply too low. No bond/burn | s_free =  -2.182787277486079e-11
# Agent supply too low. Cannot attest
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  0.9781176438782777
# PRICE pbar (from bondburn update) = 0.0
# r 5409.829719947452
# Agent supply too low. No bond/burn | s_free =  -2.182787277486079e-11
# Agent supply too low. Cannot attest
# r 5409.829719947452
# Agent supply too low. No bond/burn | s_free =  -2.182787277486079e-11
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  0.9781176438782775
# S =  19999.999999999607
# KAPPA  =  1.9562352877565168
# R =  10000.0
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0              0.000279    5383.834392
# 1  1.0                   0.0              0.001094    5409.829720
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        3.558591      -1.382432e-10                0.406
# 1             3.0        5.187472      -2.182787e-11                0.403
#
#    agent_private_price
# 0                0.406
# 1                0.403
# --------------TIMESTEP 97 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0                   0.0              0.001094     5409.82972
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1             3.0        5.187472      -2.182787e-11                0.403
#
#    agent_private_price
# 1                0.403   Time  97
# agent['agent_private_price'] =  0.40199999999999997
# agent['agent_private_alpha'] =  0.40199999999999997
# r 5409.829719947452
# Agent supply too low. No bond/burn | s_free =  -2.182787277486079e-11
# Agent supply too low. Cannot attest
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  0.9781176438782777
# PRICE pbar (from bondburn update) = 0.0
# r 5409.829719947452
# Agent supply too low. No bond/burn | s_free =  -2.182787277486079e-11
# Agent supply too low. Cannot attest
# r 5409.829719947452
# Agent supply too low. No bond/burn | s_free =  -2.182787277486079e-11
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  0.9781176438782775
# S =  19999.999999999607
# KAPPA  =  1.9562352877565168
# R =  10000.0
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0              0.000279    5383.834392
# 1  1.0                   0.0              0.001094    5409.829720
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        3.558591      -1.382432e-10                0.406
# 1             3.0        5.187472      -2.182787e-11                0.402
#
#    agent_private_price
# 0                0.406
# 1                0.402
# --------------TIMESTEP 98 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0              0.000279    5383.834392
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        3.558591      -1.382432e-10                0.406
#
#    agent_private_price
# 0                0.406   Time  98
# agent['agent_private_price'] =  0.401
# agent['agent_private_alpha'] =  0.401
# r 5383.834392269521
# Agent supply too low. No bond/burn | s_free =  -1.3824319463688482e-10
# Agent supply too low. Cannot attest
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  0.9781176438782777
# PRICE pbar (from bondburn update) = 0.0
# r 5383.834392269521
# Agent supply too low. No bond/burn | s_free =  -1.3824319463688482e-10
# Agent supply too low. Cannot attest
# r 5383.834392269521
# Agent supply too low. No bond/burn | s_free =  -1.3824319463688482e-10
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  0.9781176438782775
# S =  19999.999999999607
# KAPPA  =  1.9562352877565168
# R =  10000.0
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0              0.000279    5383.834392
# 1  1.0                   0.0              0.001094    5409.829720
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        3.558591      -1.382432e-10                0.401
# 1             3.0        5.187472      -2.182787e-11                0.402
#
#    agent_private_price
# 0                0.401
# 1                0.402
# --------------TIMESTEP 99 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0                   0.0              0.001094     5409.82972
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1             3.0        5.187472      -2.182787e-11                0.402
#
#    agent_private_price
# 1                0.402   Time  99
# agent['agent_private_price'] =  0.39999999999999997
# agent['agent_private_alpha'] =  0.39999999999999997
# r 5409.829719947452
# Agent supply too low. No bond/burn | s_free =  -2.182787277486079e-11
# Agent supply too low. Cannot attest
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  0.9781176438782777
# PRICE pbar (from bondburn update) = 0.0
# r 5409.829719947452
# PROTO RP (BURN) =  0.9778838145232779
# Agent burns. Amt to burn =  9.999999899978171
# Negative attestation. | alpha =  0.4781176438782585 private_alpha =  0.39999999999999997
# amt_neg =  0.7523295269407732
# amt_Q0 =  0.0003761870504278126
# r 5413.829719947452
# PROTO RP (BURN) =  0.9778838145232779
# Agent burns. Amt to burn =  9.999999899978171
# Negative attestation. | alpha =  0.4781176438782585 private_alpha =  0.39999999999999997
# amt_neg =  0.9160163708330191
# amt_Q0 =  0.0004580343842711975
# PRICE (ATTEST):  0.9648423683021058
# Negative attestation 1
# S =  19999.999999999607
# KAPPA  =  1.9296847366041738
# R =  10000.0
# Total execution time: 2.41s

# %%
experiments = run.run()
# Out:
# config_ids =  [{'M': {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 10000, 'C': 20000, 'f': 0.03, 'm': 0.15, 'beta': 0.9, 'dust': 1e-08, 'period': 2000, 'rules_price': 'martin', 'E': 0.2, 'ENABLE_CONTINUOUS': True, 'THETA': 0.5, 'ENABLE_BURN': False, 'fee_numerator': 997, 'fee_denominator': 1000}, 'simulation_id': 0, 'run_id': 0, 'subset_id': 0}]

# %%
experiments = experiments.sort_values(by =['ENABLE_CONTINUOUS']).reset_index(drop=True)

cols = 1
rows = 1
cc_idx = 0


while cc_idx<len(experiments):
    cc = experiments.iloc[cc_idx]['ENABLE_CONTINUOUS']
    cc_label = experiments.iloc[cc_idx]['ENABLE_CONTINUOUS']
#     secondary_label = experiments.iloc[cc_idx]['string']
    sub_experiments = experiments[experiments['ENABLE_CONTINUOUS']==cc]
    cc_idx += len(sub_experiments)
    fig, axs = plt.subplots(ncols=cols, nrows=rows, figsize=(15*cols,7*rows))
    sub_experiments.reset_index(drop=False)
    for i, experiment in sub_experiments.iterrows():
        df = experiment['dataset'].copy()
        # filter out starting point
        df = df[df.timestep > 0] 
        # FIRST RUN ONLY
        df = df[df.run == 1]  
           
        plot_label = experiment['ENABLE_CONTINUOUS']
        ax = axs
        title = 'ENABLE_CONTINUOUS TEST: Reserve Funds vs. Funds to Project' + '\n' + 'Scenario: ' + str(cc_label)  + ' ENABLE_CONTINUOUS'
        # + 'Scenario: ' + str(cc_label)  + ' rules_price'
        ax.set_title(title)
        ax.set_ylabel('Funds')
        colors = ['b','orange', 'g', 'magenta', 'r', 'k' ]
        
        df.plot(x='timestep', y='funds_from_bond', label='funds_from_bond', ax=ax, legend=True)
        df.plot(x='timestep', y='reserve', label='reserve', ax=ax, legend=True, color = colors[5])
        df.plot(x='timestep', y='UNI_reserve', label='UNI_reserve', ax=ax, legend=True, color = colors[4])
        df.plot(x='timestep', y='UNI_supply', label='UNI_supply', ax=ax, legend=True, color = colors[3])

        ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

        ax.set_xlabel('Timesteps')
        ax.grid(color='0.9', linestyle='-', linewidth=1)

        plt.tight_layout()
        
fig.tight_layout(rect=[0, 0, 1, .97])
fig.patch.set_alpha(1)
display(fig)
plt.close()

# %%
experiments.dataset[0]
# Out:
#      reserve     pbar  realized_price  spot_price     kappa   supply  \
# 0    10000.0  1.00000               0    1.000000  2.000000  20000.0
# 6    10000.0  0.87515               0    1.000000  2.000000  20000.0
# 12   10000.0  1.00000               0    1.000000  2.000000  20000.0
# 18   10000.0  0.87515               0    1.000000  2.000000  20000.0
# 24   10000.0  0.00000               0    1.000000  2.000000  20000.0
# ..       ...      ...             ...         ...       ...      ...
# 576  10000.0  0.00000               0    0.978118  1.956235  20000.0
# 582  10000.0  0.00000               0    0.978118  1.956235  20000.0
# 588  10000.0  0.00000               0    0.978118  1.956235  20000.0
# 594  10000.0  0.00000               0    0.978118  1.956235  20000.0
# 600  10000.0  0.00000               0    0.964842  1.929685  20000.0
#
#         alpha alpha_bar   supply_0  supply_1  ...  \
# 0    0.500000     [0.5]  30.000000        30  ...
# 6    0.500000     [0.5]  30.000000        30  ...
# 12   0.500000     [0.5]  30.000000        30  ...
# 18   0.500000     [0.5]  30.000001        30  ...
# 24   0.500000     [0.5]  30.000001        30  ...
# ..        ...       ...        ...       ...  ...
# 576  0.478118     [0.5]  32.746063        30  ...
# 582  0.478118     [0.5]  32.746063        30  ...
# 588  0.478118     [0.5]  32.746063        30  ...
# 594  0.478118     [0.5]  32.746063        30  ...
# 600  0.471238     [0.5]  33.662080        30  ...
#
#                                           chosen_agent  public_alpha  \
# 0                                                    0             0
# 6    {'id': 1, 'agent_attestations_1': 0, 'agent_at...             0
# 12   {'id': 1.0, 'agent_attestations_1': 0.0, 'agen...             0
# 18   {'id': 0.0, 'agent_attestations_1': 0.0, 'agen...             0
# 24   {'id': 1.0, 'agent_attestations_1': 0.0, 'agen...             0
# ..                                                 ...           ...
# 576  {'id': 1.0, 'agent_attestations_1': 0.0, 'agen...             0
# 582  {'id': 1.0, 'agent_attestations_1': 0.0, 'agen...             0
# 588  {'id': 1.0, 'agent_attestations_1': 0.0, 'agen...             0
# 594  {'id': 0.0, 'agent_attestations_1': 0.0, 'agen...             0
# 600  {'id': 1.0, 'agent_attestations_1': 0.0, 'agen...             0
#
#      funds_from_bond  UNI_supply  UNI_reserve  simulation subset run  substep  \
# 0                0.0     20000.0        10000           0      0   1        0
# 6                0.0     20000.0        10000           0      0   1        6
# 12               0.0     20000.0        10000           0      0   1        6
# 18               0.0     20000.0        10000           0      0   1        6
# 24               0.0     20000.0        10000           0      0   1        6
# ..               ...         ...          ...         ...    ...  ..      ...
# 576              0.0     20036.0         9984           0      0   1        6
# 582              0.0     20036.0         9984           0      0   1        6
# 588              0.0     20036.0         9984           0      0   1        6
# 594              0.0     20036.0         9984           0      0   1        6
# 600              0.0     20045.0         9980           0      0   1        6
#
#      timestep
# 0           0
# 6           1
# 12          2
# 18          3
# 24          4
# ..        ...
# 576        96
# 582        97
# 588        98
# 594        99
# 600       100
#
# [101 rows x 27 columns]

# %%
plt.plot(experiments.dataset[0].supply)

# %%
plt.plot(experiments.dataset[0].reserve)

# %%
plt.plot(experiments.dataset[0].UNI_supply)

# %%
plt.plot(experiments.dataset[0].UNI_reserve)

# %% [markdown]
# ## Burn allowed, secondary trading not allowed

# %% [markdown]
# ENABLE_BURN = True <br>
# ENABLE_CONTINUOUS = False

# %%
# import sys
# sys.path.append('../')
import pandas as pd

import matplotlib.pyplot as plt
# import run2

from src.sim import run

import seaborn as sns

# For analysis
import numpy as np
import pandas as pd

sns.set_style("whitegrid")
# Out:
# Initial Conditions (config.py) :  {'reserve': 10000, 'pbar': 1, 'realized_price': 0, 'spot_price': 1, 'kappa': 0, 'supply': 20000.0, 'alpha': [0.5], 'alpha_bar': [0.5], 'supply_0': 30, 'supply_1': 30, 'supply_free': 20000.0, 'attestations': 40, 'attestations_0': 20, 'attestations_1': 20, 'invariant_V': 40000.0, 'invariant_I': 20000.0, 'agents':    id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0   0                     0                     0           1000
# 1   1                     0                     0           1000
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0               3               3               4994                  0.5
# 1               3               3               4994                  0.5
#
#    agent_private_price
# 0                  0.5
# 1                  1.5  , 'chosen_agent': 0, 'public_alpha': 0, 'funds_from_bond': 0, 'UNI_supply': 20000.0, 'UNI_reserve': 10000}
# -----------------PSUB---------------------
# Params (config.py) :  {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 10000, 'C': 20000, 'f': 0.03, 'm': 0.15, 'beta': 0.9, 'dust': 1e-08, 'period': 2000, 'rules_price': 'martin', 'E': 0.2, 'ENABLE_CONTINUOUS': False, 'THETA': 0.5, 'ENABLE_BURN': True, 'fee_numerator': 997, 'fee_denominator': 1000}
#
#                   ___________    ____
#   ________ __ ___/ / ____/   |  / __ \
#  / ___/ __` / __  / /   / /| | / / / /
# / /__/ /_/ / /_/ / /___/ ___ |/ /_/ /
# \___/\__,_/\__,_/\____/_/  |_/_____/
# by cadCAD
#
# Execution Mode: multi_proc
# Configuration Count: 1
# Dimensions of the first simulation: (Timesteps, Params, Runs, Vars) = (100, 16, 1, 22)
# Execution Method: single_proc_exec
# Execution Mode: single_threaded
#    id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0   0                     0                     0           1000
# 1   1                     0                     0           1000
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0               3               3               4994                  0.5
# 1               3               3               4994                  0.5
#
#    agent_private_price
# 0                  0.5
# 1                  1.5
# --------------TIMESTEP 0 --------------
# CHOSEN AGENT =     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1   1                     0                     0           1000
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1               3               3               4994                  0.5
#
#    agent_private_price
# 1                  1.5   Time  0
# agent['agent_private_price'] =  0.499
# agent['agent_private_alpha'] =  0.499
# r 1000
# PROTO RP (BURN) =  0.8751500012484998
# Agent burns. Amt to burn =  4993.99995006
# Negative attestation. | alpha =  0.5 private_alpha =  0.499
# amt_neg =  115.59771860377556
# amt_Q0 =  0.05771558209148431
# ::::delta R:::: 4370.499062530017
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  0.8751500012484998
# PRICE pbar (from bondburn update) = 0.8751500012484998
# r 5370.499062530017
# PROTO RP (BURN) =  0.7502999868636259
# Agent burns. Amt to burn =  4.993999978151249e-05
# Negative attestation. | alpha =  0.5 private_alpha =  0.499
# amt_neg =  8.123126925889187e-07
# amt_Q0 =  5.413225423467338e-10
# r 5370.499062530017
# PROTO RP (BURN) =  0.7502999868636259
# Agent burns. Amt to burn =  4.993999978151249e-05
# Negative attestation. | alpha =  0.5 private_alpha =  0.499
# amt_neg =  7.704019131064583e-07
# amt_Q0 =  5.133937719392634e-10
# PRICE (ATTEST):  0.5221113016387572
# Negative attestation 1
# S =  15006.000049940001
# KAPPA  =  1.3917401036949744
# R =  5629.500937469983
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          0.000000e+00    1000.000000
# 1  1.0                   0.0          5.133938e-10    5370.499063
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        3.000000        4994.000000                0.500
# 1             3.0        3.000001           0.000049                0.499
#
#    agent_private_price
# 0                0.500
# 1                0.499
# --------------TIMESTEP 1 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0                   0.0          5.133938e-10    5370.499063
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1             3.0        3.000001           0.000049                0.499
#
#    agent_private_price
# 1                0.499   Time  1
# agent['agent_private_price'] =  0.498
# agent['agent_private_alpha'] =  0.498
# r 5370.499062530017
# PROTO RP (BURN) =  0.5221112918373603
# Agent burns. Amt to burn =  4.916959787611006e-05
# Positive attestation. | alpha =  0.2814750416797874 private_alpha =  0.498
# amt_pos =  1.5335668443617282e-05
# amt_Q1 =  1.0219691759516536e-08
# ::::delta R:::: 2.567200226621935e-05
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  0.5221112918373603
# PRICE pbar (from bondburn update) = 0.5221112918373603
# r 5370.499088202019
# Agent supply too low. No bond/burn | s_free =  -8.603251032586468e-12
# Agent supply too low. Cannot attest
# r 5370.499088202019
# Agent supply too low. No bond/burn | s_free =  -8.603251032586468e-12
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  0.7502999946117352
# S =  15006.000000770395
# KAPPA  =  1.9999999815482337
# R =  5629.500911797981
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          0.000000e+00    1000.000000
# 1  1.0                   0.0          5.133938e-10    5370.499088
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        3.000000       4.994000e+03                0.500
# 1             3.0        3.000001      -8.603251e-12                0.498
#
#    agent_private_price
# 0                0.500
# 1                0.498
# --------------TIMESTEP 2 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0                   0.0          5.133938e-10    5370.499088
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1             3.0        3.000001      -8.603251e-12                0.498
#
#    agent_private_price
# 1                0.498   Time  2
# agent['agent_private_price'] =  0.497
# agent['agent_private_alpha'] =  0.497
# r 5370.499088202019
# Agent supply too low. No bond/burn | s_free =  -8.603251032586468e-12
# Agent supply too low. Cannot attest
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  0.7502999946117355
# PRICE pbar (from bondburn update) = -0.0
# r 5370.499088202019
# Agent supply too low. No bond/burn | s_free =  -2.1336176857407463e-11
# Agent supply too low. Cannot attest
# r 5370.499088202019
# Agent supply too low. No bond/burn | s_free =  -2.1336176857407463e-11
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  0.7502999963225183
# S =  15006.000000770382
# KAPPA  =  1.999999986108496
# R =  5629.500911797981
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          0.000000e+00    1000.000000
# 1  1.0                   0.0          5.133938e-10    5370.499088
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        3.000000       4.994000e+03                0.500
# 1             3.0        3.000001      -2.133618e-11                0.497
#
#    agent_private_price
# 0                0.500
# 1                0.497
# --------------TIMESTEP 3 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0                   0.0         1000.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0             3.0             4994.0                  0.5
#
#    agent_private_price
# 0                  0.5   Time  3
# agent['agent_private_price'] =  0.49599999999999994
# agent['agent_private_alpha'] =  0.49599999999999994
# r 1000.0
# PROTO RP (BURN) =  0.625449999712739
# Agent burns. Amt to burn =  4993.99995006
# Positive attestation. | alpha =  0.2814750416797874 private_alpha =  0.49599999999999994
# amt_pos =  1120.2758460890843
# amt_Q1 =  0.7331154853714628
# ::::delta R:::: 3123.497267330445
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  0.625449999712739
# PRICE pbar (from bondburn update) = 0.625449999712739
# r 4123.4972673304455
# PROTO RP (BURN) =  0.5006000730851672
# Agent burns. Amt to burn =  4.993999250555495e-05
# Positive attestation. | alpha =  0.2814750416797874 private_alpha =  0.49599999999999994
# amt_pos =  1.3413269946402217e-05
# amt_Q1 =  1.339719002402262e-08
# r 4123.4972673304455
# PROTO RP (BURN) =  0.5006000730851672
# Agent burns. Amt to burn =  4.993999250555495e-05
# Positive attestation. | alpha =  0.2814750416797874 private_alpha =  0.49599999999999994
# amt_pos =  1.4285396150915153e-05
# amt_Q1 =  1.4268271009143518e-08
# PRICE (ATTEST):  0.32196151056422856
# Positive attestation 1
# S =  10012.000050710376
# KAPPA  =  1.286302462972178
# R =  2506.0036444675357
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0          1.426827e-08          0.000000e+00    4123.497267
# 1  1.0          0.000000e+00          5.133938e-10    5370.499088
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000014        3.000000       3.565460e-05                0.496
# 1        3.000000        3.000001      -2.133618e-11                0.497
#
#    agent_private_price
# 0                0.496
# 1                0.497
# --------------TIMESTEP 4 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0                   0.0          5.133938e-10    5370.499088
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1             3.0        3.000001      -2.133618e-11                0.497
#
#    agent_private_price
# 1                0.497   Time  4
# agent['agent_private_price'] =  0.495
# agent['agent_private_alpha'] =  0.495
# r 5370.499088202019
# PROTO RP (BOND) =  0.37357847687641166
# Agent bonds. Amt to bond =  5370.499034497028
# Agent supply too low. Cannot attest
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 5370.499034497028
# PRICE (BOND/BURN):  0.37357847687641166
# PRICE pbar (from bondburn update) = 0.37357847687641166
# r 5.3704990932601504e-05
# PROTO RP (BOND) =  0.4154353520721624
# Agent bonds. Amt to bond =  5.3704990395551594e-05
# Positive attestation. | alpha =  0.12530023159817266 private_alpha =  0.495
# amt_pos =  5287.385886765152
# amt_Q1 =  2.0617707107298604
# r 5.3704990932601504e-05
# PROTO RP (BOND) =  0.4154353520721624
# Agent bonds. Amt to bond =  5.3704990395551594e-05
# Positive attestation. | alpha =  0.12530023159817266 private_alpha =  0.495
# amt_pos =  6105.277644009226
# amt_Q1 =  2.3637313918794733
# PRICE (ATTEST):  -0.35416053074719683
# Positive attestation 1
# S =  24387.825658762504
# KAPPA  =  -1.096578726767204
# R =  7876.5026789645635
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0          1.426827e-08          0.000000e+00    4123.497267
# 1  1.0          2.363731e+00          5.133938e-10       0.000054
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000014        3.000000           0.000036                0.496
# 1     6108.277644        3.000001        8270.547964                0.495
#
#    agent_private_price
# 0                0.496
# 1                0.495
# --------------TIMESTEP 5 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0          1.426827e-08                   0.0    4123.497267
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000014             3.0           0.000036                0.496
#
#    agent_private_price
# 0                0.496   Time  5
# agent['agent_private_price'] =  0.494
# agent['agent_private_alpha'] =  0.494
# r 4123.4972673304455
# PROTO RP (BOND) =  -0.5303159545954366
# Agent bonds. Amt to bond =  4123.497226095473
# Negative attestation. | alpha =  0.9925299218036804 private_alpha =  0.494
# amt_neg =  1.595219796357614e-05
# amt_Q0 =  6.54104770364676e-09
# ::::delta R:::: -9.094947017729282e-13
# ::::AMTBOND:::: 4123.497226095473
# PRICE (BOND/BURN):  -0.5303159545954366
# PRICE pbar (from bondburn update) = -0.5303159545954366
# r 4.123497183172731e-05
# PROTO RP (BOND) =  -0.7921215863459468
# Agent bonds. Amt to bond =  4.123497141937759e-05
# Agent supply too low. Cannot attest
# r 4.123497183172731e-05
# PROTO RP (BOND) =  -0.7921215863459468
# Agent bonds. Amt to bond =  4.123497141937759e-05
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  1.9172926936271206
# S =  16612.27753435962
# KAPPA  =  2.6542165494270726
# R =  11999.999905060038
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0          1.426827e-08          0.000000e+00       0.000041
# 1  1.0          2.363731e+00          5.133938e-10       0.000054
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000014        3.000000       -7775.548089                0.494
# 1     6108.277644        3.000001        8270.547964                0.495
#
#    agent_private_price
# 0                0.494
# 1                0.495
# --------------TIMESTEP 6 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0              2.363731          5.133938e-10       0.000054
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1     6108.277644        3.000001        8270.547964                0.495
#
#    agent_private_price
# 1                0.495   Time  6
# agent['agent_private_price'] =  0.493
# agent['agent_private_alpha'] =  0.493
# r 5.3704990932601504e-05
# PROTO RP (BURN) =  1.2178131145978206
# Agent burns. Amt to burn =  8270.5478813374
# Negative attestation. | alpha =  0.9925299218036804 private_alpha =  0.493
# amt_neg =  3779.997910946996
# amt_Q0 =  2.1589027234265594
# ::::delta R:::: 10071.981674801904
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  1.2178131145978206
# PRICE pbar (from bondburn update) = 1.2178131145978206
# r 10071.981728506895
# PROTO RP (BURN) =  0.6134671936883844
# Agent burns. Amt to burn =  8.270548741224369e-05
# Negative attestation. | alpha =  0.9925299218036804 private_alpha =  0.493
# amt_neg =  4.758867353498836e-05
# amt_Q0 =  5.7048925585022664e-08
# r 10071.981728506895
# PROTO RP (BURN) =  0.6134671936883844
# Agent burns. Amt to burn =  8.270548741224369e-05
# Negative attestation. | alpha =  0.9925299218036804 private_alpha =  0.493
# amt_neg =  3.7935467251617364e-05
# amt_Q0 =  4.547673793215021e-08
# PRICE (ATTEST):  0.5784200950401561
# Negative attestation 1
# S =  8341.729653022227
# KAPPA  =  2.502582176338863
# R =  1928.0182302581343
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0          1.426827e-08          0.000000e+00       0.000041
# 1  1.0          2.363731e+00          4.599013e-08   10071.981729
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000014        3.000000       -7775.548089                0.494
# 1     6108.277644        3.000039           0.000045                0.493
#
#    agent_private_price
# 0                0.494
# 1                0.493
# --------------TIMESTEP 7 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0          1.426827e-08                   0.0       0.000041
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000014             3.0       -7775.548089                0.494
#
#    agent_private_price
# 0                0.494   Time  7
# agent['agent_private_price'] =  0.492
# agent['agent_private_alpha'] =  0.492
# r 4.123497183172731e-05
# Agent supply too low. No bond/burn | s_free =  -7775.548088748288
# Agent supply too low. Cannot attest
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  0.5784200950401563
# PRICE pbar (from bondburn update) = -0.0
# r 4.123497183172731e-05
# Agent supply too low. No bond/burn | s_free =  -7775.548088748292
# Agent supply too low. Cannot attest
# r 4.123497183172731e-05
# Agent supply too low. No bond/burn | s_free =  -7775.548088748292
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  2.523640006434371
# S =  8341.729653022223
# KAPPA  =  10.918736319421777
# R =  1928.0182302581343
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0          1.426827e-08          0.000000e+00       0.000041
# 1  1.0          2.363731e+00          4.599013e-08   10071.981729
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000014        3.000000       -7775.548089                0.492
# 1     6108.277644        3.000039           0.000045                0.493
#
#    agent_private_price
# 0                0.492
# 1                0.493
# --------------TIMESTEP 8 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0              2.363731          4.599013e-08   10071.981729
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1     6108.277644        3.000039           0.000045                0.493
#
#    agent_private_price
# 1                0.493   Time  8
# agent['agent_private_price'] =  0.49099999999999994
# agent['agent_private_alpha'] =  0.49099999999999994
# r 10071.981728506895
# PROTO RP (BURN) =  2.523639936260464
# Agent burns. Amt to burn =  4.4770020539981e-05
# Negative attestation. | alpha =  0.9561752222484328 private_alpha =  0.49099999999999994
# amt_neg =  2.197919422786324e-05
# amt_Q0 =  2.6348483455699603e-08
# ::::delta R:::: 0.0001129834117818973
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  2.523639936260464
# PRICE pbar (from bondburn update) = 2.523639936260464
# r 10071.981841490306
# PROTO RP (BURN) =  0.0
# Agent burns. Amt to burn =  3.677111081264775e-12
# Negative attestation. | alpha =  0.9561752222484328 private_alpha =  0.49099999999999994
# amt_neg =  2.0358304842961183e-12
# amt_Q0 =  0.0
# r 10071.981841490306
# PROTO RP (BURN) =  0.0
# Agent burns. Amt to burn =  3.677111081264775e-12
# Negative attestation. | alpha =  0.9561752222484328 private_alpha =  0.49099999999999994
# amt_neg =  1.96766915205477e-12
# amt_Q0 =  0.0
# PRICE (ATTEST):  2.5236398720914077
# Negative attestation 1
# S =  8341.729608252206
# KAPPA  =  10.918736319421777
# R =  1928.0181172747225
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0          1.426827e-08          0.000000e+00       0.000041
# 1  1.0          2.363731e+00          4.599013e-08   10071.981841
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000014        3.000000      -7.775548e+03                0.492
# 1     6108.277644        3.000039       2.118010e-12                0.491
#
#    agent_private_price
# 0                0.492
# 1                0.491
# --------------TIMESTEP 9 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0          1.426827e-08                   0.0       0.000041
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000014             3.0       -7775.548089                0.492
#
#    agent_private_price
# 0                0.492   Time  9
# agent['agent_private_price'] =  0.49
# agent['agent_private_alpha'] =  0.49
# r 4.123497183172731e-05
# Agent supply too low. No bond/burn | s_free =  -7775.548088748292
# Agent supply too low. Cannot attest
# ::::delta R:::: -2.2737367544323206e-13
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  2.523639872091407
# PRICE pbar (from bondburn update) = 0.0
# r 4.123497160435363e-05
# Agent supply too low. No bond/burn | s_free =  -7775.548088748288
# Agent supply too low. Cannot attest
# r 4.123497160435363e-05
# Agent supply too low. No bond/burn | s_free =  -7775.548088748288
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  2.523639999918697
# S =  8341.72960825221
# KAPPA  =  10.918736872477103
# R =  1928.0181172747227
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0          1.426827e-08          0.000000e+00       0.000041
# 1  1.0          2.363731e+00          4.599013e-08   10071.981841
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000014        3.000000      -7.775548e+03                0.490
# 1     6108.277644        3.000039       2.118010e-12                0.491
#
#    agent_private_price
# 0                0.490
# 1                0.491
# --------------TIMESTEP 10 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0          1.426827e-08                   0.0       0.000041
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000014             3.0       -7775.548089                 0.49
#
#    agent_private_price
# 0                 0.49   Time  10
# agent['agent_private_price'] =  0.489
# agent['agent_private_alpha'] =  0.489
# r 4.123497160435363e-05
# Agent supply too low. No bond/burn | s_free =  -7775.548088748288
# Agent supply too low. Cannot attest
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  2.5236399999186965
# PRICE pbar (from bondburn update) = 0.0
# r 4.123497160435363e-05
# Agent supply too low. No bond/burn | s_free =  -7775.548088748288
# Agent supply too low. Cannot attest
# r 4.123497160435363e-05
# Agent supply too low. No bond/burn | s_free =  -7775.548088748288
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  2.523639999918697
# S =  8341.72960825221
# KAPPA  =  10.918736872477103
# R =  1928.0181172747227
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0          1.426827e-08          0.000000e+00       0.000041
# 1  1.0          2.363731e+00          4.599013e-08   10071.981841
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000014        3.000000      -7.775548e+03                0.489
# 1     6108.277644        3.000039       2.118010e-12                0.491
#
#    agent_private_price
# 0                0.489
# 1                0.491
# --------------TIMESTEP 11 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0          1.426827e-08                   0.0       0.000041
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000014             3.0       -7775.548089                0.489
#
#    agent_private_price
# 0                0.489   Time  11
# agent['agent_private_price'] =  0.488
# agent['agent_private_alpha'] =  0.488
# r 4.123497160435363e-05
# Agent supply too low. No bond/burn | s_free =  -7775.548088748288
# Agent supply too low. Cannot attest
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  2.5236399999186965
# PRICE pbar (from bondburn update) = 0.0
# r 4.123497160435363e-05
# Agent supply too low. No bond/burn | s_free =  -7775.548088748288
# Agent supply too low. Cannot attest
# r 4.123497160435363e-05
# Agent supply too low. No bond/burn | s_free =  -7775.548088748288
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  2.523639999918697
# S =  8341.72960825221
# KAPPA  =  10.918736872477103
# R =  1928.0181172747227
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0          1.426827e-08          0.000000e+00       0.000041
# 1  1.0          2.363731e+00          4.599013e-08   10071.981841
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000014        3.000000      -7.775548e+03                0.488
# 1     6108.277644        3.000039       2.118010e-12                0.491
#
#    agent_private_price
# 0                0.488
# 1                0.491
# --------------TIMESTEP 12 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0              2.363731          4.599013e-08   10071.981841
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1     6108.277644        3.000039       2.118010e-12                0.491
#
#    agent_private_price
# 1                0.491   Time  12
# agent['agent_private_price'] =  0.487
# agent['agent_private_alpha'] =  0.487
# r 10071.981841490306
# PROTO RP (BURN) =  2.0396977095919704
# Agent burns. Amt to burn =  2.1180098468050053e-12
# Negative attestation. | alpha =  0.9561752195308333 private_alpha =  0.487
# amt_neg =  1.155769187598183e-12
# amt_Q0 =  0.0
# ::::delta R:::: 4.320099833421409e-12
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  2.0396977095919704
# PRICE pbar (from bondburn update) = 2.0396977095919704
# r 10071.98184149031
# PROTO RP (BURN) =  0.0
# Agent burns. Amt to burn =  1.9062088845308624e-20
# Negative attestation. | alpha =  0.9561752195308333 private_alpha =  0.487
# amt_neg =  1.107388196604048e-20
# amt_Q0 =  0.0
# r 10071.98184149031
# PROTO RP (BURN) =  0.0
# Agent burns. Amt to burn =  1.9062088845308624e-20
# Negative attestation. | alpha =  0.9561752195308333 private_alpha =  0.487
# amt_neg =  9.05128582409627e-21
# amt_Q0 =  0.0
# PRICE (ATTEST):  2.523639999918692
# Negative attestation 1
# S =  8341.729608252208
# KAPPA  =  10.918736872477103
# R =  1928.0181172747184
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0          1.426827e-08          0.000000e+00       0.000041
# 1  1.0          2.363731e+00          4.599013e-08   10071.981841
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000014        3.000000      -7.775548e+03                0.488
# 1     6108.277644        3.000039       1.212881e-20                0.487
#
#    agent_private_price
# 0                0.488
# 1                0.487
# --------------TIMESTEP 13 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0              2.363731          4.599013e-08   10071.981841
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1     6108.277644        3.000039       1.212881e-20                0.487
#
#    agent_private_price
# 1                0.487   Time  13
# agent['agent_private_price'] =  0.48599999999999993
# agent['agent_private_alpha'] =  0.48599999999999993
# r 10071.98184149031
# PROTO RP (BURN) =  0.0
# Agent burns. Amt to burn =  1.0915931685083553e-20
# Negative attestation. | alpha =  0.9561752195308333 private_alpha =  0.48599999999999993
# amt_neg =  4.762730083119744e-21
# amt_Q0 =  0.0
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  0.0
# PRICE pbar (from bondburn update) = 0.0
# r 10071.98184149031
# PROTO RP (BOND) =  0.4754987367120685
# Agent bonds. Amt to bond =  723.0655423768223
# Negative attestation. | alpha =  0.9561752195308333 private_alpha =  0.48599999999999993
# amt_neg =  5.335754580724636e-22
# amt_Q0 =  0.0
# r 10071.98184149031
# PROTO RP (BOND) =  0.4754987367120685
# Agent bonds. Amt to bond =  723.0655423768223
# Negative attestation. | alpha =  0.9561752195308333 private_alpha =  0.48599999999999993
# amt_neg =  6.249719846332434e-22
# amt_Q0 =  0.0
# PRICE (ATTEST):  2.5236399999186965
# Negative attestation 1
# S =  8341.729608252208
# KAPPA  =  10.918736872477123
# R =  1928.0181172747184
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0          1.426827e-08          0.000000e+00       0.000041
# 1  1.0          2.363731e+00          4.599013e-08   10071.981841
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000014        3.000000      -7.775548e+03                0.488
# 1     6108.277644        3.000039       5.879094e-22                0.486
#
#    agent_private_price
# 0                0.488
# 1                0.486
# --------------TIMESTEP 14 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0              2.363731          4.599013e-08   10071.981841
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1     6108.277644        3.000039       5.879094e-22                0.486
#
#    agent_private_price
# 1                0.486   Time  14
# agent['agent_private_price'] =  0.485
# agent['agent_private_alpha'] =  0.485
# r 10071.98184149031
# PROTO RP (BURN) =  0.0
# Agent burns. Amt to burn =  5.2911848620657e-22
# Negative attestation. | alpha =  0.9561752195308333 private_alpha =  0.485
# amt_neg =  2.3248160236236133e-22
# amt_Q0 =  0.0
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  0.0
# PRICE pbar (from bondburn update) = 0.0
# r 10071.98184149031
# PROTO RP (BOND) =  0.47549873671206905
# Agent bonds. Amt to bond =  723.0655423768223
# Agent supply too low. Cannot attest
# r 10071.98184149031
# PROTO RP (BOND) =  0.47549873671206905
# Agent bonds. Amt to bond =  723.0655423768223
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  2.5236399999186974
# S =  8341.729608252204
# KAPPA  =  10.918736872477123
# R =  1928.0181172747184
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0          1.426827e-08          0.000000e+00       0.000041
# 1  1.0          2.363731e+00          4.599013e-08   10071.981841
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000014        3.000000      -7.775548e+03                0.488
# 1     6108.277644        3.000039      -3.637979e-12                0.485
#
#    agent_private_price
# 0                0.488
# 1                0.485
# --------------TIMESTEP 15 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0              2.363731          4.599013e-08   10071.981841
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1     6108.277644        3.000039      -3.637979e-12                0.485
#
#    agent_private_price
# 1                0.485   Time  15
# agent['agent_private_price'] =  0.484
# agent['agent_private_alpha'] =  0.484
# r 10071.98184149031
# Agent supply too low. No bond/burn | s_free =  -3.637978807032922e-12
# Agent supply too low. Cannot attest
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  2.5236399999186983
# PRICE pbar (from bondburn update) = -0.0
# r 10071.98184149031
# Agent supply too low. No bond/burn | s_free =  -7.275957614124635e-12
# Agent supply too low. Cannot attest
# r 10071.98184149031
# Agent supply too low. No bond/burn | s_free =  -7.275957614124635e-12
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  2.5236399999186987
# S =  8341.7296082522
# KAPPA  =  10.918736872477123
# R =  1928.0181172747184
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0          1.426827e-08          0.000000e+00       0.000041
# 1  1.0          2.363731e+00          4.599013e-08   10071.981841
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000014        3.000000      -7.775548e+03                0.488
# 1     6108.277644        3.000039      -7.275958e-12                0.484
#
#    agent_private_price
# 0                0.488
# 1                0.484
# --------------TIMESTEP 16 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0              2.363731          4.599013e-08   10071.981841
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1     6108.277644        3.000039      -7.275958e-12                0.484
#
#    agent_private_price
# 1                0.484   Time  16
# agent['agent_private_price'] =  0.483
# agent['agent_private_alpha'] =  0.483
# r 10071.98184149031
# Agent supply too low. No bond/burn | s_free =  -7.275957614124635e-12
# Agent supply too low. Cannot attest
# ::::delta R:::: 2.2737367544323206e-13
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  2.5236399999186996
# PRICE pbar (from bondburn update) = -0.0
# r 10071.98184149031
# Agent supply too low. No bond/burn | s_free =  -1.0913936421216348e-11
# Agent supply too low. Cannot attest
# r 10071.98184149031
# Agent supply too low. No bond/burn | s_free =  -1.0913936421216348e-11
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  2.5236399999186996
# S =  8341.729608252197
# KAPPA  =  10.918736872477123
# R =  1928.0181172747182
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0          1.426827e-08          0.000000e+00       0.000041
# 1  1.0          2.363731e+00          4.599013e-08   10071.981841
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000014        3.000000      -7.775548e+03                0.488
# 1     6108.277644        3.000039      -1.091394e-11                0.483
#
#    agent_private_price
# 0                0.488
# 1                0.483
# --------------TIMESTEP 17 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0              2.363731          4.599013e-08   10071.981841
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1     6108.277644        3.000039      -1.091394e-11                0.483
#
#    agent_private_price
# 1                0.483   Time  17
# agent['agent_private_price'] =  0.482
# agent['agent_private_alpha'] =  0.482
# r 10071.98184149031
# Agent supply too low. No bond/burn | s_free =  -1.0913936421216348e-11
# Agent supply too low. Cannot attest
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  2.5236399999187005
# PRICE pbar (from bondburn update) = -0.0
# r 10071.98184149031
# Agent supply too low. No bond/burn | s_free =  -1.455191522830806e-11
# Agent supply too low. Cannot attest
# r 10071.98184149031
# Agent supply too low. No bond/burn | s_free =  -1.455191522830806e-11
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  2.5236399999187005
# S =  8341.729608252193
# KAPPA  =  10.918736872477123
# R =  1928.0181172747182
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0          1.426827e-08          0.000000e+00       0.000041
# 1  1.0          2.363731e+00          4.599013e-08   10071.981841
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000014        3.000000      -7.775548e+03                0.488
# 1     6108.277644        3.000039      -1.455192e-11                0.482
#
#    agent_private_price
# 0                0.488
# 1                0.482
# --------------TIMESTEP 18 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0              2.363731          4.599013e-08   10071.981841
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1     6108.277644        3.000039      -1.455192e-11                0.482
#
#    agent_private_price
# 1                0.482   Time  18
# agent['agent_private_price'] =  0.4809999999999999
# agent['agent_private_alpha'] =  0.4809999999999999
# r 10071.98184149031
# Agent supply too low. No bond/burn | s_free =  -1.455191522830806e-11
# Agent supply too low. Cannot attest
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  2.5236399999187014
# PRICE pbar (from bondburn update) = -0.0
# r 10071.98184149031
# Agent supply too low. No bond/burn | s_free =  -1.8189894035399774e-11
# Agent supply too low. Cannot attest
# r 10071.98184149031
# Agent supply too low. No bond/burn | s_free =  -1.8189894035399774e-11
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  2.5236399999187014
# S =  8341.72960825219
# KAPPA  =  10.918736872477123
# R =  1928.0181172747182
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0          1.426827e-08          0.000000e+00       0.000041
# 1  1.0          2.363731e+00          4.599013e-08   10071.981841
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000014        3.000000      -7.775548e+03                0.488
# 1     6108.277644        3.000039      -1.818989e-11                0.481
#
#    agent_private_price
# 0                0.488
# 1                0.481
# --------------TIMESTEP 19 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0          1.426827e-08                   0.0       0.000041
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000014             3.0       -7775.548089                0.488
#
#    agent_private_price
# 0                0.488   Time  19
# agent['agent_private_price'] =  0.48
# agent['agent_private_alpha'] =  0.48
# r 4.123497160435363e-05
# Agent supply too low. No bond/burn | s_free =  -7775.548088748288
# Agent supply too low. Cannot attest
# ::::delta R:::: 2.2737367544323206e-13
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  2.5236399999187022
# PRICE pbar (from bondburn update) = -0.0
# r 4.123497183172731e-05
# Agent supply too low. No bond/burn | s_free =  -7765.548088748292
# Agent supply too low. Cannot attest
# r 4.123497183172731e-05
# Agent supply too low. No bond/burn | s_free =  -7765.548088748292
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  2.5236399999187022
# S =  8341.729608252186
# KAPPA  =  10.918736872477123
# R =  1928.018117274718
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0          1.426827e-08          0.000000e+00       0.000041
# 1  1.0          2.363731e+00          4.599013e-08   10071.981841
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000014        3.000000      -7.765548e+03                0.480
# 1     6108.277644        3.000039      -1.818989e-11                0.481
#
#    agent_private_price
# 0                0.480
# 1                0.481
# --------------TIMESTEP 20 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0          1.426827e-08                   0.0       0.000041
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000014             3.0       -7765.548089                 0.48
#
#    agent_private_price
# 0                 0.48   Time  20
# agent['agent_private_price'] =  0.479
# agent['agent_private_alpha'] =  0.479
# r 4.123497183172731e-05
# Agent supply too low. No bond/burn | s_free =  -7765.548088748292
# Agent supply too low. Cannot attest
# ::::delta R:::: 2.2737367544323206e-13
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  2.5236399999187036
# PRICE pbar (from bondburn update) = -0.0
# r 4.123497205910098e-05
# Agent supply too low. No bond/burn | s_free =  -7765.548088748295
# Agent supply too low. Cannot attest
# r 4.123497205910098e-05
# Agent supply too low. No bond/burn | s_free =  -7765.548088748295
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  2.523639999918703
# S =  8341.729608252183
# KAPPA  =  10.918736872477123
# R =  1928.0181172747177
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0          1.426827e-08          0.000000e+00       0.000041
# 1  1.0          2.363731e+00          4.599013e-08   10071.981841
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000014        3.000000      -7.765548e+03                0.479
# 1     6108.277644        3.000039      -1.818989e-11                0.481
#
#    agent_private_price
# 0                0.479
# 1                0.481
# --------------TIMESTEP 21 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0              2.363731          4.599013e-08   10071.981841
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1     6108.277644        3.000039      -1.818989e-11                0.481
#
#    agent_private_price
# 1                0.481   Time  21
# agent['agent_private_price'] =  0.478
# agent['agent_private_alpha'] =  0.478
# r 10071.98184149031
# Agent supply too low. No bond/burn | s_free =  -1.8189894035399774e-11
# Agent supply too low. Cannot attest
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  2.523639999918704
# PRICE pbar (from bondburn update) = -0.0
# r 10071.98184149031
# Agent supply too low. No bond/burn | s_free =  -2.1827872842491486e-11
# Agent supply too low. Cannot attest
# r 10071.98184149031
# Agent supply too low. No bond/burn | s_free =  -2.1827872842491486e-11
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  2.5236399999187045
# S =  8341.729608252179
# KAPPA  =  10.918736872477123
# R =  1928.0181172747177
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0          1.426827e-08          0.000000e+00       0.000041
# 1  1.0          2.363731e+00          4.599013e-08   10071.981841
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000014        3.000000      -7.765548e+03                0.479
# 1     6108.277644        3.000039      -2.182787e-11                0.478
#
#    agent_private_price
# 0                0.479
# 1                0.478
# --------------TIMESTEP 22 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0              2.363731          4.599013e-08   10071.981841
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1     6108.277644        3.000039      -2.182787e-11                0.478
#
#    agent_private_price
# 1                0.478   Time  22
# agent['agent_private_price'] =  0.477
# agent['agent_private_alpha'] =  0.477
# r 10071.98184149031
# Agent supply too low. No bond/burn | s_free =  -2.1827872842491486e-11
# Agent supply too low. Cannot attest
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  2.5236399999187054
# PRICE pbar (from bondburn update) = -0.0
# r 10071.98184149031
# Agent supply too low. No bond/burn | s_free =  -2.54658516495832e-11
# Agent supply too low. Cannot attest
# r 10071.98184149031
# Agent supply too low. No bond/burn | s_free =  -2.54658516495832e-11
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  2.5236399999187054
# S =  8341.729608252175
# KAPPA  =  10.918736872477123
# R =  1928.0181172747177
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0          1.426827e-08          0.000000e+00       0.000041
# 1  1.0          2.363731e+00          4.599013e-08   10071.981841
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000014        3.000000      -7.765548e+03                0.479
# 1     6108.277644        3.000039      -2.546585e-11                0.477
#
#    agent_private_price
# 0                0.479
# 1                0.477
# --------------TIMESTEP 23 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0          1.426827e-08                   0.0       0.000041
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000014             3.0       -7765.548089                0.479
#
#    agent_private_price
# 0                0.479   Time  23
# agent['agent_private_price'] =  0.4759999999999999
# agent['agent_private_alpha'] =  0.4759999999999999
# r 4.123497205910098e-05
# Agent supply too low. No bond/burn | s_free =  -7765.548088748295
# Agent supply too low. Cannot attest
# ::::delta R:::: 2.2737367544323206e-13
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  2.5236399999187062
# PRICE pbar (from bondburn update) = -0.0
# r 4.123497228647466e-05
# Agent supply too low. No bond/burn | s_free =  -7765.548088748299
# Agent supply too low. Cannot attest
# r 4.123497228647466e-05
# Agent supply too low. No bond/burn | s_free =  -7765.548088748299
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  2.5236399999187062
# S =  8341.729608252172
# KAPPA  =  10.918736872477123
# R =  1928.0181172747175
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0          1.426827e-08          0.000000e+00       0.000041
# 1  1.0          2.363731e+00          4.599013e-08   10071.981841
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000014        3.000000      -7.765548e+03                0.476
# 1     6108.277644        3.000039      -2.546585e-11                0.477
#
#    agent_private_price
# 0                0.476
# 1                0.477
# --------------TIMESTEP 24 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0              2.363731          4.599013e-08   10071.981841
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1     6108.277644        3.000039      -2.546585e-11                0.477
#
#    agent_private_price
# 1                0.477   Time  24
# agent['agent_private_price'] =  0.475
# agent['agent_private_alpha'] =  0.475
# r 10071.98184149031
# Agent supply too low. No bond/burn | s_free =  -2.54658516495832e-11
# Agent supply too low. Cannot attest
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  2.523639999918707
# PRICE pbar (from bondburn update) = -0.0
# r 10071.98184149031
# Agent supply too low. No bond/burn | s_free =  -2.9103830456674912e-11
# Agent supply too low. Cannot attest
# r 10071.98184149031
# Agent supply too low. No bond/burn | s_free =  -2.9103830456674912e-11
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  2.523639999918707
# S =  8341.729608252168
# KAPPA  =  10.918736872477123
# R =  1928.0181172747175
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0          1.426827e-08          0.000000e+00       0.000041
# 1  1.0          2.363731e+00          4.599013e-08   10071.981841
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000014        3.000000      -7.765548e+03                0.476
# 1     6108.277644        3.000039      -2.910383e-11                0.475
#
#    agent_private_price
# 0                0.476
# 1                0.475
# --------------TIMESTEP 25 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0          1.426827e-08                   0.0       0.000041
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000014             3.0       -7765.548089                0.476
#
#    agent_private_price
# 0                0.476   Time  25
# agent['agent_private_price'] =  0.474
# agent['agent_private_alpha'] =  0.474
# r 4.123497228647466e-05
# Agent supply too low. No bond/burn | s_free =  -7765.548088748299
# Agent supply too low. Cannot attest
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  2.523639999918708
# PRICE pbar (from bondburn update) = -0.0
# r 4.123497228647466e-05
# Agent supply too low. No bond/burn | s_free =  -7765.548088748303
# Agent supply too low. Cannot attest
# r 4.123497228647466e-05
# Agent supply too low. No bond/burn | s_free =  -7765.548088748303
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  2.523639999918708
# S =  8341.729608252164
# KAPPA  =  10.918736872477123
# R =  1928.0181172747175
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0          1.426827e-08          0.000000e+00       0.000041
# 1  1.0          2.363731e+00          4.599013e-08   10071.981841
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000014        3.000000      -7.765548e+03                0.474
# 1     6108.277644        3.000039      -2.910383e-11                0.475
#
#    agent_private_price
# 0                0.474
# 1                0.475
# --------------TIMESTEP 26 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0          1.426827e-08                   0.0       0.000041
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000014             3.0       -7765.548089                0.474
#
#    agent_private_price
# 0                0.474   Time  26
# agent['agent_private_price'] =  0.473
# agent['agent_private_alpha'] =  0.473
# r 4.123497228647466e-05
# Agent supply too low. No bond/burn | s_free =  -7765.548088748303
# Agent supply too low. Cannot attest
# ::::delta R:::: 2.2737367544323206e-13
# ::::AMTBOND:::: 0
# ...
# 1     6108.277644         8.31922      -2.538321e-11                0.410
#
#    agent_private_price
# 0                0.412
# 1                0.410
# --------------TIMESTEP 90 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0          1.426827e-08                   0.0       0.000041
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000014             3.0       -7745.548089                0.412
#
#    agent_private_price
# 0                0.412   Time  90
# agent['agent_private_price'] =  0.40900000000000003
# agent['agent_private_alpha'] =  0.40900000000000003
# r 4.123497274122201e-05
# Agent supply too low. No bond/burn | s_free =  -7745.5480887483245
# Agent supply too low. Cannot attest
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  2.5053216988606644
# PRICE pbar (from bondburn update) = -0.0
# r 4.123497274122201e-05
# Agent supply too low. No bond/burn | s_free =  -7745.548088748328
# Agent supply too low. Cannot attest
# r 4.123497274122201e-05
# Agent supply too low. No bond/burn | s_free =  -7745.548088748328
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  2.5053216988606644
# S =  8337.04878925424
# KAPPA  =  10.895251213637675
# R =  1917.0727527635402
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0          1.426827e-08              0.000000       0.000041
# 1  1.0          2.363731e+00              0.006376   10082.927206
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000014         3.00000      -7.745548e+03                0.409
# 1     6108.277644         8.31922      -2.538321e-11                0.410
#
#    agent_private_price
# 0                0.409
# 1                0.410
# --------------TIMESTEP 91 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0              2.363731              0.006376   10082.927206
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1     6108.277644         8.31922      -2.538321e-11                 0.41
#
#    agent_private_price
# 1                 0.41   Time  91
# agent['agent_private_price'] =  0.40800000000000003
# agent['agent_private_alpha'] =  0.40800000000000003
# r 10082.927206001486
# Agent supply too low. No bond/burn | s_free =  -2.5383207753781688e-11
# Agent supply too low. Cannot attest
# ::::delta R:::: 2.2737367544323206e-13
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  2.5053216988606657
# PRICE pbar (from bondburn update) = -0.0
# r 10082.927206001486
# Agent supply too low. No bond/burn | s_free =  -2.90211865608734e-11
# Agent supply too low. Cannot attest
# r 10082.927206001486
# Agent supply too low. No bond/burn | s_free =  -2.90211865608734e-11
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  2.5053216988606652
# S =  8337.048789254237
# KAPPA  =  10.895251213637675
# R =  1917.07275276354
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0          1.426827e-08              0.000000       0.000041
# 1  1.0          2.363731e+00              0.006376   10082.927206
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000014         3.00000      -7.745548e+03                0.409
# 1     6108.277644         8.31922      -2.902119e-11                0.408
#
#    agent_private_price
# 0                0.409
# 1                0.408
# --------------TIMESTEP 92 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0          1.426827e-08                   0.0       0.000041
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000014             3.0       -7745.548089                0.409
#
#    agent_private_price
# 0                0.409   Time  92
# agent['agent_private_price'] =  0.407
# agent['agent_private_alpha'] =  0.407
# r 4.123497274122201e-05
# Agent supply too low. No bond/burn | s_free =  -7745.548088748328
# Agent supply too low. Cannot attest
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  2.5053216988606666
# PRICE pbar (from bondburn update) = -0.0
# r 4.123497274122201e-05
# Agent supply too low. No bond/burn | s_free =  -7745.548088748332
# Agent supply too low. Cannot attest
# r 4.123497274122201e-05
# Agent supply too low. No bond/burn | s_free =  -7745.548088748332
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  2.505321698860666
# S =  8337.048789254233
# KAPPA  =  10.895251213637675
# R =  1917.07275276354
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0          1.426827e-08              0.000000       0.000041
# 1  1.0          2.363731e+00              0.006376   10082.927206
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000014         3.00000      -7.745548e+03                0.407
# 1     6108.277644         8.31922      -2.902119e-11                0.408
#
#    agent_private_price
# 0                0.407
# 1                0.408
# --------------TIMESTEP 93 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0              2.363731              0.006376   10082.927206
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1     6108.277644         8.31922      -2.902119e-11                0.408
#
#    agent_private_price
# 1                0.408   Time  93
# agent['agent_private_price'] =  0.406
# agent['agent_private_alpha'] =  0.406
# r 10082.927206001486
# Agent supply too low. No bond/burn | s_free =  -2.90211865608734e-11
# Agent supply too low. Cannot attest
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  2.5053216988606675
# PRICE pbar (from bondburn update) = -0.0
# r 10082.927206001486
# Agent supply too low. No bond/burn | s_free =  -3.2659165367965114e-11
# Agent supply too low. Cannot attest
# r 10082.927206001486
# Agent supply too low. No bond/burn | s_free =  -3.2659165367965114e-11
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  2.505321698860667
# S =  8337.04878925423
# KAPPA  =  10.895251213637675
# R =  1917.07275276354
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0          1.426827e-08              0.000000       0.000041
# 1  1.0          2.363731e+00              0.006376   10082.927206
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000014         3.00000      -7.745548e+03                0.407
# 1     6108.277644         8.31922      -3.265917e-11                0.406
#
#    agent_private_price
# 0                0.407
# 1                0.406
# --------------TIMESTEP 94 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0              2.363731              0.006376   10082.927206
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1     6108.277644         8.31922      -3.265917e-11                0.406
#
#    agent_private_price
# 1                0.406   Time  94
# agent['agent_private_price'] =  0.40499999999999997
# agent['agent_private_alpha'] =  0.40499999999999997
# r 10082.927206001486
# Agent supply too low. No bond/burn | s_free =  -3.2659165367965114e-11
# Agent supply too low. Cannot attest
# ::::delta R:::: 2.2737367544323206e-13
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  2.505321698860669
# PRICE pbar (from bondburn update) = -0.0
# r 10082.927206001486
# Agent supply too low. No bond/burn | s_free =  -3.629714417505683e-11
# Agent supply too low. Cannot attest
# r 10082.927206001486
# Agent supply too low. No bond/burn | s_free =  -3.629714417505683e-11
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  2.505321698860668
# S =  8337.048789254226
# KAPPA  =  10.895251213637675
# R =  1917.0727527635397
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0          1.426827e-08              0.000000       0.000041
# 1  1.0          2.363731e+00              0.006376   10082.927206
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000014         3.00000      -7.745548e+03                0.407
# 1     6108.277644         8.31922      -3.629714e-11                0.405
#
#    agent_private_price
# 0                0.407
# 1                0.405
# --------------TIMESTEP 95 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0              2.363731              0.006376   10082.927206
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1     6108.277644         8.31922      -3.629714e-11                0.405
#
#    agent_private_price
# 1                0.405   Time  95
# agent['agent_private_price'] =  0.404
# agent['agent_private_alpha'] =  0.404
# r 10082.927206001486
# Agent supply too low. No bond/burn | s_free =  -3.629714417505683e-11
# Agent supply too low. Cannot attest
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  2.5053216988606692
# PRICE pbar (from bondburn update) = -0.0
# r 10082.927206001486
# Agent supply too low. No bond/burn | s_free =  -3.993512298214854e-11
# Agent supply too low. Cannot attest
# r 10082.927206001486
# Agent supply too low. No bond/burn | s_free =  -3.993512298214854e-11
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  2.5053216988606692
# S =  8337.048789254222
# KAPPA  =  10.895251213637675
# R =  1917.0727527635397
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0          1.426827e-08              0.000000       0.000041
# 1  1.0          2.363731e+00              0.006376   10082.927206
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000014         3.00000      -7.745548e+03                0.407
# 1     6108.277644         8.31922      -3.993512e-11                0.404
#
#    agent_private_price
# 0                0.407
# 1                0.404
# --------------TIMESTEP 96 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0              2.363731              0.006376   10082.927206
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1     6108.277644         8.31922      -3.993512e-11                0.404
#
#    agent_private_price
# 1                0.404   Time  96
# agent['agent_private_price'] =  0.403
# agent['agent_private_alpha'] =  0.403
# r 10082.927206001486
# Agent supply too low. No bond/burn | s_free =  -3.993512298214854e-11
# Agent supply too low. Cannot attest
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  2.5053216988606706
# PRICE pbar (from bondburn update) = -0.0
# r 10082.927206001486
# Agent supply too low. No bond/burn | s_free =  -4.357310178924025e-11
# Agent supply too low. Cannot attest
# r 10082.927206001486
# Agent supply too low. No bond/burn | s_free =  -4.357310178924025e-11
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  2.50532169886067
# S =  8337.048789254219
# KAPPA  =  10.895251213637675
# R =  1917.0727527635397
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0          1.426827e-08              0.000000       0.000041
# 1  1.0          2.363731e+00              0.006376   10082.927206
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000014         3.00000      -7.745548e+03                0.407
# 1     6108.277644         8.31922      -4.357310e-11                0.403
#
#    agent_private_price
# 0                0.407
# 1                0.403
# --------------TIMESTEP 97 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0          1.426827e-08                   0.0       0.000041
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000014             3.0       -7745.548089                0.407
#
#    agent_private_price
# 0                0.407   Time  97
# agent['agent_private_price'] =  0.40199999999999997
# agent['agent_private_alpha'] =  0.40199999999999997
# r 4.123497274122201e-05
# Agent supply too low. No bond/burn | s_free =  -7745.548088748332
# Agent supply too low. Cannot attest
# ::::delta R:::: -2.2737367544323206e-13
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  2.505321698860672
# PRICE pbar (from bondburn update) = -0.0
# r 4.1234972513848334e-05
# Agent supply too low. No bond/burn | s_free =  -7745.548088748335
# Agent supply too low. Cannot attest
# r 4.1234972513848334e-05
# Agent supply too low. No bond/burn | s_free =  -7745.548088748335
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  2.505321698860672
# S =  8337.048789254215
# KAPPA  =  10.895251213637675
# R =  1917.07275276354
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0          1.426827e-08              0.000000       0.000041
# 1  1.0          2.363731e+00              0.006376   10082.927206
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000014         3.00000      -7.745548e+03                0.402
# 1     6108.277644         8.31922      -4.357310e-11                0.403
#
#    agent_private_price
# 0                0.402
# 1                0.403
# --------------TIMESTEP 98 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0              2.363731              0.006376   10082.927206
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1     6108.277644         8.31922      -4.357310e-11                0.403
#
#    agent_private_price
# 1                0.403   Time  98
# agent['agent_private_price'] =  0.401
# agent['agent_private_alpha'] =  0.401
# r 10082.927206001486
# Agent supply too low. No bond/burn | s_free =  -4.357310178924025e-11
# Agent supply too low. Cannot attest
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  2.505321698860673
# PRICE pbar (from bondburn update) = -0.0
# r 10082.927206001486
# Agent supply too low. No bond/burn | s_free =  -4.7211080596331966e-11
# Agent supply too low. Cannot attest
# r 10082.927206001486
# Agent supply too low. No bond/burn | s_free =  -4.7211080596331966e-11
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  2.505321698860673
# S =  8337.048789254211
# KAPPA  =  10.895251213637675
# R =  1917.07275276354
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0          1.426827e-08              0.000000       0.000041
# 1  1.0          2.363731e+00              0.006376   10082.927206
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000014         3.00000      -7.745548e+03                0.402
# 1     6108.277644         8.31922      -4.721108e-11                0.401
#
#    agent_private_price
# 0                0.402
# 1                0.401
# --------------TIMESTEP 99 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0          1.426827e-08                   0.0       0.000041
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000014             3.0       -7745.548089                0.402
#
#    agent_private_price
# 0                0.402   Time  99
# agent['agent_private_price'] =  0.39999999999999997
# agent['agent_private_alpha'] =  0.39999999999999997
# r 4.1234972513848334e-05
# Agent supply too low. No bond/burn | s_free =  -7745.548088748335
# Agent supply too low. Cannot attest
# ::::delta R:::: 2.2737367544323206e-13
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  2.505321698860674
# PRICE pbar (from bondburn update) = -0.0
# r 4.123497274122201e-05
# Agent supply too low. No bond/burn | s_free =  -7735.548088748339
# Agent supply too low. Cannot attest
# r 4.123497274122201e-05
# Agent supply too low. No bond/burn | s_free =  -7735.548088748339
# Agent supply too low. Cannot attest
# PRICE (ATTEST):  2.5053216988606737
# S =  8337.048789254208
# KAPPA  =  10.895251213637675
# R =  1917.0727527635397
# Total execution time: 2.11s

# %%
experiments = run.run()
# Out:
# config_ids =  [{'M': {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 10000, 'C': 20000, 'f': 0.03, 'm': 0.15, 'beta': 0.9, 'dust': 1e-08, 'period': 2000, 'rules_price': 'martin', 'E': 0.2, 'ENABLE_CONTINUOUS': False, 'THETA': 0.5, 'ENABLE_BURN': True, 'fee_numerator': 997, 'fee_denominator': 1000}, 'simulation_id': 0, 'run_id': 0, 'subset_id': 0}]

# %%
experiments = experiments.sort_values(by =['ENABLE_CONTINUOUS']).reset_index(drop=True)

cols = 1
rows = 1
cc_idx = 0


while cc_idx<len(experiments):
    cc = experiments.iloc[cc_idx]['ENABLE_CONTINUOUS']
    cc_label = experiments.iloc[cc_idx]['ENABLE_CONTINUOUS']
#     secondary_label = experiments.iloc[cc_idx]['string']
    sub_experiments = experiments[experiments['ENABLE_CONTINUOUS']==cc]
    cc_idx += len(sub_experiments)
    fig, axs = plt.subplots(ncols=cols, nrows=rows, figsize=(15*cols,7*rows))
    sub_experiments.reset_index(drop=False)
    for i, experiment in sub_experiments.iterrows():
        df = experiment['dataset'].copy()
        # filter out starting point
        df = df[df.timestep > 0] 
        # FIRST RUN ONLY
        df = df[df.run == 1]  
           
        plot_label = experiment['ENABLE_CONTINUOUS']
        ax = axs
        title = 'ENABLE_CONTINUOUS TEST: Reserve Funds vs. Funds to Project' + '\n' + 'Scenario: ' + str(cc_label)  + ' ENABLE_CONTINUOUS'
        # + 'Scenario: ' + str(cc_label)  + ' rules_price'
        ax.set_title(title)
        ax.set_ylabel('Funds')
        colors = ['b','orange', 'g', 'magenta', 'r', 'k' ]
        
        df.plot(x='timestep', y='funds_from_bond', label='funds_from_bond', ax=ax, legend=True)
        df.plot(x='timestep', y='reserve', label='reserve', ax=ax, legend=True, color = colors[5])

        ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

        ax.set_xlabel('Timesteps')
        ax.grid(color='0.9', linestyle='-', linewidth=1)

        plt.tight_layout()
        
fig.tight_layout(rect=[0, 0, 1, .97])
fig.patch.set_alpha(1)
display(fig)
plt.close()

# %%
plt.plot(experiments.dataset[0].alpha)

# %%
experiments.dataset[0]
# Out:
#           reserve      pbar  realized_price  spot_price      kappa  \
# 0    10000.000000  1.000000               0    1.000000   2.000000
# 6     5629.500937  0.875150               0    0.522111   1.391740
# 12    5629.500912  0.522111               0    0.750300   2.000000
# 18    5629.500912 -0.000000               0    0.750300   2.000000
# 24    2506.003644  0.625450               0    0.321962   1.286302
# ..            ...       ...             ...         ...        ...
# 576   1917.072753 -0.000000               0    2.505322  10.895251
# 582   1917.072753 -0.000000               0    2.505322  10.895251
# 588   1917.072753 -0.000000               0    2.505322  10.895251
# 594   1917.072753 -0.000000               0    2.505322  10.895251
# 600   1917.072753 -0.000000               0    2.505322  10.895251
#
#            supply     alpha alpha_bar   supply_0     supply_1  ...  \
# 0    20000.000000  0.500000     [0.5]  30.000000    30.000000  ...
# 6    15006.000050  0.281475     [0.5]  30.000001    30.000000  ...
# 12   15006.000001  0.281475     [0.5]  30.000001    30.000000  ...
# 18   15006.000001  0.281475     [0.5]  30.000001    30.000000  ...
# 24   10012.000051  0.125300     [0.5]  30.000001    30.000014  ...
# ..            ...       ...       ...        ...          ...  ...
# 576   8337.048789  0.948496     [0.5]  35.319220  6135.277658  ...
# 582   8337.048789  0.948496     [0.5]  35.319220  6135.277658  ...
# 588   8337.048789  0.948496     [0.5]  35.319220  6135.277658  ...
# 594   8337.048789  0.948496     [0.5]  35.319220  6135.277658  ...
# 600   8337.048789  0.948496     [0.5]  35.319220  6135.277658  ...
#
#                                           chosen_agent  public_alpha  \
# 0                                                    0             0
# 6    {'id': 1, 'agent_attestations_1': 0, 'agent_at...             0
# 12   {'id': 1.0, 'agent_attestations_1': 0.0, 'agen...             0
# 18   {'id': 1.0, 'agent_attestations_1': 0.0, 'agen...             0
# 24   {'id': 0.0, 'agent_attestations_1': 1.42682710...             0
# ..                                                 ...           ...
# 576  {'id': 1.0, 'agent_attestations_1': 2.36373139...             0
# 582  {'id': 1.0, 'agent_attestations_1': 2.36373139...             0
# 588  {'id': 0.0, 'agent_attestations_1': 1.42682710...             0
# 594  {'id': 1.0, 'agent_attestations_1': 2.36373139...             0
# 600  {'id': 0.0, 'agent_attestations_1': 1.42682710...             0
#
#      funds_from_bond  UNI_supply  UNI_reserve  simulation subset run  substep  \
# 0                  0     20000.0        10000           0      0   1        0
# 6                  0         0.0            0           0      0   1        6
# 12                 0         0.0            0           0      0   1        6
# 18                 0         0.0            0           0      0   1        6
# 24                 0         0.0            0           0      0   1        6
# ..               ...         ...          ...         ...    ...  ..      ...
# 576                0         0.0            0           0      0   1        6
# 582                0         0.0            0           0      0   1        6
# 588                0         0.0            0           0      0   1        6
# 594                0         0.0            0           0      0   1        6
# 600                0         0.0            0           0      0   1        6
#
#      timestep
# 0           0
# 6           1
# 12          2
# 18          3
# 24          4
# ..        ...
# 576        96
# 582        97
# 588        98
# 594        99
# 600       100
#
# [101 rows x 27 columns]

# %%
plt.plot(experiments.dataset[0].supply)

# %%
from src.sim import run
import matplotlib.pyplot as plt
# Out:
# Initial Conditions (config.py) :  {'reserve': 300, 'price': 1, 'realized_price': 0, 'spot_price': 1, 'private_price': 0, 'private_alpha': 0, 'kappa': 0, 'supply': 600.0, 'alpha': [0.5], 'supply_0': 0, 'supply_1': 0, 'supply_free': 600.0, 'attestations_0': 1, 'attestations_1': 1, 'invariant_V': 1200.0, 'invariant_I': 650.0, 'agent_attestations_1': 0, 'agent_attestations_0': 0, 'agent_reserve': 0, 'agent_supply': 0, 'agent_supply_1': 0, 'agent_supply_0': 0}
# [{'N': 1, 'T': range(0, 400), 'M': {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 1000, 'C': 700, 'period': 2000}}]
# Params (config.py) :  {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 1000, 'C': 700, 'period': 2000}

# %%
experiments = run.run()
# Out:
#                             __________   ____
#           ________ __ _____/ ____/   |  / __ \
#          / ___/ __` / __  / /   / /| | / / / /
#         / /__/ /_/ / /_/ / /___/ ___ |/ /_/ /
#         \___/\__,_/\__,_/\____/_/  |_/_____/
#         by BlockScience
#
# Execution Mode: multi_proc: [<cadCAD.configuration.Configuration object at 0x11270ad10>]
# Configurations: [<cadCAD.configuration.Configuration object at 0x11270ad10>]

# %%
print(experiments.dataset[0].head())
# Out:
#        reserve     price  realized_price  spot_price  private_price  \
# 0   300.000000  1.000000               0    1.000000       0.000000
# 6   300.000785  1.000001               0    1.083336       1.000785
# 12  299.912213  1.083250               0    1.083041       1.001571
# 18  299.824835  1.082956               0    1.082750       1.002356
# 24  299.738646  1.082666               0    1.082462       1.003142
#
#     private_alpha     kappa      supply     alpha  supply_0  ...  invariant_I  \
# 0        0.000000  2.000000  600.000000  0.500000         0  ...   650.000000
# 6        0.750000  2.166664  599.999215 -0.374249         0  ...   650.000785
# 12      -0.124249  2.167008  600.080980 -0.374249         0  ...    38.026680
# 18      -0.124249  2.167348  600.161665 -0.374249         0  ...    37.938108
# 24      -0.124249  2.167684  600.241273 -0.374249         0  ...    37.850730
#
#     agent_attestations_1  agent_attestations_0  agent_reserve  agent_supply  \
# ...

# %%
plt.plot(experiments.dataset[0].kappa)

# %%
plt.plot(experiments.dataset[0].alpha)

# %%
experiments2 = run.run()
# Out:
#                             __________   ____
#           ________ __ _____/ ____/   |  / __ \
#          / ___/ __` / __  / /   / /| | / / / /
#         / /__/ /_/ / /_/ / /___/ ___ |/ /_/ /
#         \___/\__,_/\__,_/\____/_/  |_/_____/
#         by BlockScience
#
# Execution Mode: multi_proc: [<cadCAD.configuration.Configuration object at 0x10d0c09d0>]
# Configurations: [<cadCAD.configuration.Configuration object at 0x10d0c09d0>]
# Agent burns. P =  1 private_price =  0
# No attestation. alpha =  0.5 private_alpha =  0
# signal['dP'] =  0.25
# prev_state['timestep'] =  1
# Agent bonds. P =  1 private_price =  1.00078539687147
# No attestation. alpha =  0.5 private_alpha =  0.75
# invariant_V =  1200.0
# RESERVE =  300.0007853968715
# SUPPLY =  599.9992146036425
# SPOT PRICE P (from bondburn update) =  1.0
# PRICE pbar (from update) = 1.0000006543900286
# C = 700 alpha =  0.5 R =  300 deltaR =  0.0007853968714699455
# INVARIANT I (from update) = 650.0007853968715
# ...

# %%
print(experiments2.dataset[0].head())
# Out:
#        reserve     price  realized_price  spot_price  private_price  \
# 0   300.000000  1.000000               0    1.000000       0.000000
# 6   300.000785  1.000001               0    0.063378       1.000785
# 12  300.938978  0.062698               0    0.167393       1.001571
# 18  301.773941  0.166913               0    0.218067       1.002356
# 24  302.559016  0.217674               0    0.248164       1.003142
#
#     private_alpha     kappa      supply     alpha  supply_0  ...  invariant_I  \
# 0        0.000000  2.000000  600.000000  0.500000         0  ...   650.000000
# 6        0.750000  0.126755  599.999215 -0.374249         0  ...   650.000785
# 12      -0.124249  0.325418  585.035608 -0.290012         0  ...    38.964873
# 18      -0.040012  0.419141  580.033209 -0.250411         0  ...    98.765844
# 24      -0.000411  0.472796  576.426559 -0.227872         0  ...   127.271032
#
#     agent_attestations_1  agent_attestations_0  agent_reserve  agent_supply  \
# ...

# %%
plt.plot(experiments2.dataset[0].kappa)

# %%
plt.plot(experiments2.dataset[0].alpha)

# %%
experiments3 = run.run()
# Out:
#                             __________   ____
#           ________ __ _____/ ____/   |  / __ \
#          / ___/ __` / __  / /   / /| | / / / /
#         / /__/ /_/ / /_/ / /___/ ___ |/ /_/ /
#         \___/\__,_/\__,_/\____/_/  |_/_____/
#         by BlockScience
#
# Execution Mode: multi_proc: [<cadCAD.configuration.Configuration object at 0x10d0c09d0>]
# Configurations: [<cadCAD.configuration.Configuration object at 0x10d0c09d0>]

# %%
# Out:
#        reserve     price  realized_price  spot_price  private_price  \
# 0   300.000000  1.000000               0    1.000000       0.000000
# 6   300.000785  1.000001               0    0.063378       1.000785
# 12  300.938978  0.062698               0    0.167393       1.001571
# 18  301.773941  0.166913               0    0.218067       1.002356
# 24  302.559016  0.217674               0    0.248164       1.003142
#
#     private_alpha     kappa      supply     alpha  supply_0  ...  invariant_I  \
# 0        0.000000  2.000000  600.000000  0.500000         0  ...   650.000000
# 6        0.750000  0.126755  599.999215 -0.374249         0  ...   650.000785
# 12      -0.124249  0.325418  585.035608 -0.290012         0  ...    38.964873
# 18      -0.040012  0.419141  580.033209 -0.250411         0  ...    98.765844
# 24      -0.000411  0.472796  576.426559 -0.227872         0  ...   127.271032
#
#     agent_attestations_1  agent_attestations_0  agent_reserve  agent_supply  \
# ...

# %%
from src.sim import run
import matplotlib.pyplot as plt

# %%
experiments4 = run.run()
# Out:
#                             __________   ____
#           ________ __ _____/ ____/   |  / __ \
#          / ___/ __` / __  / /   / /| | / / / /
#         / /__/ /_/ / /_/ / /___/ ___ |/ /_/ /
#         \___/\__,_/\__,_/\____/_/  |_/_____/
#         by BlockScience
#
# Execution Mode: multi_proc: [<cadCAD.configuration.Configuration object at 0x10d0c09d0>]
# Configurations: [<cadCAD.configuration.Configuration object at 0x10d0c09d0>]

# %%
print(experiments4.dataset[0].head())
# Out:
#        reserve     price  realized_price  spot_price  private_price  \
# 0   300.000000  1.000000               0    1.000000       0.000000
# 6   300.000785  1.000001               0    0.063378       1.000785
# 12  300.938978  0.062698               0    0.167393       1.001571
# 18  301.773941  0.166913               0    0.218067       1.002356
# 24  302.559016  0.217674               0    0.248164       1.003142
#
#     private_alpha     kappa      supply     alpha  supply_0  ...  invariant_I  \
# 0        0.000000  2.000000  600.000000  0.500000         0  ...   650.000000
# 6        0.750000  0.126755  599.999215 -0.374249         0  ...   650.000785
# 12      -0.124249  0.325418  585.035608 -0.290012         0  ...    38.964873
# 18      -0.040012  0.419141  580.033209 -0.250411         0  ...    98.765844
# 24      -0.000411  0.472796  576.426559 -0.227872         0  ...   127.271032
#
#     agent_attestations_1  agent_attestations_0  agent_reserve  agent_supply  \
# ...

# %%
from src.sim import run2
import matplotlib.pyplot as plt
# Out:
#                             __________   ____
#           ________ __ _____/ ____/   |  / __ \
#          / ___/ __` / __  / /   / /| | / / / /
#         / /__/ /_/ / /_/ / /___/ ___ |/ /_/ /
#         \___/\__,_/\__,_/\____/_/  |_/_____/
#         by BlockScience
#
# Execution Mode: multi_proc: [<cadCAD.configuration.Configuration object at 0x10d0c09d0>]
# Configurations: [<cadCAD.configuration.Configuration object at 0x10d0c09d0>]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-a778bbdaa468> in <module>
# ----> 1 from src.sim import run2
#       2 import matplotlib.pyplot as plt
#
# ~/Documents/Github/ICF_Internal/Model/src/sim/run2.py in <module>
#       9 run = Executor(exec_context=multi_proc_ctx, configs=configs)
#      10
# ---> 11 raw_system_events, tensor_field = run.execute()
#      12 simulation_result = pd.DataFrame(raw_system_events)
#      13
# ...

# %%
experiments = run2.run()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-d2d0cb394258> in <module>
# ----> 1 experiments = run2.run()
#
# NameError: name 'run2' is not defined

# %%
from src.sim import run
import matplotlib.pyplot as plt

# %%
experiments5 = run.run()
# Out:
#                             __________   ____
#           ________ __ _____/ ____/   |  / __ \
#          / ___/ __` / __  / /   / /| | / / / /
#         / /__/ /_/ / /_/ / /___/ ___ |/ /_/ /
#         \___/\__,_/\__,_/\____/_/  |_/_____/
#         by BlockScience
#
# Execution Mode: multi_proc: [<cadCAD.configuration.Configuration object at 0x10d0c09d0>]
# Configurations: [<cadCAD.configuration.Configuration object at 0x10d0c09d0>]

# %%
print(experiments5.dataset[0].head())
# Out:
#        reserve     price  realized_price  spot_price  private_price  \
# 0   300.000000  1.000000               0    1.000000       0.000000
# 6   300.000785  1.000001               0    0.063378       1.000785
# 12  300.938978  0.062698               0    0.167393       1.001571
# 18  301.773941  0.166913               0    0.218067       1.002356
# 24  302.559016  0.217674               0    0.248164       1.003142
#
#     private_alpha     kappa      supply     alpha  supply_0  ...  invariant_I  \
# 0        0.000000  2.000000  600.000000  0.500000         0  ...   650.000000
# 6        0.750000  0.126755  599.999215 -0.374249         0  ...   650.000785
# 12      -0.124249  0.325418  585.035608 -0.290012         0  ...    38.964873
# 18      -0.040012  0.419141  580.033209 -0.250411         0  ...    98.765844
# 24      -0.000411  0.472796  576.426559 -0.227872         0  ...   127.271032
#
#     agent_attestations_1  agent_attestations_0  agent_reserve  agent_supply  \
# ...

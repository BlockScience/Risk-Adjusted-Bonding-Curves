# %%
from src.sim import run
import matplotlib.pyplot as plt

# %%
experiments = run.run()
# Out:
#                             __________   ____
#           ________ __ _____/ ____/   |  / __ \
#          / ___/ __` / __  / /   / /| | / / / /
#         / /__/ /_/ / /_/ / /___/ ___ |/ /_/ /
#         \___/\__,_/\__,_/\____/_/  |_/_____/
#         by BlockScience
#
# Execution Mode: multi_proc: [<cadCAD.configuration.Configuration object at 0x118406590>]
# Configurations: [<cadCAD.configuration.Configuration object at 0x118406590>]

# %%
print(experiments.dataset[0].head())
# Out:
#        reserve     price  realized_price  spot_price  private_price  \
# 0   300.000000  1.000000               0    1.000000       0.000000
# 6   300.000785  1.000001               0    1.083336       1.000785
# 12  299.912213  1.083250               0    1.083041       1.001571
# 18  299.824835  1.082956               0    1.082750       1.002356
# 24  299.738646  1.082666               0    1.082462       1.003142
#
#     private_alpha     kappa      supply     alpha  supply_0  ...  invariant_I  \
# 0        0.000000  2.000000  600.000000  0.500000       0.0  ...   650.000000
# 6        1.000785  2.166664  599.999215 -0.592795       0.0  ...   650.000785
# 12       1.001571  2.167008  600.080980 -0.592795       0.0  ...  -114.956050
# 18       1.002356  2.167348  600.161665 -0.592795       0.0  ...  -115.044622
# 24       1.003142  2.167684  600.241273 -0.592795       0.0  ...  -115.132000
#
#     agent_attestations_1  agent_attestations_0  agent_reserve  agent_supply  \
# 0               0.000000                   0.0       0.000000      0.000000
# 6               0.500785                   0.0      -0.000785     -0.500000
# 12              0.500785                   0.0       0.087787     -0.581765
# 18              0.500785                   0.0       0.175165     -0.662450
# 24              0.500785                   0.0       0.261354     -0.742058
#
#     agent_supply_1  agent_supply_0  run  substep  timestep
# 0         0.000000        0.000000    1        0         0
# 6         0.500785        0.500785    1        6         1
# 12        0.500785        0.500785    1        6         2
# 18        0.500785        0.500785    1        6         3
# 24        0.500785        0.500785    1        6         4
#
# [5 rows x 25 columns]

# %%
plt.plot(experiments.dataset[0].kappa)

# %%
plt.plot(experiments.dataset[0].alpha)

# %%
plt.plot(experiments.dataset[0].reserve)

# %%
plt.plot(experiments.dataset[0].supply)

# %%
plt.plot(experiments.dataset[0].price)

# %%
from src.sim import run
import matplotlib.pyplot as plt
# Out:
# Initial Conditions (config.py) :  {'reserve': 300, 'price': 1, 'realized_price': 0, 'spot_price': 1, 'private_price': 0, 'private_alpha': 0, 'kappa': 0, 'supply': 600.0, 'alpha': [0.5], 'supply_0': 0, 'supply_1': 0, 'supply_free': 600.0, 'attestations_0': 1, 'attestations_1': 1, 'invariant_V': 1200.0, 'invariant_I': 650.0, 'agent_attestations_1': 0, 'agent_attestations_0': 0, 'agent_reserve': 0, 'agent_supply': 0, 'agent_supply_1': 0, 'agent_supply_0': 0}
# [{'N': 1, 'T': range(0, 400), 'M': {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 1000, 'C': 700, 'period': 2000}}]
# Params (config.py) :  {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 1000, 'C': 700, 'period': 2000}

# %%
experiments = run.run()
# Out:
#                             __________   ____
#           ________ __ _____/ ____/   |  / __ \
#          / ___/ __` / __  / /   / /| | / / / /
#         / /__/ /_/ / /_/ / /___/ ___ |/ /_/ /
#         \___/\__,_/\__,_/\____/_/  |_/_____/
#         by BlockScience
#
# Execution Mode: multi_proc: [<cadCAD.configuration.Configuration object at 0x10c5de450>]
# Configurations: [<cadCAD.configuration.Configuration object at 0x10c5de450>]
# Agent burns. P =  1 private_price =  0
# No attestation. alpha =  0.5 private_alpha =  0 s =  0
# signal['dP'] =  0.25
# prev_state['timestep'] =  1
# new_private_alpha =  1.00078539687147
# Agent bonds. P =  1 private_price =  1.00078539687147
# No attestation. alpha =  0.5 private_alpha =  1.00078539687147 s =  0
# invariant_V =  1200.0
# RESERVE =  300.0007853968715
# SUPPLY =  599.9992146036425
# AGENT SUPPLY = 0.0007853963575144007 deltas =  0.0007853963575144007 policy_input['amt_to_burn'] =  0
# SPOT PRICE P (from bondburn update) =  1.0
# ...

# %%
plt.plot(experiments.dataset[0].kappa)

# %%
plt.plot(experiments.dataset[0].alpha)

# %%
plt.plot(experiments.dataset[0].reserve)

# %%
plt.plot(experiments.dataset[0].supply)

# %%
plt.plot(experiments.dataset[0].price)

# %%
plt.plot(experiments.dataset[0].spot_price)

# %%
plt.plot(experiments.dataset[0].invariant_I)

# %% [markdown]
# #### Need to impose lower bound on Reserve and Supply

# %% [markdown]
# Imposed s > 0 on burn and r > 0 on bond.

# %%
from src.sim import run
import matplotlib.pyplot as plt
# Out:
# Initial Conditions (config.py) :  {'reserve': 300, 'price': 1, 'realized_price': 0, 'spot_price': 1, 'private_price': 0, 'private_alpha': 0, 'kappa': 0, 'supply': 600.0, 'alpha': [0.5], 'supply_0': 0, 'supply_1': 0, 'supply_free': 600.0, 'attestations_0': 1, 'attestations_1': 1, 'invariant_V': 1200.0, 'invariant_I': 650.0, 'agent_attestations_1': 0, 'agent_attestations_0': 0, 'agent_reserve': 50, 'agent_supply': 0, 'agent_supply_1': 0, 'agent_supply_0': 0}
# [{'N': 1, 'T': range(0, 400), 'M': {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 1000, 'C': 700, 'period': 2000}}]
# Params (config.py) :  {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 1000, 'C': 700, 'period': 2000}

# %%
experiments2 = run.run()
# Out:
#                             __________   ____
#           ________ __ _____/ ____/   |  / __ \
#          / ___/ __` / __  / /   / /| | / / / /
#         / /__/ /_/ / /_/ / /___/ ___ |/ /_/ /
#         \___/\__,_/\__,_/\____/_/  |_/_____/
#         by BlockScience
#
# Execution Mode: multi_proc: [<cadCAD.configuration.Configuration object at 0x116950690>]
# Configurations: [<cadCAD.configuration.Configuration object at 0x116950690>]
# ----Agent supply too low---- | s =  0
# --------------------------------------2
# Agent bonds. P =  1 | private_price =  1.00078539687147
# RESERVE =  300.01963492178675  | deltaR =  0.0  | deltaS =  0
# SUPPLY =  599.9803653994779  | deltaR =  0.019634921786748638  | deltaS =  0.019634600522067558
# AGENT RESERVE = 49.980365078213254 deltar =  0.0 policy_input['amt_to_bond'] =  0.019634921786748638
# AGENT SUPPLY = 0.019634600522067558 deltas =  0.019634600522067558 policy_input['amt_to_burn'] =  0
# SPOT PRICE P (from bondburn update) =  1.0
# ...

# %%
plt.plot(experiments2.dataset[0].reserve)

# %%
plt.plot(experiments2.dataset[0].supply)

# %%
plt.plot(experiments2.dataset[0].price)

# %%
plt.plot(experiments2.dataset[0].spot_price)

# %%
plt.plot(experiments2.dataset[0].agent_reserve)

# %%
plt.plot(experiments2.dataset[0].agent_supply)

# %%
# import sys
# sys.path.append('../')
import pandas as pd

import matplotlib.pyplot as plt
# import run2

from src.sim import run

import seaborn as sns

# For analysis
import numpy as np
import pandas as pd

sns.set_style("whitegrid")

experiments = run.run()
# Out:
# Initial Conditions (config.py) :  {'reserve': 1000, 'pbar': 1, 'realized_price': 0, 'spot_price': 1, 'kappa': 0, 'supply': 2000.0, 'alpha': [0.5], 'alpha_bar': [0.5], 'supply_0': 20, 'supply_1': 30, 'supply_free': 2000.0, 'attestations': 40, 'attestations_0': 20, 'attestations_1': 20, 'invariant_V': 4000.0, 'invariant_I': 2000.0, 'agents':    id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0   0                     0                     0            100
# 1   1                     0                     0            100
# 2   2                     0                     0            100
# 3   3                     0                     0            100
# 4   4                     0                     0            100
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0               3               2                 45                  0.3
# 1               3               2                 45                  0.4
# 2               3               2                 45                  0.5
# 3               3               2                 45                  0.6
# 4               3               2                 45                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  0.9
# 2                  1.0
# 3                  1.1
# 4                  1.5  , 'chosen_agent': 0}
# -----------------PSUB---------------------
# Params (config.py) :  {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 1000, 'C': 2000, 'f': 0.03, 'm': 0.15, 'beta': 0.9, 'dust': 1e-08, 'period': 2000, 'rules_price': 'martin', 'E': 0.2}
# Params (config.py) :  {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 1000, 'C': 2000, 'f': 0.03, 'm': 0.15, 'beta': 0.9, 'dust': 1e-08, 'period': 2000, 'rules_price': 'martin', 'E': 0.2}
# Params (config.py) :  {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 1000, 'C': 2000, 'f': 0.03, 'm': 0.15, 'beta': 0.9, 'dust': 1e-08, 'period': 2000, 'rules_price': 'step', 'E': 0.2}
# Params (config.py) :  {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 1000, 'C': 2000, 'f': 0.03, 'm': 0.15, 'beta': 0.9, 'dust': 1e-08, 'period': 2000, 'rules_price': 'step', 'E': 0.2}
# Configurations Length: 4
# Execution Method: parallelize_simulations
# Execution Mode: parallelized
#    id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0   0                     0                     0            100
# 1   1                     0                     0            100
# 2   2                     0                     0            100
# 3   3                     0                     0            100
# 4   4                     0                     0            100
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0               3               2                 45                  0.3
# 1               3               2                 45                  0.4
# 2               3               2                 45                  0.5
# 3               3               2                 45                  0.6
# 4               3               2                 45                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  0.9
# 2                  1.0
# 3                  1.1
# 4                  1.5     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0   0                     0                     0            100
# 1   1                     0                     0            100
# 2   2                     0                     0            100
# 3   3                     0                     0            100
# 4   4                     0                     0            100
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0               3               2                 45                  0.3
# 1               3               2                 45                  0.4
# 2               3               2                 45                  0.5
# 3               3               2                 45                  0.6
# 4               3               2                 45                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  0.9
# 2                  1.0
# 3                  1.1
# 4                  1.5
# --------------TIMESTEP 0 --------------
#
# CHOSEN AGENT =     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0   0                     0                     0            100
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0               3               2                 45                  0.3
#
#    agent_private_price
# 0                  0.5   Time  0
# r 100
# No trade. P =  1 private_price =  0.5
# Negative attestation. | alpha =  0.5 private_alpha =  0.3
# amt_neg =  10.944710359019632
#    id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0   0                     0                     0            100
# 1   1                     0                     0            100
# 2   2                     0                     0            100
# 3   3                     0                     0            100
# 4   4                     0                     0            100
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0               3               2                 45                  0.3
# 1               3               2                 45                  0.4
# 2               3               2                 45                  0.5
# 3               3               2                 45                  0.6
# 4               3               2                 45                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  0.9
# 2                  1.0
# 3                  1.1
# 4                  1.5     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0   0                     0                     0            100
# 1   1                     0                     0            100
# 2   2                     0                     0            100
# 3   3                     0                     0            100
# 4   4                     0                     0            100
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0               3               2                 45                  0.3
# 1               3               2                 45                  0.4
# 2               3               2                 45                  0.5
# 3               3               2                 45                  0.6
# 4               3               2                 45                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  0.9
# 2                  1.0
# 3                  1.1
# 4                  1.5
#
# --------------TIMESTEP 0 --------------
# --------------TIMESTEP 0 --------------
# --------------TIMESTEP 0 --------------
# CHOSEN AGENT =  CHOSEN AGENT =     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0   0                     0                     0            100
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0               3               2                 45                  0.3
#
#    agent_private_price
# 0                  0.5     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 2   2                     0                     0            100
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 2               3               2                 45                  0.5
#
#    agent_private_price
# 2                  1.0   Time  0
#  Time  0
# r 100
# r 100
# No trade. P =  1 private_price =  0.5
# No trade. P =  1 private_price =  1.0
# Negative attestation. | alpha =  0.5 private_alpha =  0.3
# amt_neg =  12.511715665982074
# No attestation. alpha =  0.5 private_alpha =  0.5 s_free =  45
# ::::delta R:::: 0.0
# amt_Q0 =  0.06246104378015538
# ::::AMTBOND:::: 0
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# ::::delta S:::: 0.0
# ::::delta S:::: 0.0
# ::::AMTBURN:::: 0
# PRICE (BOND/BURN):  1.0
# ::::AMTBURN:::: 0
# PRICE pbar (from bondburn update) = 0.0
# PRICE (BOND/BURN):  1.0
# r 100.0
# PRICE pbar (from bondburn update) = 0.0
# No trade. P =  1.0 private_price =  1.0
# r 100.0
# CHOSEN AGENT =     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 2   2                     0                     0            100
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 2               3               2                 45                  0.5
#
#    agent_private_price
# 2                  1.0  amt_Q0 =  0.05464888926764111
#  Time  0
# ::::delta R:::: 0.0
# r 100
# ::::AMTBOND:::: 0
# ::::delta S:::: 0.0
# No trade. P =  1 private_price =  1.0
# ::::AMTBURN:::: 0
# No attestation. alpha =  0.5 private_alpha =  0.5 s_free =  45
# ::::delta R:::: 0.0
# PRICE (BOND/BURN):  1.0
# ::::AMTBOND:::: 0
# PRICE pbar (from bondburn update) = 0.0
# ::::delta S:::: 0.0
# r 100.0
# ::::AMTBURN:::: 0
# PRICE (BOND/BURN):  1.0
# No trade. P =  1.0 private_price =  0.5
# PRICE pbar (from bondburn update) = 0.0
# Negative attestation. | alpha =  0.5 private_alpha =  0.3
# r 100.0
# amt_neg =  10.202159380012606
# No trade. P =  1.0 private_price =  1.0
# amt_Q0 =  0.05094590975704083
# No attestation. alpha =  0.5 private_alpha =  0.5 s_free =  45.0
# Negative attestation 2
# PRICE (ATTEST):  1.0
# PRICE (ATTEST):  0.9966532297000859
# Negative attestation 2
# No trade. P =  1.0 private_price =  0.5
# No attestation. alpha =  0.5 private_alpha =  0.5 s_free =  45.0
# Negative attestation. | alpha =  0.5 private_alpha =  0.3
# Negative attestation 1
# amt_neg =  8.948312545421658
# PRICE (ATTEST):  1.0
# amt_Q0 =  0.04469162918412817
# Negative attestation 2
# Negative attestation 2
# Negative attestation 2
# PRICE (ATTEST):  1.0181649181265433
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0                   0.0          100.0
# 1  1.0                   0.0                   0.0          100.0
# 2  2.0                   0.0                   0.0          100.0
# 3  3.0                   0.0                   0.0          100.0
# 4  4.0                   0.0                   0.0          100.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0             2.0               45.0                  0.3
# 1             3.0             2.0               45.0                  0.4
# 2             3.0             2.0               45.0                  0.5
# 3             3.0             2.0               45.0                  0.6
# 4             3.0             2.0               45.0                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  0.9
# 2                  1.0
# 3                  1.1
# 4                  1.5  Negative attestation 2
#
# Negative attestation 1
# --------------TIMESTEP 1 --------------
# Negative attestation 2
# CHOSEN AGENT =  Negative attestation 2
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 3  3.0                   0.0                   0.0          100.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 3             3.0             2.0               45.0                  0.6
#
#    agent_private_price
# 3                  1.1   Time  1
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0                   0.0          100.0
# 1  1.0                   0.0                   0.0          100.0
# 2  2.0                   0.0                   0.0          100.0
# 3  3.0                   0.0                   0.0          100.0
# 4  4.0                   0.0                   0.0          100.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0             2.0               45.0                  0.3
# 1             3.0             2.0               45.0                  0.4
# 2             3.0             2.0               45.0                  0.5
# 3             3.0             2.0               45.0                  0.6
# 4             3.0             2.0               45.0                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  0.9
# 2                  1.0
# 3                  1.1
# 4                  1.5  r 100.0
# No trade. P =  1.0 private_price =  1.1
#
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0              0.044692          100.0
# 1  1.0                   0.0              0.000000          100.0
# 2  2.0                   0.0              0.000000          100.0
# 3  3.0                   0.0              0.000000          100.0
# 4  4.0                   0.0              0.000000          100.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0       10.948313          36.051687                  0.3
# 1             3.0        2.000000          45.000000                  0.4
# 2             3.0        2.000000          45.000000                  0.5
# 3             3.0        2.000000          45.000000                  0.6
# 4             3.0        2.000000          45.000000                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  0.9
# 2                  1.0
# 3                  1.1
# 4                  1.5
# Positive attestation. | alpha =  0.5 private_alpha =  0.6
# --------------TIMESTEP 1 --------------
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0              0.050946          100.0
# 1  1.0                   0.0              0.000000          100.0
# 2  2.0                   0.0              0.000000          100.0
# 3  3.0                   0.0              0.000000          100.0
# 4  4.0                   0.0              0.000000          100.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0       12.202159          34.797841                  0.3
# 1             3.0        2.000000          45.000000                  0.4
# 2             3.0        2.000000          45.000000                  0.5
# 3             3.0        2.000000          45.000000                  0.6
# 4             3.0        2.000000          45.000000                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  0.9
# 2                  1.0
# 3                  1.1
# 4                  1.5  --------------TIMESTEP 1 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 3  3.0                   0.0                   0.0          100.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 3             3.0             2.0               45.0                  0.6
#
#    agent_private_price
# 3                  1.1
#  Time  1
# --------------TIMESTEP 1 --------------
# r 100.0
# CHOSEN AGENT =  No trade. P =  1.0 private_price =  1.1
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0              0.044692          100.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0       10.948313          36.051687                  0.3
#
#    agent_private_price
# 0                  0.5  Positive attestation. | alpha =  0.5 private_alpha =  0.6
# amt_pos =  5.924381778807924
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0              0.050946          100.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0       12.202159          34.797841                  0.3
#
#    agent_private_price
# 0                  0.5   Time  1
# amt_pos =  5.239998492438267
# amt_Q1 =  0.02960000488680503
#  Time  1
# amt_Q1 =  0.026182853916210114
# r 100.0
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# No trade. P =  0.9966532297000859 private_price =  0.5
# ::::delta S:::: 0.0
# Negative attestation. | alpha =  0.49832099560801035 private_alpha =  0.3
# ::::AMTBURN:::: 0
# amt_neg =  10.270669340865059
# PRICE (BOND/BURN):  1.0
# PRICE pbar (from bondburn update) = 0.0
# r 100.0
# No trade. P =  1.0 private_price =  1.1
# amt_Q0 =  0.051418230928778605
# Positive attestation. | alpha =  0.5 private_alpha =  0.6
# r 100.0
# amt_pos =  7.192810138830941
# ::::delta R:::: 0.0
# amt_Q1 =  0.03593177338568676
# ::::AMTBOND:::: 0
# Positive attestation 2
# PRICE (ATTEST):  1.4298202534707734
# ::::delta S:::: 1.1368683772161603e-12
# Positive attestation 2
# ::::delta R:::: 0.0
# No trade. P =  1.0181649181265433 private_price =  0.5
# ::::AMTBURN:::: 0
# Positive attestation 1
# Positive attestation 2
# Positive attestation 2
# ::::AMTBOND:::: 0
# Negative attestation. | alpha =  0.5089204203578176 private_alpha =  0.3
# ::::delta S:::: 0.0
# amt_neg =  10.348249437830807
# ::::AMTBURN:::: 0
# amt_Q0 =  0.051789961723200745
# PRICE (BOND/BURN):  1.0
# PRICE (BOND/BURN):  0.9966532297000856
# ::::delta R:::: 0.0
# PRICE pbar (from bondburn update) = 0.0
# ::::AMTBOND:::: 0
# r 100.0
# ::::delta S:::: 2.2737367544323206e-13
# No trade. P =  1.0 private_price =  1.1
# Positive attestation. | alpha =  0.5 private_alpha =  0.6
# ::::AMTBURN:::: 0
# PRICE (BOND/BURN):  1.0181649181265435
# amt_pos =  6.806773979220135
# PRICE pbar (from bondburn update) = 0.0
# amt_Q1 =  0.034004961460998295
# PRICE pbar (from bondburn update) = 0.0
# r 100.0
# Positive attestation 2
# No trade. P =  1.0181649181265435 private_price =  0.5
# PRICE (ATTEST):  1.420169349480503
# Negative attestation. | alpha =  0.5089204203578176 private_alpha =  0.3
# amt_neg =  9.114030437729571
# Positive attestation 2
# amt_Q0 =  0.045620068644770466
# Positive attestation 1
# Positive attestation 2
# Negative attestation 2
# r 100.0
# PRICE (ATTEST):  0.8879027340379517
# Positive attestation 2
# Negative attestation 2
# No trade. P =  0.9966532297000856 private_price =  0.5
# Negative attestation 1
# Negative attestation. | alpha =  0.49832099560801035 private_alpha =  0.3
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000                   0.0          100.0
# 1  1.0              0.000000                   0.0          100.0
# 2  2.0              0.000000                   0.0          100.0
# 3  3.0              0.034005                   0.0          100.0
# 4  4.0              0.000000                   0.0          100.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000             2.0          45.000000                  0.3
# 1        3.000000             2.0          45.000000                  0.4
# 2        3.000000             2.0          45.000000                  0.5
# 3        9.806774             2.0          38.193226                  0.6
# 4        3.000000             2.0          45.000000                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  0.9
# 2                  1.0
# 3                  1.1
# 4                  1.5  Negative attestation 2
#
# Negative attestation 2
# --------------TIMESTEP 2 --------------
# amt_neg =  10.220500628055158
# amt_Q0 =  0.051167390074116324
# Negative attestation 2
# PRICE (ATTEST):  0.8721676178547424
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000                   0.0          100.0
# 1  1.0              0.000000                   0.0          100.0
# 2  2.0              0.000000                   0.0          100.0
# 3  3.0              0.035932                   0.0          100.0
# 4  4.0              0.000000                   0.0          100.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0         3.00000             2.0           45.00000                  0.3
# 1         3.00000             2.0           45.00000                  0.4
# 2         3.00000             2.0           45.00000                  0.5
# 3        10.19281             2.0           37.80719                  0.6
# 4         3.00000             2.0           45.00000                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  0.9
# 2                  1.0
# 3                  1.1
# 4                  1.5  Negative attestation 2
#
# Negative attestation 1
# --------------TIMESTEP 2 --------------
# Negative attestation 2
# Negative attestation 2
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0                   0.0                   0.0          100.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1             3.0             2.0               45.0                  0.4
#
#    agent_private_price
# 1                  0.9   Time  2
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0              0.090312          100.0
# 1  1.0                   0.0              0.000000          100.0
# 2  2.0                   0.0              0.000000          100.0
# 3  3.0                   0.0              0.000000          100.0
# 4  4.0                   0.0              0.000000          100.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0       20.062343          26.937657                  0.3
# 1             3.0        2.000000          45.000000                  0.4
# 2             3.0        2.000000          45.000000                  0.5
# 3             3.0        2.000000          45.000000                  0.6
# 4             3.0        2.000000          45.000000                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  0.9
# 2                  1.0
# 3                  1.1
# 4                  1.5      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0                   0.0                   0.0          100.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1             3.0             2.0               45.0                  0.4
#
#    agent_private_price
# 1                  0.9
#  Time  2
# r 100.0
# --------------TIMESTEP 2 --------------
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0              0.102113          100.0
# 1  1.0                   0.0              0.000000          100.0
# 2  2.0                   0.0              0.000000          100.0
# 3  3.0                   0.0              0.000000          100.0
# 4  4.0                   0.0              0.000000          100.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0        22.42266           24.57734                  0.3
# 1             3.0         2.00000           45.00000                  0.4
# 2             3.0         2.00000           45.00000                  0.5
# 3             3.0         2.00000           45.00000                  0.6
# 4             3.0         2.00000           45.00000                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  0.9
# 2                  1.0
# 3                  1.1
# 4                  1.5  No trade. P =  1.4298202534707734 private_price =  0.9
# Negative attestation. | alpha =  0.6503056948687849 private_alpha =  0.4
#
# amt_neg =  15.79986986682803
# --------------TIMESTEP 2 --------------
# amt_Q0 =  0.07884394016163476
# ::::delta R:::: 0.0
# CHOSEN AGENT =  ::::AMTBOND:::: 0
# CHOSEN AGENT =  r 100.0
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 2  2.0                   0.0                   0.0          100.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 2             3.0             2.0               45.0                  0.5
#
#    agent_private_price
# 2                  1.0  ::::delta S:::: -6.821210263296962e-13
# ::::AMTBURN:::: 0
#  Time  2
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 2  2.0                   0.0                   0.0          100.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 2             3.0             2.0               45.0                  0.5
#
#    agent_private_price
# 2                  1.0  No trade. P =  1.420169349480503 private_price =  0.9
# PRICE (BOND/BURN):  1.4298202534707736
#  Time  2
# r 100.0
# r 100.0
# Negative attestation. | alpha =  0.6479293119634644 private_alpha =  0.4
# PRICE pbar (from bondburn update) = -0.0
# amt_neg =  15.500979908717811
# No trade. P =  0.8879027340379517 private_price =  1.0
# Positive attestation. | alpha =  0.4407723667024873 private_alpha =  0.5
# amt_Q0 =  0.0773553034692176
# r 100.0
# ::::delta R:::: 0.0
# amt_pos =  3.666432724878609
# ::::AMTBOND:::: 0
# amt_Q1 =  0.018323769611074958
# No trade. P =  0.8721676178547424 private_price =  1.0
# No trade. P =  1.4298202534707736 private_price =  0.9
# ::::delta S:::: -2.2737367544323206e-13
# ::::delta R:::: -1.1368683772161603e-13
# ::::AMTBURN:::: 0
# ::::AMTBOND:::: 0
# ::::delta S:::: 1.1368683772161603e-12
# PRICE (BOND/BURN):  1.4201693494805026
# ::::AMTBURN:::: 0
# PRICE pbar (from bondburn update) = -0.0
# Positive attestation. | alpha =  0.42599924508053433 private_alpha =  0.5
# PRICE (BOND/BURN):  0.8879027340379515
# Negative attestation. | alpha =  0.6503056948687849 private_alpha =  0.4
# r 100.0
# amt_neg =  15.976909177382248
# PRICE pbar (from bondburn update) = 0.0
# No trade. P =  1.4201693494805026 private_price =  0.9
# r 99.99999999999989
# Negative attestation. | alpha =  0.6479293119634644 private_alpha =  0.4
# No trade. P =  0.8879027340379515 private_price =  1.0
# amt_pos =  4.393749524327537
# Positive attestation. | alpha =  0.4407723667024873 private_alpha =  0.5
# amt_neg =  14.861607880173509
# amt_Q0 =  0.0797256414393388
# amt_pos =  4.274259520483226
# amt_Q1 =  0.021359891478316406
# amt_Q0 =  0.07417050779520373
# Positive attestation 2
# PRICE (ATTEST):  1.0073456399354455
# Positive attestation 2
# Negative attestation 2
# Positive attestation 1
# Negative attestation 2
# PRICE (ATTEST):  0.9047951048891294
# Positive attestation 2
# Positive attestation 2
# Negative attestation 2
# PRICE (ATTEST):  0.8958810027365584
# amt_Q1 =  0.021956695210021415
# Negative attestation 2
# Negative attestation 1
# Negative attestation 2
# ::::delta R:::: 0.0
# Negative attestation 2
# Negative attestation 1
# ::::AMTBOND:::: 0
# ::::delta S:::: -4.547473508864641e-13
# Negative attestation 2
# ::::AMTBURN:::: 0
# Negative attestation 2
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000              0.000000          100.0
# 1  1.0              0.000000              0.079726          100.0
# 2  2.0              0.000000              0.000000          100.0
# 3  3.0              0.035932              0.000000          100.0
# 4  4.0              0.000000              0.000000          100.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0         3.00000        2.000000          45.000000                  0.3
# 1         3.00000       17.976909          29.023091                  0.4
# 2         3.00000        2.000000          45.000000                  0.5
# 3        10.19281        2.000000          37.807190                  0.6
# 4         3.00000        2.000000          45.000000                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  0.9
# 2                  1.0
# 3                  1.1
# 4                  1.5  PRICE (BOND/BURN):  0.8721676178547425
# PRICE pbar (from bondburn update) = -0.0
# r 100.0
#
# No trade. P =  0.8721676178547425 private_price =  1.0
# --------------TIMESTEP 3 --------------
# Positive attestation. | alpha =  0.42599924508053433 private_alpha =  0.5
# amt_pos =  5.103891198093054
# CHOSEN AGENT =  amt_Q1 =  0.02550319566573478
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 4  4.0                   0.0                   0.0          100.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 4             3.0             2.0               45.0                  0.7
#
#    agent_private_price
# 4                  1.5  Positive attestation 2
#  Time  3
# PRICE (ATTEST):  1.0038791956524171
# r 100.0
# Positive attestation 2
# Positive attestation 1
# No trade. P =  0.8958810027365584 private_price =  1.5
# Positive attestation 2
# Positive attestation. | alpha =  0.50830877153016 private_alpha =  0.7
# Positive attestation 2
# amt_pos =  9.69514908650484
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0               0.00000              0.090312          100.0
# 1  1.0               0.00000              0.000000          100.0
# 2  2.0               0.02136              0.000000          100.0
# 3  3.0               0.00000              0.000000          100.0
# 4  4.0               0.00000              0.000000          100.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0         3.00000       20.062343          26.937657                  0.3
# 1         3.00000        2.000000          45.000000                  0.4
# 2         7.27426        2.000000          40.725740                  0.5
# 3         3.00000        2.000000          45.000000                  0.6
# 4         3.00000        2.000000          45.000000                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  0.9
# 2                  1.0
# 3                  1.1
# 4                  1.5      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000              0.000000          100.0
# 1  1.0              0.000000              0.074171          100.0
# 2  2.0              0.000000              0.000000          100.0
# 3  3.0              0.034005              0.000000          100.0
# 4  4.0              0.000000              0.000000          100.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000        2.000000          45.000000                  0.3
# 1        3.000000       16.861608          30.138392                  0.4
# 2        3.000000        2.000000          45.000000                  0.5
# 3        9.806774        2.000000          38.193226                  0.6
# 4        3.000000        2.000000          45.000000                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  0.9
# 2                  1.0
# 3                  1.1
# 4                  1.5
#
# --------------TIMESTEP 3 --------------
# --------------TIMESTEP 3 --------------
# amt_Q1 =  0.04850412563153537
# ::::delta R:::: 0.0
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000              0.102113          100.0
# 1  1.0              0.000000              0.000000          100.0
# 2  2.0              0.025503              0.000000          100.0
# 3  3.0              0.000000              0.000000          100.0
# 4  4.0              0.000000              0.000000          100.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000        22.42266          24.577340                  0.3
# 1        3.000000         2.00000          45.000000                  0.4
# 2        8.103891         2.00000          39.896109                  0.5
# 3        3.000000         2.00000          45.000000                  0.6
# 4        3.000000         2.00000          45.000000                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  0.9
# 2                  1.0
# 3                  1.1
# 4                  1.5  ::::AMTBOND:::: 0
#
# --------------TIMESTEP 3 --------------
# CHOSEN AGENT =  CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 4  4.0                   0.0                   0.0          100.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 4             3.0             2.0               45.0                  0.7
#
#    agent_private_price
# 4                  1.5      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0                   0.0                   0.0          100.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1             3.0             2.0               45.0                  0.4
#
#    agent_private_price
# 1                  0.9   Time  3
#  Time  3
# r 100.0
# r 100.0
# No trade. P =  1.0073456399354455 private_price =  0.9
# No trade. P =  0.9047951048891294 private_price =  1.5
# Negative attestation. | alpha =  0.4738162746689848 private_alpha =  0.4
# amt_neg =  6.272199321206964
# Positive attestation. | alpha =  0.5135706014882745 private_alpha =  0.7
# amt_Q0 =  0.03147794967073004
# amt_pos =  10.417229051212974
# ::::delta R:::: 0.0
# amt_Q1 =  0.05210694150445928
# ::::AMTBOND:::: 0
# ::::delta S:::: 0.0
# ::::delta R:::: 0.0
# ::::AMTBURN:::: 0
# ::::AMTBOND:::: 0
# PRICE (BOND/BURN):  1.0073456399354455
# PRICE pbar (from bondburn update) = 0.0
# ::::delta S:::: -9.094947017729282e-13
# r 100.0
# ::::AMTBURN:::: 0
# No trade. P =  1.0073456399354455 private_price =  0.9
# PRICE (BOND/BURN):  0.9047951048891294
# Negative attestation. | alpha =  0.4738162746689848 private_alpha =  0.4
# PRICE pbar (from bondburn update) = -0.0
# amt_neg =  3.9466198449893923
# amt_Q0 =  0.01981243650732132
# r 100.0
# Negative attestation 2
# No trade. P =  0.9047951048891294 private_price =  1.5
# PRICE (ATTEST):  0.9283042083194168
# Positive attestation. | alpha =  0.5135706014882745 private_alpha =  0.7
# Negative attestation 2
# amt_pos =  11.913391675052232
# CHOSEN AGENT =  ::::delta S:::: 9.094947017729282e-13
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0                   0.0                   0.0          100.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1             3.0             2.0               45.0                  0.4
#
#    agent_private_price
# 1                  0.9  Negative attestation 1
# amt_Q1 =  0.05957964426080477
#  Time  3
# Negative attestation 2
# Positive attestation 2
# Negative attestation 2
# PRICE (ATTEST):  1.1767467402744924
# r 100.0
# ::::AMTBURN:::: 0
# No trade. P =  1.0038791956524171 private_price =  0.9
# Negative attestation. | alpha =  0.4647887482942498 private_alpha =  0.4
# PRICE (BOND/BURN):  0.8958810027365584
# amt_neg =  5.527779476313329
# PRICE pbar (from bondburn update) = 0.0
# amt_Q0 =  0.02776084359058591
# r 100.0
# ::::delta R:::: 0.0
# No trade. P =  0.8958810027365584 private_price =  1.5
# Positive attestation. | alpha =  0.50830877153016 private_alpha =  0.7
# ::::AMTBOND:::: 0
# amt_pos =  9.777331361965748
# ::::delta S:::: -2.2737367544323206e-13
# amt_Q1 =  0.04891477691123976
# ::::AMTBURN:::: 0
# Positive attestation 2
# PRICE (ATTEST):  1.1405118760553228
# PRICE (BOND/BURN):  1.003879195652417
# Positive attestation 2
# Positive attestation 1
# Positive attestation 2
# PRICE pbar (from bondburn update) = -0.0
# Positive attestation 2
# Positive attestation 2
# r 100.0
# No trade. P =  1.003879195652417 private_price =  0.9
# Positive attestation 1
# Negative attestation. | alpha =  0.4647887482942498 private_alpha =  0.4
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0               0.00000              0.090312          100.0
# 1  1.0               0.00000              0.019812          100.0
# 2  2.0               0.02136              0.000000          100.0
# 3  3.0               0.00000              0.000000          100.0
# 4  4.0               0.00000              0.000000          100.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0         3.00000       20.062343          26.937657                  0.3
# 1         3.00000        5.946620          41.053380                  0.4
# 2         7.27426        2.000000          40.725740                  0.5
# 3         3.00000        2.000000          45.000000                  0.6
# 4         3.00000        2.000000          45.000000                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  0.9
# 2                  1.0
# 3                  1.1
# 4                  1.5  Positive attestation 2
#
# Positive attestation 2
# amt_neg =  3.4560757929766908
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000              0.000000          100.0
# 1  1.0              0.000000              0.079726          100.0
# 2  2.0              0.000000              0.000000          100.0
# 3  3.0              0.035932              0.000000          100.0
# 4  4.0              0.048915              0.000000          100.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000        2.000000          45.000000                  0.3
# 1        3.000000       17.976909          29.023091                  0.4
# 2        3.000000        2.000000          45.000000                  0.5
# 3       10.192810        2.000000          37.807190                  0.6
# 4       12.777331        2.000000          35.222669                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  0.9
# 2                  1.0
# 3                  1.1
# 4                  1.5  amt_Q0 =  0.017361109864207584
#
# Negative attestation 2
# --------------TIMESTEP 4 --------------
# PRICE (ATTEST):  0.9270789670087666
# Negative attestation 2
# --------------TIMESTEP 4 --------------
# CHOSEN AGENT =  Negative attestation 1
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000              0.000000          100.0
# 1  1.0              0.000000              0.074171          100.0
# 2  2.0              0.000000              0.000000          100.0
# 3  3.0              0.034005              0.000000          100.0
# 4  4.0              0.059580              0.000000          100.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000        2.000000          45.000000                  0.3
# 1        3.000000       16.861608          30.138392                  0.4
# 2        3.000000        2.000000          45.000000                  0.5
# 3        9.806774        2.000000          38.193226                  0.6
# 4       14.913392        2.000000          33.086608                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  0.9
# 2                  1.0
# 3                  1.1
# 4                  1.5  Negative attestation 2
# CHOSEN AGENT =
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 3  3.0              0.035932                   0.0          100.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 3        10.19281             2.0           37.80719                  0.6
#
#    agent_private_price
# 3                  1.1  Negative attestation 2
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 3  3.0                   0.0                   0.0          100.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 3             3.0             2.0               45.0                  0.6
#
#    agent_private_price
# 3                  1.1  --------------TIMESTEP 4 --------------
# CHOSEN AGENT =   Time  4
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0                   0.0              0.074171          100.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1             3.0       16.861608          30.138392                  0.4
#
#    agent_private_price
# 1                  0.9  r 100.0
#  Time  4
# No trade. P =  0.9283042083194168 private_price =  1.1
# r 100.0
# Positive attestation. | alpha =  0.44930272300042057 private_alpha =  0.6
# amt_pos =  6.97237364000802
# No trade. P =  1.1767467402744924 private_price =  0.9
# amt_Q1 =  0.03486873719310839
# Negative attestation. | alpha =  0.5829041858533155 private_alpha =  0.4
# ::::delta R:::: 1.1368683772161603e-13
# amt_neg =  7.095116192961326
#  Time  4
# amt_Q0 =  0.035575619346716235
# ::::AMTBOND:::: 0
# ::::delta R:::: 0.0
# ::::delta S:::: 0.0
# ::::AMTBOND:::: 0
# ::::AMTBURN:::: 0
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000              0.102113          100.0
# 1  1.0              0.000000              0.017361          100.0
# 2  2.0              0.025503              0.000000          100.0
# 3  3.0              0.000000              0.000000          100.0
# 4  4.0              0.000000              0.000000          100.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000       22.422660          24.577340                  0.3
# 1        3.000000        5.456076          41.543924                  0.4
# 2        8.103891        2.000000          39.896109                  0.5
# 3        3.000000        2.000000          45.000000                  0.6
# 4        3.000000        2.000000          45.000000                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  0.9
# 2                  1.0
# 3                  1.1
# 4                  1.5  ::::delta S:::: 0.0
# PRICE (BOND/BURN):  0.9283042083194167
#
# ::::AMTBURN:::: 0
# PRICE pbar (from bondburn update) = 0.0
# PRICE (BOND/BURN):  1.1767467402744918
# r 100.00000000000011
# PRICE pbar (from bondburn update) = 0.0
# No trade. P =  0.9283042083194167 private_price =  1.1
# --------------TIMESTEP 4 --------------
# Positive attestation. | alpha =  0.44930272300042057 private_alpha =  0.6
# r 100.0
# amt_pos =  8.92463946863462
# No trade. P =  1.1767467402744918 private_price =  0.9
# amt_Q1 =  0.044621131644999645
# Negative attestation. | alpha =  0.5829041858533155 private_alpha =  0.4
# Positive attestation 2
# amt_neg =  5.448331422187616
# PRICE (ATTEST):  1.0730945354252985
# amt_Q0 =  0.027324087308715043
# Positive attestation 2
# Negative attestation 2
# Positive attestation 1
# PRICE (ATTEST):  1.01079092466811
# Positive attestation 2
# Negative attestation 2
# Positive attestation 2
# Negative attestation 1
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0                   0.0              0.017361          100.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1             3.0        5.456076          41.543924                  0.4
#
#    agent_private_price
# 1                  0.9  r 100.0
# No trade. P =  1.1405118760553228 private_price =  1.1
# Positive attestation. | alpha =  0.566266565438634 private_alpha =  0.6
#  Time  4
# amt_pos =  2.646629586392462
# r 100.0
# amt_Q1 =  0.013284893708487658
# No trade. P =  0.9270789670087666 private_price =  0.9
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# Negative attestation. | alpha =  0.44445079293800116 private_alpha =  0.4
# ::::delta S:::: 4.547473508864641e-13
# amt_neg =  1.8653010071228504
# ::::AMTBURN:::: 0
# amt_Q0 =  0.009380032406517793
# PRICE (BOND/BURN):  1.1405118760553232
# ::::delta R:::: -1.1368683772161603e-13
# PRICE pbar (from bondburn update) = 0.0
# ::::AMTBOND:::: 0
# r 100.0
# ::::delta S:::: 1.3642420526593924e-12
# No trade. P =  1.1405118760553232 private_price =  1.1
# ::::AMTBURN:::: 0
# Positive attestation. | alpha =  0.566266565438634 private_alpha =  0.6
# amt_pos =  1.393872311739517
# PRICE (BOND/BURN):  0.9270789670087664
# PRICE pbar (from bondburn update) = 0.0
# amt_Q1 =  0.006997708846282577
# r 99.99999999999989
# Positive attestation 2
# No trade. P =  0.9270789670087664 private_price =  0.9
# Negative attestation. | alpha =  0.44445079293800116 private_alpha =  0.4
# PRICE (ATTEST):  1.081775236122008
# amt_neg =  3.824227458445577
# Positive attestation 2
# amt_Q0 =  0.01922617535249896
# Positive attestation 1
# Negative attestation 2
# PRICE (ATTEST):  0.9072083510984756
# Positive attestation 2
# Negative attestation 2
# Positive attestation 2
# Negative attestation 1
# Negative attestation 2
# Negative attestation 2
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000              0.090312          100.0
# 1  1.0              0.000000              0.019812          100.0
# 2  2.0              0.021360              0.000000          100.0
# 3  3.0              0.044621              0.000000          100.0
# 4  4.0              0.000000              0.000000          100.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000       20.062343          26.937657                  0.3
# 1        3.000000        5.946620          41.053380                  0.4
# 2        7.274260        2.000000          40.725740                  0.5
# 3       11.924639        2.000000          36.075361                  0.6
# 4        3.000000        2.000000          45.000000                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  0.9
# 2                  1.0
# 3                  1.1
# 4                  1.5  Negative attestation 2
# Negative attestation 2
#
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000              0.000000          100.0
# 1  1.0              0.000000              0.079726          100.0
# 2  2.0              0.000000              0.000000          100.0
# 3  3.0              0.042929              0.000000          100.0
# 4  4.0              0.048915              0.000000          100.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000        2.000000          45.000000                  0.3
# 1        3.000000       17.976909          29.023091                  0.4
# 2        3.000000        2.000000          45.000000                  0.5
# 3       11.586682        2.000000          36.413318                  0.6
# 4       12.777331        2.000000          35.222669                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  0.9
# 2                  1.0
# 3                  1.1
# 4                  1.5
# --------------TIMESTEP 5 --------------
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000              0.000000          100.0
# 1  1.0              0.000000              0.101495          100.0
# 2  2.0              0.000000              0.000000          100.0
# 3  3.0              0.034005              0.000000          100.0
# 4  4.0              0.059580              0.000000          100.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000        2.000000          45.000000                  0.3
# 1        3.000000       22.309939          24.690061                  0.4
# 2        3.000000        2.000000          45.000000                  0.5
# 3        9.806774        2.000000          38.193226                  0.6
# 4       14.913392        2.000000          33.086608                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  0.9
# 2                  1.0
# 3                  1.1
# 4                  1.5  --------------TIMESTEP 5 --------------
# CHOSEN AGENT =
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0              0.090312          100.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0       20.062343          26.937657                  0.3
#
#    agent_private_price
# 0                  0.5  --------------TIMESTEP 5 --------------
# CHOSEN AGENT =   Time  5
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# ...
#
#    agent_private_price
# 0                  0.5  Positive attestation 2
#  Time  42
# Positive attestation 2
# amt_Q1 =  0.009236993229671173
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000              0.220458          100.0
# 1  1.0              0.000000              0.121527          100.0
# 2  2.0              0.075919              0.023742          100.0
# 3  3.0              0.145746              0.000000          100.0
# 4  4.0              0.163074              0.000000          100.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000       45.835105           1.164895                  0.3
# 1        3.000000       26.077142          20.922858                  0.4
# 2       18.130503        6.684414          35.185083                  0.5
# 3       31.840108        2.000000          26.159892                  0.6
# 4       35.351797        2.000000          12.648203                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  0.9
# 2                  1.0
# 3                  1.1
# 4                  1.5  ::::delta R:::: -1.1368683772161603e-13
# ::::AMTBOND:::: 0
#
# ::::delta S:::: 6.821210263296962e-13
# --------------TIMESTEP 42 --------------
# ::::AMTBURN:::: 0
# r 99.99999999999989
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000              0.204111          100.0
# 1  1.0              0.000000              0.160326          100.0
# 2  2.0              0.029328              0.056915          100.0
# 3  3.0              0.190414              0.000000          100.0
# 4  4.0              0.214650              0.000000          100.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000       42.622685           4.377315                  0.3
# 1        3.000000       33.653212          13.346788                  0.4
# 2        8.862976       13.235539          27.901485                  0.5
# 3       40.766722        2.000000          17.233278                  0.6
# 4       45.446560        2.000000          12.553440                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  0.9
# 2                  1.0
# 3                  1.1
# 4                  1.5  No trade. P =  1.0138189434787443 private_price =  0.5
#
# --------------TIMESTEP 43 --------------
# CHOSEN AGENT =  PRICE (BOND/BURN):  1.0316623601236274
# Negative attestation. | alpha =  0.5156932038095571 private_alpha =  0.3
# PRICE pbar (from bondburn update) = 0.0
# CHOSEN AGENT =  amt_neg =  0.5669783912394682
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0              0.220458          100.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0       45.835105           1.164895                  0.3
#
#    agent_private_price
# 0                  0.5      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 2  2.0              0.029328              0.056915          100.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 2        8.862976       13.235539          27.901485                  0.5
#
#    agent_private_price
# 2                  1.0  amt_Q0 =  0.0028931194633512215
#  Time  43
# r 99.99999999999977
# ::::delta R:::: 0.0
#  Time  42
# No trade. P =  1.0316623601236274 private_price =  1.1
# r 100.00000000000011
# ::::AMTBOND:::: 0
# No trade. P =  1.0335748692078515 private_price =  1.0
# Positive attestation. | alpha =  0.5236830266468804 private_alpha =  0.6
# ::::delta S:::: 2.2737367544323206e-13
# Negative attestation. | alpha =  0.5286100309479711 private_alpha =  0.5
# ::::AMTBURN:::: 0
# amt_neg =  1.0523727990155483
# PRICE (BOND/BURN):  1.0138189434787443
# amt_pos =  2.2260755476745073
# amt_Q0 =  0.005372012133177917
# PRICE pbar (from bondburn update) = 0.0
# ::::delta R:::: -1.1368683772161603e-13
# ::::AMTBOND:::: 0
# r 100.0
# amt_Q1 =  0.011363933737093792
# r 99.99999999999989
# ::::delta S:::: 2.2737367544323206e-13
# ::::AMTBURN:::: 0
# Positive attestation 2
# No trade. P =  1.0138189434787443 private_price =  0.5
# No trade. P =  1.0335078531050659 private_price =  0.5
# PRICE (ATTEST):  1.0336253374733555
# Negative attestation. | alpha =  0.5345008338828782 private_alpha =  0.3
# Positive attestation 2
# amt_neg =  0.2833495270245599
# Positive attestation 1
# Positive attestation 2
# amt_Q0 =  0.0014426036824778526
# Positive attestation 2
# Negative attestation. | alpha =  0.5156932038095571 private_alpha =  0.3
# PRICE (BOND/BURN):  1.0335748692078512
# amt_neg =  0.46378192241609056
# amt_Q0 =  0.002366569577108318
# PRICE pbar (from bondburn update) = 0.0
# Negative attestation 2
# ::::delta R:::: 0.0
# PRICE (ATTEST):  1.0133915348291709
# Negative attestation 2
# ::::AMTBOND:::: 0
# r 100.0
# Negative attestation 1
# Negative attestation 2
# ::::delta S:::: -9.094947017729282e-13
# Negative attestation 2
# No trade. P =  1.0335748692078512 private_price =  1.0
# ::::AMTBURN:::: 0
# PRICE (BOND/BURN):  1.0335078531050663
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000              0.190061          100.0
# 1  1.0              0.000000              0.177266          100.0
# 2  2.0              0.000000              0.056043          100.0
# 3  3.0              0.204107              0.000000          100.0
# 4  4.0              0.232611              0.000000          100.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000       39.706474           7.293526                  0.3
# 1        3.000000       37.196023           9.803977                  0.4
# 2        3.000000       13.048917          33.951083                  0.5
# 3       43.474617        2.000000          14.525383                  0.6
# 4       49.040040        2.000000           8.959960                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  0.9
# 2                  1.0
# 3                  1.1
# 4                  1.5  PRICE pbar (from bondburn update) = -0.0
# r 100.0
#
# No trade. P =  1.0335078531050663 private_price =  0.5
# Negative attestation. | alpha =  0.5286100309479711 private_alpha =  0.5
# Negative attestation. | alpha =  0.5345008338828782 private_alpha =  0.3
# --------------TIMESTEP 43 --------------
# amt_neg =  0.2408886680889421
# amt_Q0 =  0.0012264312827870987
# amt_neg =  1.3241375731947753
# amt_Q0 =  0.006759051150984406
# CHOSEN AGENT =  Negative attestation 2
# Negative attestation 2
# PRICE (ATTEST):  1.03316496940654
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 2  2.0                   0.0              0.056043          100.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 2             3.0       13.048917          33.951083                  0.5
#
#    agent_private_price
# 2                  1.0      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000              0.220726          100.0
# 1  1.0              0.000000              0.154246          100.0
# 2  2.0              0.029868              0.039632          100.0
# 3  3.0              0.182130              0.000000          100.0
# 4  4.0              0.183132              0.000000          100.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000       45.644539           1.355461                  0.3
# 1        3.000000       32.745619          14.254381                  0.4
# 2        8.887726        9.846667          41.265607                  0.5
# 3       39.087543        2.000000          18.912457                  0.6
# 4       39.393367        2.000000           8.606633                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  0.9
# 2                  1.0
# 3                  1.1
# 4                  1.5  PRICE (ATTEST):  1.0221328374759355
# Negative attestation 2
# Negative attestation 2
#  Time  43
# Negative attestation 1
#
# Negative attestation 1
# --------------TIMESTEP 43 --------------
# Negative attestation 2
# Negative attestation 2
# Negative attestation 2
# r 99.99999999999977
# Negative attestation 2
# No trade. P =  1.0336253374733555 private_price =  1.0
# Negative attestation. | alpha =  0.5284924631351432 private_alpha =  0.5
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000              0.221685          100.0
# 1  1.0              0.000000              0.121527          100.0
# 2  2.0              0.075919              0.023742          100.0
# 3  3.0              0.145746              0.000000          100.0
# 4  4.0              0.163074              0.000000          100.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000       46.075994           0.924006                  0.3
# 1        3.000000       26.077142          20.922858                  0.4
# 2       18.130503        6.684414          35.185083                  0.5
# 3       31.840108        2.000000          26.159892                  0.6
# 4       35.351797        2.000000          12.648203                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  0.9
# 2                  1.0
# 3                  1.1
# 4                  1.5  amt_neg =  1.558208264878188
#
# --------------TIMESTEP 43 --------------
# amt_Q0 =  0.007954417162790673
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000              0.204111          100.0
# 1  1.0              0.000000              0.160326          100.0
# 2  2.0              0.029328              0.063674          100.0
# 3  3.0              0.190414              0.000000          100.0
# 4  4.0              0.214650              0.000000          100.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000       42.622685           4.377315                  0.3
# 1        3.000000       33.653212          13.346788                  0.4
# 2        8.862976       14.559676          26.577348                  0.5
# 3       40.766722        2.000000          17.233278                  0.6
# 4       45.446560        2.000000          12.553440                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  0.9
# 2                  1.0
# 3                  1.1
# 4                  1.5      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 4  4.0              0.183132                   0.0          100.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 4       39.393367             2.0           8.606633                  0.7
#
#    agent_private_price
# 4                  1.5
# --------------TIMESTEP 44 --------------
# CHOSEN AGENT =  ::::delta R:::: 0.0
#  Time  43
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 4  4.0              0.163074                   0.0          100.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 4       35.351797             2.0          12.648203                  0.7
#
#    agent_private_price
# 4                  1.5  ::::AMTBOND:::: 0
# CHOSEN AGENT =  r 99.99999999999977
# No trade. P =  1.0133915348291709 private_price =  1.5
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 3  3.0              0.190414                   0.0          100.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 3       40.766722             2.0          17.233278                  0.6
#
#    agent_private_price
# 3                  1.1  Positive attestation. | alpha =  0.5145575771039442 private_alpha =  0.7
#  Time  44
# amt_pos =  2.3235255222747653
#  Time  43
# ::::delta S:::: 4.547473508864641e-13
# ::::AMTBURN:::: 0
# r 99.99999999999989
# amt_Q1 =  0.011843712106972928
# PRICE (BOND/BURN):  1.0336253374733553
# No trade. P =  1.0221328374759355 private_price =  1.1
# PRICE pbar (from bondburn update) = 0.0
# ::::delta R:::: 0.0
# ::::AMTBOND:::: 0
# Positive attestation. | alpha =  0.5254415614327814 private_alpha =  0.6
# r 99.99999999999977
# ::::delta S:::: 6.821210263296962e-13
# amt_pos =  1.4642916986664778
# No trade. P =  1.0336253374733553 private_price =  1.0
# ::::AMTBURN:::: 0
# Negative attestation. | alpha =  0.5284924631351432 private_alpha =  0.5
# PRICE (BOND/BURN):  1.013391534829171
# amt_neg =  2.44879307855591
# amt_Q1 =  0.007479109100948996
# PRICE pbar (from bondburn update) = 0.0
# amt_Q0 =  0.012499327238708299
# ::::delta R:::: 0.0
# Negative attestation 2
# r 99.99999999999977
# ::::AMTBOND:::: 0
# No trade. P =  1.013391534829171 private_price =  1.5
# ::::delta S:::: -4.547473508864641e-13
# Positive attestation. | alpha =  0.5145575771039442 private_alpha =  0.7
# ::::AMTBURN:::: 0
# amt_pos =  1.5982797666670385
# PRICE (ATTEST):  1.016687373632747
# amt_Q1 =  0.008147653267209294
# Negative attestation 2
# PRICE (BOND/BURN):  1.0221328374759358
# Positive attestation 2
# Negative attestation 1
# Negative attestation 2
# Negative attestation 2
# PRICE pbar (from bondburn update) = -0.0
# PRICE (ATTEST):  1.0220312080212957
# r 99.99999999999989
# Positive attestation 2
# No trade. P =  1.0221328374759358 private_price =  1.1
# Positive attestation 1
# Positive attestation. | alpha =  0.5254415614327814 private_alpha =  0.6
# Positive attestation 2
# amt_pos =  2.080206910389519
# Positive attestation 2
# amt_Q1 =  0.010624179241505226
# r 100.00000000000011
# No trade. P =  1.03316496940654 private_price =  1.5
# Positive attestation. | alpha =  0.5338543425112716 private_alpha =  0.7
# Positive attestation 2
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000              0.190061          100.0
# 1  1.0              0.000000              0.177266          100.0
# 2  2.0              0.000000              0.068542          100.0
# 3  3.0              0.204107              0.000000          100.0
# 4  4.0              0.232611              0.000000          100.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000       39.706474           7.293526                  0.3
# 1        3.000000       37.196023           9.803977                  0.4
# 2        3.000000       15.497710          31.502290                  0.5
# 3       43.474617        2.000000          14.525383                  0.6
# 4       49.040040        2.000000           8.959960                  0.7
#
#    agent_private_price
# 0                  0.5
# 1                  0.9
# 2                  1.0
# 3                  1.1
# 4                  1.5  amt_pos =  1.9353564250912676
#
# config_ids =  [{'M': {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 1000, 'C': 2000, 'f': 0.03, 'm': 0.15, 'beta': 0.9, 'dust': 1e-08, 'period': 2000, 'rules_price': 'martin', 'E': 0.2}, 'simulation_id': 0, 'run_id': 0}, {'M': {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 1000, 'C': 2000, 'f': 0.03, 'm': 0.15, 'beta': 0.9, 'dust': 1e-08, 'period': 2000, 'rules_price': 'martin', 'E': 0.2}, 'simulation_id': 0, 'run_id': 1}, {'M': {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 1000, 'C': 2000, 'f': 0.03, 'm': 0.15, 'beta': 0.9, 'dust': 1e-08, 'period': 2000, 'rules_price': 'step', 'E': 0.2}, 'simulation_id': 1, 'run_id': 0}, {'M': {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 1000, 'C': 2000, 'f': 0.03, 'm': 0.15, 'beta': 0.9, 'dust': 1e-08, 'period': 2000, 'rules_price': 'step', 'E': 0.2}, 'simulation_id': 1, 'run_id': 1}]
# /Users/shrutiappiah/Documents/Github/ICF_Internal/src/sim/run.py:78: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sub_df = df[df.simulation == config_id['simulation_id']][df.run == config_id['run_id'] + 1]

# %%
import sys

experiments = experiments.sort_values(by =['rules_price']).reset_index(drop=True)

cols = 1
rows = 1
cc_idx = 0
# config_labels = ['RULE 1,'RULE 2']

while cc_idx<len(experiments):
    cc = experiments.iloc[cc_idx]['rules_price']
    cc_label = experiments.iloc[cc_idx]['rules_price']
#     secondary_label = experiments.iloc[cc_idx]['string']
    sub_experiments = experiments[experiments['rules_price']==cc]
    cc_idx += len(sub_experiments)
    fig, axs = plt.subplots(ncols=cols, nrows=rows, figsize=(15*cols,7*rows))
    sub_experiments.reset_index(drop=False)
    for i, experiment in sub_experiments.iterrows():
        df = experiment['dataset'].copy()
        # filter out starting point
        df = df[df.timestep > 0] 
        # FIRST RUN ONLY
#         df = df[df.run == 1]  


#         df = df.groupby('timestep').agg({'agents': ['min', 'mean', 'max']}).reset_index()
# MAKE A FOR LOOP or FUNCTION FOR ALL AGENTS
        chosen_agents = df['chosen_agent'].tolist()
        chosen_agents_private_alphas = []
        for agent in chosen_agents:
            chosen_agents_private_alphas.append(agent['agent_private_alpha'])
        
       # print(len(chosen_agents_private_alphas))
        
        df['private_alpha'] = chosen_agents_private_alphas
      #  df['agent_2_private_alpha'] = df.agents.apply(lambda x: np.array(x['chosen_agent']))
        
        df = df.groupby('timestep').mean().reset_index()
 
        # hack subtracting starting amount
#         df['alpha'] = df.alpha.diff()
        
#         df = df.groupby('timestep').agg({'supply': ['min', 'mean', 'max']}).reset_index()
    
#         df['agent_attest_1'] = np.array(df.agent_attest_1,dtype = float)
#         print(df['agent_attest_1'])
#         print(df['agent_attest_1'][10])
        plot_label = experiment['rules_price']
        ax = axs
        title = 'Agent Private Alpha vs Global Alpha' + '\n' + 'Scenario: ' + str(cc_label)  + ' rules_price'
        ax.set_title(title)
        ax.set_ylabel('Alpha Value')
        colors = ['b','orange', 'g', 'magenta', 'r', 'k' ]
#         df['agent_1_attestations_1'] = df['agent_1_attestations_1'][0]       
#         df.plot(x='timestep', y='agent_1_attestations_0', label='agent_1_attestations_0', ax=ax, legend=True)
#         df.plot(x='timestep', y='agent_2_attestations_0', label='agent_2_attestations_0', ax=ax, legend=True)
#         df.plot(x='timestep', y='agent_3_attestations_0', label='agent_3_attestations_0', ax=ax, legend=True)
#         df.plot(x='timestep', y='agent_4_attestations_0', label='agent_4_attestations_0', ax=ax, legend=True)
#         df.plot(x='timestep', y='agent_5_attestations_0', label='agent_5_attestations_0', ax=ax, legend=True)
#        df.plot(x='timestep', y='agent_1_private_alpha', label='A1 Private Alpha', ax=ax, legend=True, kind= 'scatter', color = 'red')
        df.plot(x='timestep', y='private_alpha', label='A2 Private Alpha', ax=ax, legend=True, kind= 'scatter', color='red')
        df.plot(x='timestep', y='alpha', label='Alpha', ax=ax, legend=True, color = colors[5])
        
#         ax.fill_between(df.timestep, df[('supply','min')], df[('supply','max')], supply=0.3) 

        ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

        ax.set_xlabel('Timesteps')
        ax.grid(color='0.9', linestyle='-', linewidth=1)

        plt.tight_layout()
        
fig.tight_layout(rect=[0, 0, 1, .97])
fig.patch.set_alpha(1)
display(fig)
plt.close()

# %%
experiments = experiments.sort_values(by =['rules_price']).reset_index(drop=True)

cols = 1
rows = 1
cc_idx = 0
# config_labels = ['RULE 1,'RULE 2']


while cc_idx<len(experiments):
    cc = experiments.iloc[cc_idx]['rules_price']
    cc_label = experiments.iloc[cc_idx]['rules_price']
#     secondary_label = experiments.iloc[cc_idx]['string']
    sub_experiments = experiments[experiments['rules_price']==cc]
    cc_idx += len(sub_experiments)
    fig, axs = plt.subplots(ncols=cols, nrows=rows, figsize=(15*cols,7*rows))
    sub_experiments.reset_index(drop=False)
    for i, experiment in sub_experiments.iterrows():
        df = experiment['dataset'].copy()
        # filter out starting point
        df = df[df.timestep > 0] 
        # FIRST RUN ONLY
        df = df[df.run == 1]  

# MAKE A FOR LOOP or FUNCTION FOR ALL AGENTS
        chosen_agents = df['chosen_agent'].tolist()
        chosen_agents_private_alphas = []
        for agent in chosen_agents:
            chosen_agents_private_alphas.append(agent['agent_private_alpha'])
        
        df['private_alpha'] = chosen_agents_private_alphas
            
        df['agent_1_private_alpha'] = df.agents.apply(lambda x: np.array(x['agent_private_alpha'][0]))
        df['agent_2_private_alpha'] = df.agents.apply(lambda x: np.array(x['agent_private_alpha'][1]))
        df['agent_3_private_alpha'] = df.agents.apply(lambda x: np.array(x['agent_private_alpha'][2]))
        df['agent_4_private_alpha'] = df.agents.apply(lambda x: np.array(x['agent_private_alpha'][3]))
        df['agent_5_private_alpha'] = df.agents.apply(lambda x: np.array(x['agent_private_alpha'][4]))
# #         df['agent_1_attest_0'] = df.agents.apply(lambda x: np.array(x['agent_attestations_1'][0]))
# #         print( df['agent_1_attestations_1'])
#         df['agent_1_attestations_1'] = df.agent_1_attestations_1.diff()
#         df['agent_2_attestations_1'] = df.agent_2_attestations_1.diff()
#         df['agent_3_attestations_1'] = df.agent_3_attestations_1.diff()
#         df['agent_4_attestations_1'] = df.agent_4_attestations_1.diff()
#         df['agent_5_attestations_1'] = df.agent_5_attestations_1.diff()
        
        
#         df['agent_1_attestations_0'] = df.agents.apply(lambda x: np.array(x['agent_attestations_0'][0]))
#         df['agent_2_attestations_0'] = df.agents.apply(lambda x: np.array(x['agent_attestations_0'][1]))
#         df['agent_3_attestations_0'] = df.agents.apply(lambda x: np.array(x['agent_attestations_0'][2]))
#         df['agent_4_attestations_0'] = df.agents.apply(lambda x: np.array(x['agent_attestations_0'][3]))
#         df['agent_5_attestations_0'] = df.agents.apply(lambda x: np.array(x['agent_attestations_0'][4]))
# #         df['agent_1_attest_0'] = df.agents.apply(lambda x: np.array(x['agent_attestations_1'][0]))
# #         print( df['agent_1_attestations_1'])
#         df['agent_1_attestations_0'] = - df.agent_1_attestations_0.diff()
#         df['agent_2_attestations_0'] = - df.agent_2_attestations_0.diff()
#         df['agent_3_attestations_0'] = - df.agent_3_attestations_0.diff()
#         df['agent_4_attestations_0'] = - df.agent_4_attestations_0.diff()
#         df['agent_5_attestations_0'] = - df.agent_5_attestations_0.diff()
        
        
        # hack subtracting starting amount
#         df['alpha'] = df.alpha.diff()
        
#         df = df.groupby('timestep').agg({'supply': ['min', 'mean', 'max']}).reset_index()
    
#         df['agent_attest_1'] = np.array(df.agent_attest_1,dtype = float)
#         print(df['agent_attest_1'])
#         print(df['agent_attest_1'][10])
        plot_label = experiment['rules_price']
        ax = axs
        title = 'Agent Private Alpha vs Global Alpha' + '\n' + 'Scenario: ' + str(cc_label)  + ' rules_price'
        ax.set_title(title)
        ax.set_ylabel('Alpha Value')
        colors = ['b','orange', 'g', 'magenta', 'r', 'k' ]
#         df['agent_1_attestations_1'] = df['agent_1_attestations_1'][0]
        
        plt.hlines(y= max(df['agent_1_private_alpha']), xmin=0, xmax=max(df.timestep), label = 'Agent 1 Private Alpha',  color = colors[0])
        plt.hlines(y= max(df['agent_2_private_alpha']), xmin=0, xmax=max(df.timestep), label = 'Agent 2 Private Alpha',  color = colors[1])
        plt.hlines(y= max(df['agent_3_private_alpha']), xmin=0, xmax=max(df.timestep), label = 'Agent 3 Private Alpha',  color = colors[2])
        plt.hlines(y= max(df['agent_4_private_alpha']), xmin=0, xmax=max(df.timestep), label = 'Agent 4 Private Alpha',  color = colors[3])
        plt.hlines(y= max(df['agent_5_private_alpha']), xmin=0, xmax=max(df.timestep), label = 'Agent 5 Private Alpha',  color = colors[4])

#         df.plot(x='timestep', y='agent_1_attestations_1', label='agent_1_attestations_1', ax=ax, legend=True)
#         df.plot(x='timestep', y='agent_2_attestations_1', label='agent_2_attestations_1', ax=ax, legend=True)
#         df.plot(x='timestep', y='agent_3_attestations_1', label='agent_3_attestations_1', ax=ax, legend=True)
#         df.plot(x='timestep', y='agent_4_attestations_1', label='agent_4_attestations_1', ax=ax, legend=True)
#         df.plot(x='timestep', y='agent_5_attestations_1', label='agent_5_attestations_1', ax=ax, legend=True)
        
#         df.plot(x='timestep', y='agent_1_attestations_0', label='agent_1_attestations_0', ax=ax, legend=True)
#         df.plot(x='timestep', y='agent_2_attestations_0', label='agent_2_attestations_0', ax=ax, legend=True)
#         df.plot(x='timestep', y='agent_3_attestations_0', label='agent_3_attestations_0', ax=ax, legend=True)
#         df.plot(x='timestep', y='agent_4_attestations_0', label='agent_4_attestations_0', ax=ax, legend=True)
#         df.plot(x='timestep', y='agent_5_attestations_0', label='agent_5_attestations_0', ax=ax, legend=True)
        df.plot(x='timestep', y='private_alpha', label='Private Alpha', ax=ax, legend=True, kind= 'scatter')
        df.plot(x='timestep', y='alpha', label='Alpha', ax=ax, legend=True, color = colors[5])

#         ax.fill_between(df.timestep, df[('supply','min')], df[('supply','max')], supply=0.3) 

        ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

        ax.set_xlabel('Timesteps')
        ax.grid(color='0.9', linestyle='-', linewidth=1)

        plt.tight_layout()
        
fig.tight_layout(rect=[0, 0, 1, .97])
fig.patch.set_alpha(1)
display(fig)
plt.close()

# %%
experiments = experiments.sort_values(by =['rules_price']).reset_index(drop=True)

cols = 1
rows = 1
cc_idx = 0
# config_labels = ['RULE 1,'RULE 2']


while cc_idx<len(experiments):
    cc = experiments.iloc[cc_idx]['rules_price']
    cc_label = experiments.iloc[cc_idx]['rules_price']
#     secondary_label = experiments.iloc[cc_idx]['string']
    sub_experiments = experiments[experiments['rules_price']==cc]
    cc_idx += len(sub_experiments)
    fig, axs = plt.subplots(ncols=cols, nrows=rows, figsize=(15*cols,7*rows))
    sub_experiments.reset_index(drop=False)
    for i, experiment in sub_experiments.iterrows():
        df = experiment['dataset'].copy()
        # filter out starting point
        df = df[df.timestep > 0] 
        # FIRST RUN ONLY
#         df = df[df.run == 1]  

#         df = df.groupby('timestep').agg({'agents': ['min', 'mean', 'max']}).reset_index()
# MAKE A FOR LOOP or FUNCTION FOR ALL AGENTS
        chosen_agents = df['chosen_agent'].tolist()
        chosen_agents_private_alphas = []
        for agent in chosen_agents:
            chosen_agents_private_alphas.append(agent['agent_private_alpha'])
        
        df['private_alpha'] = chosen_agents_private_alphas
        
        df['agent_1_private_alpha'] = df.agents.apply(lambda x: np.array(x['agent_private_alpha'][0]))
        df['agent_2_private_alpha'] = df.agents.apply(lambda x: np.array(x['agent_private_alpha'][1]))
        
        df = df.groupby('timestep').mean().reset_index()
        
#         print(df)
#         df['agent_3_private_alpha'] = df.agents.apply(lambda x: np.array(x['agent_private_alpha'][2]))
#         df['agent_4_private_alpha'] = df.agents.apply(lambda x: np.array(x['agent_private_alpha'][3]))
#         df['agent_5_private_alpha'] = df.agents.apply(lambda x: np.array(x['agent_private_alpha'][4]))
# #         df['agent_1_attest_0'] = df.agents.apply(lambda x: np.array(x['agent_attestations_1'][0]))
# #         print( df['agent_1_attestations_1'])
#         df['agent_1_attestations_1'] = df.agent_1_attestations_1.diff()
#         df['agent_2_attestations_1'] = df.agent_2_attestations_1.diff()
#         df['agent_3_attestations_1'] = df.agent_3_attestations_1.diff()
#         df['agent_4_attestations_1'] = df.agent_4_attestations_1.diff()
#         df['agent_5_attestations_1'] = df.agent_5_attestations_1.diff()
        
     
#         df['agent_1_attestations_0'] = df.agents.apply(lambda x: np.array(x['agent_attestations_0'][0]))
#         df['agent_2_attestations_0'] = df.agents.apply(lambda x: np.array(x['agent_attestations_0'][1]))
#         df['agent_3_attestations_0'] = df.agents.apply(lambda x: np.array(x['agent_attestations_0'][2]))
#         df['agent_4_attestations_0'] = df.agents.apply(lambda x: np.array(x['agent_attestations_0'][3]))
#         df['agent_5_attestations_0'] = df.agents.apply(lambda x: np.array(x['agent_attestations_0'][4]))
# #         df['agent_1_attest_0'] = df.agents.apply(lambda x: np.array(x['agent_attestations_1'][0]))
# #         print( df['agent_1_attestations_1'])
#         df['agent_1_attestations_0'] = - df.agent_1_attestations_0.diff()
#         df['agent_2_attestations_0'] = - df.agent_2_attestations_0.diff()
#         df['agent_3_attestations_0'] = - df.agent_3_attestations_0.diff()
#         df['agent_4_attestations_0'] = - df.agent_4_attestations_0.diff()
#         df['agent_5_attestations_0'] = - df.agent_5_attestations_0.diff()
        
        
        # hack subtracting starting amount
#         df['alpha'] = df.alpha.diff()
        
#         df = df.groupby('timestep').agg({'supply': ['min', 'mean', 'max']}).reset_index()
    
#         df['agent_attest_1'] = np.array(df.agent_attest_1,dtype = float)
#         print(df['agent_attest_1'])
#         print(df['agent_attest_1'][10])
        plot_label = experiment['rules_price']
        ax = axs
        title = 'Agent Private Alpha vs Global Alpha' + '\n' + 'Scenario: ' + str(cc_label)  + ' rules_price'
        ax.set_title(title)
        ax.set_ylabel('Alpha Value')
        colors = ['b','orange', 'g', 'magenta', 'r', 'k' ]
#         df['agent_1_attestations_1'] = df['agent_1_attestations_1'][0]
        
#         plt.hlines(y= max(df['agent_1_private_alpha']), xmin=0, xmax=max(df.timestep), label = 'Agent 1 Private Alpha',  color = colors[0])
#         plt.hlines(y= max(df['agent_2_private_alpha']), xmin=0, xmax=max(df.timestep), label = 'Agent 2 Private Alpha',  color = colors[1])
#         plt.hlines(y= max(df['agent_3_private_alpha']), xmin=0, xmax=max(df.timestep), label = 'Agent 3 Private Alpha',  color = colors[2])
#         plt.hlines(y= max(df['agent_4_private_alpha']), xmin=0, xmax=max(df.timestep), label = 'Agent 4 Private Alpha',  color = colors[3])
#         plt.hlines(y= max(df['agent_5_private_alpha']), xmin=0, xmax=max(df.timestep), label = 'Agent 5 Private Alpha',  color = colors[4])

#         df.plot(x='timestep', y='agent_1_attestations_1', label='agent_1_attestations_1', ax=ax, legend=True)
#         df.plot(x='timestep', y='agent_2_attestations_1', label='agent_2_attestations_1', ax=ax, legend=True)
#         df.plot(x='timestep', y='agent_3_attestations_1', label='agent_3_attestations_1', ax=ax, legend=True)
#         df.plot(x='timestep', y='agent_4_attestations_1', label='agent_4_attestations_1', ax=ax, legend=True)
#         df.plot(x='timestep', y='agent_5_attestations_1', label='agent_5_attestations_1', ax=ax, legend=True)
        
#         df.plot(x='timestep', y='agent_1_attestations_0', label='agent_1_attestations_0', ax=ax, legend=True)
#         df.plot(x='timestep', y='agent_2_attestations_0', label='agent_2_attestations_0', ax=ax, legend=True)
#         df.plot(x='timestep', y='agent_3_attestations_0', label='agent_3_attestations_0', ax=ax, legend=True)
#         df.plot(x='timestep', y='agent_4_attestations_0', label='agent_4_attestations_0', ax=ax, legend=True)
#         df.plot(x='timestep', y='agent_5_attestations_0', label='agent_5_attestations_0', ax=ax, legend=True)
        df.plot(x='timestep', y='private_alpha', label='Private Alpha', ax=ax, legend=True, kind= 'scatter')
        df.plot(x='timestep', y='alpha', label='Alpha', ax=ax, legend=True, color = colors[5])

#         ax.fill_between(df.timestep, df[('supply','min')], df[('supply','max')], supply=0.3) 

        ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

        ax.set_xlabel('Timesteps')
        ax.grid(color='0.9', linestyle='-', linewidth=1)

        plt.tight_layout()
        
fig.tight_layout(rect=[0, 0, 1, .97])
fig.patch.set_alpha(1)
display(fig)
plt.close()

# %%
plt.plot(experiments.dataset[0].spot_price)

# %%
plt.plot(experiments.dataset[0].supply)

# %%
plt.plot(experiments.dataset[0].reserve)

# %%
plt.plot(experiments.dataset[0].supply_0)

# %%
plt.plot(experiments.dataset[0].supply_1)

# %%
# import sys
# sys.path.append('../')
import pandas as pd

import matplotlib.pyplot as plt
# import run2

from src.sim import run

import seaborn as sns

# For analysis
import numpy as np
import pandas as pd

sns.set_style("whitegrid")
# Out:
# -----------------PSUB---------------------
#
# CHECKPOINT 1
# CHECKPOINT 2
# Initial Conditions (config.py) :  {'reserve': 1000, 'price': 1, 'realized_price': 0, 'spot_price': 1, 'kappa': 0, 'supply': 2000.0, 'alpha': [0.5], 'alpha_bar': [0.5], 'supply_0': 20, 'supply_1': 30, 'supply_free': 2000.0, 'attestations': 40, 'attestations_0': 20, 'attestations_1': 20, 'invariant_V': 4000.0, 'invariant_I': 2000.0, 'agents':    id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0   0                     0                     0             50
# 1   1                     0                     0             50
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0               3               2                 45                  0.1
# 1               3               2                 45                  0.9
#
#    agent_private_price
# 0                  0.2
# 1                 20.0  , 'chosen_agent': 0}
# Params (config.py) :  {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 1000, 'C': 2000, 'f': 0.03, 'm': 0.15, 'beta': 0.9, 'dust': 1e-08, 'period': 2000, 'rules_price': 'martin', 'E': 0.2}
# Params (config.py) :  {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 1000, 'C': 2000, 'f': 0.03, 'm': 0.15, 'beta': 0.9, 'dust': 1e-08, 'period': 2000, 'rules_price': 'martin', 'E': 0.2}
# Params (config.py) :  {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 1000, 'C': 2000, 'f': 0.03, 'm': 0.15, 'beta': 0.9, 'dust': 1e-08, 'period': 2000, 'rules_price': 'martin', 'E': 0.2}
# Params (config.py) :  {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 1000, 'C': 2000, 'f': 0.03, 'm': 0.15, 'beta': 0.9, 'dust': 1e-08, 'period': 2000, 'rules_price': 'martin', 'E': 0.2}
# Params (config.py) :  {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 1000, 'C': 2000, 'f': 0.03, 'm': 0.15, 'beta': 0.9, 'dust': 1e-08, 'period': 2000, 'rules_price': 'martin', 'E': 0.2}
# Params (config.py) :  {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 1000, 'C': 2000, 'f': 0.03, 'm': 0.15, 'beta': 0.9, 'dust': 1e-08, 'period': 2000, 'rules_price': 'martin', 'E': 0.2}
# Params (config.py) :  {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 1000, 'C': 2000, 'f': 0.03, 'm': 0.15, 'beta': 0.9, 'dust': 1e-08, 'period': 2000, 'rules_price': 'martin', 'E': 0.2}
# Params (config.py) :  {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 1000, 'C': 2000, 'f': 0.03, 'm': 0.15, 'beta': 0.9, 'dust': 1e-08, 'period': 2000, 'rules_price': 'martin', 'E': 0.2}
# Params (config.py) :  {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 1000, 'C': 2000, 'f': 0.03, 'm': 0.15, 'beta': 0.9, 'dust': 1e-08, 'period': 2000, 'rules_price': 'martin', 'E': 0.2}
# Params (config.py) :  {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 1000, 'C': 2000, 'f': 0.03, 'm': 0.15, 'beta': 0.9, 'dust': 1e-08, 'period': 2000, 'rules_price': 'martin', 'E': 0.2}
# Params (config.py) :  {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 1000, 'C': 2000, 'f': 0.03, 'm': 0.15, 'beta': 0.9, 'dust': 1e-08, 'period': 2000, 'rules_price': 'step', 'E': 0.2}
# Params (config.py) :  {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 1000, 'C': 2000, 'f': 0.03, 'm': 0.15, 'beta': 0.9, 'dust': 1e-08, 'period': 2000, 'rules_price': 'step', 'E': 0.2}
# Params (config.py) :  {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 1000, 'C': 2000, 'f': 0.03, 'm': 0.15, 'beta': 0.9, 'dust': 1e-08, 'period': 2000, 'rules_price': 'step', 'E': 0.2}
# Params (config.py) :  {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 1000, 'C': 2000, 'f': 0.03, 'm': 0.15, 'beta': 0.9, 'dust': 1e-08, 'period': 2000, 'rules_price': 'step', 'E': 0.2}
# Params (config.py) :  {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 1000, 'C': 2000, 'f': 0.03, 'm': 0.15, 'beta': 0.9, 'dust': 1e-08, 'period': 2000, 'rules_price': 'step', 'E': 0.2}
# Params (config.py) :  {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 1000, 'C': 2000, 'f': 0.03, 'm': 0.15, 'beta': 0.9, 'dust': 1e-08, 'period': 2000, 'rules_price': 'step', 'E': 0.2}
# Params (config.py) :  {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 1000, 'C': 2000, 'f': 0.03, 'm': 0.15, 'beta': 0.9, 'dust': 1e-08, 'period': 2000, 'rules_price': 'step', 'E': 0.2}
# Params (config.py) :  {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 1000, 'C': 2000, 'f': 0.03, 'm': 0.15, 'beta': 0.9, 'dust': 1e-08, 'period': 2000, 'rules_price': 'step', 'E': 0.2}
# Params (config.py) :  {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 1000, 'C': 2000, 'f': 0.03, 'm': 0.15, 'beta': 0.9, 'dust': 1e-08, 'period': 2000, 'rules_price': 'step', 'E': 0.2}
# Params (config.py) :  {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 1000, 'C': 2000, 'f': 0.03, 'm': 0.15, 'beta': 0.9, 'dust': 1e-08, 'period': 2000, 'rules_price': 'step', 'E': 0.2}
# Configurations Length: 20
# Execution Method: parallelize_simulations
# Execution Mode: parallelized
# ----------------------------
#    id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0   0                     0                     0             50
# 1   1                     0                     0             50
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0               3               2                 45                  0.1
# 1               3               2                 45                  0.9
#
#    agent_private_price
# 0                  0.2
# 1                 20.0     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0   0                     0                     0             50
# 1   1                     0                     0             50
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0               3               2                 45                  0.1
# 1               3               2                 45                  0.9
#
#    agent_private_price
# 0                  0.2
# 1                 20.0
#
#    id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0   0                     0                     0             50
# 1   1                     0                     0             50
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0               3               2                 45                  0.1
# 1               3               2                 45                  0.9
#
#    agent_private_price
# 0                  0.2
# 1                 20.0  ----------------------------
#    id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0   0                     0                     0             50
# 1   1                     0                     0             50
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0               3               2                 45                  0.1
# 1               3               2                 45                  0.9
#
#    agent_private_price
# 0                  0.2
# 1                 20.0
# CHOSEN AGENT =     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0   0                     0                     0             50
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0               3               2                 45                  0.1
#
#    agent_private_price
# 0                  0.2
#  Time  0
# ----------------------------
# Chosen Agent:
# CHOSEN AGENT =  {'id': 0, 'agent_attestations_1': 0, 'agent_attestations_0': 0, 'agent_reserve': 50, 'agent_supply_1': 3, 'agent_supply_0': 2, 'agent_supply_free': 45, 'agent_private_alpha': 0.1, 'agent_private_price': 0.2}
# CHOSEN AGENT =     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0   0                     0                     0             50
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0               3               2                 45                  0.1
#
#    agent_private_price
# 0                  0.2  ----------------------------
#  Time  0
# r 50
# CHOSEN AGENT =  Chosen Agent:
#    id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1   1                     0                     0             50
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1               3               2                 45                  0.9
#
#    agent_private_price
# 1                 20.0  Agent burns. Amt to burn =  44.99999955
# {'id': 0, 'agent_attestations_1': 0, 'agent_attestations_0': 0, 'agent_reserve': 50, 'agent_supply_1': 3, 'agent_supply_0': 2, 'agent_supply_free': 45, 'agent_private_alpha': 0.1, 'agent_private_price': 0.2}
# Negative attestation. | alpha =  0.5 private_alpha =  0.1
#  Time  0
# amt_neg =  19.44567520211778
# Chosen Agent:
# r 50
# amt_Q0 =  0.09699318406670265
# Agent burns. Amt to burn =  44.99999955
# r 50
# {'id': 1, 'agent_attestations_1': 0, 'agent_attestations_0': 0, 'agent_reserve': 50, 'agent_supply_1': 3, 'agent_supply_0': 2, 'agent_supply_free': 45, 'agent_private_alpha': 0.9, 'agent_private_price': 20.0}
#    id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0   0                     0                     0             50
# 1   1                     0                     0             50
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0               3               2                 45                  0.1
# 1               3               2                 45                  0.9
#
#    agent_private_price
# 0                  0.2
# 1                 20.0  Agent burns. Amt to burn =  44.99999955
# Negative attestation. | alpha =  0.5 private_alpha =  0.1
# Negative attestation. | alpha =  0.5 private_alpha =  0.1
# amt_neg =  20.017091080387836
#
# amt_Q0 =  0.09983627336495271
# amt_neg =  15.729505114079844
#    id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1   1                     0                     0             50
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1               3               2                 45                  0.9
#
#    agent_private_price
# 1                 20.0  amt_Q0 =  0.07849349485204549
# ----------------------------
# PRICE pbar (from bondburn update) = 0.988750000112498
# r 50
# r 94.49374956012491
# r 50
#  Time  0
# Agent burns. Amt to burn =  44.99999955
# Negative attestation. | alpha =  0.5 private_alpha =  0.1
# CHOSEN AGENT =     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0   0                     0                     0             50
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0               3               2                 45                  0.1
#
#    agent_private_price
# 0                  0.2  Agent bonds. Amt to bond =  94.49374861518741
# amt_neg =  19.51112272939362
# Agent bonds. Amt to bond =  49.999999499999994
# Negative attestation. | alpha =  0.5 private_alpha =  0.1
# amt_neg =  1.5045133275569518e-07
#    id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0   0                     0                     0             50
# 1   1                     0                     0             50
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0               3               2                 45                  0.1
# 1               3               2                 45                  0.9
#
#    agent_private_price
# 0                  0.2
# 1                 20.0  amt_Q0 =  0.09731883973279398
# amt_Q0 =  7.357003894981062e-10
#    id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0   0                     0                     0             50
# 1   1                     0                     0             50
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0               3               2                 45                  0.1
# 1               3               2                 45                  0.9
#
#    agent_private_price
# 0                  0.2
# 1                 20.0   Time  0
#    id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0   0                     0                     0             50
# 1   1                     0                     0             50
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0               3               2                 45                  0.1
# 1               3               2                 45                  0.9
#
#    agent_private_price
# 0                  0.2
# 1                 20.0
# Positive attestation. | alpha =  0.5 private_alpha =  0.9
#
# ----------------------------
#
# ----------------------------
# CHOSEN AGENT =     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0   0                     0                     0             50
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0               3               2                 45                  0.1
#
#    agent_private_price
# 0                  0.2     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0   0                     0                     0             50
# 1   1                     0                     0             50
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0               3               2                 45                  0.1
# 1               3               2                 45                  0.9
#
#    agent_private_price
# 0                  0.2
# 1                 20.0  CHOSEN AGENT =     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1   1                     0                     0             50
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1               3               2                 45                  0.9
#
#    agent_private_price
# 1                 20.0     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0   0                     0                     0             50
# 1   1                     0                     0             50
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0               3               2                 45                  0.1
# 1               3               2                 45                  0.9
#
#    agent_private_price
# 0                  0.2
# 1                 20.0   Time  0
#
#    id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0   0                     0                     0             50
# 1   1                     0                     0             50
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0               3               2                 45                  0.1
# 1               3               2                 45                  0.9
#
#    agent_private_price
# 0                  0.2
# 1                 20.0  ----------------------------
#  Time  0
#
# ----------------------------
# Chosen Agent:
# {'id': 0, 'agent_attestations_1': 0, 'agent_attestations_0': 0, 'agent_reserve': 50, 'agent_supply_1': 3, 'agent_supply_0': 2, 'agent_supply_free': 45, 'agent_private_alpha': 0.1, 'agent_private_price': 0.2}
# ----------------------------
#    id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0   0                     0                     0             50
# 1   1                     0                     0             50
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0               3               2                 45                  0.1
# 1               3               2                 45                  0.9
#
#    agent_private_price
# 0                  0.2
# 1                 20.0  Chosen Agent:
#
# {'id': 1, 'agent_attestations_1': 0, 'agent_attestations_0': 0, 'agent_reserve': 50, 'agent_supply_1': 3, 'agent_supply_0': 2, 'agent_supply_free': 45, 'agent_private_alpha': 0.9, 'agent_private_price': 20.0}
# ----------------------------
# r 50
#
# CHOSEN AGENT =     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0   0                     0                     0             50
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0               3               2                 45                  0.1
#
#    agent_private_price
# 0                  0.2  Agent burns. Amt to burn =  44.99999955
# r 50
# CHOSEN AGENT =     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1   1                     0                     0             50
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1               3               2                 45                  0.9
#
#    agent_private_price
# 1                 20.0   Time  0
# Agent bonds. Amt to bond =  49.999999499999994
#  Time  0
# Negative attestation. | alpha =  0.5 private_alpha =  0.1
# Chosen Agent:
# Chosen Agent:
# Positive attestation. | alpha =  0.5 private_alpha =  0.9
# {'id': 0, 'agent_attestations_1': 0, 'agent_attestations_0': 0, 'agent_reserve': 50, 'agent_supply_1': 3, 'agent_supply_0': 2, 'agent_supply_free': 45, 'agent_private_alpha': 0.1, 'agent_private_price': 0.2}
# amt_neg =  20.272531216372396
# {'id': 1, 'agent_attestations_1': 0, 'agent_attestations_0': 0, 'agent_reserve': 50, 'agent_supply_1': 3, 'agent_supply_0': 2, 'agent_supply_free': 45, 'agent_private_alpha': 0.9, 'agent_private_price': 20.0}
# amt_Q1 =  0.10197186884604026
# amt_Q0 =  0.10110708999070184
# r 50
# r 50
# r 50
# Agent burns. Amt to burn =  44.99999955
# r 50
# CHOSEN AGENT =  ----------------------------
# CHOSEN AGENT =  Chosen Agent:
# Chosen Agent:
#    id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0   0                     0                     0             50
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0               3               2                 45                  0.1
#
#    agent_private_price
# 0                  0.2  Agent bonds. Amt to bond =  49.999999499999994
# amt_Q1 =  0.08964866390535065
# PRICE pbar (from bondburn update) = 0.988750000112498
# Negative attestation.
#    id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1   1                     0                     0             50
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1               3               2                 45                  0.9
#
#    agent_private_price
# 1                 20.0  {'id': 1, 'agent_attestations_1': 0, 'agent_attestations_0': 0, 'agent_reserve': 50, 'agent_supply_1': 3, 'agent_supply_0': 2, 'agent_supply_free': 45, 'agent_private_alpha': 0.9, 'agent_private_price': 20.0}
# {'id': 0, 'agent_attestations_1': 0, 'agent_attestations_0': 0, 'agent_reserve': 50, 'agent_supply_1': 3, 'agent_supply_0': 2, 'agent_supply_free': 45, 'agent_private_alpha': 0.1, 'agent_private_price': 0.2}
# r 50
# r 94.49374956012491
#  Time  0
# r 50
# r 50
# Negative attestation.
# CHOSEN AGENT =     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1   1                     0                     0             50
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1               3               2                 45                  0.9
#
#    agent_private_price
# 1                 20.0  Agent bonds. Amt to bond =  94.49374861518741
#  Time  0
# Agent bonds. Amt to bond =  49.999999499999994
# Positive attestation. | alpha =  0.5 private_alpha =  0.9
# Negative attestation. | alpha =  0.5 private_alpha =  0.1
# Chosen Agent:
# Chosen Agent:
# Agent burns. Amt to burn =  44.99999955
# Positive attestation. | alpha =  0.5 private_alpha =  0.9
#  Time  0
# amt_neg =  2.0266508428009528e-07
# {'id': 1, 'agent_attestations_1': 0, 'agent_attestations_0': 0, 'agent_reserve': 50, 'agent_supply_1': 3, 'agent_supply_0': 2, 'agent_supply_free': 45, 'agent_private_alpha': 0.9, 'agent_private_price': 20.0}
# Negative attestation. | alpha =  0.5 private_alpha =  0.1
# amt_Q1 =  0.07610260852726647
# {'id': 0, 'agent_attestations_1': 0, 'agent_attestations_0': 0, 'agent_reserve': 50, 'agent_supply_1': 3, 'agent_supply_0': 2, 'agent_supply_free': 45, 'agent_private_alpha': 0.1, 'agent_private_price': 0.2}
# amt_Q0 =  9.910250398093012e-10
# Chosen Agent:
# Agent bonds. Amt to bond =  49.999999499999994
# r 50
# amt_Q1 =  0.08059609076171537
# amt_neg =  16.04093726769162
# r 50
# Agent bonds. Amt to bond =  49.999999499999994
# Negative attestation.
# amt_Q0 =  0.08004450825591203
# Agent bonds. Amt to bond =  49.999999499999994
# r 50
# {'id': 1, 'agent_attestations_1': 0, 'agent_attestations_0': 0, 'agent_reserve': 50, 'agent_supply_1': 3, 'agent_supply_0': 2, 'agent_supply_free': 45, 'agent_private_alpha': 0.9, 'agent_private_price': 20.0}
# Positive attestation. | alpha =  0.5 private_alpha =  0.9
# Negative attestation.
# Positive attestation. | alpha =  0.5 private_alpha =  0.9
# r 50
# r 50
# amt_Q1 =  0.08630402013118932
# Negative attestation.
# Agent burns. Amt to burn =  44.99999955
# Agent burns. Amt to burn =  44.99999955
# amt_Q1 =  0.07709107137729543
# Positive attestation. | alpha =  0.5 private_alpha =  0.9
# Agent bonds. Amt to bond =  49.999999499999994
# Negative attestation. | alpha =  0.5 private_alpha =  0.1
# Negative attestation.
# Negative attestation. | alpha =  0.5 private_alpha =  0.1
# PRICE pbar (from bondburn update) = 1.0123475381759899
# r 50
# Positive attestation. | alpha =  0.5 private_alpha =  0.9
# amt_neg =  20.033790848235988
# Negative attestation.
# r 50
# Agent bonds. Amt to bond =  49.999999499999994
# amt_neg =  21.151870106868262
# r 5.000000058430487e-07
# amt_Q0 =  0.09991935729213974
# amt_Q1 =  0.09119260867184398
# Positive attestation. | alpha =  0.5 private_alpha =  0.9
# amt_Q0 =  0.10548119347989271
# PRICE pbar (from bondburn update) = 0.988750000112498
# r 50
# amt_Q1 =  0.1118699205206708
# r 50
# Agent bonds. Amt to bond =  49.999999499999994
# Negative attestation.
# amt_Q1 =  0.08782348758391123
# r 94.49374956012491
# Agent bonds. Amt to bond =  49.999999499999994
# Negative attestation. | alpha =  0.5 private_alpha =  0.1
# PRICE pbar (from bondburn update) = 1.0123475381759899
# Agent bonds. Amt to bond =  5.000000008430486e-07
# Positive attestation. | alpha =  0.5 private_alpha =  0.9
# Agent bonds. Amt to bond =  94.49374861518741
# PRICE pbar (from bondburn update) = 1.0123475381759899
# Agent burns. Amt to burn =  44.99999955
# Positive attestation. | alpha =  0.5 private_alpha =  0.9
# r 5.000000058430487e-07
# Negative attestation. | alpha =  0.5 private_alpha =  0.1
# Negative attestation. | alpha =  0.5 private_alpha =  0.1
# amt_Q1 =  0.09143252402338486
# Agent bonds. Amt to bond =  5.000000008430486e-07
# amt_neg =  16.012015559375666
# amt_neg =  1.6851941273654545e-07
# Positive attestation. | alpha =  0.5 private_alpha =  0.9
# PRICE pbar (from bondburn update) = 1.0123475381759899
# Positive attestation. | alpha =  0.5 private_alpha =  0.9
# amt_Q0 =  8.240563786898747e-10
# amt_Q0 =  0.0799004756466637
# amt_Q1 =  0.0920378082038198
# r 5.000000058430487e-07
# amt_Q1 =  0.22653143012795862
# r 5.000000058430487e-07
# amt_Q1 =  0.18592336303261625
# Negative attestation.
# PRICE pbar (from bondburn update) = 0.988750000112498
# Agent bonds. Amt to bond =  5.000000008430486e-07
# Positive attestation
# Negative attestation.
# Negative attestation.
# Positive attestation
# r 94.49374956012491
# Positive attestation. | alpha =  0.5 private_alpha =  0.9
# Agent bonds. Amt to bond =  5.000000008430486e-07
# PRICE pbar (from bondburn update) = 1.0123475381759899
# Negative attestation.
# Positive attestation. | alpha =  0.5 private_alpha =  0.9
# Positive attestation
# Agent bonds. Amt to bond =  94.49374861518741
# amt_Q1 =  0.2101847417170477
# Negative attestation.
# Negative attestation. | alpha =  0.5 private_alpha =  0.1
# Positive attestation
# Negative attestation.
# Positive attestation
# Positive attestation
# amt_neg =  1.6830172894055863e-07
# r 5.000000058430487e-07
# amt_neg =  19.477413470930422
# Positive attestation
# amt_Q0 =  8.229905645862345e-10
# Agent bonds. Amt to bond =  5.000000008430486e-07
# Negative attestation.
# Positive attestation
# amt_Q1 =  0.15996772683044114
# Positive attestation
# Negative attestation.
# Negative attestation.
# Positive attestation. | alpha =  0.5 private_alpha =  0.9
# Positive attestation
# Positive attestation
# Positive attestation
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          9.910250e-10       94.49375
# 1  1.0                   0.0          0.000000e+00       50.00000
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0             2.0       2.473349e-07                  0.1
# 1             3.0             2.0       4.500000e+01                  0.9
#
#    agent_private_price
# 0                  0.2
# 1                 20.0  Positive attestation
# Negative attestation.
# Positive attestation
# Positive attestation
#
# Agent burns. Amt to burn =  44.99999955
# Agent bonds. Amt to bond =  49.999999499999994
# amt_Q0 =  0.09715110890561096
# amt_Q1 =  0.192977062548918
# Positive attestation. | alpha =  0.5 private_alpha =  0.9
# Positive attestation
# Negative attestation. | alpha =  0.5 private_alpha =  0.1
# r 50
# Positive attestation
# amt_Q1 =  0.09783607097030522
# ----------------------------
# amt_neg =  16.68130700085115
# Agent burns. Amt to burn =  44.99999955
# Positive attestation
# Positive attestation
# PRICE pbar (from bondburn update) = 1.0123475381759899
# amt_Q0 =  0.08323334028089935
# Negative attestation. | alpha =  0.5 private_alpha =  0.1
# Positive attestation
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          7.357004e-10       94.49375
# 1  1.0                   0.0          0.000000e+00       50.00000
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0             2.0       2.995487e-07                  0.1
# 1             3.0             2.0       4.500000e+01                  0.9
#
#    agent_private_price
# 0                  0.2
# 1                 20.0  Positive attestation
# r 5.000000058430487e-07
# PRICE pbar (from bondburn update) = 0.988750000112498
# amt_neg =  16.760827334053396
# Positive attestation
#
# Positive attestation
# r 94.49374956012491
# Agent bonds. Amt to bond =  5.000000008430486e-07
# amt_Q0 =  0.08362929021571652
# Positive attestation
# Positive attestation
# Positive attestation. | alpha =  0.5 private_alpha =  0.9
# ----------------------------
# Agent bonds. Amt to bond =  94.49374861518741
# PRICE pbar (from bondburn update) = 0.988750000112498
# amt_Q1 =  0.2029475226113986
# Negative attestation.
# Negative attestation. | alpha =  0.5 private_alpha =  0.1
# Positive attestation
# amt_neg =  1.4909422718033273e-07
# r 94.49374956012491
# Negative attestation.
# Positive attestation
# amt_Q0 =  7.290656967029463e-10
# Positive attestation
# Negative attestation.
# Positive attestation
# Positive attestation
# Negative attestation.
#    id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0   0                     0                     0             50
# 1   1                     0                     0             50
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0               3               2                 45                  0.1
# 1               3               2                 45                  0.9
#
#    agent_private_price
# 0                  0.2
# 1                 20.0  Agent bonds. Amt to bond =  94.49374861518741
#    id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0   0                     0                     0             50
# 1   1                     0                     0             50
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0               3               2                 45                  0.1
# 1               3               2                 45                  0.9
#
#    agent_private_price
# 0                  0.2
# 1                 20.0
# Negative attestation.
#
# ----------------------------
# amt_Q1 =  0.07858122393251754
# PRICE pbar (from bondburn update) = 1.3088426948778706
# Negative attestation. | alpha =  0.5 private_alpha =  0.1
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000                   0.0   5.000000e+01
# 1  1.0              0.192977                   0.0   5.000000e-07
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000             2.0          45.000000                  0.1
# 1       42.739328             2.0          54.650825                  0.9
#
#    agent_private_price
# 0                  0.2
# 1                 20.0  ----------------------------
# amt_neg =  1.4935780290337054e-07
# Negative attestation.
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000                   0.0   5.000000e+01
# 1  1.0              0.185923                   0.0   5.000000e-07
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000             2.0          45.000000                  0.1
# 1       41.280057             2.0          56.110096                  0.9
#
#    agent_private_price
# 0                  0.2
# 1                 20.0
# amt_Q0 =  7.303535554115115e-10
# ----------------------------
# Negative attestation.
# Negative attestation.
# Negative attestation.
# CHOSEN AGENT =     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0   0                     0                     0             50
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0               3               2                 45                  0.1
#
#    agent_private_price
# 0                  0.2  CHOSEN AGENT =  Negative attestation.
# CHOSEN AGENT =     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1   1                     0                     0             50
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1               3               2                 45                  0.9
#
#    agent_private_price
# 1                 20.0   Time  0
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0              0.192977                   0.0   5.000000e-07
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1       42.739328             2.0          54.650825                  0.9
#
#    agent_private_price
# 1                 20.0  Negative attestation.
#  Time  0
#  Time  1
# Chosen Agent:
# Negative attestation.
# CHOSEN AGENT =
# Chosen Agent:
# {'id': 0, 'agent_attestations_1': 0, 'agent_attestations_0': 0, 'agent_reserve': 50, 'agent_supply_1': 3, 'agent_supply_0': 2, 'agent_supply_free': 45, 'agent_private_alpha': 0.1, 'agent_private_price': 0.2}
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0                   0.0                   0.0           50.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1             3.0             2.0               45.0                  0.9
#
#    agent_private_price
# 1                 20.0  Chosen Agent:
# {'id': 1, 'agent_attestations_1': 0, 'agent_attestations_0': 0, 'agent_reserve': 50, 'agent_supply_1': 3, 'agent_supply_0': 2, 'agent_supply_free': 45, 'agent_private_alpha': 0.9, 'agent_private_price': 20.0}
# r 50
# Agent burns. Amt to burn =  44.99999955
# r 50
# Negative attestation. | alpha =  0.5 private_alpha =  0.1
# Agent bonds. Amt to bond =  49.999999499999994
# amt_neg =  20.65919444851436
# ----------------------------
# amt_Q0 =  0.10303058968231582
# Positive attestation. | alpha =  0.5 private_alpha =  0.9
# amt_Q1 =  0.11309864388547641
# r 50
# {'id': 1.0, 'agent_attestations_1': 0.192977062548918, 'agent_attestations_0': 0.0, 'agent_reserve': 5.000000058430487e-07, 'agent_supply_1': 42.739328143225535, 'agent_supply_0': 2.0, 'agent_supply_free': 54.650824560744226, 'agent_private_alpha': 0.9, 'agent_private_price': 20.0}
# Agent burns. Amt to burn =  44.99999955
# r 50
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          7.303536e-10       94.49375
# 1  1.0                   0.0          0.000000e+00       50.00000
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0             2.0       3.006422e-07                  0.1
# 1             3.0             2.0       4.500000e+01                  0.9
#
#    agent_private_price
# 0                  0.2
# 1                 20.0  Agent bonds. Amt to bond =  49.999999499999994
# Negative attestation. | alpha =  0.5 private_alpha =  0.1
# r 5.000000058430487e-07
#
# Positive attestation. | alpha =  0.5 private_alpha =  0.9
# amt_neg =  16.807616027981886
# ----------------------------
# amt_Q1 =  0.07545400761762355
# Agent bonds. Amt to bond =  5.000000008430486e-07
# amt_Q0 =  0.0838622581812265
# PRICE pbar (from bondburn update) = 1.0123475381759899
# PRICE pbar (from bondburn update) = 0.988750000112498
# r 5.000000058430487e-07
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0              0.185923                   0.0   5.000000e-07
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1       41.280057             2.0          56.110096                  0.9
#
#    agent_private_price
# 1                 20.0   Time  1
# r 94.49374956012491
# Agent bonds. Amt to bond =  5.000000008430486e-07
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0                   0.0                   0.0           50.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1             3.0             2.0               45.0                  0.9
#
#    agent_private_price
# 1                 20.0  Agent bonds. Amt to bond =  94.49374861518741
# Chosen Agent:
# Positive attestation. | alpha =  0.6237623760023527 private_alpha =  0.9
# Positive attestation. | alpha =  0.5 private_alpha =  0.9
#  Time  1
# Negative attestation. | alpha =  0.5 private_alpha =  0.1
# amt_Q1 =  0.0839325973913585
# amt_Q1 =  0.18125876923152262
# amt_neg =  1.916299348308016e-07
# Chosen Agent:
# amt_Q0 =  9.370637599204201e-10
# Positive attestation
# {'id': 1.0, 'agent_attestations_1': 0.18592336303261625, 'agent_attestations_0': 0.0, 'agent_reserve': 5.000000058430487e-07, 'agent_supply_1': 41.280056655150716, 'agent_supply_0': 2.0, 'agent_supply_free': 56.110096048819045, 'agent_private_alpha': 0.9, 'agent_private_price': 20.0}
# r 5.000000058430487e-07
# {'id': 1.0, 'agent_attestations_1': 0.0, 'agent_attestations_0': 0.0, 'agent_reserve': 50.0, 'agent_supply_1': 3.0, 'agent_supply_0': 2.0, 'agent_supply_free': 45.0, 'agent_private_alpha': 0.9, 'agent_private_price': 20.0}
#  Time  1
# Negative attestation.
# Positive attestation
# r 5.000000058430487e-07
# Agent bonds. Amt to bond =  5.000000008430486e-07
# r 50.0
# Positive attestation
# Negative attestation.
# Positive attestation. | alpha =  0.6237623760023527 private_alpha =  0.9
# Positive attestation
# Agent bonds. Amt to bond =  49.999999499999994
# Negative attestation.
# Positive attestation
# amt_Q1 =  0.08056184226380214
# Positive attestation. | alpha =  0.6211686254846903 private_alpha =  0.9
# Agent bonds. Amt to bond =  5.000000008430486e-07
# Negative attestation.
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000                   0.0   5.000000e+01
# 1  1.0              0.159968                   0.0   5.000000e-07
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000             2.0          45.000000                  0.1
# 1       35.914736             2.0          61.475416                  0.9
#
#    agent_private_price
# 0                  0.2
# 1                 20.0      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0                   0.0                   0.0           50.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1             3.0             2.0               45.0                  0.9
#
#    agent_private_price
# 1                 20.0      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          8.229906e-10       94.49375
# 1  1.0                   0.0          0.000000e+00       50.00000
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0             2.0       2.816983e-07                  0.1
# 1             3.0             2.0       4.500000e+01                  0.9
#
#    agent_private_price
# 0                  0.2
# 1                 20.0  r 5.000000124016587e-15
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          8.240564e-10       94.49375
# 1  1.0                   0.0          0.000000e+00       50.00000
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0             2.0       2.814806e-07                  0.1
# 1             3.0             2.0       4.500000e+01                  0.9
#
#    agent_private_price
# 0                  0.2
# 1                 20.0      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000                   0.0   5.000000e+01
# 1  1.0              0.226531                   0.0   5.000000e-07
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000             2.0          45.000000                  0.1
# 1       49.688047             2.0          47.702106                  0.9
#
#    agent_private_price
# 0                  0.2
# 1                 20.0
#  Time  1
#
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000                   0.0   5.000000e+01
# 1  1.0              0.210185                   0.0   5.000000e-07
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000             2.0          45.000000                  0.1
# 1       46.301397             2.0          51.088756                  0.9
#
#    agent_private_price
# 0                  0.2
# 1                 20.0
# Chosen Agent:
#
#
# Chosen Agent:
# ----------------------------
# ----------------------------
# ----------------------------
# ----------------------------
# {'id': 1.0, 'agent_attestations_1': 0.0, 'agent_attestations_0': 0.0, 'agent_reserve': 50.0, 'agent_supply_1': 3.0, 'agent_supply_0': 2.0, 'agent_supply_free': 45.0, 'agent_private_alpha': 0.9, 'agent_private_price': 20.0}
# Positive attestation. | alpha =  0.6237623760023527 private_alpha =  0.9
# ----------------------------
# {'id': 1.0, 'agent_attestations_1': 0.0, 'agent_attestations_0': 0.0, 'agent_reserve': 50.0, 'agent_supply_1': 3.0, 'agent_supply_0': 2.0, 'agent_supply_free': 45.0, 'agent_private_alpha': 0.9, 'agent_private_price': 20.0}
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000                   0.0   5.000000e+01
# 1  1.0              0.202948                   0.0   5.000000e-07
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0         3.00000             2.0          45.000000                  0.1
# 1        44.80289             2.0          52.587263                  0.9
#
#    agent_private_price
# 0                  0.2
# 1                 20.0      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          7.290657e-10       94.49375
# 1  1.0                   0.0          0.000000e+00       50.00000
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0             2.0       3.009058e-07                  0.1
# 1             3.0             2.0       4.500000e+01                  0.9
#
#    agent_private_price
# 0                  0.2
# 1                 20.0  CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0              0.159968                   0.0   5.000000e-07
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1       35.914736             2.0          61.475416                  0.9
#
#    agent_private_price
# 1                 20.0  r 50.0
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0              0.210185                   0.0   5.000000e-07
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1       46.301397             2.0          51.088756                  0.9
#
#    agent_private_price
# 1                 20.0  r 50.0
#
#  Time  1
# Agent bonds. Amt to bond =  49.999999499999994
# CHOSEN AGENT =  CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0              0.226531                   0.0   5.000000e-07
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1       49.688047             2.0          47.702106                  0.9
#
#    agent_private_price
# 1                 20.0  Agent bonds. Amt to bond =  49.999999499999994
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0                   0.0                   0.0           50.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1             3.0             2.0               45.0                  0.9
#
#    agent_private_price
# 1                 20.0  ----------------------------
#  Time  1
# Chosen Agent:
# CHOSEN AGENT =   Time  1
# Positive attestation. | alpha =  0.6211686254846903 private_alpha =  0.9
# {'id': 1.0, 'agent_attestations_1': 0.15996772683044114, 'agent_attestations_0': 0.0, 'agent_reserve': 5.000000058430487e-07, 'agent_supply_1': 35.91473647453162, 'agent_supply_0': 2.0, 'agent_supply_free': 61.47541622943814, 'agent_private_alpha': 0.9, 'agent_private_price': 20.0}
#  Time  1
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0                   0.0                   0.0           50.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1             3.0             2.0               45.0                  0.9
#
#    agent_private_price
# 1                 20.0  Chosen Agent:
# amt_Q1 =  0.08007086943609852
# Positive attestation. | alpha =  0.6211686254846903 private_alpha =  0.9
# amt_Q1 =  0.09632554954113637
# Chosen Agent:
# r 5.000000058430487e-07
# Chosen Agent:
#  Time  1
# {'id': 1.0, 'agent_attestations_1': 0.22653143012795862, 'agent_attestations_0': 0.0, 'agent_reserve': 5.000000058430487e-07, 'agent_supply_1': 49.68804698544697, 'agent_supply_0': 2.0, 'agent_supply_free': 47.702105718522795, 'agent_private_alpha': 0.9, 'agent_private_price': 20.0}
# r 50.0
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0              0.202948                   0.0   5.000000e-07
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1        44.80289             2.0          52.587263                  0.9
#
#    agent_private_price
# 1                 20.0  amt_Q1 =  0.07241842931258198
# {'id': 1.0, 'agent_attestations_1': 0.2101847417170477, 'agent_attestations_0': 0.0, 'agent_reserve': 5.000000058430487e-07, 'agent_supply_1': 46.30139696980077, 'agent_supply_0': 2.0, 'agent_supply_free': 51.08875573416899, 'agent_private_alpha': 0.9, 'agent_private_price': 20.0}
# Agent bonds. Amt to bond =  5.000000008430486e-07
# {'id': 1.0, 'agent_attestations_1': 0.0, 'agent_attestations_0': 0.0, 'agent_reserve': 50.0, 'agent_supply_1': 3.0, 'agent_supply_0': 2.0, 'agent_supply_free': 45.0, 'agent_private_alpha': 0.9, 'agent_private_price': 20.0}
#
# Agent bonds. Amt to bond =  49.999999499999994
# r 5.000000058430487e-07
# Chosen Agent:
#  Time  1
# Positive attestation. | alpha =  0.6237623760023527 private_alpha =  0.9
# r 5.000000058430487e-07
# Positive attestation. | alpha =  0.6211686254846903 private_alpha =  0.9
# r 50.0
# Agent bonds. Amt to bond =  5.000000008430486e-07
# {'id': 1.0, 'agent_attestations_1': 0.0, 'agent_attestations_0': 0.0, 'agent_reserve': 50.0, 'agent_supply_1': 3.0, 'agent_supply_0': 2.0, 'agent_supply_free': 45.0, 'agent_private_alpha': 0.9, 'agent_private_price': 20.0}
# amt_Q1 =  0.08535927586592607
# Chosen Agent:
# Agent bonds. Amt to bond =  5.000000008430486e-07
# amt_Q1 =  0.05357376343621551
# r 50.0
# Positive attestation. | alpha =  0.6237623760023527 private_alpha =  0.9
# Agent bonds. Amt to bond =  49.999999499999994
# r 5.000000058430487e-07
# r 50.0
# Positive attestation. | alpha =  0.6237623760023527 private_alpha =  0.9
# PRICE pbar (from bondburn update) = 1.3680678981163137
# Positive attestation. | alpha =  0.6211686254846903 private_alpha =  0.9
# Agent bonds. Amt to bond =  5.000000008430486e-07
# amt_Q1 =  0.07627419869650431
# Agent bonds. Amt to bond =  49.999999499999994
# amt_Q1 =  0.07791856872148006
# amt_Q1 =  0.07098756293334951
# r 5.000002332167242e-07
# Positive attestation. | alpha =  0.6237623760023527 private_alpha =  0.9
# ----------------------------
# {'id': 1.0, 'agent_attestations_1': 0.2029475226113986, 'agent_attestations_0': 0.0, 'agent_reserve': 5.000000058430487e-07, 'agent_supply_1': 44.80288958682026, 'agent_supply_0': 2.0, 'agent_supply_free': 52.587263117149504, 'agent_private_alpha': 0.9, 'agent_private_price': 20.0}
# r 5.000000058430487e-07
# Positive attestation. | alpha =  0.6211686254846903 private_alpha =  0.9
# Agent bonds. Amt to bond =  49.999999499999994
# Agent bonds. Amt to bond =  5.000002282167218e-07
# r 50.0
# r 5.000000058430487e-07
# amt_Q1 =  0.08509266200920518
# Agent bonds. Amt to bond =  5.000000008430486e-07
# amt_Q1 =  0.06023528152867171
# Positive attestation. | alpha =  0.6211686254846903 private_alpha =  0.9
# Agent bonds. Amt to bond =  49.999999499999994
# Agent bonds. Amt to bond =  5.000000008430486e-07
# PRICE pbar (from bondburn update) = 1.3088426948778706
# Positive attestation. | alpha =  0.6237623760023527 private_alpha =  0.9
# Positive attestation. | alpha =  0.6211686254846903 private_alpha =  0.9
# r 50.0
# amt_Q1 =  0.10543513221608222
# Positive attestation. | alpha =  0.6211686254846903 private_alpha =  0.9
# r 5.000000124016587e-15
# Positive attestation. | alpha =  0.6237623760023527 private_alpha =  0.9
# r 5.000000058430487e-07
# amt_Q1 =  0.07303043733816218
# amt_Q1 =  0.07858074888698496
# Agent bonds. Amt to bond =  49.999999499999994
# Positive attestation
# Agent bonds. Amt to bond =  5.0000000740165855e-15
# amt_Q1 =  0.08706402051142703
# PRICE pbar (from bondburn update) = 1.3088426948778706
# PRICE pbar (from bondburn update) = 1.3680678981163137
# Positive attestation
# Positive attestation. | alpha =  0.6211686254846903 private_alpha =  0.9
# Positive attestation. | alpha =  0.6237623760023527 private_alpha =  0.9
# PRICE pbar (from bondburn update) = 1.3088426948778706
# amt_Q1 =  0.0595933859112205
# r 5.000000058430487e-07
# Negative attestation.
#    id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0   0                     0                     0             50
# 1   1                     0                     0             50
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0               3               2                 45                  0.1
# 1               3               2                 45                  0.9
#
#    agent_private_price
# 0                  0.2
# 1                 20.0  CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0                   0.0                   0.0           50.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1             3.0             2.0               45.0                  0.9
#
#    agent_private_price
# ...
# r 50.0
# Positive attestation. | alpha =  0.8309073517233295 private_alpha =  0.9
# Agent bonds. Amt to bond =  5.00000229747805e-15
# ----------------------------
# Positive attestation
# Agent bonds. Amt to bond =  5.000002315682486e-23
# Positive attestation
# ----------------------------
# Chosen Agent:
# Agent bonds. Amt to bond =  5.000002315682486e-23
# Positive attestation
# PRICE pbar (from bondburn update) = 5.000000074016585e-10
# Positive attestation
# r 5.000000156871975e-23
# Agent burns. Amt to burn =  2.5826714464091406e-07
# {'id': 1.0, 'agent_attestations_1': 0.18142321202396372, 'agent_attestations_0': 0.0, 'agent_reserve': 5.0000023474780736e-15, 'agent_supply_1': 40.8510351760911, 'agent_supply_0': 2.0, 'agent_supply_free': 43.69685851121557, 'agent_private_alpha': 0.9, 'agent_private_price': 20.0}
# r 94.49374985587417
# Positive attestation. | alpha =  0.6445157061194485 private_alpha =  0.9
# amt_Q1 =  0.01687410375419418
# Agent burns. Amt to burn =  44.99999955
# Positive attestation. | alpha =  0.759850467402821 private_alpha =  0.9
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0              0.231524                   0.0   5.000000e-15
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1       50.599667             2.0          46.790486                  0.9
#
#    agent_private_price
# 1                 20.0      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000          1.352403e-09   1.259546e+02
# 1  1.0              0.302664          0.000000e+00   5.000000e-23
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000             2.0       1.667542e-07                  0.1
# 1       65.365749             2.0       3.202440e+01                  0.9
#
#    agent_private_price
# 0                  0.2
# 1                 20.0  Positive attestation. | alpha =  0.8000136514174153 private_alpha =  0.9
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0              0.239637                   0.0   5.000002e-23
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1       53.005681             2.0          31.542213                  0.9
#
#    agent_private_price
# 1                 20.0      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000          9.279066e-10   9.449375e+01
# 1  1.0              0.146765          0.000000e+00   5.000002e-07
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000             2.0       2.602431e-07                  0.1
# 1       33.661974             2.0       5.088592e+01                  0.9
#
#    agent_private_price
# 0                  0.2
# 1                 20.0  {'id': 0.0, 'agent_attestations_1': 0.0, 'agent_attestations_0': 1.436153418410413e-09, 'agent_reserve': 119.55426058736623, 'agent_supply_1': 3.0, 'agent_supply_0': 2.0000003007869585, 'agent_supply_free': 1.4921304344144167e-07, 'agent_private_alpha': 0.1, 'agent_private_price': 0.2}
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0                   0.0           50.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0             2.0               45.0                  0.1
#
#    agent_private_price
# 0                  0.2  Positive attestation. | alpha =  0.8059233684538953 private_alpha =  0.9
# Positive attestation
# r 5.000000156871975e-23
# Negative attestation. | alpha =  0.6445157061182695 private_alpha =  0.1
# Agent bonds. Amt to bond =  5.000000106871973e-23
# Agent bonds. Amt to bond =  94.49374891093667
# r 5.0000023474780736e-15
# r 5.000000156871975e-23
# Negative attestation. | alpha =  0.8330281129110955 private_alpha =  0.1
# amt_Q1 =  0.06415916290796589
# amt_Q1 =  0.044790206389306024
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0               0.00000          1.389262e-09   1.221533e+02
# 1  1.0               0.30002          0.000000e+00   5.000000e-23
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000             2.0       1.590346e-07                  0.1
# 1       64.772794             2.0       3.261736e+01                  0.9
#
#    agent_private_price
# 0                  0.2
# 1                 20.0   Time  4
# amt_Q1 =  0.03142691510211878
#
#  Time  2
#
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0               0.00000          7.290657e-10   9.449375e+01
# 1  1.0               0.20429          0.000000e+00   5.000002e-15
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000             2.0      -4.517383e-13                  0.1
# 1       45.632723             2.0       3.891517e+01                  0.9
#
#    agent_private_price
# 0                  0.2
# 1                 20.0   Time  4
# r 119.55426058736623
# amt_Q1 =  0.018746000842537417
# amt_neg =  1.1955242190742928e-07
# Agent bonds. Amt to bond =  5.000000106871973e-23
# Positive attestation. | alpha =  0.7749329708777336 private_alpha =  0.9
# Agent supply too low. Cannot attest
# Agent bonds. Amt to bond =  5.00000229747805e-15
# Agent bonds. Amt to bond =  5.000000106871973e-23
# amt_neg =  29.61116338350805
# r 5.000002332167242e-07
#
# r 5.0000023474780736e-15
# Chosen Agent:
# r 5.0000023656825094e-23
# ----------------------------
# Chosen Agent:
# ----------------------------
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000                   0.0   5.000000e+01
# 1  1.0              0.326451                   0.0   5.000000e-31
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000             2.0          45.000000                  0.1
# 1       70.163814             2.0          27.226339                  0.9
#
#    agent_private_price
# 0                  0.2
# 1                 20.0
# Agent burns. Amt to burn =  1.4921304194931124e-07
# Chosen Agent:
# r 5.0000023656825094e-23
# amt_Q1 =  0.029534151740300274
# amt_Q0 =  5.743405751260102e-10
# Positive attestation. | alpha =  0.8074335966559104 private_alpha =  0.9
# Positive attestation. | alpha =  0.7559295169784641 private_alpha =  0.9
# Positive attestation. | alpha =  0.8309073517233295 private_alpha =  0.9
# amt_Q0 =  0.14396950209938364
# ----------------------------
# Agent bonds. Amt to bond =  5.000002282167218e-07
# Agent bonds. Amt to bond =  5.00000229747805e-15
# {'id': 1.0, 'agent_attestations_1': 0.23963651658908283, 'agent_attestations_0': 0.0, 'agent_reserve': 5.0000023656825094e-23, 'agent_supply_1': 53.00568090774848, 'agent_supply_0': 2.0, 'agent_supply_free': 31.54221276928045, 'agent_private_alpha': 0.9, 'agent_private_price': 20.0}
# Agent bonds. Amt to bond =  5.000002315682486e-23
# {'id': 1.0, 'agent_attestations_1': 0.2315243791324617, 'agent_attestations_0': 0.0, 'agent_reserve': 5.000000124016587e-15, 'agent_supply_1': 50.59966699736414, 'agent_supply_0': 2.0, 'agent_supply_free': 46.7904860886225, 'agent_private_alpha': 0.9, 'agent_private_price': 20.0}
#
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          1.352403e-09     125.954621
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0             2.0       1.667542e-07                  0.1
#
#    agent_private_price
# 0                  0.2      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000          9.672307e-10   9.449375e+01
# 1  1.0              0.133577          0.000000e+00   5.000002e-07
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000             2.0      -4.522253e-13                  0.1
# 1       30.897643             2.0       5.365025e+01                  0.9
#
#    agent_private_price
# 0                  0.2
# 1                 20.0  ----------------------------
# Negative attestation. | alpha =  0.8402560470387557 private_alpha =  0.1
# {'id': 0.0, 'agent_attestations_1': 0.0, 'agent_attestations_0': 0.0, 'agent_reserve': 50.0, 'agent_supply_1': 3.0, 'agent_supply_0': 2.0, 'agent_supply_free': 45.0, 'agent_private_alpha': 0.1, 'agent_private_price': 0.2}
# Agent bonds. Amt to bond =  5.000002315682486e-23
# amt_Q1 =  0.02215906829982739
# Positive attestation
# PRICE pbar (from bondburn update) = 1.172669343927388
# amt_Q1 =  0.017560602568784667
# amt_Q1 =  0.029440679920011086
# Positive attestation. | alpha =  0.6445157061194485 private_alpha =  0.9
# r 50.0
# Positive attestation. | alpha =  0.759850467402821 private_alpha =  0.9
# ----------------------------
# Positive attestation. | alpha =  0.8000136514174153 private_alpha =  0.9
#  Time  4
#
# amt_neg =  1.0053657769534788e-07
# CHOSEN AGENT =  r 5.0000023656825094e-23
# r 5.000000124016587e-15
# Positive attestation. | alpha =  0.8059233684538953 private_alpha =  0.9
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          9.279066e-10       94.49375
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0             2.0       2.602431e-07                  0.1
#
#    agent_private_price
# 0                  0.2  r 50.0
# Positive attestation
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0          1.389262e-09     122.153317
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0             2.0       1.590346e-07                  0.1
#
#    agent_private_price
# 0                  0.2  Positive attestation
# r 94.49374986298687
# PRICE pbar (from bondburn update) = 1.0995116512773954e-10
# Agent burns. Amt to burn =  44.99999955
# amt_Q1 =  0.08097986819308897
# r 5.0000023474780736e-15
# amt_Q1 =  0.032434054752206884
# amt_Q1 =  0.038558629941878614
# amt_Q0 =  4.800249087455991e-10
# ----------------------------
# Chosen Agent:
# Agent bonds. Amt to bond =  5.000002315682486e-23
# amt_Q1 =  0.022839673899941047
# Agent bonds. Amt to bond =  5.0000000740165855e-15
#  Time  4
# Positive attestation
# Agent burns. Amt to burn =  44.99999955
# Positive attestation
# Agent bonds. Amt to bond =  94.49374891804938
# r 5.000000192179537e-31
# Negative attestation. | alpha =  0.8330281129110955 private_alpha =  0.1
# PRICE pbar (from bondburn update) = 1.1450734574274597
# Agent bonds. Amt to bond =  5.00000229747805e-15
# PRICE pbar (from bondburn update) = -5.497560684999819e-11
# PRICE pbar (from bondburn update) = 5.00000229747805e-10
# r 119.55426058736623
# {'id': 0.0, 'agent_attestations_1': 0.0, 'agent_attestations_0': 1.3524026343247897e-09, 'agent_reserve': 125.95462120865466, 'agent_supply_1': 3.0, 'agent_supply_0': 2.0000002832458352, 'agent_supply_free': 1.667541662591544e-07, 'agent_private_alpha': 0.1, 'agent_private_price': 0.2}
# Positive attestation. | alpha =  0.8189680188546147 private_alpha =  0.9
# PRICE pbar (from bondburn update) = 1.0995121369999639e-10
# Positive attestation. | alpha =  0.7724042428598475 private_alpha =  0.9
# Positive attestation
# Chosen Agent:
# Negative attestation. | alpha =  0.842118179456802 private_alpha =  0.1
# Agent supply too low. Cannot attest
# Agent bonds. Amt to bond =  5.000000142179535e-31
# amt_neg =  32.575838948312615
# r 5.0000023474780736e-15
# Positive attestation. | alpha =  0.7559295169784641 private_alpha =  0.9
# CHOSEN AGENT =  Positive attestation
# r 5.0000023656825094e-23
# r 5.000002366844086e-31
# Agent burns. Amt to burn =  1.4921304194931124e-07
# r 125.95462120865466
#  Time  2
# amt_Q1 =  0.011528932812011125
# r 5.000002366844086e-31
# amt_Q1 =  0.044438051885236085
# Positive attestation
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0              0.133577                   0.0   5.000002e-07
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1       30.897643             2.0           53.65025                  0.9
#
#    agent_private_price
# 1                 20.0  {'id': 0.0, 'agent_attestations_1': 0.0, 'agent_attestations_0': 1.3892620387423449e-09, 'agent_reserve': 122.15331711073179, 'agent_supply_1': 3.0, 'agent_supply_0': 2.000000290966321, 'agent_supply_free': 1.590345904447906e-07, 'agent_private_alpha': 0.1, 'agent_private_price': 0.2}
# amt_neg =  29.685787175143076
# Positive attestation. | alpha =  0.8309073517233295 private_alpha =  0.9
# amt_Q0 =  0.1583271310278178
# Agent bonds. Amt to bond =  5.00000229747805e-15
# Positive attestation
# amt_Q1 =  0.036670608185279854
# Agent bonds. Amt to bond =  5.000002315682486e-23
# Agent bonds. Amt to bond =  5.000002316844062e-31
# Agent burns. Amt to burn =  1.6675416459161273e-07
# Negative attestation. | alpha =  0.8402560470387557 private_alpha =  0.1
# Agent bonds. Amt to bond =  5.000002316844062e-31
# r 5.0000023656825094e-23
#  Time  3
# Chosen Agent:
# r 5.000000124016587e-15
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000          9.375700e-10   9.449375e+01
# 1  1.0              0.142118          0.000000e+00   5.000002e-07
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000             2.0      -9.069120e-13                  0.1
# 1       32.687696             2.0       5.186020e+01                  0.9
#
#    agent_private_price
# 0                  0.2
# 1                 20.0  Positive attestation
# CHOSEN AGENT =  CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 1  1.0               0.20429                   0.0   5.000002e-15
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 1       45.632723             2.0          38.915171                  0.9
#
#    agent_private_price
# 1                 20.0  amt_Q0 =  0.14433102324946656
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0                   0.0           50.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0             2.0               45.0                  0.1
#
#    agent_private_price
# 0                  0.2  r 122.15331711073179
# amt_Q1 =  0.011899193403923647
# PRICE pbar (from bondburn update) = 1.31106174167609
# Positive attestation. | alpha =  0.6445157061194485 private_alpha =  0.9
# PRICE pbar (from bondburn update) = -0.0054975606649838304
# Positive attestation. | alpha =  0.759850467402821 private_alpha =  0.9
# Positive attestation. | alpha =  0.8000136514174153 private_alpha =  0.9
# amt_neg =  1.1594995882615956e-07
# Negative attestation. | alpha =  0.85271481738728 private_alpha =  0.1
# Agent bonds. Amt to bond =  5.000002315682486e-23
# Positive attestation. | alpha =  0.8059233684538953 private_alpha =  0.9
# {'id': 0.0, 'agent_attestations_1': 0.0, 'agent_attestations_0': 9.279066404133118e-10, 'agent_reserve': 94.49374956012491, 'agent_supply_1': 3.0, 'agent_supply_0': 2.0000001897569053, 'agent_supply_free': 2.6024309645176906e-07, 'agent_private_alpha': 0.1, 'agent_private_price': 0.2}
# Agent bonds. Amt to bond =  5.0000000740165855e-15
#
#  Time  4
#  Time  4
# r 50.0
# Agent burns. Amt to burn =  1.5903458885444468e-07
# Positive attestation
# Chosen Agent:
# amt_Q1 =  0.09309569793575977
# r 108.99777778544626
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000                   0.0   5.000000e+01
# 1  1.0              0.266956                   0.0   5.000000e-23
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000             2.0          45.000000                  0.1
# 1       57.873556             2.0          39.516597                  0.9
#
#    agent_private_price
# 0                  0.2
# 1                 20.0

# %%
from src.sim import run
try:
    experiments = run.run()
except error:
    print('oops error')

# %%
import pandas as pd

import matplotlib.pyplot as plt


import seaborn as sns

# For analysis
import numpy as np
import pandas as pd

sns.set_style("whitegrid")

# %%
import sys

experiments = experiments.sort_values(by =['rules_price']).reset_index(drop=True)

cols = 1
rows = 1
cc_idx = 0
# config_labels = ['RULE 1,'RULE 2']

while cc_idx<len(experiments):
    cc = experiments.iloc[cc_idx]['rules_price']
    cc_label = experiments.iloc[cc_idx]['rules_price']
#     secondary_label = experiments.iloc[cc_idx]['string']
    sub_experiments = experiments[experiments['rules_price']==cc]
    cc_idx += len(sub_experiments)
    fig, axs = plt.subplots(ncols=cols, nrows=rows, figsize=(15*cols,7*rows))
    sub_experiments.reset_index(drop=False)
    for i, experiment in sub_experiments.iterrows():
        df = experiment['dataset'].copy()
        # filter out starting point
        df = df[df.timestep > 0] 
        # FIRST RUN ONLY
#         df = df[df.run == 1]  


#         df = df.groupby('timestep').agg({'agents': ['min', 'mean', 'max']}).reset_index()
# MAKE A FOR LOOP or FUNCTION FOR ALL AGENTS
        chosen_agents = df['chosen_agent'].tolist()
        chosen_agents_private_alphas = []
        for agent in chosen_agents:
            chosen_agents_private_alphas.append(agent['agent_private_alpha'])
        
        #df['kaka'] = chosen_agents_private_alphas
       # print(len(chosen_agents_private_alphas))
        
        df['kaka'] = chosen_agents_private_alphas
      #  df['agent_2_private_alpha'] = df.agents.apply(lambda x: np.array(x['chosen_agent']))
        
        #print("DF 1 = ", df['kaka'].to_string())
        df = df.groupby('timestep').mean().reset_index()
        #print("DF 2 = ", df['kaka'].to_string())
 
        # hack subtracting starting amount
#         df['alpha'] = df.alpha.diff()
        
#         df = df.groupby('timestep').agg({'supply': ['min', 'mean', 'max']}).reset_index()
    
#         df['agent_attest_1'] = np.array(df.agent_attest_1,dtype = float)
#         print(df['agent_attest_1'])
#         print(df['agent_attest_1'][10])
        plot_label = experiment['rules_price']
        ax = axs
        title = 'Agent Private Alpha vs Global Alpha' + '\n' + 'Scenario: ' + str(cc_label)  + ' rules_price'
        ax.set_title(title)
        ax.set_ylabel('Alpha Value')
        colors = ['b','orange', 'g', 'magenta', 'r', 'k' ]
#         df['agent_1_attestations_1'] = df['agent_1_attestations_1'][0]       
#         df.plot(x='timestep', y='agent_1_attestations_0', label='agent_1_attestations_0', ax=ax, legend=True)
#         df.plot(x='timestep', y='agent_2_attestations_0', label='agent_2_attestations_0', ax=ax, legend=True)
#         df.plot(x='timestep', y='agent_3_attestations_0', label='agent_3_attestations_0', ax=ax, legend=True)
#         df.plot(x='timestep', y='agent_4_attestations_0', label='agent_4_attestations_0', ax=ax, legend=True)
#         df.plot(x='timestep', y='agent_5_attestations_0', label='agent_5_attestations_0', ax=ax, legend=True)
#        df.plot(x='timestep', y='agent_1_private_alpha', label='A1 Private Alpha', ax=ax, legend=True, kind= 'scatter', color = 'red')
        df.plot(x='timestep', y='kaka', label='A2 Private Alpha', ax=ax, legend=True, kind= 'scatter', color='red')
        df.plot(x='timestep', y='alpha', label='Alpha', ax=ax, legend=True, color = colors[5])
        
        print("KAKA = ", chosen_agents_private_alphas)
#         ax.fill_between(df.timestep, df[('supply','min')], df[('supply','max')], supply=0.3) 

        ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

        ax.set_xlabel('Timesteps')
        ax.grid(color='0.9', linestyle='-', linewidth=1)

        plt.tight_layout()
        
fig.tight_layout(rect=[0, 0, 1, .97])
fig.patch.set_alpha(1)
display(fig)
plt.close()
# Out:
# KAKA =  [0.9, 0.9, 0.1, 0.9, 0.1, 0.9, 0.1, 0.1, 0.1, 0.1, 0.9, 0.9, 0.1, 0.1, 0.9, 0.9, 0.1, 0.1, 0.1, 0.1]
# KAKA =  [0.9, 0.9, 0.1, 0.9, 0.1, 0.9, 0.1, 0.1, 0.1, 0.1, 0.9, 0.9, 0.1, 0.1, 0.9, 0.9, 0.1, 0.1, 0.1, 0.1]

# %%
experiments = experiments.sort_values(by =['rules_price']).reset_index(drop=True)

cols = 1
rows = 1
cc_idx = 0
# config_labels = ['RULE 1,'RULE 2']


while cc_idx<len(experiments):
    cc = experiments.iloc[cc_idx]['rules_price']
    cc_label = experiments.iloc[cc_idx]['rules_price']
#     secondary_label = experiments.iloc[cc_idx]['string']
    sub_experiments = experiments[experiments['rules_price']==cc]
    cc_idx += len(sub_experiments)
    fig, axs = plt.subplots(ncols=cols, nrows=rows, figsize=(15*cols,7*rows))
    sub_experiments.reset_index(drop=False)
    for i, experiment in sub_experiments.iterrows():
        df = experiment['dataset'].copy()
        # filter out starting point
        df = df[df.timestep > 0] 
        # FIRST RUN ONLY
        df = df[df.run == 1]  

# MAKE A FOR LOOP or FUNCTION FOR ALL AGENTS
        chosen_agents = df['chosen_agent'].tolist()
        chosen_agents_private_alphas = []
        for agent in chosen_agents:
            chosen_agents_private_alphas.append(agent['agent_private_alpha'])
        
        df['private_alpha'] = chosen_agents_private_alphas
            
        df['agent_1_private_alpha'] = df.agents.apply(lambda x: np.array(x['agent_private_alpha'][0]))
        df['agent_2_private_alpha'] = df.agents.apply(lambda x: np.array(x['agent_private_alpha'][1]))
#         df['agent_3_private_alpha'] = df.agents.apply(lambda x: np.array(x['agent_private_alpha'][2]))
#         df['agent_4_private_alpha'] = df.agents.apply(lambda x: np.array(x['agent_private_alpha'][3]))
#         df['agent_5_private_alpha'] = df.agents.apply(lambda x: np.array(x['agent_private_alpha'][4]))
# #         df['agent_1_attest_0'] = df.agents.apply(lambda x: np.array(x['agent_attestations_1'][0]))
# #         print( df['agent_1_attestations_1'])
#         df['agent_1_attestations_1'] = df.agent_1_attestations_1.diff()
#         df['agent_2_attestations_1'] = df.agent_2_attestations_1.diff()
#         df['agent_3_attestations_1'] = df.agent_3_attestations_1.diff()
#         df['agent_4_attestations_1'] = df.agent_4_attestations_1.diff()
#         df['agent_5_attestations_1'] = df.agent_5_attestations_1.diff()
        
        
#         df['agent_1_attestations_0'] = df.agents.apply(lambda x: np.array(x['agent_attestations_0'][0]))
#         df['agent_2_attestations_0'] = df.agents.apply(lambda x: np.array(x['agent_attestations_0'][1]))
#         df['agent_3_attestations_0'] = df.agents.apply(lambda x: np.array(x['agent_attestations_0'][2]))
#         df['agent_4_attestations_0'] = df.agents.apply(lambda x: np.array(x['agent_attestations_0'][3]))
#         df['agent_5_attestations_0'] = df.agents.apply(lambda x: np.array(x['agent_attestations_0'][4]))
# #         df['agent_1_attest_0'] = df.agents.apply(lambda x: np.array(x['agent_attestations_1'][0]))
# #         print( df['agent_1_attestations_1'])
#         df['agent_1_attestations_0'] = - df.agent_1_attestations_0.diff()
#         df['agent_2_attestations_0'] = - df.agent_2_attestations_0.diff()
#         df['agent_3_attestations_0'] = - df.agent_3_attestations_0.diff()
#         df['agent_4_attestations_0'] = - df.agent_4_attestations_0.diff()
#         df['agent_5_attestations_0'] = - df.agent_5_attestations_0.diff()
        
        
        # hack subtracting starting amount
#         df['alpha'] = df.alpha.diff()
        
#         df = df.groupby('timestep').agg({'supply': ['min', 'mean', 'max']}).reset_index()
    
#         df['agent_attest_1'] = np.array(df.agent_attest_1,dtype = float)
#         print(df['agent_attest_1'])
#         print(df['agent_attest_1'][10])
        plot_label = experiment['rules_price']
        ax = axs
        title = 'Agent Private Alpha vs Global Alpha' + '\n' + 'Scenario: ' + str(cc_label)  + ' rules_price'
        ax.set_title(title)
        ax.set_ylabel('Alpha Value')
        colors = ['b','orange', 'g', 'magenta', 'r', 'k' ]
#         df['agent_1_attestations_1'] = df['agent_1_attestations_1'][0]
        
        plt.hlines(y= max(df['agent_1_private_alpha']), xmin=0, xmax=max(df.timestep), label = 'Agent 1 Private Alpha',  color = colors[0])
        plt.hlines(y= max(df['agent_2_private_alpha']), xmin=0, xmax=max(df.timestep), label = 'Agent 2 Private Alpha',  color = colors[1])
#         plt.hlines(y= max(df['agent_3_private_alpha']), xmin=0, xmax=max(df.timestep), label = 'Agent 3 Private Alpha',  color = colors[2])
#         plt.hlines(y= max(df['agent_4_private_alpha']), xmin=0, xmax=max(df.timestep), label = 'Agent 4 Private Alpha',  color = colors[3])
#         plt.hlines(y= max(df['agent_5_private_alpha']), xmin=0, xmax=max(df.timestep), label = 'Agent 5 Private Alpha',  color = colors[4])

#         df.plot(x='timestep', y='agent_1_attestations_1', label='agent_1_attestations_1', ax=ax, legend=True)
#         df.plot(x='timestep', y='agent_2_attestations_1', label='agent_2_attestations_1', ax=ax, legend=True)
#         df.plot(x='timestep', y='agent_3_attestations_1', label='agent_3_attestations_1', ax=ax, legend=True)
#         df.plot(x='timestep', y='agent_4_attestations_1', label='agent_4_attestations_1', ax=ax, legend=True)
#         df.plot(x='timestep', y='agent_5_attestations_1', label='agent_5_attestations_1', ax=ax, legend=True)
        
#         df.plot(x='timestep', y='agent_1_attestations_0', label='agent_1_attestations_0', ax=ax, legend=True)
#         df.plot(x='timestep', y='agent_2_attestations_0', label='agent_2_attestations_0', ax=ax, legend=True)
#         df.plot(x='timestep', y='agent_3_attestations_0', label='agent_3_attestations_0', ax=ax, legend=True)
#         df.plot(x='timestep', y='agent_4_attestations_0', label='agent_4_attestations_0', ax=ax, legend=True)
#         df.plot(x='timestep', y='agent_5_attestations_0', label='agent_5_attestations_0', ax=ax, legend=True)
        df.plot(x='timestep', y='private_alpha', label='Private Alpha', ax=ax, legend=True, kind= 'scatter')
        df.plot(x='timestep', y='alpha', label='Alpha', ax=ax, legend=True, color = colors[5])

#         ax.fill_between(df.timestep, df[('supply','min')], df[('supply','max')], supply=0.3) 

        ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

        ax.set_xlabel('Timesteps')
        ax.grid(color='0.9', linestyle='-', linewidth=1)

        plt.tight_layout()
        
fig.tight_layout(rect=[0, 0, 1, .97])
fig.patch.set_alpha(1)
display(fig)
plt.close()

# %%
experiments = experiments.sort_values(by =['rules_price']).reset_index(drop=True)

cols = 1
rows = 1
cc_idx = 0
# config_labels = ['RULE 1,'RULE 2']


while cc_idx<len(experiments):
    cc = experiments.iloc[cc_idx]['rules_price']
    cc_label = experiments.iloc[cc_idx]['rules_price']
#     secondary_label = experiments.iloc[cc_idx]['string']
    sub_experiments = experiments[experiments['rules_price']==cc]
    cc_idx += len(sub_experiments)
    fig, axs = plt.subplots(ncols=cols, nrows=rows, figsize=(15*cols,7*rows))
    sub_experiments.reset_index(drop=False)
    for i, experiment in sub_experiments.iterrows():
        df = experiment['dataset'].copy()
        # filter out starting point
        df = df[df.timestep > 0] 
        # FIRST RUN ONLY
#         df = df[df.run == 1]  

#         df = df.groupby('timestep').agg({'agents': ['min', 'mean', 'max']}).reset_index()
# MAKE A FOR LOOP or FUNCTION FOR ALL AGENTS
        chosen_agents = df['chosen_agent'].tolist()
        chosen_agents_private_alphas = []
        for agent in chosen_agents:
            chosen_agents_private_alphas.append(agent['agent_private_alpha'])
        
        df['private_alpha'] = chosen_agents_private_alphas
        
        df['agent_1_private_alpha'] = df.agents.apply(lambda x: np.array(x['agent_private_alpha'][0]))
        df['agent_2_private_alpha'] = df.agents.apply(lambda x: np.array(x['agent_private_alpha'][1]))
        
        df = df.groupby('timestep').mean().reset_index()
        
#         print(df)
#         df['agent_3_private_alpha'] = df.agents.apply(lambda x: np.array(x['agent_private_alpha'][2]))
#         df['agent_4_private_alpha'] = df.agents.apply(lambda x: np.array(x['agent_private_alpha'][3]))
#         df['agent_5_private_alpha'] = df.agents.apply(lambda x: np.array(x['agent_private_alpha'][4]))
# #         df['agent_1_attest_0'] = df.agents.apply(lambda x: np.array(x['agent_attestations_1'][0]))
# #         print( df['agent_1_attestations_1'])
#         df['agent_1_attestations_1'] = df.agent_1_attestations_1.diff()
#         df['agent_2_attestations_1'] = df.agent_2_attestations_1.diff()
#         df['agent_3_attestations_1'] = df.agent_3_attestations_1.diff()
#         df['agent_4_attestations_1'] = df.agent_4_attestations_1.diff()
#         df['agent_5_attestations_1'] = df.agent_5_attestations_1.diff()
        
     
#         df['agent_1_attestations_0'] = df.agents.apply(lambda x: np.array(x['agent_attestations_0'][0]))
#         df['agent_2_attestations_0'] = df.agents.apply(lambda x: np.array(x['agent_attestations_0'][1]))
#         df['agent_3_attestations_0'] = df.agents.apply(lambda x: np.array(x['agent_attestations_0'][2]))
#         df['agent_4_attestations_0'] = df.agents.apply(lambda x: np.array(x['agent_attestations_0'][3]))
#         df['agent_5_attestations_0'] = df.agents.apply(lambda x: np.array(x['agent_attestations_0'][4]))
# #         df['agent_1_attest_0'] = df.agents.apply(lambda x: np.array(x['agent_attestations_1'][0]))
# #         print( df['agent_1_attestations_1'])
#         df['agent_1_attestations_0'] = - df.agent_1_attestations_0.diff()
#         df['agent_2_attestations_0'] = - df.agent_2_attestations_0.diff()
#         df['agent_3_attestations_0'] = - df.agent_3_attestations_0.diff()
#         df['agent_4_attestations_0'] = - df.agent_4_attestations_0.diff()
#         df['agent_5_attestations_0'] = - df.agent_5_attestations_0.diff()
        
        
        # hack subtracting starting amount
#         df['alpha'] = df.alpha.diff()
        
#         df = df.groupby('timestep').agg({'supply': ['min', 'mean', 'max']}).reset_index()
    
#         df['agent_attest_1'] = np.array(df.agent_attest_1,dtype = float)
#         print(df['agent_attest_1'])
#         print(df['agent_attest_1'][10])
        plot_label = experiment['rules_price']
        ax = axs
        title = 'Agent Private Alpha vs Global Alpha' + '\n' + 'Scenario: ' + str(cc_label)  + ' rules_price'
        ax.set_title(title)
        ax.set_ylabel('Alpha Value')
        colors = ['b','orange', 'g', 'magenta', 'r', 'k' ]
#         df['agent_1_attestations_1'] = df['agent_1_attestations_1'][0]
        
#         plt.hlines(y= max(df['agent_1_private_alpha']), xmin=0, xmax=max(df.timestep), label = 'Agent 1 Private Alpha',  color = colors[0])
#         plt.hlines(y= max(df['agent_2_private_alpha']), xmin=0, xmax=max(df.timestep), label = 'Agent 2 Private Alpha',  color = colors[1])
#         plt.hlines(y= max(df['agent_3_private_alpha']), xmin=0, xmax=max(df.timestep), label = 'Agent 3 Private Alpha',  color = colors[2])
#         plt.hlines(y= max(df['agent_4_private_alpha']), xmin=0, xmax=max(df.timestep), label = 'Agent 4 Private Alpha',  color = colors[3])
#         plt.hlines(y= max(df['agent_5_private_alpha']), xmin=0, xmax=max(df.timestep), label = 'Agent 5 Private Alpha',  color = colors[4])

#         df.plot(x='timestep', y='agent_1_attestations_1', label='agent_1_attestations_1', ax=ax, legend=True)
#         df.plot(x='timestep', y='agent_2_attestations_1', label='agent_2_attestations_1', ax=ax, legend=True)
#         df.plot(x='timestep', y='agent_3_attestations_1', label='agent_3_attestations_1', ax=ax, legend=True)
#         df.plot(x='timestep', y='agent_4_attestations_1', label='agent_4_attestations_1', ax=ax, legend=True)
#         df.plot(x='timestep', y='agent_5_attestations_1', label='agent_5_attestations_1', ax=ax, legend=True)
        
#         df.plot(x='timestep', y='agent_1_attestations_0', label='agent_1_attestations_0', ax=ax, legend=True)
#         df.plot(x='timestep', y='agent_2_attestations_0', label='agent_2_attestations_0', ax=ax, legend=True)
#         df.plot(x='timestep', y='agent_3_attestations_0', label='agent_3_attestations_0', ax=ax, legend=True)
#         df.plot(x='timestep', y='agent_4_attestations_0', label='agent_4_attestations_0', ax=ax, legend=True)
#         df.plot(x='timestep', y='agent_5_attestations_0', label='agent_5_attestations_0', ax=ax, legend=True)
        df.plot(x='timestep', y='private_alpha', label='Private Alpha', ax=ax, legend=True, kind= 'scatter')
        df.plot(x='timestep', y='alpha', label='Alpha', ax=ax, legend=True, color = colors[5])

#         ax.fill_between(df.timestep, df[('supply','min')], df[('supply','max')], supply=0.3) 

        ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

        ax.set_xlabel('Timesteps')
        ax.grid(color='0.9', linestyle='-', linewidth=1)

        plt.tight_layout()
        
fig.tight_layout(rect=[0, 0, 1, .97])
fig.patch.set_alpha(1)
display(fig)
plt.close()

# %%
# import sys
# sys.path.append('../')
import pandas as pd

import matplotlib.pyplot as plt
# import run2

from src.sim import run

import seaborn as sns

# For analysis
import numpy as np
import pandas as pd

sns.set_style("whitegrid")
experiments = run.run()
# Out:
# -----------------PSUB---------------------
#
# Initial Conditions (config.py) :  {'reserve': 1000, 'pbar': 1, 'realized_price': 0, 'spot_price': 1, 'kappa': 0, 'supply': 2000.0, 'alpha': [0.5], 'alpha_bar': [0.5], 'supply_0': 20, 'supply_1': 30, 'supply_free': 2000.0, 'attestations': 40, 'attestations_0': 20, 'attestations_1': 20, 'invariant_V': 4000.0, 'invariant_I': 2000.0, 'agents':    id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0   0                     0                     0             50
# 1   1                     0                     0             50
# 2   2                     0                     0             50
# 3   3                     0                     0             50
# 4   4                     0                     0             50
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0               3               2                 45                 0.10
# 1               3               2                 45                 0.25
# 2               3               2                 45                 0.50
# 3               3               2                 45                 0.75
# 4               3               2                 45                 0.90
#
#    agent_private_price
# 0                  1.5
# 1                  1.5
# 2                  1.5
# 3                  1.5
# 4                  1.5  , 'chosen_agent': 0}
# Params (config.py) :  {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 1000, 'C': 2000, 'f': 0.03, 'm': 0.15, 'beta': 0.9, 'dust': 1e-08, 'period': 2000, 'rules_price': 'martin', 'E': 0.2}
# Params (config.py) :  {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 1000, 'C': 2000, 'f': 0.03, 'm': 0.15, 'beta': 0.9, 'dust': 1e-08, 'period': 2000, 'rules_price': 'martin', 'E': 0.2}
# Params (config.py) :  {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 1000, 'C': 2000, 'f': 0.03, 'm': 0.15, 'beta': 0.9, 'dust': 1e-08, 'period': 2000, 'rules_price': 'step', 'E': 0.2}
# Params (config.py) :  {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 1000, 'C': 2000, 'f': 0.03, 'm': 0.15, 'beta': 0.9, 'dust': 1e-08, 'period': 2000, 'rules_price': 'step', 'E': 0.2}
# Configurations Length: 4
# Execution Method: parallelize_simulations
# Execution Mode: parallelized
#    id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0   0                     0                     0             50
# 1   1                     0                     0             50
# 2   2                     0                     0             50
# 3   3                     0                     0             50
# 4   4                     0                     0             50
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0               3               2                 45                 0.10
# 1               3               2                 45                 0.25
# 2               3               2                 45                 0.50
# 3               3               2                 45                 0.75
# 4               3               2                 45                 0.90
#
#    agent_private_price
# 0                  1.5
# 1                  1.5
# 2                  1.5
# 3                  1.5
# 4                  1.5     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0   0                     0                     0             50
# 1   1                     0                     0             50
# 2   2                     0                     0             50
# 3   3                     0                     0             50
# 4   4                     0                     0             50
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0               3               2                 45                 0.10
# 1               3               2                 45                 0.25
# 2               3               2                 45                 0.50
# 3               3               2                 45                 0.75
# 4               3               2                 45                 0.90
#
#    agent_private_price
# 0                  1.5
# 1                  1.5
# 2                  1.5
# 3                  1.5
# 4                  1.5
#
# --------------TIMESTEP 0 --------------
#    id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0   0                     0                     0             50
# 1   1                     0                     0             50
# 2   2                     0                     0             50
# 3   3                     0                     0             50
# 4   4                     0                     0             50
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0               3               2                 45                 0.10
# 1               3               2                 45                 0.25
# 2               3               2                 45                 0.50
# 3               3               2                 45                 0.75
# 4               3               2                 45                 0.90
#
#    agent_private_price
# 0                  1.5
# 1                  1.5
# 2                  1.5
# 3                  1.5
# 4                  1.5     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0   0                     0                     0             50
# 1   1                     0                     0             50
# 2   2                     0                     0             50
# 3   3                     0                     0             50
# 4   4                     0                     0             50
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0               3               2                 45                 0.10
# 1               3               2                 45                 0.25
# 2               3               2                 45                 0.50
# 3               3               2                 45                 0.75
# 4               3               2                 45                 0.90
#
#    agent_private_price
# 0                  1.5
# 1                  1.5
# 2                  1.5
# 3                  1.5
# 4                  1.5  --------------TIMESTEP 0 --------------
# CHOSEN AGENT =     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 2   2                     0                     0             50
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 2               3               2                 45                  0.5
#
#    agent_private_price
# 2                  1.5
#
# --------------TIMESTEP 0 --------------
# --------------TIMESTEP 0 --------------
#  Time  0
# r 50
# No trade. P =  1 private_price =  1.5
# CHOSEN AGENT =     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 2   2                     0                     0             50
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 2               3               2                 45                  0.5
#
#    agent_private_price
# 2                  1.5  CHOSEN AGENT =     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0   0                     0                     0             50
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0               3               2                 45                  0.1
#
#    agent_private_price
# 0                  1.5   Time  0
#  Time  0
# CHOSEN AGENT =  No attestation. alpha =  0.5 private_alpha =  0.5 s_free =  45
# r 50
# r 50
# agent['agent_private_price'] =  1.5
# No trade. P =  1 private_price =  1.5
# No trade. P =  1 private_price =  1.5
# Negative attestation. | alpha =  0.5 private_alpha =  0.1
# No attestation. alpha =  0.5 private_alpha =  0.5 s_free =  45
# agent['agent_private_alpha'] =  0.5
# amt_neg =  17.36577485384458
# agent['agent_private_price'] =  1.5
# amt_Q0 =  0.08664120680132115
# agent['agent_private_alpha'] =  0.5
# r 50
# agent['agent_private_price'] =  1.5
# r 50
# agent['agent_private_alpha'] =  0.1
# No trade. P =  1 private_price =  1.5
# r 50
# No attestation. alpha =  0.5 private_alpha =  0.5 s_free =  45
# No trade. P =  1 private_price =  1.5
# No trade. P =  1 private_price =  1.5
# PRICE (BOND/BURN):  1.0
# Negative attestation. | alpha =  0.5 private_alpha =  0.1
# PRICE pbar (from bondburn update) = 0.0
# amt_neg =  16.490846045504675
#    id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0   0                     0                     0             50
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0               3               2                 45                  0.1
#
#    agent_private_price
# 0                  1.5  r 50.0
# amt_Q0 =  0.08228495986203566
# No attestation. alpha =  0.5 private_alpha =  0.5 s_free =  45
# PRICE (BOND/BURN):  1.0
# No trade. P =  1.0 private_price =  1.5
# PRICE (BOND/BURN):  1.0
# PRICE pbar (from bondburn update) = 0.0
# PRICE pbar (from bondburn update) = 0.0
# No attestation. alpha =  0.5 private_alpha =  0.5 s_free =  45.0
# r 50.0
# r 50.0
# PRICE (ATTEST):  1.0
# No trade. P =  1.0 private_price =  1.5
#  Time  0
# No trade. P =  1.0 private_price =  1.5
# Negative attestation. | alpha =  0.5 private_alpha =  0.1
# amt_neg =  20.981234957333324
# No attestation. alpha =  0.5 private_alpha =  0.5 s_free =  45.0
# r 50
# PRICE (ATTEST):  1.0
# No trade. P =  1 private_price =  1.5
# amt_Q0 =  0.104632475911286
# Negative attestation. | alpha =  0.5 private_alpha =  0.1
# Negative attestation 2
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0                   0.0           50.0
# 1  1.0                   0.0                   0.0           50.0
# 2  2.0                   0.0                   0.0           50.0
# 3  3.0                   0.0                   0.0           50.0
# 4  4.0                   0.0                   0.0           50.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0             2.0               45.0                 0.10
# 1             3.0             2.0               45.0                 0.25
# 2             3.0             2.0               45.0                 0.50
# 3             3.0             2.0               45.0                 0.75
# 4             3.0             2.0               45.0                 0.90
#
#    agent_private_price
# 0                  1.5
# 1                  1.5
# 2                  1.5
# 3                  1.5
# 4                  1.5  amt_neg =  17.19149883548514
#
# amt_Q0 =  0.08577356655941948
# --------------TIMESTEP 1 --------------
# agent['agent_private_price'] =  1.5
# PRICE (ATTEST):  1.25
# Negative attestation 2
# CHOSEN AGENT =  agent['agent_private_alpha'] =  0.1
# Negative attestation 1
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0                   0.0           50.0
# 1  1.0                   0.0                   0.0           50.0
# 2  2.0                   0.0                   0.0           50.0
# 3  3.0                   0.0                   0.0           50.0
# 4  4.0                   0.0                   0.0           50.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0             2.0               45.0                 0.10
# 1             3.0             2.0               45.0                 0.25
# 2             3.0             2.0               45.0                 0.50
# 3             3.0             2.0               45.0                 0.75
# 4             3.0             2.0               45.0                 0.90
#
#    agent_private_price
# 0                  1.5
# 1                  1.5
# 2                  1.5
# 3                  1.5
# 4                  1.5  r 50
# Negative attestation 2
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 3  3.0                   0.0                   0.0           50.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 3             3.0             2.0               45.0                 0.75
#
#    agent_private_price
# 3                  1.5  No trade. P =  1 private_price =  1.5
# Negative attestation. | alpha =  0.5 private_alpha =  0.1
#  Time  1
# amt_neg =  15.668300008665872
# amt_Q0 =  0.078188663366352
# r 50.0
# PRICE (BOND/BURN):  1.0
# No trade. P =  1.0 private_price =  1.5
# PRICE pbar (from bondburn update) = 0.0
# r 50.0
# Positive attestation. | alpha =  0.5 private_alpha =  0.75
# Negative attestation 2
# No trade. P =  1.0 private_price =  1.5
# amt_Q1 =  0.07112023511824717
#
# Negative attestation. | alpha =  0.5 private_alpha =  0.1
# agent['agent_private_price'] =  1.5
# amt_neg =  18.239920678897125
# agent['agent_private_alpha'] =  0.75
# amt_Q0 =  0.0909926120084803
# r 50.0
# Negative attestation 2
# No trade. P =  1.0 private_price =  1.5
# PRICE (ATTEST):  1.25
# Positive attestation. | alpha =  0.5 private_alpha =  0.75
# Negative attestation 2
# amt_Q1 =  0.055774313174414836
# Negative attestation 1
# Negative attestation 2
# PRICE (BOND/BURN):  1.0
# Negative attestation 2
# --------------TIMESTEP 1 --------------
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0              0.104632           50.0
# 1  1.0                   0.0              0.000000           50.0
# 2  2.0                   0.0              0.000000           50.0
# 3  3.0                   0.0              0.000000           50.0
# 4  4.0                   0.0              0.000000           50.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0       22.981235          24.018765                 0.10
# 1             3.0        2.000000          45.000000                 0.25
# 2             3.0        2.000000          45.000000                 0.50
# 3             3.0        2.000000          45.000000                 0.75
# 4             3.0        2.000000          45.000000                 0.90
#
#    agent_private_price
# 0                  1.5
# 1                  1.5
# 2                  1.5
# 3                  1.5
# 4                  1.5      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0              0.090993           50.0
# 1  1.0                   0.0              0.000000           50.0
# 2  2.0                   0.0              0.000000           50.0
# 3  3.0                   0.0              0.000000           50.0
# 4  4.0                   0.0              0.000000           50.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0       20.239921          26.760079                 0.10
# 1             3.0        2.000000          45.000000                 0.25
# 2             3.0        2.000000          45.000000                 0.50
# 3             3.0        2.000000          45.000000                 0.75
# 4             3.0        2.000000          45.000000                 0.90
#
#    agent_private_price
# 0                  1.5
# 1                  1.5
# 2                  1.5
# 3                  1.5
# 4                  1.5  CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 3  3.0                   0.0                   0.0           50.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 3             3.0             2.0               45.0                 0.75
#
#    agent_private_price
# 3                  1.5   Time  1
#
# r 50.0
#
# --------------TIMESTEP 1 --------------
# No trade. P =  1.0 private_price =  1.5
# Positive attestation. | alpha =  0.5 private_alpha =  0.75
# --------------TIMESTEP 1 --------------
# PRICE pbar (from bondburn update) = 0.0
# amt_Q1 =  0.0695453683742775
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 4  4.0                   0.0                   0.0           50.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 4             3.0             2.0               45.0                  0.9
#
#    agent_private_price
# 4                  1.5  r 50.0
# CHOSEN AGENT =  agent['agent_private_price'] =  1.5
#  Time  1
# No trade. P =  1.0 private_price =  1.5
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 4  4.0                   0.0                   0.0           50.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 4             3.0             2.0               45.0                  0.9
#
#    agent_private_price
# 4                  1.5  agent['agent_private_alpha'] =  0.75
#  Time  1
# r 50.0
# r 50.0
# Positive attestation. | alpha =  0.5 private_alpha =  0.75
# r 50.0
# No trade. P =  1.0 private_price =  1.5
# No trade. P =  1.25 private_price =  1.5
# Positive attestation. | alpha =  0.5 private_alpha =  0.75
# Positive attestation. | alpha =  0.6 private_alpha =  0.9
# amt_Q1 =  0.04987431742738746
# No trade. P =  1.25 private_price =  1.5
# amt_Q1 =  0.05370373798441186
# amt_Q1 =  0.08853856985183632
# PRICE (BOND/BURN):  1.0
# agent['agent_private_price'] =  1.5
# PRICE pbar (from bondburn update) = 0.0
# Positive attestation 2
# Positive attestation. | alpha =  0.6 private_alpha =  0.9
# agent['agent_private_alpha'] =  0.9
# PRICE (ATTEST):  1.25
# r 50.0
# r 50.0
# amt_Q1 =  0.06991761810961028
# Positive attestation 2
# No trade. P =  1.25 private_price =  1.5
# No trade. P =  1.0 private_price =  1.5
# Positive attestation. | alpha =  0.6 private_alpha =  0.9
# agent['agent_private_price'] =  1.5
# Positive attestation 1
# Positive attestation. | alpha =  0.5 private_alpha =  0.75
# agent['agent_private_alpha'] =  0.9
# amt_Q1 =  0.07524677373776992
# Positive attestation 2
# amt_Q1 =  0.06176987731235872
# Positive attestation 2
# PRICE (BOND/BURN):  1.2499999999999996
# Positive attestation 2
# PRICE pbar (from bondburn update) = 0.0
# PRICE (ATTEST):  1.25
# r 50.0
# No trade. P =  1.2499999999999996 private_price =  1.5
# Positive attestation 2
# Positive attestation. | alpha =  0.6 private_alpha =  0.9
# Positive attestation 1
# amt_Q1 =  0.07014718133405609
# Positive attestation 2
# Positive attestation 2
# Positive attestation 2
# PRICE (ATTEST):  0.8119841961835336
# r 50.0
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000                   0.0           50.0
# 1  1.0              0.000000                   0.0           50.0
# 2  2.0              0.000000                   0.0           50.0
# 3  3.0              0.053704                   0.0           50.0
# 4  4.0              0.000000                   0.0           50.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000             2.0          45.000000                 0.10
# 1        3.000000             2.0          45.000000                 0.25
# 2        3.000000             2.0          45.000000                 0.50
# 3       13.755168             2.0          34.244832                 0.75
# 4        3.000000             2.0          45.000000                 0.90
#
#    agent_private_price
# 0                  1.5
# 1                  1.5
# 2                  1.5
# 3                  1.5
# 4                  1.5  No trade. P =  1.25 private_price =  1.5
#
# Positive attestation. | alpha =  0.6 private_alpha =  0.9
# --------------TIMESTEP 2 --------------
# amt_Q1 =  0.08907854603118213
# Positive attestation 2
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0               0.00000                   0.0           50.0
# 1  1.0               0.00000                   0.0           50.0
# 2  2.0               0.00000                   0.0           50.0
# 3  3.0               0.06177                   0.0           50.0
# 4  4.0               0.00000                   0.0           50.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000             2.0          45.000000                 0.10
# 1        3.000000             2.0          45.000000                 0.25
# 2        3.000000             2.0          45.000000                 0.50
# 3       15.373053             2.0          32.626947                 0.75
# 4        3.000000             2.0          45.000000                 0.90
#
#    agent_private_price
# 0                  1.5
# 1                  1.5
# 2                  1.5
# 3                  1.5
# 4                  1.5  Positive attestation 1
#
# Positive attestation 2
# --------------TIMESTEP 2 --------------
# CHOSEN AGENT =  PRICE (BOND/BURN):  1.2499999999999996
# CHOSEN AGENT =  Positive attestation 2
# PRICE pbar (from bondburn update) = 0.0
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0                   0.0           50.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0             2.0               45.0                  0.1
#
#    agent_private_price
# 0                  1.5      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0                   0.0           50.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0             2.0               45.0                  0.1
#
#    agent_private_price
# 0                  1.5  r 50.0
#  Time  2
# No trade. P =  1.2499999999999996 private_price =  1.5
# Positive attestation. | alpha =  0.6 private_alpha =  0.9
# r 50.0
# amt_Q1 =  0.061516880973108236
#  Time  2
# No trade. P =  1.25 private_price =  1.5
# Positive attestation 2
# Negative attestation. | alpha =  0.6 private_alpha =  0.1
# PRICE (ATTEST):  0.8328605770272249
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000              0.104632           50.0
# 1  1.0              0.000000              0.000000           50.0
# 2  2.0              0.000000              0.000000           50.0
# 3  3.0              0.000000              0.000000           50.0
# 4  4.0              0.070147              0.000000           50.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000       22.981235          24.018765                 0.10
# 1        3.000000        2.000000          45.000000                 0.25
# 2        3.000000        2.000000          45.000000                 0.50
# 3        3.000000        2.000000          45.000000                 0.75
# 4       16.980769        2.000000          31.019231                 0.90
#
#    agent_private_price
# 0                  1.5
# 1                  1.5
# 2                  1.5
# 3                  1.5
# 4                  1.5  amt_neg =  24.894495133983
# Positive attestation 2
# r 50.0
#
# No trade. P =  1.25 private_price =  1.5
# Positive attestation 1
# --------------TIMESTEP 2 --------------
# Negative attestation. | alpha =  0.6 private_alpha =  0.1
# Positive attestation 2
# amt_neg =  19.25051355358854
# amt_Q0 =  0.12408753277515672
# Positive attestation 2
# CHOSEN AGENT =  amt_Q0 =  0.09602206185885365
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 2  2.0                   0.0                   0.0           50.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 2             3.0             2.0               45.0                  0.5
#
#    agent_private_price
# 2                  1.5  agent['agent_private_price'] =  1.5
#  Time  2
# agent['agent_private_alpha'] =  0.1
# r 50.0
# r 50.0
# No trade. P =  0.8119841961835336 private_price =  1.5
# No trade. P =  1.25 private_price =  1.5
# agent['agent_private_price'] =  1.5
# Positive attestation. | alpha =  0.4226469153154765 private_alpha =  0.5
# Negative attestation. | alpha =  0.6 private_alpha =  0.1
# amt_Q1 =  0.02261908390838256
# amt_neg =  19.93224783121683
# agent['agent_private_price'] =  1.5
# amt_Q0 =  0.09941415977698043
# agent['agent_private_alpha'] =  0.5
# PRICE (BOND/BURN):  1.2499999999999996
# r 50.0
# PRICE pbar (from bondburn update) = 0.0
# No trade. P =  0.8119841961835336 private_price =  1.5
# r 50.0
# Positive attestation. | alpha =  0.4226469153154765 private_alpha =  0.5
# amt_Q1 =  0.023706914240557556
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000              0.090993           50.0
# 1  1.0              0.000000              0.000000           50.0
# 2  2.0              0.000000              0.000000           50.0
# 3  3.0              0.000000              0.000000           50.0
# 4  4.0              0.061517              0.000000           50.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000       20.239921          26.760079                 0.10
# 1        3.000000        2.000000          45.000000                 0.25
# 2        3.000000        2.000000          45.000000                 0.50
# 3        3.000000        2.000000          45.000000                 0.75
# 4       15.266405        2.000000          32.733595                 0.90
#
#    agent_private_price
# 0                  1.5
# 1                  1.5
# 2                  1.5
# 3                  1.5
# 4                  1.5  No trade. P =  1.2499999999999996 private_price =  1.5
# Negative attestation. | alpha =  0.6 private_alpha =  0.1
# agent['agent_private_alpha'] =  0.1
#
# PRICE (BOND/BURN):  0.8119841961835337
# r 50.0
# amt_neg =  19.96248112837234
# --------------TIMESTEP 2 --------------
# No trade. P =  1.25 private_price =  1.5
# amt_Q0 =  0.0995645780119947
# PRICE pbar (from bondburn update) = -0.0
# Negative attestation 2
# r 50.0
# PRICE (ATTEST):  1.307496283601213
# No trade. P =  0.8119841961835337 private_price =  1.5
# Negative attestation 2
# Positive attestation. | alpha =  0.4226469153154765 private_alpha =  0.5
# CHOSEN AGENT =  Negative attestation. | alpha =  0.6 private_alpha =  0.1
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 2  2.0                   0.0                   0.0           50.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 2             3.0             2.0               45.0                  0.5
#
#    agent_private_price
# 2                  1.5  Negative attestation 1
#  Time  2
# amt_neg =  26.30835162892651
# amt_Q1 =  0.01787329789730434
# r 50.0
# Negative attestation 2
# amt_Q0 =  0.1311119992360421
# No trade. P =  0.8328605770272249 private_price =  1.5
# PRICE (BOND/BURN):  1.2499999999999996
# Positive attestation 2
# Positive attestation. | alpha =  0.4396253644719924 private_alpha =  0.5
# Negative attestation 2
# PRICE pbar (from bondburn update) = 0.0
# amt_Q1 =  0.025079963340896693
# r 50.0
# agent['agent_private_price'] =  1.5
# No trade. P =  1.2499999999999996 private_price =  1.5
# agent['agent_private_alpha'] =  0.5
# Negative attestation. | alpha =  0.6 private_alpha =  0.1
# r 50.0
# amt_neg =  26.16834606391734
# No trade. P =  0.8328605770272249 private_price =  1.5
# amt_Q0 =  0.13041651861141812
# Positive attestation. | alpha =  0.4396253644719924 private_alpha =  0.5
# Negative attestation 2
# amt_Q1 =  0.016625099265115798
# PRICE (ATTEST):  1.2814834190701543
# PRICE (BOND/BURN):  0.8328605770272249
# Negative attestation 2
# PRICE pbar (from bondburn update) = 0.0
# Negative attestation 1
# r 50.0
# Negative attestation 2
# No trade. P =  0.8328605770272249 private_price =  1.5
# Negative attestation 2
# Positive attestation. | alpha =  0.4396253644719924 private_alpha =  0.5
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0               0.00000              0.099565           50.0
# 1  1.0               0.00000              0.000000           50.0
# 2  2.0               0.00000              0.000000           50.0
# 3  3.0               0.06177              0.000000           50.0
# 4  4.0               0.00000              0.000000           50.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000       21.962481          25.037519                 0.10
# 1        3.000000        2.000000          45.000000                 0.25
# 2        3.000000        2.000000          45.000000                 0.50
# 3       15.373053        2.000000          32.626947                 0.75
# 4        3.000000        2.000000          45.000000                 0.90
#
#    agent_private_price
# 0                  1.5
# 1                  1.5
# 2                  1.5
# 3                  1.5
# 4                  1.5  PRICE (ATTEST):  1.1390851573401328
# Positive attestation 2
#
# Positive attestation 1
# amt_Q1 =  0.023814066817263477
# Positive attestation 2
# --------------TIMESTEP 3 --------------
# Positive attestation 2
# Positive attestation 2
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000              0.130417           50.0
# 1  1.0              0.000000              0.000000           50.0
# 2  2.0              0.000000              0.000000           50.0
# 3  3.0              0.053704              0.000000           50.0
# 4  4.0              0.000000              0.000000           50.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000       28.168346          18.831654                 0.10
# 1        3.000000        2.000000          45.000000                 0.25
# 2        3.000000        2.000000          45.000000                 0.50
# 3       13.755168        2.000000          34.244832                 0.75
# 4        3.000000        2.000000          45.000000                 0.90
#
#    agent_private_price
# 0                  1.5
# 1                  1.5
# 2                  1.5
# 3                  1.5
# 4                  1.5  PRICE (ATTEST):  1.1331214617388503
#
# Positive attestation 2
# --------------TIMESTEP 3 --------------
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 2  2.0                   0.0                   0.0           50.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 2             3.0             2.0               45.0                  0.5
#
#    agent_private_price
# 2                  1.5  Positive attestation 1
#  Time  3
# Positive attestation 2
# r 50.0
# Positive attestation 2
# No trade. P =  1.2814834190701543 private_price =  1.5
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000              0.104632           50.0
# 1  1.0              0.000000              0.000000           50.0
# 2  2.0              0.017873              0.000000           50.0
# 3  3.0              0.000000              0.000000           50.0
# 4  4.0              0.070147              0.000000           50.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000       22.981235          24.018765                 0.10
# 1        3.000000        2.000000          45.000000                 0.25
# 2        6.557636        2.000000          41.442364                 0.50
# 3        3.000000        2.000000          45.000000                 0.75
# 4       16.980769        2.000000          31.019231                 0.90
#
#    agent_private_price
# 0                  1.5
# 1                  1.5
# 2                  1.5
# 3                  1.5
# 4                  1.5  Negative attestation. | alpha =  0.6708098974865548 private_alpha =  0.5
#
# CHOSEN AGENT =  --------------TIMESTEP 3 --------------
# amt_neg =  7.773382998390769
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 2  2.0                   0.0                   0.0           50.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 2             3.0             2.0               45.0                  0.5
#
#    agent_private_price
# 2                  1.5  amt_Q0 =  0.039082420878887324
# agent['agent_private_price'] =  1.5
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000              0.090993           50.0
# 1  1.0              0.000000              0.000000           50.0
# 2  2.0              0.023814              0.000000           50.0
# 3  3.0              0.000000              0.000000           50.0
# 4  4.0              0.061517              0.000000           50.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000       20.239921          26.760079                 0.10
# 1        3.000000        2.000000          45.000000                 0.25
# 2        7.744052        2.000000          40.255948                 0.50
# 3        3.000000        2.000000          45.000000                 0.75
# 4       15.266405        2.000000          32.733595                 0.90
#
#    agent_private_price
# 0                  1.5
# 1                  1.5
# 2                  1.5
# 3                  1.5
# 4                  1.5  agent['agent_private_alpha'] =  0.5
#
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 3  3.0                   0.0                   0.0           50.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 3             3.0             2.0               45.0                 0.75
#
#    agent_private_price
# 3                  1.5  --------------TIMESTEP 3 --------------
#  Time  3
#  Time  3
# r 50.0
# r 50.0
# r 50.0
# No trade. P =  1.307496283601213 private_price =  1.5
# No trade. P =  1.1390851573401328 private_price =  1.5
# Negative attestation. | alpha =  0.6793487087510912 private_alpha =  0.5
# Positive attestation. | alpha =  0.5176522099723128 private_alpha =  0.75
# amt_neg =  7.935622494151286
# amt_Q1 =  0.05999413278830514
# amt_Q0 =  0.039836162723389135
# agent['agent_private_price'] =  1.5
# agent['agent_private_price'] =  1.5
# CHOSEN AGENT =  No trade. P =  1.2814834190701543 private_price =  1.5
# agent['agent_private_alpha'] =  0.75
# agent['agent_private_alpha'] =  0.5
# r 50.0
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 3  3.0                   0.0                   0.0           50.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 3             3.0             2.0               45.0                 0.75
#
#    agent_private_price
# 3                  1.5  r 50.0
#  Time  3
# No trade. P =  1.1390851573401328 private_price =  1.5
# No trade. P =  1.307496283601213 private_price =  1.5
# Positive attestation. | alpha =  0.5176522099723128 private_alpha =  0.75
# Negative attestation. | alpha =  0.6793487087510912 private_alpha =  0.5
# amt_Q1 =  0.06862763530702226
# amt_neg =  10.597494515036598
# PRICE (BOND/BURN):  1.1390851573401333
# amt_Q0 =  0.05318090137885419
# r 50.0
# Negative attestation. | alpha =  0.6708098974865548 private_alpha =  0.5
# PRICE pbar (from bondburn update) = -0.0
# PRICE (BOND/BURN):  1.307496283601213
# No trade. P =  1.1331214617388503 private_price =  1.5
# Positive attestation. | alpha =  0.5250072514984395 private_alpha =  0.75
# r 50.0
# PRICE pbar (from bondburn update) = -0.0
# amt_Q1 =  0.0634678137291779
# No trade. P =  1.1390851573401333 private_price =  1.5
# r 50.0
# amt_neg =  9.362894004465403
# agent['agent_private_price'] =  1.5
# Positive attestation. | alpha =  0.5176522099723128 private_alpha =  0.75
# agent['agent_private_alpha'] =  0.75
# No trade. P =  1.307496283601213 private_price =  1.5
# amt_Q1 =  0.07502810217632201
# Negative attestation. | alpha =  0.6793487087510912 private_alpha =  0.5
# Positive attestation 2
# amt_neg =  10.00215492933603
# PRICE (ATTEST):  1.0586995409091895
# r 50.0
# amt_Q0 =  0.050197058157395294
# amt_Q0 =  0.047064720599867355
# Positive attestation 2
# No trade. P =  1.1331214617388503 private_price =  1.5
# Negative attestation 2
# Positive attestation. | alpha =  0.5250072514984395 private_alpha =  0.75
# Positive attestation 1
# PRICE (ATTEST):  0.8871152156373745
# Positive attestation 2
# Negative attestation 2
# Positive attestation 2
# amt_Q1 =  0.05668999315539119
# PRICE (BOND/BURN):  1.2814834190701538
# Negative attestation 1
# PRICE (BOND/BURN):  1.1331214617388499
# PRICE pbar (from bondburn update) = 0.0
# PRICE pbar (from bondburn update) = 0.0
# r 50.0
# No trade. P =  1.1331214617388499 private_price =  1.5
# Negative attestation 2
# r 49.999999999999886
# Positive attestation. | alpha =  0.5250072514984395 private_alpha =  0.75
# No trade. P =  1.2814834190701538 private_price =  1.5
# amt_Q1 =  0.07345907144758461
# Positive attestation 2
# Negative attestation 2
# Negative attestation. | alpha =  0.6708098974865548 private_alpha =  0.5
# PRICE (ATTEST):  1.0822190102032598
# Positive attestation 2
# amt_neg =  9.386831233626399
# Positive attestation 1
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000              0.104632           50.0
# 1  1.0              0.000000              0.000000           50.0
# 2  2.0              0.017873              0.000000           50.0
# 3  3.0              0.075028              0.000000           50.0
# 4  4.0              0.070147              0.000000           50.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000       22.981235          24.018765                 0.10
# 1        3.000000        2.000000          45.000000                 0.25
# 2        6.557636        2.000000          41.442364                 0.50
# 3       17.955379        2.000000          30.044621                 0.75
# 4       16.980769        2.000000          31.019231                 0.90
#
#    agent_private_price
# 0                  1.5
# 1                  1.5
# 2                  1.5
# 3                  1.5
# 4                  1.5  amt_Q0 =  0.047184905847466124
# Positive attestation 2
# Positive attestation 2
# Negative attestation 2
#
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0               0.00000              0.099565           50.0
# 1  1.0               0.00000              0.000000           50.0
# 2  2.0               0.00000              0.050197           50.0
# 3  3.0               0.06177              0.000000           50.0
# 4  4.0               0.00000              0.000000           50.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000       21.962481          25.037519                 0.10
# 1        3.000000        2.000000          45.000000                 0.25
# 2        3.000000       12.002155          34.997845                 0.50
# 3       15.373053        2.000000          32.626947                 0.75
# 4        3.000000        2.000000          45.000000                 0.90
#
#    agent_private_price
# 0                  1.5
# 1                  1.5
# 2                  1.5
# 3                  1.5
# 4                  1.5  --------------TIMESTEP 4 --------------
# PRICE (ATTEST):  0.8339725644387085
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000              0.090993           50.0
# 1  1.0              0.000000              0.000000           50.0
# 2  2.0              0.023814              0.000000           50.0
# 3  3.0              0.073459              0.000000           50.0
# 4  4.0              0.061517              0.000000           50.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000       20.239921          26.760079                 0.10
# 1        3.000000        2.000000          45.000000                 0.25
# 2        7.744052        2.000000          40.255948                 0.50
# 3       17.652012        2.000000          30.347988                 0.75
# 4       15.266405        2.000000          32.733595                 0.90
#
#    agent_private_price
# 0                  1.5
# 1                  1.5
# 2                  1.5
# 3                  1.5
# 4                  1.5  Negative attestation 2
# CHOSEN AGENT =
#
# Negative attestation 1
# --------------TIMESTEP 4 --------------
# Negative attestation 2
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 2  2.0              0.017873                   0.0           50.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 2        6.557636             2.0          41.442364                  0.5
#
#    agent_private_price
# 2                  1.5  --------------TIMESTEP 4 --------------
# CHOSEN AGENT =  Negative attestation 2
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 2  2.0              0.023814                   0.0           50.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 2        7.744052             2.0          40.255948                  0.5
#
#    agent_private_price
# 2                  1.5      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000              0.130417           50.0
# 1  1.0              0.000000              0.000000           50.0
# 2  2.0              0.000000              0.047185           50.0
# 3  3.0              0.053704              0.000000           50.0
# 4  4.0              0.000000              0.000000           50.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000       28.168346          18.831654                 0.10
# 1        3.000000        2.000000          45.000000                 0.25
# 2        3.000000       11.386831          35.613169                 0.50
# 3       13.755168        2.000000          34.244832                 0.75
# 4        3.000000        2.000000          45.000000                 0.90
#
#    agent_private_price
# 0                  1.5
# 1                  1.5
# 2                  1.5
# 3                  1.5
# 4                  1.5   Time  4
#
# r 50.0
# --------------TIMESTEP 4 --------------
# No trade. P =  1.0822190102032598 private_price =  1.5
# CHOSEN AGENT =  Negative attestation. | alpha =  0.5514398673393289 private_alpha =  0.5
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 4  4.0                   0.0                   0.0           50.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 4             3.0             2.0               45.0                  0.9
#
#    agent_private_price
# 4                  1.5  amt_neg =  3.7698185417122727
#  Time  4
# amt_Q0 =  0.01892593489864542
# CHOSEN AGENT =   Time  4
# r 50.0
# agent['agent_private_price'] =  1.5
# No trade. P =  0.8339725644387085 private_price =  1.5
# agent['agent_private_alpha'] =  0.5
# Positive attestation. | alpha =  0.46886240699893394 private_alpha =  0.9
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 4  4.0                   0.0                   0.0           50.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 4             3.0             2.0               45.0                  0.9
#
#    agent_private_price
# 4                  1.5  r 50.0
# amt_Q1 =  0.10419384121555504
# No trade. P =  1.0822190102032598 private_price =  1.5
# agent['agent_private_price'] =  1.5
# Negative attestation. | alpha =  0.5514398673393289 private_alpha =  0.5
# agent['agent_private_alpha'] =  0.9
# amt_neg =  2.5638976627391843
# r 50.0
# amt_Q0 =  0.01287368771921489
# No trade. P =  0.8339725644387085 private_price =  1.5
#  Time  4
# r 50.0
# r 50.0
# PRICE (BOND/BURN):  1.0822190102032596
# No trade. P =  1.0586995409091895 private_price =  1.5
# No trade. P =  0.8871152156373745 private_price =  1.5
# PRICE pbar (from bondburn update) = 0.0
# Negative attestation. | alpha =  0.5370379418777151 private_alpha =  0.5
# Positive attestation. | alpha =  0.5146387094395855 private_alpha =  0.9
# amt_neg =  2.8333349528539418
# amt_Q1 =  0.08752466884453035
# Positive attestation. | alpha =  0.46886240699893394 private_alpha =  0.9
# agent['agent_private_price'] =  1.5
# amt_Q0 =  0.01423574943065024
# agent['agent_private_alpha'] =  0.9
# r 50.0
# agent['agent_private_price'] =  1.5
# r 50.0
# No trade. P =  1.0822190102032596 private_price =  1.5
# agent['agent_private_alpha'] =  0.5
# No trade. P =  0.8871152156373745 private_price =  1.5
# r 50.0
# Negative attestation. | alpha =  0.5514398673393289 private_alpha =  0.5
# Positive attestation. | alpha =  0.5146387094395855 private_alpha =  0.9
# No trade. P =  1.0586995409091895 private_price =  1.5
# amt_Q1 =  0.07286146225706659
# Negative attestation. | alpha =  0.5370379418777151 private_alpha =  0.5
# PRICE (BOND/BURN):  0.8871152156373747
# amt_neg =  2.3623565320338913
# amt_neg =  3.0784419717342213
# PRICE pbar (from bondburn update) = -0.0
# amt_Q0 =  0.011870073329690421
# amt_Q0 =  0.015456293351813357
# r 49.999999999999886
# PRICE (BOND/BURN):  1.0586995409091893
# No trade. P =  0.8871152156373747 private_price =  1.5
# PRICE pbar (from bondburn update) = 0.0
# Positive attestation. | alpha =  0.5146387094395855 private_alpha =  0.9
# amt_Q1 =  0.09519352005937415
# r 50.0
# amt_Q1 =  0.07642461240020947
# No trade. P =  1.0586995409091893 private_price =  1.5
# Negative attestation 2
# Positive attestation 2
# Negative attestation. | alpha =  0.5370379418777151 private_alpha =  0.5
# PRICE (ATTEST):  0.912861210553229
# amt_neg =  2.7313422852504528
# Positive attestation 2
# amt_Q0 =  0.013723474363093296
# Positive attestation 1
# PRICE (ATTEST):  1.2107428765820185
# Negative attestation 2
# Positive attestation 2
# PRICE (ATTEST):  1.1972614788144074
# Negative attestation 2
# Positive attestation 2
# Negative attestation 2
# Negative attestation 1
# PRICE (BOND/BURN):  0.8339725644387084
# Negative attestation 1
# Negative attestation 2
# Negative attestation 2
# PRICE pbar (from bondburn update) = 0.0
# Negative attestation 2
# r 49.999999999999886
# Negative attestation 2
# No trade. P =  0.8339725644387084 private_price =  1.5
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000              0.090993           50.0
# 1  1.0              0.000000              0.000000           50.0
# 2  2.0              0.023814              0.015456           50.0
# 3  3.0              0.073459              0.000000           50.0
# 4  4.0              0.061517              0.000000           50.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000       20.239921          26.760079                 0.10
# 1        3.000000        2.000000          45.000000                 0.25
# 2        7.744052        5.078442          37.177506                 0.50
# 3       17.652012        2.000000          30.347988                 0.75
# 4       15.266405        2.000000          32.733595                 0.90
#
#    agent_private_price
# 0                  1.5
# 1                  1.5
# 2                  1.5
# 3                  1.5
# 4                  1.5  Positive attestation. | alpha =  0.46886240699893394 private_alpha =  0.9
#
# amt_Q1 =  0.09947727912186546
# --------------TIMESTEP 5 --------------
# Positive attestation 2
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0              0.090993           50.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0       20.239921          26.760079                  0.1
#
#    agent_private_price
# 0                  1.5  PRICE (ATTEST):  0.8877286282166474
#  Time  5
# Positive attestation 2
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000              0.099565           50.0
# 1  1.0              0.000000              0.000000           50.0
# 2  2.0              0.000000              0.050197           50.0
# ...
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 3  3.0              0.310908                   0.0           50.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 3       64.208953             2.0           3.791047                 0.75
#
#    agent_private_price
# 3                  1.5  PRICE (ATTEST):  0.9893422992473832
#  Time  77
# r 50.0
# Positive attestation 2
# No trade. P =  1.0034677048555498 private_price =  1.5
# Positive attestation 1
# Positive attestation. | alpha =  0.504533755756214 private_alpha =  0.75
# r 50.00000000000034
# Positive attestation 2
# amt_Q1 =  0.006220143081230055
# Positive attestation 2
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000              0.226356           50.0
# 1  1.0              0.000000              0.278605           50.0
# 2  2.0              0.049378              0.096425           50.0
# 3  3.0              0.275164              0.000000           50.0
# 4  4.0              0.227921              0.000000           50.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000       46.962223           0.037777                 0.10
# 1        3.000000       56.762288           0.237712                 0.25
# 2       12.702621       21.031463          26.265916                 0.50
# 3       57.189164        2.000000           0.810836                 0.75
# 4       47.987740        2.000000           0.012260                 0.90
#
#    agent_private_price
# 0                  1.5
# 1                  1.5
# 2                  1.5
# 3                  1.5
# 4                  1.5  No trade. P =  0.9899056539975181 private_price =  1.5
#
# Positive attestation. | alpha =  0.48937092856383924 private_alpha =  0.75
# --------------TIMESTEP 78 --------------
# amt_Q1 =  0.0043124836315643665
# agent['agent_private_price'] =  1.5
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 4  4.0              0.227921                   0.0           50.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 4        47.98774             2.0            0.01226                  0.9
#
#    agent_private_price
# 4                  1.5  agent['agent_private_price'] =  1.5
# agent['agent_private_alpha'] =  0.75
#  Time  78
# r 50.00000000000034
# r 49.999999999999886
# No trade. P =  0.9899056539975181 private_price =  1.5
# Positive attestation. | alpha =  0.48937092856383924 private_alpha =  0.75
# No trade. P =  1.000232000606132 private_price =  1.5
# amt_Q1 =  0.0030474814873197808
# PRICE (BOND/BURN):  0.9899056539975183
# agent['agent_private_alpha'] =  0.75
# Positive attestation. | alpha =  0.5002082587567802 private_alpha =  0.9
# PRICE pbar (from bondburn update) = -0.0
# r 50.00000000000034
# No trade. P =  0.9899056539975183 private_price =  1.5
# amt_Q1 =  2.543542787845925e-05
# r 50.0
# Positive attestation. | alpha =  0.48937092856383924 private_alpha =  0.75
# agent['agent_private_price'] =  1.5
# amt_Q1 =  0.0031064300333685517
# agent['agent_private_alpha'] =  0.9
# Positive attestation 2
# No trade. P =  1.0034677048555498 private_price =  1.5
# PRICE (ATTEST):  0.9928032689316839
# r 49.999999999999886
# Positive attestation 2
# No trade. P =  1.000232000606132 private_price =  1.5
# Positive attestation 1
# Positive attestation. | alpha =  0.504533755756214 private_alpha =  0.75
# Positive attestation 2
# Positive attestation. | alpha =  0.5002082587567802 private_alpha =  0.9
# Positive attestation 2
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000              0.226182           50.0
# 1  1.0              0.000000              0.274705           50.0
# 2  2.0              0.057467              0.088916           50.0
# 3  3.0              0.226401              0.000000           50.0
# 4  4.0              0.227667              0.000000           50.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000       46.984428           0.015572                 0.10
# 1        3.000000       56.021305           0.978695                 0.25
# 2       14.295321       19.573313          36.131366                 0.50
# 3       47.588463        2.000000           0.411537                 0.75
# 4       47.993554        2.000000           0.006446                 0.90
#
#    agent_private_price
# 0                  1.5
# 1                  1.5
# 2                  1.5
# 3                  1.5
# 4                  1.5  amt_Q1 =  0.00565055565805803
# PRICE (BOND/BURN):  1.0034677048555496
#
# PRICE pbar (from bondburn update) = 0.0
# --------------TIMESTEP 78 --------------
# r 50.0
# amt_Q1 =  2.3606877612045448e-05
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 4  4.0              0.227667                   0.0           50.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 4       47.993554             2.0           0.006446                  0.9
#
#    agent_private_price
# 4                  1.5  No trade. P =  1.0034677048555496 private_price =  1.5
#  Time  78
# Positive attestation. | alpha =  0.504533755756214 private_alpha =  0.75
# r 50.00000000000023
# amt_Q1 =  0.005278583175549663
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000              0.225824           50.0
# 1  1.0              0.000000              0.268923           50.0
# 2  2.0              0.060994              0.135336           50.0
# 3  3.0              0.268726              0.000000           50.0
# 4  4.0              0.227207              0.000000           50.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000       46.984027           0.015973                 0.10
# 1        3.000000       54.598791           2.401209                 0.25
# 2       14.927121       28.782169          16.290710                 0.50
# 3       55.994367        2.000000           2.005633                 0.75
# 4       47.996086        2.000000           0.003914                 0.90
#
#    agent_private_price
# 0                  1.5
# 1                  1.5
# 2                  1.5
# 3                  1.5
# 4                  1.5  PRICE (BOND/BURN):  1.0002320006061323
# No trade. P =  0.9893422992473832 private_price =  1.5
# Positive attestation 2
# PRICE pbar (from bondburn update) = 0.0
# Positive attestation. | alpha =  0.4893302123892673 private_alpha =  0.9
# PRICE (ATTEST):  1.008772153684699
# amt_Q1 =  1.429154825221009e-05
# Positive attestation 2
# agent['agent_private_price'] =  1.5
# Positive attestation 1
# agent['agent_private_alpha'] =  0.9
# Positive attestation 2
# r 50.00000000000023
# r 49.999999999999886
#
# Positive attestation 2
# No trade. P =  1.0002320006061323 private_price =  1.5
# --------------TIMESTEP 78 --------------
# Positive attestation. | alpha =  0.5002082587567802 private_alpha =  0.9
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0              0.225824           50.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0       46.984027           0.015973                  0.1
#
#    agent_private_price
# 0                  1.5  amt_Q1 =  2.8710307543011136e-05
#  Time  78
# Positive attestation 2
# r 49.999999999999886
# PRICE (ATTEST):  1.0002367631788953
# No trade. P =  0.9928032689316839 private_price =  1.5
# Positive attestation 2
# Positive attestation 1
# Negative attestation. | alpha =  0.4910995390928575 private_alpha =  0.1
# Positive attestation 2
# No trade. P =  0.9893422992473832 private_price =  1.5
# amt_neg =  0.006222207738439737
# Positive attestation 2
# amt_Q0 =  3.2091141217909045e-05
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000              0.225412           50.0
# 1  1.0              0.000000              0.278358           50.0
# 2  2.0              0.032383              0.098184           50.0
# 3  3.0              0.316186              0.000000           50.0
# 4  4.0              0.227312              0.000000           50.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000       46.874065           0.125935                 0.10
# 1        3.000000       56.639218           0.360782                 0.25
# 2        9.408918       21.356818          19.234265                 0.50
# 3       65.233955        2.000000           2.766045                 0.75
# 4       47.987137        2.000000           0.012863                 0.90
#
#    agent_private_price
# 0                  1.5
# 1                  1.5
# 2                  1.5
# 3                  1.5
# 4                  1.5  Positive attestation. | alpha =  0.4893302123892673 private_alpha =  0.9
#
# amt_Q1 =  1.6322002139381375e-05
# --------------TIMESTEP 78 --------------
# PRICE (BOND/BURN):  0.9893422992473829
# CHOSEN AGENT =      id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0                   0.0              0.225412           50.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0             3.0       46.874065           0.125935                  0.1
#
#    agent_private_price
# 0                  1.5  PRICE pbar (from bondburn update) = 0.0
# r 50.00000000000023
#  Time  78
# agent['agent_private_price'] =  1.5
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000              0.226356           50.0
# 1  1.0              0.000000              0.278605           50.0
# 2  2.0              0.049378              0.096425           50.0
# 3  3.0              0.275164              0.000000           50.0
# 4  4.0              0.227950              0.000000           50.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000       46.962223           0.037777                 0.10
# 1        3.000000       56.762288           0.237712                 0.25
# 2       12.702621       21.031463          26.265916                 0.50
# 3       57.189164        2.000000           0.810836                 0.75
# 4       47.993315        2.000000           0.006685                 0.90
#
#    agent_private_price
# 0                  1.5
# 1                  1.5
# 2                  1.5
# 3                  1.5
# 4                  1.5  agent['agent_private_alpha'] =  0.1
# No trade. P =  0.9893422992473829 private_price =  1.5
# r 50.000000000000114
# r 49.999999999999886
# Positive attestation. | alpha =  0.4893302123892673 private_alpha =  0.9
# No trade. P =  1.008772153684699 private_price =  1.5
#
# No trade. P =  0.9928032689316839 private_price =  1.5
# amt_Q1 =  1.5271945740115192e-05
# Negative attestation. | alpha =  0.5066345264371853 private_alpha =  0.1
# --------------TIMESTEP 79 --------------
# Positive attestation 2
# Negative attestation. | alpha =  0.4910995390928575 private_alpha =  0.1
# amt_neg =  0.05816778803161134
# amt_neg =  0.006425611559916274
# PRICE (ATTEST):  0.9893512829747262
# amt_Q0 =  0.00029959034719638603
# amt_Q0 =  3.314019901263186e-05
# Positive attestation 2
# agent['agent_private_price'] =  1.5
# Positive attestation 1
# agent['agent_private_alpha'] =  0.1
# Positive attestation 2
# r 50.000000000000114
# PRICE (BOND/BURN):  0.9928032689316837
# Positive attestation 2
# No trade. P =  1.008772153684699 private_price =  1.5
# CHOSEN AGENT =  PRICE pbar (from bondburn update) = 0.0
# Negative attestation. | alpha =  0.5066345264371853 private_alpha =  0.1
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 3  3.0              0.275164                   0.0           50.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 3       57.189164             2.0           0.810836                 0.75
#
#    agent_private_price
# 3                  1.5  r 49.999999999999886
#  Time  79
# No trade. P =  0.9928032689316837 private_price =  1.5
# r 49.99999999999977
# Negative attestation. | alpha =  0.4910995390928575 private_alpha =  0.1
# No trade. P =  1.0002367631788953 private_price =  1.5
# amt_neg =  0.007256042590492434
# amt_Q0 =  3.742315704744257e-05
# Positive attestation. | alpha =  0.5002225075942351 private_alpha =  0.75
# Negative attestation 2
# amt_neg =  0.05381009988678469
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000              0.226182           50.0
# 1  1.0              0.000000              0.274705           50.0
# 2  2.0              0.057467              0.088916           50.0
# 3  3.0              0.226401              0.000000           50.0
# 4  4.0              0.227682              0.000000           50.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000       46.984428           0.015572                 0.10
# 1        3.000000       56.021305           0.978695                 0.25
# 2       14.295321       19.573313          36.131366                 0.50
# 3       47.588463        2.000000           0.411537                 0.75
# 4       47.996520        2.000000           0.003480                 0.90
#
#    agent_private_price
# 0                  1.5
# 1                  1.5
# 2                  1.5
# 3                  1.5
# 4                  1.5  amt_Q1 =  0.0009028532417237403
# amt_Q0 =  0.00027714643850727333
#
# PRICE (ATTEST):  0.9932415455606535
# PRICE (BOND/BURN):  1.0087721536846985
# --------------TIMESTEP 79 --------------
# agent['agent_private_price'] =  1.5
# Negative attestation 2
# PRICE pbar (from bondburn update) = 0.0
# Negative attestation 1
# agent['agent_private_alpha'] =  0.75
# Negative attestation 2
# r 49.99999999999977
# Negative attestation 2
# No trade. P =  1.0002367631788953 private_price =  1.5
# CHOSEN AGENT =  r 50.00000000000023
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 3  3.0              0.226401                   0.0           50.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 3       47.588463             2.0           0.411537                 0.75
#
#    agent_private_price
# 3                  1.5  No trade. P =  1.0087721536846985 private_price =  1.5
#  Time  79
# Negative attestation. | alpha =  0.5066345264371853 private_alpha =  0.1
# amt_neg =  0.051396741147220475
# r 50.0
# amt_Q0 =  0.0002647166254456402
# No trade. P =  0.9893512829747262 private_price =  1.5
# Positive attestation. | alpha =  0.5002225075942351 private_alpha =  0.75
# Negative attestation 2
# Positive attestation. | alpha =  0.48934086107685903 private_alpha =  0.75
# PRICE (ATTEST):  1.0102514070255455
# amt_Q1 =  0.000540497349248014
# Negative attestation 2
# agent['agent_private_price'] =  1.5
# config_ids =  [{'M': {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 1000, 'C': 2000, 'f': 0.03, 'm': 0.15, 'beta': 0.9, 'dust': 1e-08, 'period': 2000, 'rules_price': 'martin', 'E': 0.2}, 'simulation_id': 0, 'run_id': 0}, {'M': {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 1000, 'C': 2000, 'f': 0.03, 'm': 0.15, 'beta': 0.9, 'dust': 1e-08, 'period': 2000, 'rules_price': 'martin', 'E': 0.2}, 'simulation_id': 0, 'run_id': 1}, {'M': {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 1000, 'C': 2000, 'f': 0.03, 'm': 0.15, 'beta': 0.9, 'dust': 1e-08, 'period': 2000, 'rules_price': 'step', 'E': 0.2}, 'simulation_id': 1, 'run_id': 0}, {'M': {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 1000, 'C': 2000, 'f': 0.03, 'm': 0.15, 'beta': 0.9, 'dust': 1e-08, 'period': 2000, 'rules_price': 'step', 'E': 0.2}, 'simulation_id': 1, 'run_id': 1}]
# /Users/shrutiappiah/Documents/Github/ICF_Internal/src/sim/run.py:78: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sub_df = df[df.simulation == config_id['simulation_id']][df.run == config_id['run_id'] + 1]

# %%
experiments = run.run()
# Out:
# config_ids =  [{'M': {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 1000, 'C': 700, 'f': 0.03, 'm': 0.15, 'beta': 0.9, 'dust': 1e-08, 'period': 2000, 'rules_price': 'martin'}, 'simulation_id': 0, 'run_id': 0}, {'M': {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 1000, 'C': 700, 'f': 0.03, 'm': 0.15, 'beta': 0.9, 'dust': 1e-08, 'period': 2000, 'rules_price': 'martin'}, 'simulation_id': 0, 'run_id': 1}, {'M': {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 1000, 'C': 700, 'f': 0.03, 'm': 0.15, 'beta': 0.9, 'dust': 1e-08, 'period': 2000, 'rules_price': 'step'}, 'simulation_id': 1, 'run_id': 0}, {'M': {'starting_kappa': 2, 'starting_alpha': 0.5, 'money_raised': 1000, 'C': 700, 'f': 0.03, 'm': 0.15, 'beta': 0.9, 'dust': 1e-08, 'period': 2000, 'rules_price': 'step'}, 'simulation_id': 1, 'run_id': 1}]
# /Users/shrutiappiah/Documents/Github/ICF_Internal/src/sim/run.py:78: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sub_df = df[df.simulation == config_id['simulation_id']][df.run == config_id['run_id'] + 1]

# %%
experiments
# Out:
#    index  starting_kappa  starting_alpha  money_raised     C     f     m  \
# 0      0               2             0.5          1000  2000  0.03  0.15
# 1      0               2             0.5          1000  2000  0.03  0.15
#
#    beta          dust  period rules_price    E  \
# 0   0.9  1.000000e-08    2000      martin  0.2
# 1   0.9  1.000000e-08    2000        step  0.2
#
#                                              dataset
# 0           reserve      pbar  realized_price  sp...
# 1            reserve  pbar  realized_price  spot_...

# %%
experiments.dataset[0].head()
# Out:
#         reserve      pbar  realized_price  spot_price     kappa  supply  \
# 0   1000.000000  1.000000               0    1.000000  2.000000  2000.0
# 5   1000.000000  0.000000               0    1.250000  2.500000  2000.0
# 10  1000.000000  0.000000               0    1.344834  2.689669  2000.0
# 15  1000.000000  0.000000               0    0.963567  1.927134  2000.0
# 20  1042.908003  0.953511               0    0.981981  1.925531  2045.0
#
#        alpha alpha_bar   supply_0   supply_1  ...  attestations_0  \
# 0   0.500000     [0.5]  20.000000  30.000000  ...       20.000000
# 5   0.600000     [0.5]  20.000000  44.730717  ...       20.000000
# 10  0.691028     [0.5]  33.333755  44.730717  ...       20.066558
# 15  0.572997     [0.5]  45.764549  44.730717  ...       20.128822
# 20  0.515750     [0.5]  45.764550  44.730717  ...       20.128822
#
#     attestations_1    invariant_V  invariant_I  \
# 0        20.000000    4000.000000  2000.000000
# 5        20.073518  178885.438200  2000.000000
# 10       20.073518  756269.579532  2200.000000
# 15       20.073518    2298.936455  2382.055357
# 20       20.073518    2272.980008  2145.994231
#
#                                                agents  \
# 0      id  agent_attestations_1  agent_attestation...
# 5       id  agent_attestations_1  agent_attestatio...
# 10      id  agent_attestations_1  agent_attestatio...
# 15      id  agent_attestations_1  agent_attestatio...
# 20      id  agent_attestations_1  agent_attestatio...
#
#                                          chosen_agent simulation run  substep  \
# 0                                                   0          0   1        0
# 5   {'id': 3, 'agent_attestations_1': 0.0735184622...          0   1        5
# 10  {'id': 1.0, 'agent_attestations_1': 0.0, 'agen...          0   1        5
# 15  {'id': 1.0, 'agent_attestations_1': 0.0, 'agen...          0   1        5
# 20  {'id': 0.0, 'agent_attestations_1': 0.0, 'agen...          0   1        5
#
#     timestep
# 0          0
# 5          1
# 10         2
# 15         3
# 20         4
#
# [5 rows x 22 columns]

# %%
experiments.dataset[0].tail()
# Out:
#           reserve     price  realized_price  spot_price  private_price  \
# 1981  3008.580998  1.228164               0    1.227992       1.232946
# 1986  3008.580998  0.000000               0    1.227992       1.227458
# 1991  3009.076094  1.227976               0    1.227992       0.000000
# 1996  3009.076094 -0.000000               0    1.227992       1.226731
# 2001  3009.076094 -0.000000               0    1.227992      -0.000000
#
#       private_alpha     kappa       supply     alpha    supply_0  ...  \
# 1981            0.5  1.181278  2894.130879  0.779126  334.532431  ...
# 1986            0.6  1.181278  2894.130879  0.779126  334.532431  ...
# 1991            0.9  1.181248  2894.534060  0.779126  334.532431  ...
# 1996            0.7  1.181248  2894.534060  0.779126  334.532431  ...
# 2001            0.7  1.181248  2894.534060  0.779126  334.532431  ...
#
#       attestations_0  attestations_1  invariant_V  invariant_I  \
# 1981       20.728373       21.464669     4.079927  3553.969537
# 1986       20.728373       21.464669     4.079927  3553.969537
# 1991       20.728373       21.464669     4.078957  3554.464634
# 1996       20.728373       21.464669     4.078957  3554.464634
# 2001       20.728373       21.464669     4.078957  3554.464634
#
#                                                  agents  \
# 1981     agent_attestations_1  agent_attestations_0 ...
# 1986     agent_attestations_1  agent_attestations_0 ...
# 1991     agent_attestations_1  agent_attestations_0 ...
# 1996     agent_attestations_1  agent_attestations_0 ...
# 2001     agent_attestations_1  agent_attestations_0 ...
#
#                                            chosen_agent  simulation run  \
# 1981  {'agent_attestations_1': 0.0, 'agent_attestati...           0   2
# 1986  {'agent_attestations_1': 0.24726712075616497, ...           0   2
# 1991  {'agent_attestations_1': 0.6253962050760945, '...           0   2
# 1996  {'agent_attestations_1': 0.09816696540161313, ...           0   2
# 2001  {'agent_attestations_1': 0.09816696540161313, ...           0   2
#
#      substep  timestep
# 1981       5       196
# 1986       5       197
# 1991       5       198
# 1996       5       199
# 2001       5       200
#
# [5 rows x 23 columns]

# %%
import matplotlib.pyplot as plt
plt.plot(experiments.dataset[0].agents[0].agent_private_price)

# %%
import matplotlib.pyplot as plt
plt.plot(experiments.dataset[0].price)

# %%
import matplotlib.pyplot as plt
plt.plot(experiments.dataset[0].private_alpha)

# %%
plt.plot(experiments.dataset[0].alpha)

# %%
len(experiments.dataset[0])
# Out:
# 402

# %%
experiments = experiments.sort_values(by =['rules_price']).reset_index(drop=True)
# df = experiments
cols = 1
rows = 1
cc_idx = 0

# len(experiments)
# df = experiments.copy()
# print(df.head())

while cc_idx<len(experiments):
    cc = experiments.iloc[cc_idx]['rules_price']
    cc_label = experiments.iloc[cc_idx]['rules_price']
#     secondary_label = experiments.iloc[cc_idx]['string']
    sub_experiments = experiments[experiments['rules_price']==cc]
    cc_idx += len(sub_experiments)
    fig, axs = plt.subplots(ncols=cols, nrows=rows, figsize=(15*cols,7*rows))
    sub_experiments.reset_index(drop=False)
    for i, experiment in sub_experiments.iterrows():
        df = experiment['dataset'].copy()
        # filter out starting point
        df = df[df.timestep > 0]       
#         print(df['price'])

        df = df.groupby('timestep').agg({'price': ['min', 'mean', 'max']}).reset_index()

#         print(df.head())
        plot_label = experiment['rules_price']
        ax = axs
        title = 'Price' + '\n' + 'Scenario: ' + str(cc_label)  + ' rules_price'
        ax.set_title(title)
        ax.set_ylabel('Price')
        colors = ['b','orange', 'g', 'magenta', 'r']
        
#         ax.plot(df.timestep, df['price'],color = colors[0], label='Price')
        df.plot(x='timestep', y=('price','mean'), label='Mean', ax=ax, legend=True)
        ax.fill_between(df.timestep, df[('price','min')], df[('price','max')], alpha=0.3) 


        ax.legend()

        ax.set_xlabel('Timesteps')
        ax.grid(color='0.9', linestyle='-', linewidth=1)

        plt.tight_layout()
        
fig.tight_layout(rect=[0, 0, 1, .97])
fig.patch.set_alpha(1)
display(fig)
plt.close()

# %% [markdown]
# ## Payout at Settlement

# %% [markdown]
# The total payout $\Theta$ comprises of the shares of payout corresponding to their holdings of $s_{free}$, $s_1$ and $s_0$.
# $$\Theta = \frac{S_{free}}{S} (\alpha_t C+R) + \alpha_t \frac{S_1}{S} (C+R) + (1-\alpha_t) \frac{S_0}{S} (R)$$

# %%
experiments.dataset[0].alpha
# Out:
# 0      0.500000
# 5      0.600000
# 10     0.742074
# 15     0.742074
# 20     0.742074
#          ...
# 881    0.802044
# 886    0.802893
# 891    0.803641
# 896    0.803641
# 901    0.804509
# Name: alpha, Length: 182, dtype: float64

# %% [markdown]
# From the above, we can see that at Settlement, $\alpha = 0.771830$

# %%
experiments.dataset[0].supply_free[901]
# Out:
# 1920.4676961853463

# %%
plt.plot(experiments.dataset[0].supply_free)

# %%
experiments.dataset[0].supply[901]
# Out:
# 2047.755792003647

# %%
experiments.dataset[0].supply_1[901]
# Out:
# 351.11899744998095

# %%
experiments.dataset[0].supply_0[901]
# Out:
# 341.80405153322164

# %%
experiments.C
# Out:
# 0    700
# 1    700
# Name: C, dtype: int64

# %%
experiments.dataset[0].reserve[901]
# Out:
# 1047.875966610239

# %%
experiments.dataset[0].attestations_0[901]
# Out:
# 20.03539268393729

# %%
experiments.dataset[0].attestations_1[901]
# Out:
# 20.353312339980825

# %% [markdown]
# ## Payout at Settlement
# The payout $\Theta$ comprises of the share of payout corresponding to the portions of $S_{free}$, $S_1$ and $S_0$.
# $$\Theta_a = \frac{s_{free}}{S} (\alpha_t C+R) + \alpha_t \frac{s_1}{S} (C+R) + (1-\alpha_t) \frac{s_0}{S} (R)$$

# %%
t = 901

S_free = experiments.dataset[0].supply_free[t]
S_0 = experiments.dataset[0].supply_0[t]
S_1 = experiments.dataset[0].supply_1[t]

R = experiments.dataset[0].reserve[t]
S = experiments.dataset[0].supply[t]

Q_0 = experiments.dataset[0].attestations_0[t]
Q_1 = experiments.dataset[0].attestations_1[t]

alpha = experiments.dataset[0].alpha[t]

C = experiments.C

T1 = (S_free/S)*(alpha*C + R)
T2 = (S_1/S)*alpha*(C+R)
T3 = (S_0/S)*(1-alpha)*(R)

#print("T1 = ", T1, "T2 = ", T2, "T3 = ", T3,)

payout = T1 + T2 + T3

print("Total payout = ", payout)
# Out:
# Total payout =  0    1893.86075
# 1    1893.86075
# Name: C, dtype: float64

# %% [markdown]
# ### Agent Payout
# The payout $\Theta_a$ of an agent comprises of their share of payout corresponding to their holdings of $s_{free}$, $s_1$ and $s_0$.
# $$\Theta_a = \frac{s_{free}}{S} (\alpha_t C+R) + \alpha_t \frac{q_1}{Q_1} \frac{s_1}{S} (C+R) + (1-\alpha_t) \frac{q_0}{Q_0} \frac{s_0}{S} (R)$$

# %%
experiments.dataset[0].agents[t]
# Out:
#     id  agent_attestations_1  agent_attestations_0  agent_reserve  \
# 0  0.0              0.000000              0.226182           50.0
# 1  1.0              0.000000              0.274705           50.0
# 2  2.0              0.057467              0.088916           50.0
# 3  3.0              0.239112              0.000000           50.0
# 4  4.0              0.227682              0.000000           50.0
#
#    agent_supply_1  agent_supply_0  agent_supply_free  agent_private_alpha  \
# 0        3.000000       46.984428           0.015572                 0.10
# 1        3.000000       56.021305           0.978695                 0.25
# 2       14.295321       19.573313          36.131366                 0.50
# 3       50.058487        2.000000           7.941513                 0.75
# 4       47.996520        2.000000           0.003480                 0.90
#
#    agent_private_price
# 0                  1.5
# 1                  1.5
# 2                  1.5
# 3                  1.5
# 4                  1.5

# %% [markdown]
# ### Agents vs their Positive Attestations

# %%
experiments = experiments.sort_values(by =['rules_price']).reset_index(drop=True)

cols = 1
rows = 1
cc_idx = 0
# config_labels = ['RULE 1,'RULE 2']


while cc_idx<len(experiments):
    cc = experiments.iloc[cc_idx]['rules_price']
    cc_label = experiments.iloc[cc_idx]['rules_price']
#     secondary_label = experiments.iloc[cc_idx]['string']
    sub_experiments = experiments[experiments['rules_price']==cc]
    cc_idx += len(sub_experiments)
    fig, axs = plt.subplots(ncols=cols, nrows=rows, figsize=(15*cols,7*rows))
    sub_experiments.reset_index(drop=False)
    for i, experiment in sub_experiments.iterrows():
        df = experiment['dataset'].copy()
        # filter out starting point
        df = df[df.timestep > 0] 
        # FIRST RUN ONLY
        df = df[df.run == 1]  
        

# MAKE A FOR LOOP or FUNCTION FOR ALL AGENTS
        df['agent_1_attest_1'] = df.agents.apply(lambda x: np.array(x['agent_attestations_1'][0]))
        df['agent_2_attest_1'] = df.agents.apply(lambda x: np.array(x['agent_attestations_1'][1]))
        df['agent_3_attest_1'] = df.agents.apply(lambda x: np.array(x['agent_attestations_1'][2]))
        df['agent_4_attest_1'] = df.agents.apply(lambda x: np.array(x['agent_attestations_1'][3]))
        df['agent_5_attest_1'] = df.agents.apply(lambda x: np.array(x['agent_attestations_1'][4]))
    
#         df = df.groupby('timestep').agg({'supply': ['min', 'mean', 'max']}).reset_index()
    
#         df['agent_attest_1'] = np.array(df.agent_attest_1,dtype = float)
#         print(df['agent_attest_1'])
#         print(df['agent_attest_1'][10])
        plot_label = experiment['rules_price']
        ax = axs
        title = 'agent_attest_1' + '\n' + 'Scenario: ' + str(cc_label)  + ' rules_price'
        ax.set_title(title)
        ax.set_ylabel('Amount')
        colors = ['b','orange', 'g', 'magenta', 'r']
        
#         ax.plot(df.timestep, df['price'],color = colors[0], label='Price')
        df.plot(x='timestep', y='agent_1_attest_1', label='agent_1', ax=ax, legend=True)
        df.plot(x='timestep', y='agent_2_attest_1', label='agent_2', ax=ax, legend=True)
        df.plot(x='timestep', y='agent_3_attest_1', label='agent_3', ax=ax, legend=True)
        df.plot(x='timestep', y='agent_4_attest_1', label='agent_4', ax=ax, legend=True)
        df.plot(x='timestep', y='agent_5_attest_1', label='agent_5', ax=ax, legend=True)

#         ax.fill_between(df.timestep, df[('supply','min')], df[('supply','max')], supply=0.3) 

        ax.legend()

        ax.set_xlabel('Timesteps')
        ax.grid(color='0.9', linestyle='-', linewidth=1)

        plt.tight_layout()
        
fig.tight_layout(rect=[0, 0, 1, .97])
fig.patch.set_alpha(1)
display(fig)
plt.close()
plt.title("AGENTS VS THEIR POSITIVE ATTESTATIONS")
# Out:
# Text(0.5, 1, 'AGENTS VS THEIR POSITIVE ATTESTATIONS')

# %% [markdown]
# ### Agents vs their Negative Attestations

# %%
experiments = experiments.sort_values(by =['rules_price']).reset_index(drop=True)

cols = 1
rows = 1
cc_idx = 0
# config_labels = ['RULE 1,'RULE 2']


while cc_idx<len(experiments):
    cc = experiments.iloc[cc_idx]['rules_price']
    cc_label = experiments.iloc[cc_idx]['rules_price']
#     secondary_label = experiments.iloc[cc_idx]['string']
    sub_experiments = experiments[experiments['rules_price']==cc]
    cc_idx += len(sub_experiments)
    fig, axs = plt.subplots(ncols=cols, nrows=rows, figsize=(15*cols,7*rows))
    sub_experiments.reset_index(drop=False)
    for i, experiment in sub_experiments.iterrows():
        df = experiment['dataset'].copy()
        # filter out starting point
        df = df[df.timestep > 0] 
        # FIRST RUN ONLY
        df = df[df.run == 1]  
        

# MAKE A FOR LOOP or FUNCTION FOR ALL AGENTS
        df['agent_1_attest_0'] = df.agents.apply(lambda x: np.array(x['agent_attestations_0'][0]))
        df['agent_2_attest_0'] = df.agents.apply(lambda x: np.array(x['agent_attestations_0'][1]))
        df['agent_3_attest_0'] = df.agents.apply(lambda x: np.array(x['agent_attestations_0'][2]))
        df['agent_4_attest_0'] = df.agents.apply(lambda x: np.array(x['agent_attestations_0'][3]))
        df['agent_5_attest_0'] = df.agents.apply(lambda x: np.array(x['agent_attestations_0'][4]))
    
#         df = df.groupby('timestep').agg({'supply': ['min', 'mean', 'max']}).reset_index()
    
#         df['agent_attest_1'] = np.array(df.agent_attest_1,dtype = float)
#         print(df['agent_attest_1'])
#         print(df['agent_attest_1'][10])
        plot_label = experiment['rules_price']
        ax = axs
        title = 'agent_attest_0' + '\n' + 'Scenario: ' + str(cc_label)  + ' rules_price'
        ax.set_title(title)
        ax.set_ylabel('Amount')
        colors = ['b','orange', 'g', 'magenta', 'r']
        
#         ax.plot(df.timestep, df['price'],color = colors[0], label='Price')
        df.plot(x='timestep', y='agent_1_attest_0', label='agent_1', ax=ax, legend=True)
        df.plot(x='timestep', y='agent_2_attest_0', label='agent_2', ax=ax, legend=True)
        df.plot(x='timestep', y='agent_3_attest_0', label='agent_3', ax=ax, legend=True)
        df.plot(x='timestep', y='agent_4_attest_0', label='agent_4', ax=ax, legend=True)
        df.plot(x='timestep', y='agent_5_attest_0', label='agent_5', ax=ax, legend=True)

#         ax.fill_between(df.timestep, df[('supply','min')], df[('supply','max')], supply=0.3) 

        ax.legend()

        ax.set_xlabel('Timesteps')
        ax.grid(color='0.9', linestyle='-', linewidth=1)

        plt.tight_layout()
        
fig.tight_layout(rect=[0, 0, 1, .97])
fig.patch.set_alpha(1)
display(fig)
plt.close()

# %%
agent_0_q1 = experiments.dataset[0].agents[t].agent_attestations_1[0]
agent_0_q0 = experiments.dataset[0].agents[t].agent_attestations_0[0]
agent_0_s1 = experiments.dataset[0].agents[t].agent_supply_1[0]
agent_0_s0 = experiments.dataset[0].agents[t].agent_supply_0[0]
agent_0_s_free = experiments.dataset[0].agents[t].agent_supply_free[0]

Q0 = experiments.dataset[0].attestations_0[t]
Q1 = experiments.dataset[0].attestations_1[t]

R = experiments.dataset[0].reserve[t]
S = experiments.dataset[0].supply[t]

C = experiments.C
alpha = experiments.dataset[0].alpha[t]

T1 = (S_free/S)*(alpha*C + R)
T2 = (S_1/S)*(agent_0_q1/Q1)*alpha*(C+R)
T3 = (S_0/S)*(agent_0_q0/Q0)*(1-alpha)*(R)

agent_1_payout = T1+T2+T3

print("Agent 1's Payout = ", agent_1_payout)
# Out:
# Agent 1's Payout =  0    1761.489765
# 1    1761.489765
# Name: C, dtype: float64

# %%
agent_1_q1 = experiments.dataset[0].agents[t].agent_attestations_1[1]
agent_1_q0 = experiments.dataset[0].agents[t].agent_attestations_0[1]
agent_1_s1 = experiments.dataset[0].agents[t].agent_supply_1[1]
agent_1_s0 = experiments.dataset[0].agents[t].agent_supply_0[1]
agent_1_s_free = experiments.dataset[0].agents[t].agent_supply_free[1]

Q0 = experiments.dataset[0].attestations_0[t]
Q1 = experiments.dataset[0].attestations_1[t]

R = experiments.dataset[0].reserve[t]
S = experiments.dataset[0].supply[t]

C = experiments.C
alpha = experiments.dataset[0].alpha[t]

T1 = (S_free/S)*(alpha*C + R)
T2 = (S_1/S)*(agent_1_q1/Q1)*alpha*(C+R)
T3 = (S_0/S)*(agent_1_q0/Q0)*(1-alpha)*(R)

agent_2_payout = T1+T2+T3

print("Agent 2's Payout = ", agent_2_payout)
# Out:
# Agent 2's Payout =  0    1761.571946
# 1    1761.571946
# Name: C, dtype: float64

# %%
agent_2_q1 = experiments.dataset[0].agents[t].agent_attestations_1[2]
agent_2_q0 = experiments.dataset[0].agents[t].agent_attestations_0[2]
agent_2_s1 = experiments.dataset[0].agents[t].agent_supply_1[2]
agent_2_s0 = experiments.dataset[0].agents[t].agent_supply_0[2]
agent_2_s_free = experiments.dataset[0].agents[t].agent_supply_free[2]

Q0 = experiments.dataset[0].attestations_0[t]
Q1 = experiments.dataset[0].attestations_1[t]

R = experiments.dataset[0].reserve[t]
S = experiments.dataset[0].supply[t]

C = experiments.C
alpha = experiments.dataset[0].alpha[t]

T1 = (S_free/S)*(alpha*C + R)
T2 = (S_1/S)*(agent_2_q1/Q1)*alpha*(C+R)
T3 = (S_0/S)*(agent_2_q0/Q0)*(1-alpha)*(R)

agent_3_payout = T1+T2+T3

print("Agent 3's Payout = ", agent_3_payout)
# Out:
# Agent 3's Payout =  0    1761.531347
# 1    1761.531347
# Name: C, dtype: float64

# %% [markdown]
# #### Agent 4 is the closest alpha estimator, since system alpha at settlement $\alpha_{final}= 0.771830$ and $\hat\alpha_3 = 0.8$

# %%
agent_3_q1 = experiments.dataset[0].agents[t].agent_attestations_1[3]
agent_3_q0 = experiments.dataset[0].agents[t].agent_attestations_0[3]
agent_3_s1 = experiments.dataset[0].agents[t].agent_supply_1[3]
agent_3_s0 = experiments.dataset[0].agents[t].agent_supply_0[3]
agent_3_s_free = experiments.dataset[0].agents[t].agent_supply_free[3]

Q0 = experiments.dataset[0].attestations_0[t]
Q1 = experiments.dataset[0].attestations_1[t]

R = experiments.dataset[0].reserve[t]
S = experiments.dataset[0].supply[t]

C = experiments.C
alpha = experiments.dataset[0].alpha[t]

T1 = (S_free/S)*(alpha*C + R)
T2 = (S_1/S)*(agent_3_q1/Q1)*alpha*(C+R)
T3 = (S_0/S)*(agent_3_q0/Q0)*(1-alpha)*(R)

agent_4_payout = T1+T2+T3

print("Agent 4's Payout = ", agent_4_payout)
# Out:
# Agent 4's Payout =  0    1762.24703
# 1    1762.24703
# Name: C, dtype: float64

# %% [markdown]
# #### At $\Theta_3 = 383.764479$, Agent 4 has the second highest payout

# %%
agent_4_q1 = experiments.dataset[0].agents[t].agent_attestations_1[4]
agent_4_q0 = experiments.dataset[0].agents[t].agent_attestations_0[4]
agent_4_s1 = experiments.dataset[0].agents[t].agent_supply_1[4]
agent_4_s0 = experiments.dataset[0].agents[t].agent_supply_0[4]
agent_4_s_free = experiments.dataset[0].agents[t].agent_supply_free[4]

Q0 = experiments.dataset[0].attestations_0[t]
Q1 = experiments.dataset[0].attestations_1[t]

R = experiments.dataset[0].reserve[t]
S = experiments.dataset[0].supply[t]

C = experiments.C
alpha = experiments.dataset[0].alpha[t]

T1 = (S_free/S)*(alpha*C + R)
T2 = (S_1/S)*(agent_4_q1/Q1)*alpha*(C+R)
T3 = (S_0/S)*(agent_4_q0/Q0)*(1-alpha)*(R)

agent_5_payout = T1+T2+T3

print("Agent 5's Payout = ", agent_5_payout)
# Out:
# Agent 5's Payout =  0    1762.192521
# 1    1762.192521
# Name: C, dtype: float64

# %%
# Agent payouts
print("Agent 1's Payout = ", agent_1_payout)
print("Agent 2's Payout = ", agent_2_payout)
print("Agent 3's Payout = ", agent_3_payout)
print("Agent 4's Payout = ", agent_4_payout)
print("Agent 5's Payout = ", agent_5_payout)
# Out:
# Agent 1's Payout =  0    1761.489765
# 1    1761.489765
# Name: C, dtype: float64
# Agent 2's Payout =  0    1761.571946
# 1    1761.571946
# Name: C, dtype: float64
# Agent 3's Payout =  0    1761.531347
# 1    1761.531347
# Name: C, dtype: float64
# Agent 4's Payout =  0    1762.24703
# 1    1762.24703
# Name: C, dtype: float64
# Agent 5's Payout =  0    1762.192521
# 1    1762.192521
# Name: C, dtype: float64

# %%
agent_4_q1 = experiments.dataset[0].agents[t].agent_attestations_1[4]
agent_4_q0 = experiments.dataset[0].agents[t].agent_attestations_0[4]
agent_4_s1 = experiments.dataset[0].agents[t].agent_supply_1[4]
agent_4_s0 = experiments.dataset[0].agents[t].agent_supply_0[4]
agent_4_s_free = experiments.dataset[0].agents[t].agent_supply_free[4]

s = agent_4_s1 + agent_4_s0 + agent_4_s_free

Q0 = experiments.dataset[0].attestations_0[t]
Q1 = experiments.dataset[0].attestations_1[t]

R = experiments.dataset[0].reserve[t]
S = experiments.dataset[0].supply[t]

C = experiments.C
alpha = experiments.dataset[0].alpha[t]

T1 = (agent_4_s_free/s)*(alpha*C + R)
T2 = (agent_4_s1/s)*(agent_4_q1/Q1)*alpha*(C+R)
T3 = (agent_4_s0/s)*(agent_4_q0/Q0)*(1-alpha)*(R)

agent_5_payout = T1+T2+T3

print("Agent 5's Payout = ", agent_5_payout)
# Out:
# Agent 5's Payout =  0    17.825862
# 1    17.825862
# Name: C, dtype: float64

# %%
agent_3_q1 = experiments.dataset[0].agents[t].agent_attestations_1[3]
agent_3_q0 = experiments.dataset[0].agents[t].agent_attestations_0[3]
agent_3_s1 = experiments.dataset[0].agents[t].agent_supply_1[3]
agent_3_s0 = experiments.dataset[0].agents[t].agent_supply_0[3]
agent_3_s_free = experiments.dataset[0].agents[t].agent_supply_free[3]

s = agent_3_s1 + agent_3_s0 + agent_3_s_free

Q0 = experiments.dataset[0].attestations_0[t]
Q1 = experiments.dataset[0].attestations_1[t]

R = experiments.dataset[0].reserve[t]
S = experiments.dataset[0].supply[t]

C = experiments.C
alpha = experiments.dataset[0].alpha[t]

T1 = (agent_3_s_free/s)*(alpha*C + R)
T2 = (agent_3_s1/s)*(agent_3_q1/Q1)*alpha*(C+R)
T3 = (agent_3_s0/s)*(agent_3_q0/Q0)*(1-alpha)*(R)

agent_4_payout = T1+T2+T3

print("Agent 4's Payout = ", agent_4_payout)
# Out:
# Agent 4's Payout =  0    276.166068
# 1    276.166068
# Name: C, dtype: float64

# %%
agent_3_q1 = experiments.dataset[0].agents[t].agent_attestations_1[2]
agent_3_q0 = experiments.dataset[0].agents[t].agent_attestations_0[2]
agent_3_s1 = experiments.dataset[0].agents[t].agent_supply_1[2]
agent_3_s0 = experiments.dataset[0].agents[t].agent_supply_0[2]
agent_3_s_free = experiments.dataset[0].agents[t].agent_supply_free[2]

s = agent_3_s1 + agent_3_s0 + agent_3_s_free

Q0 = experiments.dataset[0].attestations_0[t]
Q1 = experiments.dataset[0].attestations_1[t]

R = experiments.dataset[0].reserve[t]
S = experiments.dataset[0].supply[t]

C = experiments.C
alpha = experiments.dataset[0].alpha[t]

T1 = (agent_3_s_free/s)*(alpha*C + R)
T2 = (agent_3_s1/s)*(agent_3_q1/Q1)*alpha*(C+R)
T3 = (agent_3_s0/s)*(agent_3_q0/Q0)*(1-alpha)*(R)

agent_3_payout = T1+T2+T3

print("Agent 3's Payout = ", agent_3_payout)
# Out:
# Agent 3's Payout =  0    7.538039
# 1    7.538039
# Name: C, dtype: float64

# %%
agent_3_q1 = experiments.dataset[0].agents[t].agent_attestations_1[1]
agent_3_q0 = experiments.dataset[0].agents[t].agent_attestations_0[1]
agent_3_s1 = experiments.dataset[0].agents[t].agent_supply_1[1]
agent_3_s0 = experiments.dataset[0].agents[t].agent_supply_0[1]
agent_3_s_free = experiments.dataset[0].agents[t].agent_supply_free[1]

s = agent_3_s1 + agent_3_s0 + agent_3_s_free

Q0 = experiments.dataset[0].attestations_0[t]
Q1 = experiments.dataset[0].attestations_1[t]

R = experiments.dataset[0].reserve[t]
S = experiments.dataset[0].supply[t]

C = experiments.C
alpha = experiments.dataset[0].alpha[t]

T1 = (agent_3_s_free/s)*(alpha*C + R)
T2 = (agent_3_s1/s)*(agent_3_q1/Q1)*alpha*(C+R)
T3 = (agent_3_s0/s)*(agent_3_q0/Q0)*(1-alpha)*(R)

agent_2_payout = T1+T2+T3

print("Agent 2's Payout = ", agent_2_payout)
# Out:
# Agent 2's Payout =  0    38.636855
# 1    38.636855
# Name: C, dtype: float64

# %% [markdown]
# ### From these results, we can infer
#
# #### Observation
# Agent 4 with $\hat\alpha = 0.8$ and Agent 5 with $\hat\alpha = 0.9$ earned the higest payouts. <br/>
# #### Inference
# The system acts as a fairly good estimator of $\alpha$. The agents input their information via positive and negative attestations. This information reveals the agents' private belief of $\alpha$.
#
# <br/>
#
# #### Observation
# Agent 5 had a higher payout $\Theta_5 = 385.965398$ whereas Agent 4 had a payout $\Theta_5 = 383.764479$ despite being the better alpha estimator.
# #### Inference
# Attestating positively is a strictly dominant strategy. Since Agent 5 made no negative attestations and still produced a fairly close estimate of alpha, it earned a higher payout.

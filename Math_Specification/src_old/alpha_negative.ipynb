# %% [markdown]
# # Alpha update upon a negative attestation

# %% [markdown]
# $$\bar\alpha = \frac{R(B - \frac{\Delta s}{S})}{\frac{\Delta s}{S}(C)-B(R)}$$

# %% [markdown]
# $$\alpha_{t+1} = (\epsilon)\alpha + (1-\epsilon)(1-\delta)\alpha + (1-\epsilon)(\delta)\bar\alpha$$

# %%
E = 0.45
C = 7000
R = 3000
S = 300
private_alpha = [0.6]
alpha = [0.5]
max_deltas = 20
Q0 = [100]
q0 = [0]
S1 = [100] 
S0 = [100]
s0 = [0]
s = [20]

deltas = [1, 4, 5, 6, 3, 1] 
#deltaq0 = [1, 4, 5, 6, 3, 1]

for i in range(len(deltas)): 
    print(deltas[i])
# Out:
# 1
# 4
# 5
# 6
# 3
# 1

# %%
import math

for i in range(len(deltas)): 
    
    A = 1+(deltas[i]/S)
    deltaq0[i] = Q0[i]*(math.sqrt(A-1))
    
    attest_prop_after = (q0[i]+deltaq0[i])/(Q0[i]+deltaq0[i])
    supply_prop_after = (S0[i]+deltas[i])/S
    attest_supply_before = (q0[i]*S0[i])/(Q0[i]*S)
    
    B = (attest_prop_after * supply_prop_after) - attest_supply_before
    
    D = deltas[i]/(S1[i]+S0[i]+deltas[i])
    
    pre1= B-deltas[i]/S
    
    pre2 = ((deltas[i]/S)*C)
    
    alpha_bar = (R*(pre1))/((pre2*C)+(B*R))
    
    T1 = E*alpha[i]
    
    T2 = (1-E)*(1-D)*alpha[i]
    
    T3 = (1-E)*(D)*alpha_bar
    
    new_alpha = T1+T2+T3
    
    print("D = ", D)
    print("alpha_bar = ", alpha_bar)
    print("alpha[i] =", alpha[i], "| new_alpha = ", new_alpha)
    print("deltas =", deltas[i], " | deltaq0 = ", deltaq0[i])
    print("s[i] =" , s[i])
    print("____________________________")    
    
    # Update operations
    Q0.append(Q0[i] + deltaq0[i])
    S0.append(S0[i] + deltas[i])
    S1.append(S1[i])
    s0.append(s0[i] + deltas[i])
    s.append(s[i] - deltas[i])
    q0.append(q0[i] + deltaq0[i])
    alpha.append(new_alpha)
# Out:
# D =  0.004975124378109453
# alpha_bar =  0.0002762096825186302
# alpha[i] = 0.5 | new_alpha =  0.4986325965936587
# deltas = 1  | deltaq0 =  5.773502691896324
# s[i] = 20
# ____________________________
# D =  0.01951219512195122
# alpha_bar =  9.93870323219118e-05
# alpha[i] = 0.4986325965936587 | new_alpha =  0.4932824841008054
# deltas = 4  | deltaq0 =  12.213672050459229
# s[i] = 19
# ____________________________
# D =  0.023809523809523808
# alpha_bar =  7.862666845750826e-05
# alpha[i] = 0.4932824841008054 | new_alpha =  0.4868238621582389
# deltas = 5  | deltaq0 =  15.232078761440219
# s[i] = 15
# ____________________________
# D =  0.027777777777777776
# alpha_bar =  6.412073738319819e-05
# alpha[i] = 0.4868238621582389 | new_alpha =  0.4793872549976425
# deltas = 6  | deltaq0 =  18.84004750742875
# s[i] = 10
# ____________________________
# D =  0.0136986301369863
# alpha_bar =  0.00010491184932874367
# alpha[i] = 0.4793872549976425 | new_alpha =  0.4757762236451552
# deltas = 3  | deltaq0 =  15.205930101122458
# s[i] = 4
# ____________________________
# D =  0.004545454545454545
# alpha_bar =  0.00020309561777700572
# alpha[i] = 0.4757762236451552 | new_alpha =  0.47458729082508677
# deltas = 1  | deltaq0 =  9.657062620877959
# s[i] = 1
# ____________________________

# %% [markdown]
# ### Try without D

# %%
import math

for i in range(len(deltas)): 
    
    A = 1+(deltas[i]/S)
    deltaq0[i] = Q0[i]*(math.sqrt(A-1))
    
    attest_prop_after = (q0[i]+deltaq0[i])/(Q0[i]+deltaq0[i])
    supply_prop_after = (S0[i]+deltas[i])/S
    attest_supply_before = (q0[i]*S0[i])/(Q0[i]*S)
    
    B = (attest_prop_after * supply_prop_after) - attest_supply_before
    
    D = deltas[i]/(S1[i]+S0[i]+deltas[i])
    
    pre1= B-deltas[i]/S
    
    pre2 = ((deltas[i]/S)*C)
    
    alpha_bar = (R*(pre1))/((pre2*C)+(B*R))
    
    T1 = E*alpha[i]
    
    T2 = (1-E)*(1)*alpha[i]
    
    T3 = (1-E)*(1)*alpha_bar
    
    new_alpha = T1+T2+T3
    
    print("D = ", D)
    print("alpha_bar = ", alpha_bar)
    print("alpha[i] =", alpha[i], "| new_alpha = ", new_alpha)
    print("deltas =", deltas[i], " | deltaq0 = ", deltaq0[i])
    print("s[i] =" , s[i])
    print("____________________________")    
    
    # Update operations
    Q0.append(Q0[i] + deltaq0[i])
    S0.append(S0[i] + deltas[i])
    S1.append(S1[i])
    s0.append(s0[i] + deltas[i])
    s.append(s[i] - deltas[i])
    q0.append(q0[i] + deltaq0[i])
    alpha.append(new_alpha)
# Out:
# D =  0.004975124378109453
# alpha_bar =  0.0002762096825186302
# alpha[i] = 0.5 | new_alpha =  0.5001519153253853
# deltas = 1  | deltaq0 =  5.773502691896324
# s[i] = 20
# ____________________________
# D =  0.01951219512195122
# alpha_bar =  9.93870323219118e-05
# alpha[i] = 0.4986325965936587 | new_alpha =  0.49868725946143583
# deltas = 4  | deltaq0 =  12.213672050459229
# s[i] = 19
# ____________________________
# D =  0.023809523809523808
# alpha_bar =  7.862666845750826e-05
# alpha[i] = 0.4932824841008054 | new_alpha =  0.4933257287684571
# deltas = 5  | deltaq0 =  15.232078761440219
# s[i] = 15
# ____________________________
# D =  0.027777777777777776
# alpha_bar =  6.412073738319819e-05
# alpha[i] = 0.4868238621582389 | new_alpha =  0.4868591285637997
# deltas = 6  | deltaq0 =  18.84004750742875
# s[i] = 10
# ____________________________
# D =  0.0136986301369863
# alpha_bar =  0.00010491184932874367
# alpha[i] = 0.4793872549976425 | new_alpha =  0.4794449565147733
# deltas = 3  | deltaq0 =  15.205930101122458
# s[i] = 4
# ____________________________
# D =  0.004545454545454545
# alpha_bar =  0.00020309561777700572
# alpha[i] = 0.4757762236451552 | new_alpha =  0.47588792623493253
# deltas = 1  | deltaq0 =  9.657062620877959
# s[i] = 1
# ____________________________

# %% [markdown]
# ### Case with deltas = 0 and with D

# %%
E = 0.45
C = 7000
R = 3000
S = 300
private_alpha = [0.6]
alpha = [0.5]
max_deltas = 20
Q0 = [100]
q0 = [0]
S1 = [100] 
S0 = [100]
s0 = [0]
s = [10]

deltas = [1, 0, 4, 3, 1, 0, 1]

# %%
import math

for i in range(len(deltas)): 
  
    A = 1+(deltas[i]/S)
    deltaq0 = Q0[i]*(math.sqrt(A-1))
    
    if deltas[i] == 0:
        new_alpha = alpha[i]
        print("alpha[i] =", alpha[i], "| new_alpha = ", new_alpha)
        print("____________________________")
    else:    
        attest_prop_after = (q0[i]+deltaq0)/(Q0[i]+deltaq0)
        supply_prop_after = (S0[i]+deltas[i])/S
        attest_supply_before = (q0[i]*S0[i])/(Q0[i]*S)
    
        B = (attest_prop_after * supply_prop_after) - attest_supply_before
    
        D = deltas[i]/(S1[i]+S0[i]+deltas[i])
    
        pre1= B-deltas[i]/S
    
        pre2 = ((deltas[i]/S)*C)
    
        alpha_bar = (R*(pre1))/((pre2*C)+(B*R))
    
        T1 = E*alpha[i]
    
        T2 = (1-E)*(1-D)*alpha[i]
    
        T3 = (1-E)*(D)*alpha_bar
    
        new_alpha = T1+T2+T3
    
        print("D = ", D)
        print("alpha_bar = ", alpha_bar)
        print("alpha[i] =", alpha[i], "| new_alpha = ", new_alpha)
        print("deltas =", deltas[i], " | deltaq0 = ", deltaq0)
        print("Q0[i] = ", Q0[i])
        print("s[i] =" , s[i])
        print("____________________________")    
    
    # Update operations
    Q0.append(Q0[i] + deltaq0)
    #print("Q0 = ", Q0, " | deltaq0 = ", deltaq0)
    S0.append(S0[i] + deltas[i])
    #print("S0 = ", S0, " | deltas[i] = ", deltas[i])
    S1.append(S1[i])
    #print("S1 = ", S1)
    s0.append(s0[i] + deltas[i])
    #print("s0 = ", s0, " | deltas[i] = ", deltas[i])
    s.append(s[i] - deltas[i])
    #print("s = ", s, " | deltas[i] = ", deltas[i])
    q0.append(q0[i] + deltaq0)
    #print("q0 = ", q0, " | deltaq0 = ", deltaq0)
    alpha.append(new_alpha)
    #print("alpha = ", alpha)
    print("_____________________________________________________________________________________________________")
# Out:
# D =  0.004975124378109453
# alpha_bar =  0.0002762096825186302
# alpha[i] = 0.5 | new_alpha =  0.4986325965936587
# deltas = 1  | deltaq0 =  5.773502691896324
# Q0[i] =  100
# s[i] = 10
# ____________________________
# _____________________________________________________________________________________________________
# alpha[i] = 0.4986325965936587 | new_alpha =  0.4986325965936587
# ____________________________
# _____________________________________________________________________________________________________
# D =  0.01951219512195122
# alpha_bar =  9.93870323219118e-05
# alpha[i] = 0.4986325965936587 | new_alpha =  0.4932824841008054
# deltas = 4  | deltaq0 =  12.213672050459229
# Q0[i] =  105.77350269189633
# s[i] = 9
# ____________________________
# _____________________________________________________________________________________________________
# D =  0.014423076923076924
# alpha_bar =  0.00011791251315974413
# alpha[i] = 0.4932824841008054 | new_alpha =  0.48937036129734574
# deltas = 3  | deltaq0 =  11.798717474235561
# Q0[i] =  117.98717474235555
# s[i] = 5
# ____________________________
# _____________________________________________________________________________________________________
# D =  0.004784688995215311
# alpha_bar =  0.00023342172699600359
# alpha[i] = 0.48937036129734574 | new_alpha =  0.4880831588247922
# deltas = 1  | deltaq0 =  7.49319198082655
# Q0[i] =  129.78589221659112
# s[i] = 2
# ____________________________
# _____________________________________________________________________________________________________
# alpha[i] = 0.4880831588247922 | new_alpha =  0.4880831588247922
# ____________________________
# _____________________________________________________________________________________________________
# D =  0.004761904761904762
# alpha_bar =  0.00022311665372629424
# alpha[i] = 0.4880831588247922 | new_alpha =  0.4868054301429156
# deltas = 1  | deltaq0 =  7.9258116215485295
# Q0[i] =  137.27908419741766
# s[i] = 1
# ____________________________
# _____________________________________________________________________________________________________
